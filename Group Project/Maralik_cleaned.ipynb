# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Maralik = pd.read_csv('hotel_full_Maralik.csv')
hotel_full_Maralik
# Out:
#                                    city                              country  \
# 0                                   NaN                                  NaN
# 1    Dzorakap, Shirak Province, Armenia   Dzorakap, Shirak Province, Armenia
# 2    Dzorakap, Shirak Province, Armenia   Dzorakap, Shirak Province, Armenia
# 3               Gyumri, Shirak, Armenia              Gyumri, Shirak, Armenia
# 4               Гюмри, Армения, Armenia              Гюмри, Армения, Armenia
# ..                                  ...                                  ...
# 94     Gyumri, Shirak Province, Armenia     Gyumri, Shirak Province, Armenia
# 95     Gyumri, Shirak Province, Armenia     Gyumri, Shirak Province, Armenia
# 96     Gyumri, Shirak Province, Armenia     Gyumri, Shirak Province, Armenia
# 97  Pemzashen, Shirak Province, Armenia  Pemzashen, Shirak Province, Armenia
# 98     Gyumri, Shirak Province, Armenia     Gyumri, Shirak Province, Armenia
#
# ...

# %%
hotel_full_Maralik = hotel_full_Maralik.drop(labels = 0, axis = 0)
hotel_full_Maralik
# Out:
#                                    city                              country  \
# 1    Dzorakap, Shirak Province, Armenia   Dzorakap, Shirak Province, Armenia
# 2    Dzorakap, Shirak Province, Armenia   Dzorakap, Shirak Province, Armenia
# 3               Gyumri, Shirak, Armenia              Gyumri, Shirak, Armenia
# 4               Гюмри, Армения, Armenia              Гюмри, Армения, Armenia
# 5       Artik, Shirak Province, Armenia      Artik, Shirak Province, Armenia
# ..                                  ...                                  ...
# 94     Gyumri, Shirak Province, Armenia     Gyumri, Shirak Province, Armenia
# 95     Gyumri, Shirak Province, Armenia     Gyumri, Shirak Province, Armenia
# 96     Gyumri, Shirak Province, Armenia     Gyumri, Shirak Province, Armenia
# 97  Pemzashen, Shirak Province, Armenia  Pemzashen, Shirak Province, Armenia
# 98     Gyumri, Shirak Province, Armenia     Gyumri, Shirak Province, Armenia
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Maralik.replace("", nan_value, inplace = True)
hotel_full_Maralik.dropna(inplace= True)
hotel_full_Maralik
# Out:
#                                       city  \
# 2       Dzorakap, Shirak Province, Armenia
# 3                  Gyumri, Shirak, Armenia
# 4                  Гюмри, Армения, Armenia
# 6         Gyumri, Shirak Province, Armenia
# 7         Gyumri, Shirak Province, Armenia
# 8         Gyumri, Shirak Province, Armenia
# 9         Gyumri, Shirak Province, Armenia
# 10        Gyumri, Shirak Province, Armenia
# 12        Gyumri, Shirak Province, Armenia
# 13        Gyumri, Shirak Province, Armenia
# 15        Gyumri, Shirak Province, Armenia
# 18        Gyumri, Shirak Province, Armenia
# 19        Gyumri, Shirak Province, Armenia
# 21      Dzorakap, Shirak Province, Armenia
# 22        Gyumri, Shirak Province, Armenia
# 23        Gyumri, Shirak Province, Armenia
# 24        Gyumri, Shirak Province, Armenia
# 25        Gyumri, Shirak Province, Armenia
# 26        Gyumri, Shirak Province, Armenia
# 28        Gyumri, Shirak Province, Armenia
# 29        Gyumri, Shirak Province, Armenia
# ...

# %%
hotel_full_Maralik["city"]= hotel_full_Maralik["city"].replace({"Гюмри, Армения, Armenia" : "Gyumri, Shirak Province, Armenia"})

hotel_full_Maralik["city"]= hotel_full_Maralik["city"].replace({"Armenia" : "Artik, Shirak Province, Armenia"})
hotel_full_Maralik["country"]= hotel_full_Maralik["country"].replace({"Armenia" : "Artik, Shirak Province, Armenia"})
hotel_full_Maralik
# Out:
#                                       city  \
# 2       Dzorakap, Shirak Province, Armenia
# 3                  Gyumri, Shirak, Armenia
# 4         Gyumri, Shirak Province, Armenia
# 6         Gyumri, Shirak Province, Armenia
# 7         Gyumri, Shirak Province, Armenia
# 8         Gyumri, Shirak Province, Armenia
# 9         Gyumri, Shirak Province, Armenia
# 10        Gyumri, Shirak Province, Armenia
# 12        Gyumri, Shirak Province, Armenia
# 13        Gyumri, Shirak Province, Armenia
# 15        Gyumri, Shirak Province, Armenia
# 18        Gyumri, Shirak Province, Armenia
# 19        Gyumri, Shirak Province, Armenia
# 21      Dzorakap, Shirak Province, Armenia
# 22        Gyumri, Shirak Province, Armenia
# 23        Gyumri, Shirak Province, Armenia
# 24        Gyumri, Shirak Province, Armenia
# 25        Gyumri, Shirak Province, Armenia
# 26        Gyumri, Shirak Province, Armenia
# 28        Gyumri, Shirak Province, Armenia
# 29        Gyumri, Shirak Province, Armenia
# ...

# %%
city_list = []
for i in hotel_full_Maralik.index:
    text = re.sub(",", "", hotel_full_Maralik["city"][i][:hotel_full_Maralik["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Maralik["city"]= city_list
hotel_full_Maralik
# Out:
#                              city                                 country  \
# 2       Dzorakap Shirak Province       Dzorakap, Shirak Province, Armenia
# 3                  Gyumri Shirak                  Gyumri, Shirak, Armenia
# 4         Gyumri Shirak Province                  Гюмри, Армения, Armenia
# 6         Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 7         Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 8         Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 9         Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 10        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 12        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 13        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 15        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 18        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Maralik.replace("", nan_value, inplace = True)
hotel_full_Maralik.dropna(inplace= True)
hotel_full_Maralik
# Out:
#                              city                                 country  \
# 2       Dzorakap Shirak Province       Dzorakap, Shirak Province, Armenia
# 3                  Gyumri Shirak                  Gyumri, Shirak, Armenia
# 4         Gyumri Shirak Province                  Гюмри, Армения, Armenia
# 6         Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 7         Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 8         Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 9         Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 10        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 12        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 13        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 15        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# 18        Gyumri Shirak Province         Gyumri, Shirak Province, Armenia
# ...

# %%
c_l = []    
for k in hotel_full_Maralik["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Maralik["city"]= c_l
hotel_full_Maralik
# Out:
#             city                                 country  \
# 2       Dzorakap      Dzorakap, Shirak Province, Armenia
# 3         Gyumri                 Gyumri, Shirak, Armenia
# 4         Gyumri                 Гюмри, Армения, Armenia
# 6         Gyumri        Gyumri, Shirak Province, Armenia
# 7         Gyumri        Gyumri, Shirak Province, Armenia
# 8         Gyumri        Gyumri, Shirak Province, Armenia
# 9         Gyumri        Gyumri, Shirak Province, Armenia
# 10        Gyumri        Gyumri, Shirak Province, Armenia
# 12        Gyumri        Gyumri, Shirak Province, Armenia
# 13        Gyumri        Gyumri, Shirak Province, Armenia
# 15        Gyumri        Gyumri, Shirak Province, Armenia
# 18        Gyumri        Gyumri, Shirak Province, Armenia
# 19        Gyumri        Gyumri, Shirak Province, Armenia
# 21      Dzorakap      Dzorakap, Shirak Province, Armenia
# 22        Gyumri        Gyumri, Shirak Province, Armenia
# ...

# %%
country_list = []
for i in hotel_full_Maralik.index:
    text = re.search("Armenia", hotel_full_Maralik["country"][i]).group()
    country_list.append(text)

hotel_full_Maralik["country"] = country_list

# %%
hotel_full_Maralik
# Out:
#             city  country                                               name  \
# 2       Dzorakap  Armenia             Apple Tree Family House (Family Suite)
# 3         Gyumri  Armenia                         Modern apartment in Gyumri
# 4         Gyumri  Armenia             Contemporary and comfortable apartment
# 6         Gyumri  Armenia                                       KAYARAN home
# 7         Gyumri  Armenia                               Full House in Gyumri
# 8         Gyumri  Armenia    Центральный Гюмри ДОМ МЕЧТЫ Guest Hausse A.S.T.
# 9         Gyumri  Armenia                              New Central apartment
# 10        Gyumri  Armenia         Cozy and Modern Gyumri House with a Garden
# 12        Gyumri  Armenia                               Rest and reliability
# 13        Gyumri  Armenia                                            Room #5
# 15        Gyumri  Armenia                       Downtown Apartment in Gyumri
# ...

# %%
host_since_list = []
for i in hotel_full_Maralik.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Maralik.host_since = hs 
hotel_full_Maralik.host_since
# Out:
# 2     2019
# 3     2013
# 4     2019
# 6     2014
# 7     2018
# 8     2016
# 9     2014
# 10    2020
# 12    2021
# 13    2017
# 15    2018
# 18    2018
# 19    2016
# 21    2019
# 22    2016
# 23    2016
# 24    2016
# 25    2019
# 26    2019
# 28    2013
# 29    2019
# 32    2016
# 36    2018
# 38    2014
# 39    2018
# 40    2014
# 41    2019
# 44    2013
# 46    2018
# 47    2018
# 48    2014
# 49    2019
# 51    2014
# 52    2014
# 54    2014
# 55    2020
# 56    2019
# 57    2018
# 58    2018
# 62    2019
# 64    2014
# 66    2021
# 67    2019
# 68    2018
# 69    2019
# 71    2018
# 73    2014
# 74    2018
# 75    2019
# 77    2018
# 79    2019
# 81    2020
# 83    2019
# 84    2019
# 88    2019
# 90    2020
# 91    2019
# 94    2019
# 96    2019
# Name: host_since, dtype: int64

# %%
hotel_full_Maralik
# Out:
#             city  country                                               name  \
# 2       Dzorakap  Armenia             Apple Tree Family House (Family Suite)
# 3         Gyumri  Armenia                         Modern apartment in Gyumri
# 4         Gyumri  Armenia             Contemporary and comfortable apartment
# 6         Gyumri  Armenia                                       KAYARAN home
# 7         Gyumri  Armenia                               Full House in Gyumri
# 8         Gyumri  Armenia    Центральный Гюмри ДОМ МЕЧТЫ Guest Hausse A.S.T.
# 9         Gyumri  Armenia                              New Central apartment
# 10        Gyumri  Armenia         Cozy and Modern Gyumri House with a Garden
# 12        Gyumri  Armenia                               Rest and reliability
# 13        Gyumri  Armenia                                            Room #5
# 15        Gyumri  Armenia                       Downtown Apartment in Gyumri
# ...

# %%
string = []
for i in hotel_full_Maralik.index:
    st = hotel_full_Maralik.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["1 Review', 'Identity verified",
#  "78 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  '8 Reviews',
#  "43 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "14 Reviews', 'Identity verified', 'Airbnb.org supporter",
#  '18 Reviews',
#  "16 Reviews', '\\U000f0003', 'Superhost",
#  "7 Reviews', 'Identity verified",
#  'Identity verified',
#  "65 Reviews', 'Identity verified",
#  "14 Reviews', 'Identity verified', 'Airbnb.org supporter",
#  "35 Reviews', 'Identity verified",
#  '18 Reviews',
#  "1 Review', 'Identity verified",
#  '6 Reviews',
#  '18 Reviews',
#  '18 Reviews',
#  "1 Review', 'Identity verified",
#  "6 Reviews', 'Identity verified",
#  '65 Reviews',
#  "1 Review', 'Identity verified",
#  '18 Reviews',
#  '40 Reviews',
#  '30 Reviews',
#  '5 Reviews',
#  '30 Reviews',
#  "1 Review', 'Identity verified",
#  '65 Reviews',
#  '40 Reviews',
#  '3 Reviews',
#  '30 Reviews',
#  "1 Review', 'Identity verified",
#  '30 Reviews',
#  '27 Reviews',
# ...

# %%
hotel_full_Maralik.host_identity_verified = string
hotel_full_Maralik.host_identity_verified
# Out:
# 2                         1 Review', 'Identity verified
# 3     78 Reviews', 'Identity verified', '\U000f0003'...
# 4                                             8 Reviews
# 6     43 Reviews', 'Identity verified', '\U000f0003'...
# 7     14 Reviews', 'Identity verified', 'Airbnb.org ...
# 8                                            18 Reviews
# 9                 16 Reviews', '\U000f0003', 'Superhost
# 10                       7 Reviews', 'Identity verified
# 12                                    Identity verified
# 13                      65 Reviews', 'Identity verified
# 15    14 Reviews', 'Identity verified', 'Airbnb.org ...
# 18                      35 Reviews', 'Identity verified
# 19                                           18 Reviews
# 21                        1 Review', 'Identity verified
# 22                                            6 Reviews
# 23                                           18 Reviews
# 24                                           18 Reviews
# ...

# %%
for i in hotel_full_Maralik.index:
    if "Identity verified" in  hotel_full_Maralik.host_identity_verified[i]:
        hotel_full_Maralik.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Maralik.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Maralik
# Out:
#             city  country                                               name  \
# 2       Dzorakap  Armenia             Apple Tree Family House (Family Suite)
# 3         Gyumri  Armenia                         Modern apartment in Gyumri
# 4         Gyumri  Armenia             Contemporary and comfortable apartment
# 6         Gyumri  Armenia                                       KAYARAN home
# 7         Gyumri  Armenia                               Full House in Gyumri
# 8         Gyumri  Armenia    Центральный Гюмри ДОМ МЕЧТЫ Guest Hausse A.S.T.
# 9         Gyumri  Armenia                              New Central apartment
# 10        Gyumri  Armenia         Cozy and Modern Gyumri House with a Garden
# 12        Gyumri  Armenia                               Rest and reliability
# 13        Gyumri  Armenia                                            Room #5
# 15        Gyumri  Armenia                       Downtown Apartment in Gyumri
# ...

# %%
for i in hotel_full_Maralik.index:
    if "Review" in  hotel_full_Maralik.review[i]:
        hotel_full_Maralik.loc[i, 'review'] = re.search("(\d+)", hotel_full_Maralik.review[i]).group()
        
    else:
        hotel_full_Maralik.loc[i, 'review'] = 0

# %%
hotel_full_Maralik
# Out:
#             city  country                                               name  \
# 2       Dzorakap  Armenia             Apple Tree Family House (Family Suite)
# 3         Gyumri  Armenia                         Modern apartment in Gyumri
# 4         Gyumri  Armenia             Contemporary and comfortable apartment
# 6         Gyumri  Armenia                                       KAYARAN home
# 7         Gyumri  Armenia                               Full House in Gyumri
# 8         Gyumri  Armenia    Центральный Гюмри ДОМ МЕЧТЫ Guest Hausse A.S.T.
# 9         Gyumri  Armenia                              New Central apartment
# 10        Gyumri  Armenia         Cozy and Modern Gyumri House with a Garden
# 12        Gyumri  Armenia                               Rest and reliability
# 13        Gyumri  Armenia                                            Room #5
# 15        Gyumri  Armenia                       Downtown Apartment in Gyumri
# ...

# %%
for i in hotel_full_Maralik.index:
    if "Superhost" in  hotel_full_Maralik.superhost[i]:
        hotel_full_Maralik.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Maralik.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Maralik.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire residential home',
#  'Entire bed and breakfast',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire residential home',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire guesthouse',
#  'Entire rental unit',
#  'Entire residential home',
#  'Room in aparthotel',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Room in hotel  Gyumri',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire guest suite',
#  'Entire rental unit',
#  'Private room in residential home -Anna',
#  'Entire rental unit',
#  'Private room in residential home -Anna',
#  'Room in hotel  Gyumri',
#  'Private room in residential home',
#  'Entire rental unit',
#  'Room in boutique hotel',
#  'Private room in residential home -Anna',
#  'Room in hotel  Gyumri',
#  'Private room in residential home -Anna',
# ...

# %%
hotel_full_Maralik.property_type =prop_list

# %%
hotel_full_Maralik
# Out:
#             city  country                                               name  \
# 2       Dzorakap  Armenia             Apple Tree Family House (Family Suite)
# 3         Gyumri  Armenia                         Modern apartment in Gyumri
# 4         Gyumri  Armenia             Contemporary and comfortable apartment
# 6         Gyumri  Armenia                                       KAYARAN home
# 7         Gyumri  Armenia                               Full House in Gyumri
# 8         Gyumri  Armenia    Центральный Гюмри ДОМ МЕЧТЫ Guest Hausse A.S.T.
# 9         Gyumri  Armenia                              New Central apartment
# 10        Gyumri  Armenia         Cozy and Modern Gyumri House with a Garden
# 12        Gyumri  Armenia                               Rest and reliability
# 13        Gyumri  Armenia                                            Room #5
# 15        Gyumri  Armenia                       Downtown Apartment in Gyumri
# ...

# %%
accomodates_list = []
for i in hotel_full_Maralik.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Maralik.accomodates = number

# %%
for i in hotel_full_Maralik.index:
    if "Shared half-bath" in  hotel_full_Maralik.number_bathroom[i]:
        hotel_full_Maralik.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Maralik.number_bathroom[i]:
        hotel_full_Maralik.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Maralik.number_bathroom[i]:
        hotel_full_Maralik.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Maralik.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Maralik.number_bedroom[i])
        hotel_full_Maralik.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Maralik.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Maralik.number_bedroom[i])
        hotel_full_Maralik.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Maralik.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Maralik.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Maralik.index:
    if "bed" in  hotel_full_Maralik.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Maralik.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Maralik.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['8',
#  '3',
#  None,
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '0',
#  '4',
#  '1',
#  '4',
#  '1',
#  '2',
#  '4',
#  '1',
#  '1',
#  '1',
#  '4',
#  '1',
#  '1',
#  '4',
#  '3',
#  '0',
#  '1',
#  '4',
#  '1',
#  '0',
#  '3',
#  '1',
#  '0',
#  '1',
#  '4',
#  '12',
#  '2',
#  '8',
#  '2',
#  '2',
#  '1',
#  '1',
#  '3',
#  '8',
#  '2',
#  '3',
#  '1',
#  '1',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '2',
#  '3',
#  '2',
#  '4',
#  '12',
#  '4',
#  '5',
#  '4']

# %%
len(hotel_full_Maralik.number_beds)
# Out:
# 59

# %%
len(number_beds_list)
# Out:
# 59

# %%
hotel_full_Maralik.number_beds = number_beds_list

# %%
hotel_full_Maralik.number_beds
# Out:
# 2        8
# 3        3
# 4     None
# 6        2
# 7        2
# 8        1
# 9        2
# 10       2
# 12       0
# 13       4
# 15       1
# 18       4
# 19       1
# 21       2
# 22       4
# 23       1
# 24       1
# 25       1
# 26       4
# 28       1
# 29       1
# 32       4
# 36       3
# 38       0
# 39       1
# 40       4
# 41       1
# 44       0
# 46       3
# 47       1
# 48       0
# 49       1
# 51       4
# 52      12
# 54       2
# 55       8
# 56       2
# 57       2
# 58       1
# 62       1
# 64       3
# 66       8
# 67       2
# 68       3
# 69       1
# 71       1
# 73       2
# 74       1
# 75       1
# 77       1
# 79       1
# 81       2
# 83       3
# 84       2
# 88       4
# 90      12
# 91       4
# 94       5
# 96       4
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Maralik.index:
    if "Studio" in  hotel_full_Maralik.number_bedroom[i]:
        hotel_full_Maralik.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Maralik.number_bedroom[i])
        hotel_full_Maralik.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Maralik.index:
    if "Cleanliness" in  hotel_full_Maralik.cleanliness[i]:
        hotel_full_Maralik.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Maralik.cleanliness[i])
    else:
        hotel_full_Maralik.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Maralik.index:
    if "Accuracy" in  hotel_full_Maralik.accuracy[i]:
        hotel_full_Maralik.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Maralik.accuracy[i])
    else:
        hotel_full_Maralik.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Maralik.index:
    if "Communication" in  hotel_full_Maralik.communication[i]:
        hotel_full_Maralik.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Maralik.communication[i])
    else:
        hotel_full_Maralik.loc[i, 'communication'] = None

# %%
for i in hotel_full_Maralik.index:
    if "Location" in  hotel_full_Maralik.location[i]:
        try:
            hotel_full_Maralik.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Maralik.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Maralik.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Maralik.location[i])
    
    else:
        hotel_full_Maralik.loc[i, 'location'] = None

# %%
for i in hotel_full_Maralik.index:
    if "Check-in" in  hotel_full_Maralik.check_in[i]:
        hotel_full_Maralik.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Maralik.check_in[i])
    else:
        hotel_full_Maralik.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Maralik.index:
    if "Value" in  hotel_full_Maralik.value[i]:
        hotel_full_Maralik.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Maralik.value[i])
    else:
        hotel_full_Maralik.loc[i, 'value'] = None

# %%
for i in hotel_full_Maralik.index:
    if "No reviews (yet)" in  hotel_full_Maralik.rating[i]:
        hotel_full_Maralik.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Maralik.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Maralik.price = price_list

# %%
for i in hotel_full_Maralik.index:
    if "Response rate" in  hotel_full_Maralik.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Maralik.host_response_rate[i])
        hotel_full_Maralik.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Maralik.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Maralik = hotel_full_Maralik.astype(convert_dict)

# %%
hotel_full_Maralik.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Maralik.to_csv("cleaned_hotel_full_Maralik.csv", index=False)
hotel_full_Maralik.to_excel("cleaned_hotel_full_Maralik2.xlsx", index=False)
