# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Masis = pd.read_csv('hotel_full_Masis.csv')
hotel_full_Masis
# Out:
#                                         city  \
# 0                                        NaN
# 1                           Yerevan, Armenia
# 2            Garni, Kotayk Province, Armenia
# 3                           Yerevan, Armenia
# 4    Vagharshapat, Armavir Province, Armenia
# ..                                       ...
# 294                         Yerevan, Armenia
# 295                         Yerevan, Armenia
# 296                         Yerevan, Armenia
# 297                         Yerevan, Armenia
# 298                         Yerevan, Armenia
#
#                                      country  \
# 0                                        NaN
# 1                           Yerevan, Armenia
# 2            Garni, Kotayk Province, Armenia
# 3                           Yerevan, Armenia
# 4    Vagharshapat, Armavir Province, Armenia
# ..                                       ...
# 294                         Yerevan, Armenia
# 295                         Yerevan, Armenia
# ...

# %%
hotel_full_Masis = hotel_full_Masis.drop(labels = 0, axis = 0)
hotel_full_Masis
# Out:
#                                         city  \
# 1                           Yerevan, Armenia
# 2            Garni, Kotayk Province, Armenia
# 3                           Yerevan, Armenia
# 4    Vagharshapat, Armavir Province, Armenia
# 5                           Yerevan, Armenia
# ..                                       ...
# 294                         Yerevan, Armenia
# 295                         Yerevan, Armenia
# 296                         Yerevan, Armenia
# 297                         Yerevan, Armenia
# 298                         Yerevan, Armenia
#
#                                      country  \
# 1                           Yerevan, Armenia
# 2            Garni, Kotayk Province, Armenia
# 3                           Yerevan, Armenia
# 4    Vagharshapat, Armavir Province, Armenia
# 5                           Yerevan, Armenia
# ..                                       ...
# 294                         Yerevan, Armenia
# 295                         Yerevan, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Masis.replace("", nan_value, inplace = True)
hotel_full_Masis.dropna(inplace= True)
hotel_full_Masis
# Out:
#                                         city  \
# 2            Garni, Kotayk Province, Armenia
# 3                           Yerevan, Armenia
# 4    Vagharshapat, Armavir Province, Armenia
# 5                           Yerevan, Armenia
# 6                           Yerevan, Armenia
# ..                                       ...
# 292                         Yerevan, Armenia
# 295                         Yerevan, Armenia
# 296                         Yerevan, Armenia
# 297                         Yerevan, Armenia
# 298                         Yerevan, Armenia
#
#                                      country  \
# 2            Garni, Kotayk Province, Armenia
# 3                           Yerevan, Armenia
# 4    Vagharshapat, Armavir Province, Armenia
# 5                           Yerevan, Armenia
# 6                           Yerevan, Armenia
# ..                                       ...
# 292                         Yerevan, Armenia
# 295                         Yerevan, Armenia
# ...

# %%
hotel_full_Masis["city"]= hotel_full_Masis["city"].replace({"Երևան, Armenia" : "Yerevan, Armenia"})

# %%
hotel_full_Masis["city"]= hotel_full_Masis["city"].replace({"Գառնի, Armenia" : "Garni, Armenia"})

# %%
hotel_full_Masis["city"]= hotel_full_Masis["city"].replace({"Ереван, United States" : "Yerevan, Armenia"})

# %%
hotel_full_Masis["city"]= hotel_full_Masis["city"].replace({"Երևան, Yerevan, Armenia" : "Yerevan, Armenia"})

# %%
city_list = []
for i in hotel_full_Masis.index:
    text = re.sub(",", "", hotel_full_Masis["city"][i][:hotel_full_Masis["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Masis["city"]= city_list
hotel_full_Masis
# Out:
#                                city                                  country  \
# 2            Garni Kotayk Province           Garni, Kotayk Province, Armenia
# 3                          Yerevan                          Yerevan, Armenia
# 4    Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 5                          Yerevan                          Yerevan, Armenia
# 6                          Yerevan                          Yerevan, Armenia
# ..                              ...                                      ...
# 292                        Yerevan                          Yerevan, Armenia
# 295                        Yerevan                          Yerevan, Armenia
# 296                        Yerevan                          Yerevan, Armenia
# 297                        Yerevan                          Yerevan, Armenia
# 298                        Yerevan                          Yerevan, Armenia
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Masis.replace("", nan_value, inplace = True)
hotel_full_Masis.dropna(inplace= True)
hotel_full_Masis
# Out:
#                                city                                  country  \
# 2            Garni Kotayk Province           Garni, Kotayk Province, Armenia
# 3                          Yerevan                          Yerevan, Armenia
# 4    Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 5                          Yerevan                          Yerevan, Armenia
# 6                          Yerevan                          Yerevan, Armenia
# ..                              ...                                      ...
# 292                        Yerevan                          Yerevan, Armenia
# 295                        Yerevan                          Yerevan, Armenia
# 296                        Yerevan                          Yerevan, Armenia
# 297                        Yerevan                          Yerevan, Armenia
# 298                        Yerevan                          Yerevan, Armenia
#
# ...

# %%
c_l = []    
for k in hotel_full_Masis["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Masis["city"]= c_l
hotel_full_Masis
# Out:
#              city                                  country  \
# 2           Garni          Garni, Kotayk Province, Armenia
# 3         Yerevan                         Yerevan, Armenia
# 4    Vagharshapat  Vagharshapat, Armavir Province, Armenia
# 5         Yerevan                         Yerevan, Armenia
# 6         Yerevan                         Yerevan, Armenia
# ..            ...                                      ...
# 292       Yerevan                         Yerevan, Armenia
# 295       Yerevan                         Yerevan, Armenia
# 296       Yerevan                         Yerevan, Armenia
# 297       Yerevan                         Yerevan, Armenia
# 298       Yerevan                         Yerevan, Armenia
#
#                                                   name  \
# 2                                      Cherry blossoms
# 3             КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4                                             Art home
# ...

# %%
country_list = []
for i in hotel_full_Masis.index:
    text = re.search("Armenia", hotel_full_Masis["country"][i]).group()
    country_list.append(text)

hotel_full_Masis["country"] = country_list

# %%
hotel_full_Masis
# Out:
#              city  country                                               name  \
# 2           Garni  Armenia                                    Cherry blossoms
# 3         Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    Vagharshapat  Armenia                                           Art home
# 5         Yerevan  Armenia                                      #4 apartment!
# 6         Yerevan  Armenia                                  Comfort apartment
# ..            ...      ...                                                ...
# 292       Yerevan  Armenia                  Lovely 1 bedroom app on main road
# 295       Yerevan  Armenia          One BDR apt on 11th floor on Koghbatsi 16
# 296       Yerevan  Armenia        Cozy and Warm Apartment in Yerevan's Center
# 297       Yerevan  Armenia   Modern Fancy Apt in Center✔2 Bathroom✔Opera View
# 298       Yerevan  Armenia  Peerless 2 BDR in Downtown with Ararat view by...
#
#                   host_since  \
# ...

# %%
host_since_list = []
for i in hotel_full_Masis.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Masis.host_since = hs 
hotel_full_Masis.host_since
# Out:
# 2      2017
# 3      2018
# 4      2019
# 5      2017
# 6      2018
#        ...
# 292    2021
# 295    2020
# 296    2020
# 297    2020
# 298    2014
# Name: host_since, Length: 245, dtype: int64

# %%
hotel_full_Masis
# Out:
#              city  country                                               name  \
# 2           Garni  Armenia                                    Cherry blossoms
# 3         Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    Vagharshapat  Armenia                                           Art home
# 5         Yerevan  Armenia                                      #4 apartment!
# 6         Yerevan  Armenia                                  Comfort apartment
# ..            ...      ...                                                ...
# 292       Yerevan  Armenia                  Lovely 1 bedroom app on main road
# 295       Yerevan  Armenia          One BDR apt on 11th floor on Koghbatsi 16
# 296       Yerevan  Armenia        Cozy and Warm Apartment in Yerevan's Center
# 297       Yerevan  Armenia   Modern Fancy Apt in Center✔2 Bathroom✔Opera View
# 298       Yerevan  Armenia  Peerless 2 BDR in Downtown with Ararat view by...
#
# ...

# %%
string = []
for i in hotel_full_Masis.index:
    st = hotel_full_Masis.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["98 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "97 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "6 Reviews', 'Identity verified",
#  "47 Reviews', 'Identity verified",
#  "39 Reviews', '\\U000f0003', 'Superhost",
#  "13 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "190 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "152 Reviews', 'Identity verified",
#  "395 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "98 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "137 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  '18 Reviews',
#  "11 Reviews', 'Identity verified",
#  "333 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "240 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "7 Reviews', 'Identity verified",
#  "3 Reviews', 'Identity verified",
#  "13 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
# ...

# %%
hotel_full_Masis.host_identity_verified = string
hotel_full_Masis.host_identity_verified
# Out:
# 2      98 Reviews', 'Identity verified', '\U000f0003'...
# 3      97 Reviews', 'Identity verified', '\U000f0003'...
# 4                         6 Reviews', 'Identity verified
# 5                        47 Reviews', 'Identity verified
# 6                  39 Reviews', '\U000f0003', 'Superhost
#                              ...
# 292                                    Identity verified
# 295    174 Reviews', 'Identity verified', '\U000f0003...
# 296                                            3 Reviews
# 297    21 Reviews', 'Identity verified', 'Airbnb.org ...
# 298    536 Reviews', 'Identity verified', '\U000f0003...
# Name: host_identity_verified, Length: 245, dtype: object

# %%
for i in hotel_full_Masis.index:
    if "Identity verified" in  hotel_full_Masis.host_identity_verified[i]:
        hotel_full_Masis.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Masis.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Masis
# Out:
#              city  country                                               name  \
# 2           Garni  Armenia                                    Cherry blossoms
# 3         Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    Vagharshapat  Armenia                                           Art home
# 5         Yerevan  Armenia                                      #4 apartment!
# 6         Yerevan  Armenia                                  Comfort apartment
# ..            ...      ...                                                ...
# 292       Yerevan  Armenia                  Lovely 1 bedroom app on main road
# 295       Yerevan  Armenia          One BDR apt on 11th floor on Koghbatsi 16
# 296       Yerevan  Armenia        Cozy and Warm Apartment in Yerevan's Center
# 297       Yerevan  Armenia   Modern Fancy Apt in Center✔2 Bathroom✔Opera View
# 298       Yerevan  Armenia  Peerless 2 BDR in Downtown with Ararat view by...
#
# ...

# %%
for i in hotel_full_Masis.index:
    if "Review" in  hotel_full_Masis.review[i]:
        hotel_full_Masis.loc[i, 'review'] = re.search("(\d+)", hotel_full_Masis.review[i]).group()
        
    else:
        hotel_full_Masis.loc[i, 'review'] = 0

# %%
hotel_full_Masis
# Out:
#              city  country                                               name  \
# 2           Garni  Armenia                                    Cherry blossoms
# 3         Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    Vagharshapat  Armenia                                           Art home
# 5         Yerevan  Armenia                                      #4 apartment!
# 6         Yerevan  Armenia                                  Comfort apartment
# ..            ...      ...                                                ...
# 292       Yerevan  Armenia                  Lovely 1 bedroom app on main road
# 295       Yerevan  Armenia          One BDR apt on 11th floor on Koghbatsi 16
# 296       Yerevan  Armenia        Cozy and Warm Apartment in Yerevan's Center
# 297       Yerevan  Armenia   Modern Fancy Apt in Center✔2 Bathroom✔Opera View
# 298       Yerevan  Armenia  Peerless 2 BDR in Downtown with Ararat view by...
#
# ...

# %%
for i in hotel_full_Masis.index:
    if "Superhost" in  hotel_full_Masis.superhost[i]:
        hotel_full_Masis.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Masis.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Masis.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire residential home',
#  'Entire rental unit  Inn',
#  'Entire loft',
#  'Entire guesthouse',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire residential home',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
# ...

# %%
hotel_full_Masis.property_type =prop_list

# %%
hotel_full_Masis
# Out:
#              city  country                                               name  \
# 2           Garni  Armenia                                    Cherry blossoms
# 3         Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    Vagharshapat  Armenia                                           Art home
# 5         Yerevan  Armenia                                      #4 apartment!
# 6         Yerevan  Armenia                                  Comfort apartment
# ..            ...      ...                                                ...
# 292       Yerevan  Armenia                  Lovely 1 bedroom app on main road
# 295       Yerevan  Armenia          One BDR apt on 11th floor on Koghbatsi 16
# 296       Yerevan  Armenia        Cozy and Warm Apartment in Yerevan's Center
# 297       Yerevan  Armenia   Modern Fancy Apt in Center✔2 Bathroom✔Opera View
# 298       Yerevan  Armenia  Peerless 2 BDR in Downtown with Ararat view by...
#
# ...

# %%
accomodates_list = []
for i in hotel_full_Masis.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Masis.accomodates = number

# %%
for i in hotel_full_Masis.index:
    if "Shared half-bath" in  hotel_full_Masis.number_bathroom[i]:
        hotel_full_Masis.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Masis.number_bathroom[i]:
        hotel_full_Masis.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Masis.number_bathroom[i]:
        hotel_full_Masis.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Masis.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Masis.number_bedroom[i])
        hotel_full_Masis.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Masis.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Masis.number_bedroom[i])
        hotel_full_Masis.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Masis.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Masis.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Masis.index:
    if "bed" in  hotel_full_Masis.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Masis.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Masis.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['4',
#  '1',
#  '2',
#  '2',
#  '2',
#  '3',
#  '1',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '2',
#  '4',
#  '1',
#  '1',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '2',
#  '1',
#  '1',
#  '3',
#  '1',
#  '2',
#  '3',
#  '1',
#  '2',
#  '2',
#  '1',
#  '3',
#  '1',
#  '2',
#  '4',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '2',
#  '1',
#  '2',
#  '1',
#  '2',
#  '1',
#  '2',
#  '1',
#  '3',
#  '1',
#  '2',
#  '1',
#  '1',
#  '1',
#  '0',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '2',
#  '3',
#  '1',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '4',
#  '3',
#  '2',
#  '1',
#  '2',
#  '4',
#  '1',
#  '2',
#  '1',
#  '4',
#  '5',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '4',
#  '3',
#  '2',
#  '3',
#  '1',
#  '2',
#  '2',
#  '1',
#  '2',
#  '4',
#  '8',
#  '2',
#  '1',
#  '3',
#  '2',
#  '2',
# ...

# %%
len(hotel_full_Masis.number_beds)
# Out:
# 245

# %%
len(number_beds_list)
# Out:
# 245

# %%
hotel_full_Masis.number_beds = number_beds_list

# %%
hotel_full_Masis.number_beds
# Out:
# 2      4
# 3      1
# 4      2
# 5      2
# 6      2
#       ..
# 292    2
# 295    2
# 296    2
# 297    2
# 298    5
# Name: number_beds, Length: 245, dtype: object

# %%
for i in hotel_full_Masis.index:
    if "Studio" in  hotel_full_Masis.number_bedroom[i]:
        hotel_full_Masis.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Masis.number_bedroom[i])
        hotel_full_Masis.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Masis.index:
    if "Cleanliness" in  hotel_full_Masis.cleanliness[i]:
        hotel_full_Masis.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Masis.cleanliness[i])
    else:
        hotel_full_Masis.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Masis.index:
    if "Accuracy" in  hotel_full_Masis.accuracy[i]:
        hotel_full_Masis.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Masis.accuracy[i])
    else:
        hotel_full_Masis.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Masis.index:
    if "Communication" in  hotel_full_Masis.communication[i]:
        hotel_full_Masis.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Masis.communication[i])
    else:
        hotel_full_Masis.loc[i, 'communication'] = None

# %%
for i in hotel_full_Masis.index:
    if "Location" in  hotel_full_Masis.location[i]:
        try:
            hotel_full_Masis.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Masis.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Masis.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Masis.location[i])
    
    else:
        hotel_full_Masis.loc[i, 'location'] = None

# %%
for i in hotel_full_Masis.index:
    if "Check-in" in  hotel_full_Masis.check_in[i]:
        hotel_full_Masis.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Masis.check_in[i])
    else:
        hotel_full_Masis.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Masis.index:
    if "Value" in  hotel_full_Masis.value[i]:
        hotel_full_Masis.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Masis.value[i])
    else:
        hotel_full_Masis.loc[i, 'value'] = None

# %%
for i in hotel_full_Masis.index:
    if "No reviews (yet)" in  hotel_full_Masis.rating[i]:
        hotel_full_Masis.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Masis.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Masis.price = price_list

# %%
for i in hotel_full_Masis.index:
    if "Response rate" in  hotel_full_Masis.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Masis.host_response_rate[i])
        hotel_full_Masis.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Masis.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Masis = hotel_full_Masis.astype(convert_dict)

# %%
hotel_full_Masis.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Masis.to_csv("cleaned_hotel_full_Masis.csv", index=False)
hotel_full_Masis.to_excel("cleaned_hotel_full_Masis2.xlsx", index=False)
