# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Tsaxkadzor = pd.read_csv('hotel_full_Tsaxkadzor.csv')
hotel_full_Tsaxkadzor
# Out:
#                                       city  \
# 0                                      NaN
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2    Tsaghkadzor, Kotayk Province, Armenia
# 3    Tsaghkadzor, Kotayk Province, Armenia
# 4    Tsaghkadzor, Kotayk Province, Armenia
# ..                                     ...
# 110  Tsaghkadzor, Kotayk Province, Armenia
# 111           Tsaghkadzor, Kotayk, Armenia
# 112           Tsaghkadzor, Kotayk, Armenia
# 113           Tsaghkadzor, Kotayk, Armenia
# 114  Tsaghkadzor, Kotayk Province, Armenia
#
#                                    country  \
# 0                                      NaN
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2    Tsaghkadzor, Kotayk Province, Armenia
# 3    Tsaghkadzor, Kotayk Province, Armenia
# 4    Tsaghkadzor, Kotayk Province, Armenia
# ..                                     ...
# 110  Tsaghkadzor, Kotayk Province, Armenia
# 111           Tsaghkadzor, Kotayk, Armenia
# 112           Tsaghkadzor, Kotayk, Armenia
# ...

# %%
hotel_full_Tsaxkadzor = hotel_full_Tsaxkadzor.drop(labels = 0, axis = 0)
hotel_full_Tsaxkadzor
# Out:
#                                       city  \
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2    Tsaghkadzor, Kotayk Province, Armenia
# 3    Tsaghkadzor, Kotayk Province, Armenia
# 4    Tsaghkadzor, Kotayk Province, Armenia
# 5    Tsaghkadzor, Kotayk Province, Armenia
# ..                                     ...
# 110  Tsaghkadzor, Kotayk Province, Armenia
# 111           Tsaghkadzor, Kotayk, Armenia
# 112           Tsaghkadzor, Kotayk, Armenia
# 113           Tsaghkadzor, Kotayk, Armenia
# 114  Tsaghkadzor, Kotayk Province, Armenia
#
#                                    country  \
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2    Tsaghkadzor, Kotayk Province, Armenia
# 3    Tsaghkadzor, Kotayk Province, Armenia
# 4    Tsaghkadzor, Kotayk Province, Armenia
# 5    Tsaghkadzor, Kotayk Province, Armenia
# ..                                     ...
# 110  Tsaghkadzor, Kotayk Province, Armenia
# 111           Tsaghkadzor, Kotayk, Armenia
# 112           Tsaghkadzor, Kotayk, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Tsaxkadzor.replace("", nan_value, inplace = True)
hotel_full_Tsaxkadzor.dropna(inplace= True)
hotel_full_Tsaxkadzor
# Out:
#                                       city  \
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2    Tsaghkadzor, Kotayk Province, Armenia
# 3    Tsaghkadzor, Kotayk Province, Armenia
# 4    Tsaghkadzor, Kotayk Province, Armenia
# 5    Tsaghkadzor, Kotayk Province, Armenia
# 7    Tsaghkadzor, Kotayk Province, Armenia
# 8    Tsaghkadzor, Kotayk Province, Armenia
# 9    Tsaghkadzor, Kotayk Province, Armenia
# 12   Tsaghkadzor, Kotayk Province, Armenia
# 16                       Ծաղկաձոր, Armenia
# 17   Tsaghkadzor, Kotayk Province, Armenia
# 19   Tsaghkadzor, Kotayk Province, Armenia
# 20   Tsaghkadzor, Kotayk Province, Armenia
# 22   Tsaghkadzor, Kotayk Province, Armenia
# 23   Tsaghkadzor, Kotayk Province, Armenia
# 26   Tsaghkadzor, Kotayk Province, Armenia
# 28   Tsaghkadzor, Kotayk Province, Armenia
# 29   Tsaghkadzor, Kotayk Province, Armenia
# 34               Ծաղկաձոր, Կոտայք, Armenia
# 43       Hrazdan, Kotayk Province, Armenia
# 44   Tsaghkadzor, Kotayk Province, Armenia
# ...

# %%
hotel_full_Tsaxkadzor["city"]= hotel_full_Tsaxkadzor["city"].replace({"Ծաղկաձոր, Armenia" : "Tsaghkadzor, Kotayk, Armenia"})

hotel_full_Tsaxkadzor["city"]= hotel_full_Tsaxkadzor["city"].replace({"Цахкадзор, Котайк, Armenia" : "Tsaghkadzor, Kotayk, Armenia"})


hotel_full_Tsaxkadzor["city"]= hotel_full_Tsaxkadzor["city"].replace({"Ծաղկաձոր, Կոտայք, Armenia" : "Tsaghkadzor, Kotayk, Armenia"})

hotel_full_Tsaxkadzor["city"]= hotel_full_Tsaxkadzor["city"].replace({"Цахкадзор , Армения, Armenia" : "Tsaghkadzor, Kotayk, Armenia"})
hotel_full_Tsaxkadzor["city"]= hotel_full_Tsaxkadzor["city"].replace({"Tsaghkadzor, Цахкадзор,Tsaxkadzor, Armenia" : "Tsaghkadzor, Kotayk, Armenia"})
hotel_full_Tsaxkadzor["city"]= hotel_full_Tsaxkadzor["city"].replace({"Цахкадзор, Армения, Armenia" : "Tsaghkadzor, Kotayk, Armenia"})
hotel_full_Tsaxkadzor["city"]= hotel_full_Tsaxkadzor["city"].replace({"Цахкадзор, Котайк, Armenia" : "Tsaghkadzor, Kotayk, Armenia"})


hotel_full_Tsaxkadzor
# Out:
#                                       city  \
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2    Tsaghkadzor, Kotayk Province, Armenia
# 3    Tsaghkadzor, Kotayk Province, Armenia
# 4    Tsaghkadzor, Kotayk Province, Armenia
# 5    Tsaghkadzor, Kotayk Province, Armenia
# 7    Tsaghkadzor, Kotayk Province, Armenia
# 8    Tsaghkadzor, Kotayk Province, Armenia
# 9    Tsaghkadzor, Kotayk Province, Armenia
# 12   Tsaghkadzor, Kotayk Province, Armenia
# 16            Tsaghkadzor, Kotayk, Armenia
# 17   Tsaghkadzor, Kotayk Province, Armenia
# 19   Tsaghkadzor, Kotayk Province, Armenia
# 20   Tsaghkadzor, Kotayk Province, Armenia
# 22   Tsaghkadzor, Kotayk Province, Armenia
# 23   Tsaghkadzor, Kotayk Province, Armenia
# 26   Tsaghkadzor, Kotayk Province, Armenia
# 28   Tsaghkadzor, Kotayk Province, Armenia
# 29   Tsaghkadzor, Kotayk Province, Armenia
# 34            Tsaghkadzor, Kotayk, Armenia
# 43       Hrazdan, Kotayk Province, Armenia
# 44   Tsaghkadzor, Kotayk Province, Armenia
# ...

# %%
city_list = []
for i in hotel_full_Tsaxkadzor.index:
    text = re.sub(",", "", hotel_full_Tsaxkadzor["city"][i][:hotel_full_Tsaxkadzor["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Tsaxkadzor["city"]= city_list
hotel_full_Tsaxkadzor
# Out:
#                              city                                country  \
# 1    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 2    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 3    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 4    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 5    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 7    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 8    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 9    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 12   Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 16            Tsaghkadzor Kotayk                       Ծաղկաձոր, Armenia
# 17   Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 19   Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Tsaxkadzor.replace("", nan_value, inplace = True)
hotel_full_Tsaxkadzor.dropna(inplace= True)
hotel_full_Tsaxkadzor
# Out:
#                              city                                country  \
# 1    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 2    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 3    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 4    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 5    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 7    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 8    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 9    Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 12   Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 16            Tsaghkadzor Kotayk                       Ծաղկաձոր, Armenia
# 17   Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# 19   Tsaghkadzor Kotayk Province   Tsaghkadzor, Kotayk Province, Armenia
# ...

# %%
c_l = []    
for k in hotel_full_Tsaxkadzor["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Tsaxkadzor["city"]= c_l
hotel_full_Tsaxkadzor
# Out:
#             city                                country  \
# 1    Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 2    Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 3    Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 4    Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 5    Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 7    Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 8    Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 9    Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 12   Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 16   Tsaghkadzor                      Ծաղկաձոր, Armenia
# 17   Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 19   Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 20   Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 22   Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 23   Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# 26   Tsaghkadzor  Tsaghkadzor, Kotayk Province, Armenia
# ...

# %%
country_list = []
for i in hotel_full_Tsaxkadzor.index:
    text = re.search("Armenia", hotel_full_Tsaxkadzor["country"][i]).group()
    country_list.append(text)

hotel_full_Tsaxkadzor["country"] = country_list

# %%
hotel_full_Tsaxkadzor
# Out:
#             city  country                                               name  \
# 1    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 2    Tsaghkadzor  Armenia                     Hillside Apartment Tsaghkadzor
# 3    Tsaghkadzor  Armenia    Beautiful hotel room in the city of Tsaghkadzor
# 4    Tsaghkadzor  Armenia                  Forest Castle Tsaghkadzor (Villa)
# 5    Tsaghkadzor  Armenia                            Crown Hotel Tsaghkadzor
# 7    Tsaghkadzor  Armenia   Mountain view apartment Квартира с видом на горы
# 8    Tsaghkadzor  Armenia                               Tsaghkadzor Homeland
# 9    Tsaghkadzor  Armenia               Villa with three separate apartments
# 12   Tsaghkadzor  Armenia                          Alaska Resort Tsaghkadzor
# 16   Tsaghkadzor  Armenia                      Вилла Provence in Tsakhkadzor
# 17   Tsaghkadzor  Armenia   Forest Castle Tsaghkadzor ( Cozy Vacation Home )
# ...

# %%
host_since_list = []
for i in hotel_full_Tsaxkadzor.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Tsaxkadzor.host_since = hs 
hotel_full_Tsaxkadzor.host_since
# Out:
# 1      2016
# 2      2018
# 3      2018
# 4      2019
# 5      2018
# 7      2019
# 8      2021
# 9      2021
# 12     2016
# 16     2019
# 17     2019
# 19     2021
# 20     2017
# 22     2021
# 23     2018
# 26     2019
# 28     2020
# 29     2019
# 34     2019
# 43     2017
# 44     2017
# 46     2017
# 47     2018
# 48     2017
# 51     2017
# 54     2017
# 55     2017
# 57     2017
# 61     2017
# 66     2017
# 72     2017
# 73     2017
# 75     2020
# 77     2017
# 78     2017
# 79     2017
# 82     2017
# 84     2014
# 85     2017
# 86     2013
# 88     2017
# 89     2017
# 95     2017
# 97     2015
# 102    2014
# 104    2014
# 106    2014
# 107    2014
# 108    2014
# 111    2014
# 112    2014
# 113    2014
# 114    2018
# Name: host_since, dtype: int64

# %%
hotel_full_Tsaxkadzor
# Out:
#             city  country                                               name  \
# 1    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 2    Tsaghkadzor  Armenia                     Hillside Apartment Tsaghkadzor
# 3    Tsaghkadzor  Armenia    Beautiful hotel room in the city of Tsaghkadzor
# 4    Tsaghkadzor  Armenia                  Forest Castle Tsaghkadzor (Villa)
# 5    Tsaghkadzor  Armenia                            Crown Hotel Tsaghkadzor
# 7    Tsaghkadzor  Armenia   Mountain view apartment Квартира с видом на горы
# 8    Tsaghkadzor  Armenia                               Tsaghkadzor Homeland
# 9    Tsaghkadzor  Armenia               Villa with three separate apartments
# 12   Tsaghkadzor  Armenia                          Alaska Resort Tsaghkadzor
# 16   Tsaghkadzor  Armenia                      Вилла Provence in Tsakhkadzor
# 17   Tsaghkadzor  Armenia   Forest Castle Tsaghkadzor ( Cozy Vacation Home )
# ...

# %%
string = []
for i in hotel_full_Tsaxkadzor.index:
    st = hotel_full_Tsaxkadzor.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["241 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "7 Reviews', 'Identity verified",
#  "79 Reviews', 'Identity verified",
#  "3 Reviews', 'Identity verified",
#  '5 Reviews',
#  "21 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  'Identity verified',
#  'Identity verified',
#  "74 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "6 Reviews', 'Identity verified",
#  "3 Reviews', 'Identity verified",
#  'Identity verified',
#  "21 Reviews', 'Identity verified",
#  'Identity verified',
#  "4 Reviews', 'Identity verified",
#  "27 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  '3 Reviews',
#  "31 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "5 Reviews', 'Identity verified",
#  "38 Reviews', 'Identity verified",
#  "38 Reviews', 'Identity verified",
#  "38 Reviews', 'Identity verified",
#  '1 Review',
#  "38 Reviews', 'Identity verified",
#  "38 Reviews', 'Identity verified",
#  "38 Reviews', 'Identity verified",
# ...

# %%
hotel_full_Tsaxkadzor.host_identity_verified = string
hotel_full_Tsaxkadzor.host_identity_verified
# Out:
# 1      241 Reviews', 'Identity verified', '\U000f0003...
# 2                         7 Reviews', 'Identity verified
# 3                        79 Reviews', 'Identity verified
# 4                         3 Reviews', 'Identity verified
# 5                                              5 Reviews
# 7      21 Reviews', 'Identity verified', '\U000f0003'...
# 8                                      Identity verified
# 9                                      Identity verified
# 12     74 Reviews', 'Identity verified', '\U000f0003'...
# 16                        6 Reviews', 'Identity verified
# 17                        3 Reviews', 'Identity verified
# 19                                     Identity verified
# 20                       21 Reviews', 'Identity verified
# 22                                     Identity verified
# 23                        4 Reviews', 'Identity verified
# 26     27 Reviews', 'Identity verified', '\U000f0003'...
# ...

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Identity verified" in  hotel_full_Tsaxkadzor.host_identity_verified[i]:
        hotel_full_Tsaxkadzor.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Tsaxkadzor.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Tsaxkadzor
# Out:
#             city  country                                               name  \
# 1    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 2    Tsaghkadzor  Armenia                     Hillside Apartment Tsaghkadzor
# 3    Tsaghkadzor  Armenia    Beautiful hotel room in the city of Tsaghkadzor
# 4    Tsaghkadzor  Armenia                  Forest Castle Tsaghkadzor (Villa)
# 5    Tsaghkadzor  Armenia                            Crown Hotel Tsaghkadzor
# 7    Tsaghkadzor  Armenia   Mountain view apartment Квартира с видом на горы
# 8    Tsaghkadzor  Armenia                               Tsaghkadzor Homeland
# 9    Tsaghkadzor  Armenia               Villa with three separate apartments
# 12   Tsaghkadzor  Armenia                          Alaska Resort Tsaghkadzor
# 16   Tsaghkadzor  Armenia                      Вилла Provence in Tsakhkadzor
# 17   Tsaghkadzor  Armenia   Forest Castle Tsaghkadzor ( Cozy Vacation Home )
# ...

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Review" in  hotel_full_Tsaxkadzor.review[i]:
        hotel_full_Tsaxkadzor.loc[i, 'review'] = re.search("(\d+)", hotel_full_Tsaxkadzor.review[i]).group()
        
    else:
        hotel_full_Tsaxkadzor.loc[i, 'review'] = 0

# %%
hotel_full_Tsaxkadzor
# Out:
#             city  country                                               name  \
# 1    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 2    Tsaghkadzor  Armenia                     Hillside Apartment Tsaghkadzor
# 3    Tsaghkadzor  Armenia    Beautiful hotel room in the city of Tsaghkadzor
# 4    Tsaghkadzor  Armenia                  Forest Castle Tsaghkadzor (Villa)
# 5    Tsaghkadzor  Armenia                            Crown Hotel Tsaghkadzor
# 7    Tsaghkadzor  Armenia   Mountain view apartment Квартира с видом на горы
# 8    Tsaghkadzor  Armenia                               Tsaghkadzor Homeland
# 9    Tsaghkadzor  Armenia               Villa with three separate apartments
# 12   Tsaghkadzor  Armenia                          Alaska Resort Tsaghkadzor
# 16   Tsaghkadzor  Armenia                      Вилла Provence in Tsakhkadzor
# 17   Tsaghkadzor  Armenia   Forest Castle Tsaghkadzor ( Cozy Vacation Home )
# ...

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Superhost" in  hotel_full_Tsaxkadzor.superhost[i]:
        hotel_full_Tsaxkadzor.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Tsaxkadzor.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Tsaxkadzor.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire condominium (condo)',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire villa',
#  'Room in hotel',
#  'Entire rental unit',
#  'Entire villa',
#  'Room in aparthotel',
#  'Entire cottage',
#  'Entire villa',
#  'Entire residential home',
#  'Entire serviced apartment',
#  'Entire chalet',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire cottage',
#  'Entire townhouse',
#  'Entire rental unit',
#  'Entire villa',
#  'Entire villa',
#  'Entire residential home',
#  'Entire residential home',
#  'Entire villa',
#  'Entire residential home',
#  'Entire residential home',
#  'Entire residential home',
#  'Entire villa',
#  'Entire residential home',
#  'Entire residential home',
#  'Entire villa',
#  'Entire villa',
#  'Private room in serviced apartment',
#  'Shared room in hostel',
#  'Entire residential home',
#  'Entire residential home',
#  'Shared room in hostel',
#  'Entire residential home',
# ...

# %%
hotel_full_Tsaxkadzor.property_type =prop_list

# %%
hotel_full_Tsaxkadzor
# Out:
#             city  country                                               name  \
# 1    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 2    Tsaghkadzor  Armenia                     Hillside Apartment Tsaghkadzor
# 3    Tsaghkadzor  Armenia    Beautiful hotel room in the city of Tsaghkadzor
# 4    Tsaghkadzor  Armenia                  Forest Castle Tsaghkadzor (Villa)
# 5    Tsaghkadzor  Armenia                            Crown Hotel Tsaghkadzor
# 7    Tsaghkadzor  Armenia   Mountain view apartment Квартира с видом на горы
# 8    Tsaghkadzor  Armenia                               Tsaghkadzor Homeland
# 9    Tsaghkadzor  Armenia               Villa with three separate apartments
# 12   Tsaghkadzor  Armenia                          Alaska Resort Tsaghkadzor
# 16   Tsaghkadzor  Armenia                      Вилла Provence in Tsakhkadzor
# 17   Tsaghkadzor  Armenia   Forest Castle Tsaghkadzor ( Cozy Vacation Home )
# ...

# %%
accomodates_list = []
for i in hotel_full_Tsaxkadzor.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Tsaxkadzor.accomodates = number

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Shared half-bath" in  hotel_full_Tsaxkadzor.number_bathroom[i]:
        hotel_full_Tsaxkadzor.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Tsaxkadzor.number_bathroom[i]:
        hotel_full_Tsaxkadzor.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Tsaxkadzor.number_bathroom[i]:
        hotel_full_Tsaxkadzor.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Tsaxkadzor.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Tsaxkadzor.number_bedroom[i])
        hotel_full_Tsaxkadzor.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Tsaxkadzor.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Tsaxkadzor.number_bedroom[i])
        hotel_full_Tsaxkadzor.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Tsaxkadzor.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Tsaxkadzor.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Tsaxkadzor.index:
    if "bed" in  hotel_full_Tsaxkadzor.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Tsaxkadzor.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Tsaxkadzor.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['1',
#  '1',
#  '1',
#  '9',
#  '1',
#  '4',
#  '4',
#  '9',
#  '5',
#  '4',
#  '7',
#  '3',
#  '4',
#  '3',
#  '3',
#  '1',
#  '4',
#  '6',
#  '1',
#  '2',
#  '10',
#  '6',
#  '5',
#  '8',
#  '6',
#  '8',
#  '6',
#  '12',
#  '6',
#  '10',
#  '7',
#  '10',
#  '1',
#  '4',
#  '12',
#  '6',
#  '4',
#  '16',
#  '7',
#  '1',
#  '6',
#  '4',
#  '3',
#  '1',
#  '4',
#  '5',
#  '4',
#  '5',
#  '2',
#  '9',
#  '2',
#  '2',
#  '3']

# %%
len(hotel_full_Tsaxkadzor.number_beds)
# Out:
# 53

# %%
len(number_beds_list)
# Out:
# 53

# %%
hotel_full_Tsaxkadzor.number_beds = number_beds_list

# %%
hotel_full_Tsaxkadzor.number_beds
# Out:
# 1       1
# 2       1
# 3       1
# 4       9
# 5       1
# 7       4
# 8       4
# 9       9
# 12      5
# 16      4
# 17      7
# 19      3
# 20      4
# 22      3
# 23      3
# 26      1
# 28      4
# 29      6
# 34      1
# 43      2
# 44     10
# 46      6
# 47      5
# 48      8
# 51      6
# 54      8
# 55      6
# 57     12
# 61      6
# 66     10
# 72      7
# 73     10
# 75      1
# 77      4
# 78     12
# 79      6
# 82      4
# 84     16
# 85      7
# 86      1
# 88      6
# 89      4
# 95      3
# 97      1
# 102     4
# 104     5
# 106     4
# 107     5
# 108     2
# 111     9
# 112     2
# 113     2
# 114     3
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Studio" in  hotel_full_Tsaxkadzor.number_bedroom[i]:
        hotel_full_Tsaxkadzor.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Tsaxkadzor.number_bedroom[i])
        hotel_full_Tsaxkadzor.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Cleanliness" in  hotel_full_Tsaxkadzor.cleanliness[i]:
        hotel_full_Tsaxkadzor.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Tsaxkadzor.cleanliness[i])
    else:
        hotel_full_Tsaxkadzor.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Accuracy" in  hotel_full_Tsaxkadzor.accuracy[i]:
        hotel_full_Tsaxkadzor.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Tsaxkadzor.accuracy[i])
    else:
        hotel_full_Tsaxkadzor.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Communication" in  hotel_full_Tsaxkadzor.communication[i]:
        hotel_full_Tsaxkadzor.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Tsaxkadzor.communication[i])
    else:
        hotel_full_Tsaxkadzor.loc[i, 'communication'] = None

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Location" in  hotel_full_Tsaxkadzor.location[i]:
        try:
            hotel_full_Tsaxkadzor.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Tsaxkadzor.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Tsaxkadzor.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Tsaxkadzor.location[i])
    
    else:
        hotel_full_Tsaxkadzor.loc[i, 'location'] = None

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Check-in" in  hotel_full_Tsaxkadzor.check_in[i]:
        hotel_full_Tsaxkadzor.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Tsaxkadzor.check_in[i])
    else:
        hotel_full_Tsaxkadzor.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Value" in  hotel_full_Tsaxkadzor.value[i]:
        hotel_full_Tsaxkadzor.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Tsaxkadzor.value[i])
    else:
        hotel_full_Tsaxkadzor.loc[i, 'value'] = None

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "No reviews (yet)" in  hotel_full_Tsaxkadzor.rating[i]:
        hotel_full_Tsaxkadzor.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Tsaxkadzor.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Tsaxkadzor.price = price_list

# %%
for i in hotel_full_Tsaxkadzor.index:
    if "Response rate" in  hotel_full_Tsaxkadzor.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Tsaxkadzor.host_response_rate[i])
        hotel_full_Tsaxkadzor.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Tsaxkadzor.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Tsaxkadzor = hotel_full_Tsaxkadzor.astype(convert_dict)

# %%
hotel_full_Tsaxkadzor.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Tsaxkadzor.to_csv("cleaned_hotel_full_Tsaxkadzor.csv", index=False)
hotel_full_Tsaxkadzor.to_excel("cleaned_hotel_full_Tsaxkadzor2.xlsx", index=False)
