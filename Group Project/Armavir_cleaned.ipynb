# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Armavir = pd.read_csv('hotel_full_Armavir.csv')
hotel_full_Armavir
# Out:
#                                    city                             country  \
# 0                                   NaN                                 NaN
# 1    Armavir, Armavir Province, Armenia  Armavir, Armavir Province, Armenia
# 2                      Yerevan, Armenia                    Yerevan, Armenia
# 3                      Yerevan, Armenia                    Yerevan, Armenia
# 4                      Yerevan, Armenia                    Yerevan, Armenia
# ..                                  ...                                 ...
# 294                    Yerevan, Armenia                    Yerevan, Armenia
# 295                    Yerevan, Armenia                    Yerevan, Armenia
# 296                    Yerevan, Armenia                    Yerevan, Armenia
# 297                    Yerevan, Armenia                    Yerevan, Armenia
# 298                    Yerevan, Armenia                    Yerevan, Armenia
#
# ...

# %%
hotel_full_Armavir = hotel_full_Armavir.drop(labels = 0, axis = 0)
hotel_full_Armavir
# Out:
#                                    city                             country  \
# 1    Armavir, Armavir Province, Armenia  Armavir, Armavir Province, Armenia
# 2                      Yerevan, Armenia                    Yerevan, Armenia
# 3                      Yerevan, Armenia                    Yerevan, Armenia
# 4                      Yerevan, Armenia                    Yerevan, Armenia
# 5                      Yerevan, Armenia                    Yerevan, Armenia
# ..                                  ...                                 ...
# 294                    Yerevan, Armenia                    Yerevan, Armenia
# 295                    Yerevan, Armenia                    Yerevan, Armenia
# 296                    Yerevan, Armenia                    Yerevan, Armenia
# 297                    Yerevan, Armenia                    Yerevan, Armenia
# 298                    Yerevan, Armenia                    Yerevan, Armenia
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Armavir.replace("", nan_value, inplace = True)
hotel_full_Armavir.dropna(inplace= True)
hotel_full_Armavir
# Out:
#                           city                    country  \
# 3             Yerevan, Armenia           Yerevan, Armenia
# 4             Yerevan, Armenia           Yerevan, Armenia
# 5             Yerevan, Armenia           Yerevan, Armenia
# 6             Yerevan, Armenia           Yerevan, Armenia
# 8    Yerevan, Armenia, Armenia  Yerevan, Armenia, Armenia
# ..                         ...                        ...
# 291           Yerevan, Armenia           Yerevan, Armenia
# 292           Yerevan, Armenia           Yerevan, Armenia
# 293           Yerevan, Armenia           Yerevan, Armenia
# 295           Yerevan, Armenia           Yerevan, Armenia
# 297           Yerevan, Armenia           Yerevan, Armenia
#
#                                                   name  \
# 3             КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 5                                     Moris&Sona house
# ...

# %%
hotel_full_Armavir["city"]= hotel_full_Armavir["city"].replace({"Armavir, Armavir Province, Armenia" : "Armavir, Armenia"})

# %%
hotel_full_Armavir["city"]= hotel_full_Armavir["city"].replace({"Yerevan, Armenia, Armenia" : "Yerevan, Armenia"})

# %%
hotel_full_Armavir["city"]= hotel_full_Armavir["city"].replace({"Ереван, United States" : "Yerevan, Armenia"})

# %%
hotel_full_Armavir["city"]= hotel_full_Armavir["city"].replace({"Երևան, Armenia" : "Yerevan, Armenia"})

# %%
city_list = []
for i in hotel_full_Armavir.index:
    text = re.sub(",", "", hotel_full_Armavir["city"][i][:hotel_full_Armavir["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_
host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Armavir.host_since = hs 
hotel_full_Armavir.host_since
# Out:
# 3      2018
# 4      2020
# 5      2014
# 6      2015
# 8      2014
#        ...
# 291    2013
# 292    2017
# 293    2018
# 295    2016
# 297    2015
# Name: host_since, Length: 230, dtype: int64

# %%
hotel_full_Armavir
# Out:
#         city  country                                               name  \
# 3    Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    Yerevan  Armenia  ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 5    Yerevan  Armenia                                   Moris&Sona house
# 6    Yerevan  Armenia    The loft apartment in front of the Central Bank
# 8    Yerevan  Armenia                 Quiet apartment in the city center
# ..       ...      ...                                                ...
# 291  Yerevan  Armenia        Modern and nice apartment near Republic sq.
# 292  Yerevan  Armenia                          Cozy 2 storey guest house
# 293  Yerevan  Armenia            Уютная квартира студия в центре Еревана
# 295  Yerevan  Armenia             Tripple room in a cozy guesthouse N3:)
# 297  Yerevan  Armenia                          Opera Apartment in centre
#
#      host_since                                 host_response_rate  \
# ...

# %%
string = []
for i in hotel_full_Armavir.index:
    st = hotel_full_Armavir.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["97 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "191 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "395 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "152 Reviews', 'Identity verified",
#  "137 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "39 Reviews', '\\U000f0003', 'Superhost",
#  "39 Reviews', '\\U000f0003', 'Superhost",
#  "7 Reviews', 'Identity verified",
#  "333 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "69 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "47 Reviews', 'Identity verified",
#  "191 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "191 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "31 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  '1 Review',
#  "14 Reviews', '\\U000f0003', 'Superhost",
#  "13 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "191 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
# ...

# %%
hotel_full_Armavir.host_identity_verified = string
hotel_full_Armavir.host_identity_verified
# Out:
# 3      97 Reviews', 'Identity verified', '\U000f0003'...
# 4      191 Reviews', 'Identity verified', '\U000f0003...
# 5      395 Reviews', 'Identity verified', '\U000f0003...
# 6                       152 Reviews', 'Identity verified
# 8      137 Reviews', 'Identity verified', '\U000f0003...
#                              ...
# 291    341 Reviews', 'Identity verified', '\U000f0003...
# 292    39 Reviews', 'Identity verified', 'Airbnb.org ...
# 293                      35 Reviews', 'Identity verified
# 295                     132 Reviews', 'Identity verified
# 297    219 Reviews', 'Identity verified', '\U000f0003...
# Name: host_identity_verified, Length: 230, dtype: object

# %%
for i in hotel_full_Armavir.index:
    if "Identity verified" in  hotel_full_Armavir.host_identity_verified[i]:
        hotel_full_Armavir.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Armavir.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Armavir
# Out:
#         city  country                                               name  \
# 3    Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    Yerevan  Armenia  ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 5    Yerevan  Armenia                                   Moris&Sona house
# 6    Yerevan  Armenia    The loft apartment in front of the Central Bank
# 8    Yerevan  Armenia                 Quiet apartment in the city center
# ..       ...      ...                                                ...
# 291  Yerevan  Armenia        Modern and nice apartment near Republic sq.
# 292  Yerevan  Armenia                          Cozy 2 storey guest house
# 293  Yerevan  Armenia            Уютная квартира студия в центре Еревана
# 295  Yerevan  Armenia             Tripple room in a cozy guesthouse N3:)
# 297  Yerevan  Armenia                          Opera Apartment in centre
#
#      host_since                                 host_response_rate  \
# ...

# %%
for i in hotel_full_Armavir.index:
    if "Review" in  hotel_full_Armavir.review[i]:
        hotel_full_Armavir.loc[i, 'review'] = re.search("(\d+)", hotel_full_Armavir.review[i]).group()
        
    else:
        hotel_full_Armavir.loc[i, 'review'] = 0

# %%
hotel_full_Armavir
# Out:
#         city  country                                               name  \
# 3    Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    Yerevan  Armenia  ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 5    Yerevan  Armenia                                   Moris&Sona house
# 6    Yerevan  Armenia    The loft apartment in front of the Central Bank
# 8    Yerevan  Armenia                 Quiet apartment in the city center
# ..       ...      ...                                                ...
# 291  Yerevan  Armenia        Modern and nice apartment near Republic sq.
# 292  Yerevan  Armenia                          Cozy 2 storey guest house
# 293  Yerevan  Armenia            Уютная квартира студия в центре Еревана
# 295  Yerevan  Armenia             Tripple room in a cozy guesthouse N3:)
# 297  Yerevan  Armenia                          Opera Apartment in centre
#
#      host_since                                 host_response_rate  \
# ...

# %%
for i in hotel_full_Armavir.index:
    if "Superhost" in  hotel_full_Armavir.superhost[i]:
        hotel_full_Armavir.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Armavir.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Armavir.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire guesthouse',
#  'Entire loft',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Entire rental unit  Авет',
#  'Entire serviced apartment',
#  'Entire residential home',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Entire rental unit  Авет',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire rental unit  Inn',
# ...

# %%
hotel_full_Armavir.property_type =prop_list

# %%
hotel_full_Armavir
# Out:
#         city  country                                               name  \
# 3    Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 4    Yerevan  Armenia  ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 5    Yerevan  Armenia                                   Moris&Sona house
# 6    Yerevan  Armenia    The loft apartment in front of the Central Bank
# 8    Yerevan  Armenia                 Quiet apartment in the city center
# ..       ...      ...                                                ...
# 291  Yerevan  Armenia        Modern and nice apartment near Republic sq.
# 292  Yerevan  Armenia                          Cozy 2 storey guest house
# 293  Yerevan  Armenia            Уютная квартира студия в центре Еревана
# 295  Yerevan  Armenia             Tripple room in a cozy guesthouse N3:)
# 297  Yerevan  Armenia                          Opera Apartment in centre
#
#      host_since                                 host_response_rate  \
# ...

# %%
accomodates_list = []
for i in hotel_full_Armavir.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Armavir.accomodates = number

# %%
for i in hotel_full_Armavir.index:
    if "Shared half-bath" in  hotel_full_Armavir.number_bathroom[i]:
        hotel_full_Armavir.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Armavir.number_bathroom[i]:
        hotel_full_Armavir.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Armavir.number_bathroom[i]:
        hotel_full_Armavir.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Armavir.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Armavir.number_bedroom[i])
        hotel_full_Armavir.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Armavir.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Armavir.number_bedroom[i])
        hotel_full_Armavir.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Armavir.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Armavir.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Armavir.index:
    if "bed" in  hotel_full_Armavir.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Armavir.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Armavir.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['1',
#  '1',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '2',
#  '1',
#  '4',
#  '1',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '3',
#  '3',
#  '1',
#  '2',
#  '1',
#  '3',
#  '4',
#  '1',
#  '1',
#  '2',
#  '3',
#  '1',
#  '3',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '2',
#  '3',
#  '2',
#  '1',
#  '4',
#  '2',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '2',
#  '3',
#  '1',
#  '2',
#  '0',
#  '1',
#  '1',
#  '1',
#  '3',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '3',
#  '2',
#  '4',
#  '2',
#  '1',
#  '1',
#  '2',
#  '3',
#  '2',
#  '1',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '3',
#  '8',
#  '2',
#  '2',
#  '1',
#  '3',
#  '2',
#  '3',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '3',
#  '2',
#  '4',
#  '2',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
# ...

# %%
len(hotel_full_Armavir.number_beds)
# Out:
# 230

# %%
len(number_beds_list)
# Out:
# 230

# %%
hotel_full_Armavir.number_beds = number_beds_list

# %%
hotel_full_Armavir.number_beds
# Out:
# 3      1
# 4      1
# 5      2
# 6      2
# 8      1
#       ..
# 291    2
# 292    2
# 293    1
# 295    3
# 297    1
# Name: number_beds, Length: 230, dtype: object

# %%
for i in hotel_full_Armavir.index:
    if "Studio" in  hotel_full_Armavir.number_bedroom[i]:
        hotel_full_Armavir.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Armavir.number_bedroom[i])
        hotel_full_Armavir.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Armavir.index:
    if "Cleanliness" in  hotel_full_Armavir.cleanliness[i]:
        hotel_full_Armavir.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Armavir.cleanliness[i])
    else:
        hotel_full_Armavir.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Armavir.index:
    if "Accuracy" in  hotel_full_Armavir.accuracy[i]:
        hotel_full_Armavir.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Armavir.accuracy[i])
    else:
        hotel_full_Armavir.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Armavir.index:
    if "Communication" in  hotel_full_Armavir.communication[i]:
        hotel_full_Armavir.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Armavir.communication[i])
    else:
        hotel_full_Armavir.loc[i, 'communication'] = None

# %%
for i in hotel_full_Armavir.index:
    if "Location" in  hotel_full_Armavir.location[i]:
        try:
            hotel_full_Armavir.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Armavir.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Armavir.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Armavir.location[i])
    
    else:
        hotel_full_Armavir.loc[i, 'location'] = None

# %%
for i in hotel_full_Armavir.index:
    if "Check-in" in  hotel_full_Armavir.check_in[i]:
        hotel_full_Armavir.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Armavir.check_in[i])
    else:
        hotel_full_Armavir.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Armavir.index:
    if "Value" in  hotel_full_Armavir.value[i]:
        hotel_full_Armavir.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Armavir.value[i])
    else:
        hotel_full_Armavir.loc[i, 'value'] = None

# %%
for i in hotel_full_Armavir.index:
    if "No reviews (yet)" in  hotel_full_Armavir.rating[i]:
        hotel_full_Armavir.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Armavir.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Armavir.price = price_list

# %%
for i in hotel_full_Armavir.index:
    if "Response rate" in  hotel_full_Armavir.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Armavir.host_response_rate[i])
        hotel_full_Armavir.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Armavir.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Armavir = hotel_full_Armavir.astype(convert_dict)

# %%
hotel_full_Armavir.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Armavir.to_csv("cleaned_hotel_full_Armavir.csv", index=False)
hotel_full_Armavir.to_excel("cleaned_hotel_full_Armavir2.xlsx", index=False)
