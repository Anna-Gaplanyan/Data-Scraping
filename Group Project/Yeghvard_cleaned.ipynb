# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Yeghvard = pd.read_csv('hotel_full_Yeghvard.csv')
hotel_full_Yeghvard
# Out:
#                          city                    country  \
# 0                         NaN                        NaN
# 1            Yerevan, Armenia           Yerevan, Armenia
# 2            Yerevan, Armenia           Yerevan, Armenia
# 3   Yegvard Province, Armenia  Yegvard Province, Armenia
# 4            Yerevan, Armenia           Yerevan, Armenia
# ..                        ...                        ...
# 90           Yerevan, Armenia           Yerevan, Armenia
# 91           Yerevan, Armenia           Yerevan, Armenia
# 92           Yerevan, Armenia           Yerevan, Armenia
# 93    Arinj, Yerevan, Armenia    Arinj, Yerevan, Armenia
# 94           Yerevan, Armenia           Yerevan, Armenia
#
#                                                  name  \
# 0                                                 NaN
# 1                                        Emma's place
# 2                                 Great place to live
# 3   1 BDR house - sleeps 4, facing Ararat in Yeghv...
# ...

# %%
hotel_full_Yeghvard = hotel_full_Yeghvard.drop(labels = 0, axis = 0)
hotel_full_Yeghvard
# Out:
#                                  city                            country  \
# 1                    Yerevan, Armenia                   Yerevan, Armenia
# 2                    Yerevan, Armenia                   Yerevan, Armenia
# 3           Yegvard Province, Armenia          Yegvard Province, Armenia
# 4                    Yerevan, Armenia                   Yerevan, Armenia
# 5   Yerevan, Kotayk Province, Armenia  Yerevan, Kotayk Province, Armenia
# ..                                ...                                ...
# 90                   Yerevan, Armenia                   Yerevan, Armenia
# 91                   Yerevan, Armenia                   Yerevan, Armenia
# 92                   Yerevan, Armenia                   Yerevan, Armenia
# 93            Arinj, Yerevan, Armenia            Arinj, Yerevan, Armenia
# 94                   Yerevan, Armenia                   Yerevan, Armenia
#
#                                                  name  \
# ...

# %%
nan_value = float("Nan")
hotel_full_Yeghvard.replace("", nan_value, inplace = True)
hotel_full_Yeghvard.dropna(inplace= True)
hotel_full_Yeghvard
# Out:
#                                    city                              country  \
# 1                      Yerevan, Armenia                     Yerevan, Armenia
# 5     Yerevan, Kotayk Province, Armenia    Yerevan, Kotayk Province, Armenia
# 11                     Yerevan, Armenia                     Yerevan, Armenia
# 13                     Yerevan, Armenia                     Yerevan, Armenia
# 15                     Yerevan, Armenia                     Yerevan, Armenia
# 16                     Yerevan, Armenia                     Yerevan, Armenia
# 17                     Yerevan, Armenia                     Yerevan, Armenia
# 18                     Yerevan, Armenia                     Yerevan, Armenia
# 20                     Yerevan, Armenia                     Yerevan, Armenia
# 21                     Yerevan, Armenia                     Yerevan, Armenia
# 22                     Yerevan, Armenia                     Yerevan, Armenia
# ...

# %%
hotel_full_Yeghvard["city"]= hotel_full_Yeghvard["city"].replace({"Երևան, Yerevan, Armenia" : "Yerevan, Armenia"})

# %%
hotel_full_Yeghvard["city"]= hotel_full_Yeghvard["city"].replace({"Ереван, Armenia, Armenia" : "Yerevan, Armenia"})

# %%
hotel_full_Yeghvard["city"]= hotel_full_Yeghvard["city"].replace({"Երևան, Armenia" : "Yerevan, Armenia"})

# %%
city_list = []
for i in hotel_full_Yeghvard.index:
    text = re.sub(",", "", hotel_full_Yeghvard["city"][i][:hotel_full_Yeghvard["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_
host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Yeghvard.host_since = hs 
hotel_full_Yeghvard.host_since
# Out:
# 1     2017
# 5     2016
# 11    2018
# 13    2014
# 15    2013
# 16    2020
# 17    2019
# 18    2019
# 20    2018
# 21    2019
# 22    2018
# 23    2019
# 25    2021
# 27    2012
# 28    2017
# 29    2017
# 33    2016
# 37    2018
# 41    2015
# 45    2021
# 48    2018
# 50    2019
# 54    2015
# 58    2021
# 59    2021
# 61    2021
# 69    2015
# 74    2017
# 75    2015
# 85    2016
# 90    2019
# 94    2015
# Name: host_since, dtype: int64

# %%
hotel_full_Yeghvard
# Out:
#          city  country                                               name  \
# 1     Yerevan  Armenia                                       Emma's place
# 5     Yerevan  Armenia                                   Yerkir eco house
# 11    Yerevan  Armenia       Welcome to my Cosy, Comfy, Corner in Yerevan
# 13    Yerevan  Armenia           New renovated Luxury 1 bedroom apartment
# 15    Yerevan  Armenia                          New cozy apartment Adonts
# 16    Yerevan  Armenia     Beautiful Villa, pool, view to Ararat mountain
# 17    Yerevan  Armenia                                        комната 102
# 18    Yerevan  Armenia  Spacious deluxe apartment with garden - Davita...
# 20    Yerevan  Armenia                                  Квартира супер S1
# 21    Yerevan  Armenia  Spacious deluxe apartment with garden - Davita...
# 22    Yerevan  Armenia               Квартира суперская на севере Еревана
# 23    Yerevan  Armenia                                        комната 102
# ...

# %%
string = []
for i in hotel_full_Yeghvard.index:
    st = hotel_full_Yeghvard.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["53 Reviews', 'Identity verified",
#  "281 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "12 Reviews', 'Identity verified",
#  "88 Reviews', '\\U000f0003', 'Superhost",
#  "7 Reviews', 'Identity verified",
#  'Identity verified',
#  'Identity verified',
#  'Identity verified',
#  "6 Reviews', 'Identity verified",
#  'Identity verified',
#  "6 Reviews', 'Identity verified",
#  'Identity verified',
#  'Identity verified',
#  'Identity verified',
#  'Identity verified',
#  "6 Reviews', 'Identity verified",
#  '2 Reviews',
#  '5 Reviews',
#  "110 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  'Identity verified',
#  "6 Reviews', 'Identity verified",
#  'Identity verified',
#  "110 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  'Identity verified',
#  'Identity verified',
#  'Identity verified',
#  'Identity verified',
#  "1 Review', 'Identity verified",
#  "4 Reviews', 'Identity verified",
#  "1 Review', 'Identity verified",
# ...

# %%
hotel_full_Yeghvard.host_identity_verified = string
hotel_full_Yeghvard.host_identity_verified
# Out:
# 1                       53 Reviews', 'Identity verified
# 5     281 Reviews', 'Identity verified', '\U000f0003...
# 11                      12 Reviews', 'Identity verified
# 13                88 Reviews', '\U000f0003', 'Superhost
# 15                       7 Reviews', 'Identity verified
# 16                                    Identity verified
# 17                                    Identity verified
# 18                                    Identity verified
# 20                       6 Reviews', 'Identity verified
# 21                                    Identity verified
# 22                       6 Reviews', 'Identity verified
# 23                                    Identity verified
# 25                                    Identity verified
# 27                                    Identity verified
# 28                                    Identity verified
# 29                       6 Reviews', 'Identity verified
# 33                                            2 Reviews
# ...

# %%
for i in hotel_full_Yeghvard.index:
    if "Identity verified" in  hotel_full_Yeghvard.host_identity_verified[i]:
        hotel_full_Yeghvard.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Yeghvard.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Yeghvard
# Out:
#          city  country                                               name  \
# 1     Yerevan  Armenia                                       Emma's place
# 5     Yerevan  Armenia                                   Yerkir eco house
# 11    Yerevan  Armenia       Welcome to my Cosy, Comfy, Corner in Yerevan
# 13    Yerevan  Armenia           New renovated Luxury 1 bedroom apartment
# 15    Yerevan  Armenia                          New cozy apartment Adonts
# 16    Yerevan  Armenia     Beautiful Villa, pool, view to Ararat mountain
# 17    Yerevan  Armenia                                        комната 102
# 18    Yerevan  Armenia  Spacious deluxe apartment with garden - Davita...
# 20    Yerevan  Armenia                                  Квартира супер S1
# 21    Yerevan  Armenia  Spacious deluxe apartment with garden - Davita...
# 22    Yerevan  Armenia               Квартира суперская на севере Еревана
# 23    Yerevan  Armenia                                        комната 102
# ...

# %%
for i in hotel_full_Yeghvard.index:
    if "Review" in  hotel_full_Yeghvard.review[i]:
        hotel_full_Yeghvard.loc[i, 'review'] = re.search("(\d+)", hotel_full_Yeghvard.review[i]).group()
        
    else:
        hotel_full_Yeghvard.loc[i, 'review'] = 0

# %%
hotel_full_Yeghvard
# Out:
#          city  country                                               name  \
# 1     Yerevan  Armenia                                       Emma's place
# 5     Yerevan  Armenia                                   Yerkir eco house
# 11    Yerevan  Armenia       Welcome to my Cosy, Comfy, Corner in Yerevan
# 13    Yerevan  Armenia           New renovated Luxury 1 bedroom apartment
# 15    Yerevan  Armenia                          New cozy apartment Adonts
# 16    Yerevan  Armenia     Beautiful Villa, pool, view to Ararat mountain
# 17    Yerevan  Armenia                                        комната 102
# 18    Yerevan  Armenia  Spacious deluxe apartment with garden - Davita...
# 20    Yerevan  Armenia                                  Квартира супер S1
# 21    Yerevan  Armenia  Spacious deluxe apartment with garden - Davita...
# 22    Yerevan  Armenia               Квартира суперская на севере Еревана
# 23    Yerevan  Armenia                                        комната 102
# ...

# %%
for i in hotel_full_Yeghvard.index:
    if "Superhost" in  hotel_full_Yeghvard.superhost[i]:
        hotel_full_Yeghvard.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Yeghvard.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Yeghvard.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire guesthouse',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire residential home',
#  'Room in hotel',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Room in hotel',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire villa',
#  'Private room in residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire residential home',
#  'Entire villa',
#  'Entire rental unit',
#  'Room in hotel',
#  'Entire villa',
#  'Entire villa',
#  'Entire residential home',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Private room in bed and breakfast',
#  'Private room in rental unit',
#  'Shared room in rental unit',
#  'Entire guest suite']

# %%
hotel_full_Yeghvard.property_type =prop_list

# %%
hotel_full_Yeghvard
# Out:
#          city  country                                               name  \
# 1     Yerevan  Armenia                                       Emma's place
# 5     Yerevan  Armenia                                   Yerkir eco house
# 11    Yerevan  Armenia       Welcome to my Cosy, Comfy, Corner in Yerevan
# 13    Yerevan  Armenia           New renovated Luxury 1 bedroom apartment
# 15    Yerevan  Armenia                          New cozy apartment Adonts
# 16    Yerevan  Armenia     Beautiful Villa, pool, view to Ararat mountain
# 17    Yerevan  Armenia                                        комната 102
# 18    Yerevan  Armenia  Spacious deluxe apartment with garden - Davita...
# 20    Yerevan  Armenia                                  Квартира супер S1
# 21    Yerevan  Armenia  Spacious deluxe apartment with garden - Davita...
# 22    Yerevan  Armenia               Квартира суперская на севере Еревана
# 23    Yerevan  Armenia                                        комната 102
# ...

# %%
accomodates_list = []
for i in hotel_full_Yeghvard.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Yeghvard.accomodates = number

# %%
for i in hotel_full_Yeghvard.index:
    if "Shared half-bath" in  hotel_full_Yeghvard.number_bathroom[i]:
        hotel_full_Yeghvard.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Yeghvard.number_bathroom[i]:
        hotel_full_Yeghvard.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Yeghvard.number_bathroom[i]:
        hotel_full_Yeghvard.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Yeghvard.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Yeghvard.number_bedroom[i])
        hotel_full_Yeghvard.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Yeghvard.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Yeghvard.number_bedroom[i])
        hotel_full_Yeghvard.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Yeghvard.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Yeghvard.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Yeghvard.index:
    if "bed" in  hotel_full_Yeghvard.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Yeghvard.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Yeghvard.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['2',
#  '4',
#  '1',
#  '2',
#  '4',
#  '4',
#  '1',
#  '3',
#  '0',
#  '3',
#  '3',
#  '1',
#  '2',
#  '2',
#  '7',
#  '6',
#  '1',
#  '2',
#  '10',
#  '5',
#  '3',
#  '1',
#  '5',
#  '5',
#  '1',
#  '1',
#  '2',
#  '1',
#  '25',
#  '1',
#  '1',
#  '6']

# %%
len(hotel_full_Yeghvard.number_beds)
# Out:
# 32

# %%
len(number_beds_list)
# Out:
# 32

# %%
hotel_full_Yeghvard.number_beds = number_beds_list

# %%
hotel_full_Yeghvard.number_beds
# Out:
# 1      2
# 5      4
# 11     1
# 13     2
# 15     4
# 16     4
# 17     1
# 18     3
# 20     0
# 21     3
# 22     3
# 23     1
# 25     2
# 27     2
# 28     7
# 29     6
# 33     1
# 37     2
# 41    10
# 45     5
# 48     3
# 50     1
# 54     5
# 58     5
# 59     1
# 61     1
# 69     2
# 74     1
# 75    25
# 85     1
# 90     1
# 94     6
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Yeghvard.index:
    if "Studio" in  hotel_full_Yeghvard.number_bedroom[i]:
        hotel_full_Yeghvard.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Yeghvard.number_bedroom[i])
        hotel_full_Yeghvard.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Yeghvard.index:
    if "Cleanliness" in  hotel_full_Yeghvard.cleanliness[i]:
        hotel_full_Yeghvard.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Yeghvard.cleanliness[i])
    else:
        hotel_full_Yeghvard.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Yeghvard.index:
    if "Accuracy" in  hotel_full_Yeghvard.accuracy[i]:
        hotel_full_Yeghvard.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Yeghvard.accuracy[i])
    else:
        hotel_full_Yeghvard.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Yeghvard.index:
    if "Communication" in  hotel_full_Yeghvard.communication[i]:
        hotel_full_Yeghvard.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Yeghvard.communication[i])
    else:
        hotel_full_Yeghvard.loc[i, 'communication'] = None

# %%
for i in hotel_full_Yeghvard.index:
    if "Location" in  hotel_full_Yeghvard.location[i]:
        try:
            hotel_full_Yeghvard.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Yeghvard.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Yeghvard.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Yeghvard.location[i])
    
    else:
        hotel_full_Yeghvard.loc[i, 'location'] = None

# %%
for i in hotel_full_Yeghvard.index:
    if "Check-in" in  hotel_full_Yeghvard.check_in[i]:
        hotel_full_Yeghvard.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Yeghvard.check_in[i])
    else:
        hotel_full_Yeghvard.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Yeghvard.index:
    if "Value" in  hotel_full_Yeghvard.value[i]:
        hotel_full_Yeghvard.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Yeghvard.value[i])
    else:
        hotel_full_Yeghvard.loc[i, 'value'] = None

# %%
for i in hotel_full_Yeghvard.index:
    if "No reviews (yet)" in  hotel_full_Yeghvard.rating[i]:
        hotel_full_Yeghvard.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Yeghvard.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Yeghvard.price = price_list

# %%
for i in hotel_full_Yeghvard.index:
    if "Response rate" in  hotel_full_Yeghvard.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Yeghvard.host_response_rate[i])
        hotel_full_Yeghvard.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Yeghvard.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Yeghvard = hotel_full_Yeghvard.astype(convert_dict)

# %%
hotel_full_Yeghvard.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Yeghvard.to_csv("cleaned_hotel_full_Yeghvard.csv", index=False)
hotel_full_Yeghvard.to_excel("cleaned_hotel_full_Yeghvard2.xlsx", index=False)
