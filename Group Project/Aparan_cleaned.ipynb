# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Aparan = pd.read_csv('hotel_full_Aparan.csv')
hotel_full_Aparan
# Out:
#                                       city  \
# 0                                      NaN
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2     Aparan, Aragatsotn Province, Armenia
# 3                         Yerevan, Armenia
# 4        Dilijan, Tavush Province, Armenia
# ..                                     ...
# 294                       Yerevan, Armenia
# 295                        Ереван, Armenia
# 296                       Yerevan, Armenia
# 297                       Yerevan, Armenia
# 298                       Yerevan, Armenia
#
#                                    country  \
# 0                                      NaN
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2     Aparan, Aragatsotn Province, Armenia
# 3                         Yerevan, Armenia
# 4        Dilijan, Tavush Province, Armenia
# ..                                     ...
# 294                       Yerevan, Armenia
# 295                        Ереван, Armenia
# 296                       Yerevan, Armenia
# ...

# %%
hotel_full_Aparan = hotel_full_Aparan.drop(labels = 0, axis = 0)
hotel_full_Aparan
# Out:
#                                       city  \
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2     Aparan, Aragatsotn Province, Armenia
# 3                         Yerevan, Armenia
# 4        Dilijan, Tavush Province, Armenia
# 5    Baghramyan, Armavir Province, Armenia
# ..                                     ...
# 294                       Yerevan, Armenia
# 295                        Ереван, Armenia
# 296                       Yerevan, Armenia
# 297                       Yerevan, Armenia
# 298                       Yerevan, Armenia
#
#                                    country  \
# 1    Tsaghkadzor, Kotayk Province, Armenia
# 2     Aparan, Aragatsotn Province, Armenia
# 3                         Yerevan, Armenia
# 4        Dilijan, Tavush Province, Armenia
# 5    Baghramyan, Armavir Province, Armenia
# ..                                     ...
# 294                       Yerevan, Armenia
# 295                        Ереван, Armenia
# 296                       Yerevan, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Aparan.replace("", nan_value, inplace = True)
hotel_full_Aparan.dropna(inplace= True)
hotel_full_Aparan
# Out:
#                                         city  \
# 1      Tsaghkadzor, Kotayk Province, Armenia
# 4          Dilijan, Tavush Province, Armenia
# 5      Baghramyan, Armavir Province, Armenia
# 6    Vagharshapat, Armavir Province, Armenia
# 7       Tegher, Aragatsotn Province, Armenia
# ..                                       ...
# 286                         Yerevan, Armenia
# 287                         Yerevan, Armenia
# 293                         Yerevan, Armenia
# 297                         Yerevan, Armenia
# 298                         Yerevan, Armenia
#
#                                      country  \
# 1      Tsaghkadzor, Kotayk Province, Armenia
# 4          Dilijan, Tavush Province, Armenia
# 5      Baghramyan, Armavir Province, Armenia
# 6    Vagharshapat, Armavir Province, Armenia
# 7       Tegher, Aragatsotn Province, Armenia
# ..                                       ...
# 286                         Yerevan, Armenia
# 287                         Yerevan, Armenia
# ...

# %%
hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Երևան, Armenia" : "Yerevan, Armenia"})
hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Гюмри, Армения, Armenia" : "Gyumri, Shirak Province, Armenia"})
hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Երևան, Yerevan, Armenia" : "Yerevan, Armenia"})

hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Yerevan, Armenia, Armenia" : "Yerevan, Armenia"})

hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Ереван, United States" : "Yerevan, Armenia"})

hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Ծաղկաձոր, Armenia" : "Tsaghkadzor, Kotayk Province, Armenia"})

hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Armenia" : "Yerevan, Armenia"})

hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Հրազդան, Կոտայք, Armenia" : "Hrazdan, Kotayk Province, Armenia"})

hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Դիլիջան, Տավուշի մարզ, Armenia" : "Dilijan, Tavush Province, Armenia"})
hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Ереван, Armenia" : "Yerevan, Armenia"})
hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Երևան, Yerevan, Armenia" : "Yerevan, Armenia"})
hotel_full_Aparan["city"]= hotel_full_Aparan["city"].replace({"Yerevan , Yerevan, Armenia" : "Yerevan, Armenia"})
hotel_full_Aparan
# Out:
#                                         city  \
# 1      Tsaghkadzor, Kotayk Province, Armenia
# 4          Dilijan, Tavush Province, Armenia
# 5      Baghramyan, Armavir Province, Armenia
# 6    Vagharshapat, Armavir Province, Armenia
# 7       Tegher, Aragatsotn Province, Armenia
# ..                                       ...
# 286                         Yerevan, Armenia
# 287                         Yerevan, Armenia
# 293                         Yerevan, Armenia
# 297                         Yerevan, Armenia
# 298                         Yerevan, Armenia
#
#                                      country  \
# 1      Tsaghkadzor, Kotayk Province, Armenia
# 4          Dilijan, Tavush Province, Armenia
# 5      Baghramyan, Armavir Province, Armenia
# 6    Vagharshapat, Armavir Province, Armenia
# 7       Tegher, Aragatsotn Province, Armenia
# ..                                       ...
# 286                         Yerevan, Armenia
# 287                         Yerevan, Armenia
# ...

# %%
city_list = []
for i in hotel_full_Aparan.index:
    text = re.sub(",", "", hotel_full_Aparan["city"][i][:hotel_full_Aparan["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Aparan["city"]= city_list
hotel_full_Aparan
# Out:
#                                city                                  country  \
# 1      Tsaghkadzor Kotayk Province     Tsaghkadzor, Kotayk Province, Armenia
# 4          Dilijan Tavush Province         Dilijan, Tavush Province, Armenia
# 5      Baghramyan Armavir Province     Baghramyan, Armavir Province, Armenia
# 6    Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 7       Tegher Aragatsotn Province      Tegher, Aragatsotn Province, Armenia
# ..                              ...                                      ...
# 286                        Yerevan                          Yerevan, Armenia
# 287                        Yerevan                          Yerevan, Armenia
# 293                        Yerevan                          Yerevan, Armenia
# 297                        Yerevan                          Yerevan, Armenia
# 298                        Yerevan                          Yerevan, Armenia
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Aparan.replace("", nan_value, inplace = True)
hotel_full_Aparan.dropna(inplace= True)
hotel_full_Aparan
# Out:
#                                city                                  country  \
# 1      Tsaghkadzor Kotayk Province     Tsaghkadzor, Kotayk Province, Armenia
# 4          Dilijan Tavush Province         Dilijan, Tavush Province, Armenia
# 5      Baghramyan Armavir Province     Baghramyan, Armavir Province, Armenia
# 6    Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 7       Tegher Aragatsotn Province      Tegher, Aragatsotn Province, Armenia
# ..                              ...                                      ...
# 286                        Yerevan                          Yerevan, Armenia
# 287                        Yerevan                          Yerevan, Armenia
# 293                        Yerevan                          Yerevan, Armenia
# 297                        Yerevan                          Yerevan, Armenia
# 298                        Yerevan                          Yerevan, Armenia
#
# ...

# %%
c_l = []    
for k in hotel_full_Aparan["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Aparan["city"]= c_l
hotel_full_Aparan
# Out:
#              city                                  country  \
# 1     Tsaghkadzor    Tsaghkadzor, Kotayk Province, Armenia
# 4         Dilijan        Dilijan, Tavush Province, Armenia
# 5      Baghramyan    Baghramyan, Armavir Province, Armenia
# 6    Vagharshapat  Vagharshapat, Armavir Province, Armenia
# 7          Tegher     Tegher, Aragatsotn Province, Armenia
# ..            ...                                      ...
# 286       Yerevan                         Yerevan, Armenia
# 287       Yerevan                         Yerevan, Armenia
# 293       Yerevan                         Yerevan, Armenia
# 297       Yerevan                         Yerevan, Armenia
# 298       Yerevan                         Yerevan, Armenia
#
#                                                   name  \
# 1    Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4     Cosy and comfortable apartment with a great view
# 5    Green paradise near Yerevan,free transfer,SIM ...
# ...

# %%
for i in hotel_full_Aparan.index:
    hotel_full_Aparan["country"][i] = "Armenia"

# %%
hotel_full_Aparan
# Out:
#              city  country                                               name  \
# 1     Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4         Dilijan  Armenia   Cosy and comfortable apartment with a great view
# 5      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 6    Vagharshapat  Armenia                                           Art home
# 7          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# ..            ...      ...                                                ...
# 286       Yerevan  Armenia                3-х комнатная на Северном проспекте
# 287       Yerevan  Armenia      Studio Apartment on Mashtots Street by Picnic
# 293       Yerevan  Armenia   Светлая квартира в центре Еревана YEREVAN centre
# 297       Yerevan  Armenia                                    Sunny apartment
# 298       Yerevan  Armenia      NEW Modern and Cozy Studio in the City Center
#
#                    host_since  \
# ...

# %%
host_since_list = []
for i in hotel_full_Aparan.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Aparan.host_since = hs 
hotel_full_Aparan.host_since
# Out:
# 1      2016
# 4      2018
# 5      2019
# 6      2019
# 7      2015
#        ...
# 286    2020
# 287    2017
# 293    2014
# 297    2018
# 298    2017
# Name: host_since, Length: 225, dtype: int64

# %%
hotel_full_Aparan
# Out:
#              city  country                                               name  \
# 1     Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4         Dilijan  Armenia   Cosy and comfortable apartment with a great view
# 5      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 6    Vagharshapat  Armenia                                           Art home
# 7          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# ..            ...      ...                                                ...
# 286       Yerevan  Armenia                3-х комнатная на Северном проспекте
# 287       Yerevan  Armenia      Studio Apartment on Mashtots Street by Picnic
# 293       Yerevan  Armenia   Светлая квартира в центре Еревана YEREVAN centre
# 297       Yerevan  Armenia                                    Sunny apartment
# 298       Yerevan  Armenia      NEW Modern and Cozy Studio in the City Center
#
# ...

# %%
string = []
for i in hotel_full_Aparan.index:
    st = hotel_full_Aparan.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["240 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "26 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "13 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "6 Reviews', 'Identity verified",
#  '26 Reviews',
#  "30 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "97 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "7 Reviews', 'Identity verified",
#  "78 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "27 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  '7 Reviews',
#  "189 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "152 Reviews', 'Identity verified",
#  "1 Review', 'Identity verified",
#  "13 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "84 Reviews', 'Identity verified",
#  "4 Reviews', 'Identity verified",
#  "189 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "186 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
# ...

# %%
hotel_full_Aparan.host_identity_verified = string
hotel_full_Aparan.host_identity_verified
# Out:
# 1      240 Reviews', 'Identity verified', '\U000f0003...
# 4      26 Reviews', 'Identity verified', '\U000f0003'...
# 5      13 Reviews', 'Identity verified', '\U000f0003'...
# 6                         6 Reviews', 'Identity verified
# 7                                             26 Reviews
#                              ...
# 286    68 Reviews', 'Identity verified', '\U000f0003'...
# 287                     121 Reviews', 'Identity verified
# 293    136 Reviews', 'Identity verified', '\U000f0003...
# 297                39 Reviews', '\U000f0003', 'Superhost
# 298    333 Reviews', 'Identity verified', '\U000f0003...
# Name: host_identity_verified, Length: 225, dtype: object

# %%
for i in hotel_full_Aparan.index:
    if "Identity verified" in  hotel_full_Aparan.host_identity_verified[i]:
        hotel_full_Aparan.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Aparan.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Aparan
# Out:
#              city  country                                               name  \
# 1     Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4         Dilijan  Armenia   Cosy and comfortable apartment with a great view
# 5      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 6    Vagharshapat  Armenia                                           Art home
# 7          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# ..            ...      ...                                                ...
# 286       Yerevan  Armenia                3-х комнатная на Северном проспекте
# 287       Yerevan  Armenia      Studio Apartment on Mashtots Street by Picnic
# 293       Yerevan  Armenia   Светлая квартира в центре Еревана YEREVAN centre
# 297       Yerevan  Armenia                                    Sunny apartment
# 298       Yerevan  Armenia      NEW Modern and Cozy Studio in the City Center
#
# ...

# %%
for i in hotel_full_Aparan.index:
    if "Review" in  hotel_full_Aparan.review[i]:
        hotel_full_Aparan.loc[i, 'review'] = re.search("(\d+)", hotel_full_Aparan.review[i]).group()
        
    else:
        hotel_full_Aparan.loc[i, 'review'] = 0

# %%
hotel_full_Aparan
# Out:
#              city  country                                               name  \
# 1     Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4         Dilijan  Armenia   Cosy and comfortable apartment with a great view
# 5      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 6    Vagharshapat  Armenia                                           Art home
# 7          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# ..            ...      ...                                                ...
# 286       Yerevan  Armenia                3-х комнатная на Северном проспекте
# 287       Yerevan  Armenia      Studio Apartment on Mashtots Street by Picnic
# 293       Yerevan  Armenia   Светлая квартира в центре Еревана YEREVAN centre
# 297       Yerevan  Armenia                                    Sunny apartment
# 298       Yerevan  Armenia      NEW Modern and Cozy Studio in the City Center
#
# ...

# %%
for i in hotel_full_Aparan.index:
    if "Superhost" in  hotel_full_Aparan.superhost[i]:
        hotel_full_Aparan.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Aparan.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Aparan.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire condominium (condo)',
#  'Entire rental unit',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire guest suite',
#  'Hut',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire bed and breakfast',
#  'Entire villa',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire loft',
#  'Entire residential home',
#  'Entire residential home',
#  'Entire residential home',
#  'Entire guest suite',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Entire cottage',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire guesthouse',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Room in boutique hotel',
#  'Entire condominium (condo)',
# ...

# %%
hotel_full_Aparan.property_type =prop_list

# %%
hotel_full_Aparan
# Out:
#              city  country                                               name  \
# 1     Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4         Dilijan  Armenia   Cosy and comfortable apartment with a great view
# 5      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 6    Vagharshapat  Armenia                                           Art home
# 7          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# ..            ...      ...                                                ...
# 286       Yerevan  Armenia                3-х комнатная на Северном проспекте
# 287       Yerevan  Armenia      Studio Apartment on Mashtots Street by Picnic
# 293       Yerevan  Armenia   Светлая квартира в центре Еревана YEREVAN centre
# 297       Yerevan  Armenia                                    Sunny apartment
# 298       Yerevan  Armenia      NEW Modern and Cozy Studio in the City Center
#
# ...

# %%
accomodates_list = []
for i in hotel_full_Aparan.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Aparan.accomodates = number

# %%
for i in hotel_full_Aparan.index:
    if "Shared half-bath" in  hotel_full_Aparan.number_bathroom[i]:
        hotel_full_Aparan.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Aparan.number_bathroom[i]:
        hotel_full_Aparan.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Aparan.number_bathroom[i]:
        hotel_full_Aparan.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Aparan.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Aparan.number_bedroom[i])
        hotel_full_Aparan.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Aparan.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Aparan.number_bedroom[i])
        hotel_full_Aparan.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Aparan.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Aparan.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Aparan.index:
    if "bed" in  hotel_full_Aparan.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Aparan.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Aparan.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['1',
#  '1',
#  '3',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '3',
#  '4',
#  None,
#  '1',
#  '2',
#  '8',
#  '4',
#  '3',
#  '4',
#  '1',
#  '1',
#  '4',
#  '1',
#  '1',
#  '2',
#  None,
#  '1',
#  '3',
#  '1',
#  '2',
#  '1',
#  '2',
#  '4',
#  '1',
#  '1',
#  '3',
#  '3',
#  '1',
#  '1',
#  '1',
#  '3',
#  '2',
#  '8',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '2',
#  '2',
#  '1',
#  '3',
#  '5',
#  '1',
#  '1',
#  '2',
#  '6',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '2',
#  '4',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '3',
#  '8',
#  '1',
#  '1',
#  '1',
#  '2',
#  '2',
#  '2',
#  '4',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '3',
#  '2',
#  '3',
#  '2',
#  '3',
#  '5',
#  '0',
#  '1',
#  '1',
#  '1',
#  '1',
#  '6',
#  '1',
#  '3',
#  '4',
#  '2',
#  '1',
#  '1',
#  '2',
#  '3',
#  '2',
#  '3',
#  '3',
#  '5',
#  '2',
#  '3',
# ...

# %%
len(hotel_full_Aparan.number_beds)
# Out:
# 225

# %%
len(number_beds_list)
# Out:
# 225

# %%
hotel_full_Aparan.number_beds = number_beds_list

# %%
hotel_full_Aparan.number_beds
# Out:
# 1      1
# 4      1
# 5      3
# 6      2
# 7      2
#       ..
# 286    2
# 287    1
# 293    2
# 297    2
# 298    1
# Name: number_beds, Length: 225, dtype: object

# %%
for i in hotel_full_Aparan.index:
    if "Studio" in  hotel_full_Aparan.number_bedroom[i]:
        hotel_full_Aparan.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Aparan.number_bedroom[i])
        hotel_full_Aparan.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Aparan.index:
    if "Cleanliness" in  hotel_full_Aparan.cleanliness[i]:
        hotel_full_Aparan.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Aparan.cleanliness[i])
    else:
        hotel_full_Aparan.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Aparan.index:
    if "Accuracy" in  hotel_full_Aparan.accuracy[i]:
        hotel_full_Aparan.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Aparan.accuracy[i])
    else:
        hotel_full_Aparan.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Aparan.index:
    if "Communication" in  hotel_full_Aparan.communication[i]:
        hotel_full_Aparan.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Aparan.communication[i])
    else:
        hotel_full_Aparan.loc[i, 'communication'] = None

# %%
for i in hotel_full_Aparan.index:
    if "Location" in  hotel_full_Aparan.location[i]:
        try:
            hotel_full_Aparan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Aparan.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Aparan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Aparan.location[i])
    
    else:
        hotel_full_Aparan.loc[i, 'location'] = None

# %%
for i in hotel_full_Aparan.index:
    if "Check-in" in  hotel_full_Aparan.check_in[i]:
        hotel_full_Aparan.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Aparan.check_in[i])
    else:
        hotel_full_Aparan.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Aparan.index:
    if "Value" in  hotel_full_Aparan.value[i]:
        hotel_full_Aparan.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Aparan.value[i])
    else:
        hotel_full_Aparan.loc[i, 'value'] = None

# %%
for i in hotel_full_Aparan.index:
    if "No reviews (yet)" in  hotel_full_Aparan.rating[i]:
        hotel_full_Aparan.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Aparan.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Aparan.price = price_list

# %%
for i in hotel_full_Aparan.index:
    if "Response rate" in  hotel_full_Aparan.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Aparan.host_response_rate[i])
        hotel_full_Aparan.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Aparan.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Aparan = hotel_full_Aparan.astype(convert_dict)

# %%
hotel_full_Aparan.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Aparan.to_csv("cleaned_hotel_full_Aparan.csv", index=False)
hotel_full_Aparan.to_excel("cleaned_hotel_full_Aparan2.xlsx", index=False)
