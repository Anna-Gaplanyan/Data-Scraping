# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Metsamor = pd.read_csv('hotel_full_Metsamor.csv')
hotel_full_Metsamor
# Out:
#                                        city  \
# 0                                       NaN
# 1     Oshakan, Aragatsotn Province, Armenia
# 2     Baghramyan, Armavir Province, Armenia
# 3  Aragatsotn, Aragatsotn Province, Armenia
# 4   Vagharshapat, Armavir Province, Armenia
# 5   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat, Armavir Province, Armenia
# 7   Vagharshapat, Armavir Province, Armenia
#
#                                     country  \
# 0                                       NaN
# 1     Oshakan, Aragatsotn Province, Armenia
# 2     Baghramyan, Armavir Province, Armenia
# 3  Aragatsotn, Aragatsotn Province, Armenia
# 4   Vagharshapat, Armavir Province, Armenia
# 5   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat, Armavir Province, Armenia
# 7   Vagharshapat, Armavir Province, Armenia
#
#                                                 name              host_since  \
# 0                                                NaN                     NaN
# ...

# %%
hotel_full_Metsamor = hotel_full_Metsamor.drop(labels = 0, axis = 0)
hotel_full_Metsamor
# Out:
#                                        city  \
# 1     Oshakan, Aragatsotn Province, Armenia
# 2     Baghramyan, Armavir Province, Armenia
# 3  Aragatsotn, Aragatsotn Province, Armenia
# 4   Vagharshapat, Armavir Province, Armenia
# 5   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat, Armavir Province, Armenia
# 7   Vagharshapat, Armavir Province, Armenia
#
#                                     country  \
# 1     Oshakan, Aragatsotn Province, Armenia
# 2     Baghramyan, Armavir Province, Armenia
# 3  Aragatsotn, Aragatsotn Province, Armenia
# 4   Vagharshapat, Armavir Province, Armenia
# 5   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat, Armavir Province, Armenia
# 7   Vagharshapat, Armavir Province, Armenia
#
#                                                 name              host_since  \
# 1                           Old-stylish Armenian B&B     Joined in July 2019
# 2  Дом...милый дом,рядом с Ереваном,free transfer...  Joined in January 2019
# ...

# %%
nan_value = float("Nan")
hotel_full_Metsamor.replace("", nan_value, inplace = True)
hotel_full_Metsamor.dropna(inplace= True)
hotel_full_Metsamor
# Out:
#                                       city  \
# 2    Baghramyan, Armavir Province, Armenia
# 4  Vagharshapat, Armavir Province, Armenia
#
#                                    country  \
# 2    Baghramyan, Armavir Province, Armenia
# 4  Vagharshapat, Armavir Province, Armenia
#
#                                                 name              host_since  \
# 2  Дом...милый дом,рядом с Ереваном,free transfer...  Joined in January 2019
# 4               RICHMIND HOTEL- в гормонии с мыслями  Joined in October 2019
#
#                                   host_response_rate  \
# 2  Languages: English, Русский\nResponse rate: 10...
# 4                        Languages: English, Русский
#
#                               host_identity_verified  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
#                                               review  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# ...

# %%
city_list = []
for i in hotel_full_Metsamor.index:
    text = re.sub(",", "", hotel_full_Metsamor["city"][i][:hotel_full_Metsamor["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Metsamor["city"]= city_list
hotel_full_Metsamor
# Out:
#                              city                                  country  \
# 2    Baghramyan Armavir Province     Baghramyan, Armavir Province, Armenia
# 4  Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
#
#                                                 name              host_since  \
# 2  Дом...милый дом,рядом с Ереваном,free transfer...  Joined in January 2019
# 4               RICHMIND HOTEL- в гормонии с мыслями  Joined in October 2019
#
#                                   host_response_rate  \
# 2  Languages: English, Русский\nResponse rate: 10...
# 4                        Languages: English, Русский
#
#                               host_identity_verified  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
#                                               review  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Metsamor.replace("", nan_value, inplace = True)
hotel_full_Metsamor.dropna(inplace= True)
hotel_full_Metsamor
# Out:
#                              city                                  country  \
# 2    Baghramyan Armavir Province     Baghramyan, Armavir Province, Armenia
# 4  Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
#
#                                                 name              host_since  \
# 2  Дом...милый дом,рядом с Ереваном,free transfer...  Joined in January 2019
# 4               RICHMIND HOTEL- в гормонии с мыслями  Joined in October 2019
#
#                                   host_response_rate  \
# 2  Languages: English, Русский\nResponse rate: 10...
# 4                        Languages: English, Русский
#
#                               host_identity_verified  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
#                                               review  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
# ...

# %%
c_l = []    
for k in hotel_full_Metsamor["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Metsamor["city"]= c_l
hotel_full_Metsamor
# Out:
#            city                                  country  \
# 2    Baghramyan    Baghramyan, Armavir Province, Armenia
# 4  Vagharshapat  Vagharshapat, Armavir Province, Armenia
#
#                                                 name              host_since  \
# 2  Дом...милый дом,рядом с Ереваном,free transfer...  Joined in January 2019
# 4               RICHMIND HOTEL- в гормонии с мыслями  Joined in October 2019
#
#                                   host_response_rate  \
# 2  Languages: English, Русский\nResponse rate: 10...
# 4                        Languages: English, Русский
#
#                               host_identity_verified  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
#                                               review  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
#                                      superhost  \
# ...

# %%
country_list = []
for i in hotel_full_Metsamor.index:
    text = re.search("Armenia", hotel_full_Metsamor["country"][i]).group()
    country_list.append(text)

hotel_full_Metsamor["country"] = country_list

# %%
hotel_full_Metsamor
# Out:
#            city  country                                               name  \
# 2    Baghramyan  Armenia  Дом...милый дом,рядом с Ереваном,free transfer...
# 4  Vagharshapat  Armenia               RICHMIND HOTEL- в гормонии с мыслями
#
#                host_since                                 host_response_rate  \
# 2  Joined in January 2019  Languages: English, Русский\nResponse rate: 10...
# 4  Joined in October 2019                        Languages: English, Русский
#
#                               host_identity_verified  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
#                                               review  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
#                                      superhost  \
# 2  13 Reviews\nIdentity verified\n󰀃\nSuperhost
# 4                            Identity verified
#
# ...

# %%
host_since_list = []
for i in hotel_full_Metsamor.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Metsamor.host_since = hs 
hotel_full_Metsamor.host_since
# Out:
# 2    2019
# 4    2019
# Name: host_since, dtype: int64

# %%
hotel_full_Metsamor
# Out:
#            city  country                                               name  \
# 2    Baghramyan  Armenia  Дом...милый дом,рядом с Ереваном,free transfer...
# 4  Vagharshapat  Armenia               RICHMIND HOTEL- в гормонии с мыслями
#
#    host_since                                 host_response_rate  \
# 2        2019  Languages: English, Русский\nResponse rate: 10...
# 4        2019                        Languages: English, Русский
#
#                               host_identity_verified  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
#                                               review  \
# 2  ['13 Reviews', 'Identity verified', '\U000f000...
# 4                              ['Identity verified']
#
#                                      superhost  \
# 2  13 Reviews\nIdentity verified\n󰀃\nSuperhost
# 4                            Identity verified
#
#                              property_type  \
# ...

# %%
string = []
for i in hotel_full_Metsamor.index:
    st = hotel_full_Metsamor.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["13 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  'Identity verified']

# %%
hotel_full_Metsamor.host_identity_verified = string
hotel_full_Metsamor.host_identity_verified
# Out:
# 2    13 Reviews', 'Identity verified', '\U000f0003'...
# 4                                    Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Metsamor.index:
    if "Identity verified" in  hotel_full_Metsamor.host_identity_verified[i]:
        hotel_full_Metsamor.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Metsamor.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Metsamor
# Out:
#            city  country                                               name  \
# 2    Baghramyan  Armenia  Дом...милый дом,рядом с Ереваном,free transfer...
# 4  Vagharshapat  Armenia               RICHMIND HOTEL- в гормонии с мыслями
#
#    host_since                                 host_response_rate  \
# 2        2019  Languages: English, Русский\nResponse rate: 10...
# 4        2019                        Languages: English, Русский
#
#   host_identity_verified                                             review  \
# 2      Identity verified  ['13 Reviews', 'Identity verified', '\U000f000...
# 4      Identity verified                              ['Identity verified']
#
#                                      superhost  \
# 2  13 Reviews\nIdentity verified\n󰀃\nSuperhost
# 4                            Identity verified
#
#                              property_type  \
# 2  Entire residential home hosted by Karen
# 4         Room in hotel hosted by Richmind
#
# ...

# %%
for i in hotel_full_Metsamor.index:
    if "Review" in  hotel_full_Metsamor.review[i]:
        hotel_full_Metsamor.loc[i, 'review'] = re.search("(\d+)", hotel_full_Metsamor.review[i]).group()
        
    else:
        hotel_full_Metsamor.loc[i, 'review'] = 0

# %%
hotel_full_Metsamor
# Out:
#            city  country                                               name  \
# 2    Baghramyan  Armenia  Дом...милый дом,рядом с Ереваном,free transfer...
# 4  Vagharshapat  Armenia               RICHMIND HOTEL- в гормонии с мыслями
#
#    host_since                                 host_response_rate  \
# 2        2019  Languages: English, Русский\nResponse rate: 10...
# 4        2019                        Languages: English, Русский
#
#   host_identity_verified review                                    superhost  \
# 2      Identity verified     13  13 Reviews\nIdentity verified\n󰀃\nSuperhost
# 4      Identity verified      0                            Identity verified
#
#                              property_type  \
# 2  Entire residential home hosted by Karen
# 4         Room in hotel hosted by Richmind
#
#                                          accomodates  ...  \
# 2  Entire residential home hosted by Karen\n8 gue...  ...
# ...

# %%
for i in hotel_full_Metsamor.index:
    if "Superhost" in  hotel_full_Metsamor.superhost[i]:
        hotel_full_Metsamor.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Metsamor.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Metsamor.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire residential home', 'Room in hotel']

# %%
hotel_full_Metsamor.property_type =prop_list

# %%
hotel_full_Metsamor
# Out:
#            city  country                                               name  \
# 2    Baghramyan  Armenia  Дом...милый дом,рядом с Ереваном,free transfer...
# 4  Vagharshapat  Armenia               RICHMIND HOTEL- в гормонии с мыслями
#
#    host_since                                 host_response_rate  \
# 2        2019  Languages: English, Русский\nResponse rate: 10...
# 4        2019                        Languages: English, Русский
#
#   host_identity_verified review     superhost            property_type  \
# 2      Identity verified     13    Super host  Entire residential home
# 4      Identity verified      0  regular host            Room in hotel
#
#                                          accomodates  ...  \
# 2  Entire residential home hosted by Karen\n8 gue...  ...
# 4  Room in hotel hosted by Richmind\n1 guest\n·\n...  ...
#
#                                       number_bedroom  \
# 2  Entire residential home hosted by Karen\n8 gue...
# ...

# %%
accomodates_list = []
for i in hotel_full_Metsamor.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Metsamor.accomodates = number

# %%
for i in hotel_full_Metsamor.index:
    if "Shared half-bath" in  hotel_full_Metsamor.number_bathroom[i]:
        hotel_full_Metsamor.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Metsamor.number_bathroom[i]:
        hotel_full_Metsamor.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Metsamor.number_bathroom[i]:
        hotel_full_Metsamor.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Metsamor.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Metsamor.number_bedroom[i])
        hotel_full_Metsamor.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Metsamor.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Metsamor.number_bedroom[i])
        hotel_full_Metsamor.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Metsamor.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Metsamor.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Metsamor.index:
    if "bed" in  hotel_full_Metsamor.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Metsamor.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Metsamor.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['4', '2']

# %%
len(hotel_full_Metsamor.number_beds)
# Out:
# 2

# %%
len(number_beds_list)
# Out:
# 2

# %%
hotel_full_Metsamor.number_beds = number_beds_list

# %%
hotel_full_Metsamor.number_beds
# Out:
# 2    4
# 4    2
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Metsamor.index:
    if "Studio" in  hotel_full_Metsamor.number_bedroom[i]:
        hotel_full_Metsamor.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Metsamor.number_bedroom[i])
        hotel_full_Metsamor.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Metsamor.index:
    if "Cleanliness" in  hotel_full_Metsamor.cleanliness[i]:
        hotel_full_Metsamor.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Metsamor.cleanliness[i])
    else:
        hotel_full_Metsamor.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Metsamor.index:
    if "Accuracy" in  hotel_full_Metsamor.accuracy[i]:
        hotel_full_Metsamor.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Metsamor.accuracy[i])
    else:
        hotel_full_Metsamor.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Metsamor.index:
    if "Communication" in  hotel_full_Metsamor.communication[i]:
        hotel_full_Metsamor.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Metsamor.communication[i])
    else:
        hotel_full_Metsamor.loc[i, 'communication'] = None

# %%
for i in hotel_full_Metsamor.index:
    if "Location" in  hotel_full_Metsamor.location[i]:
        try:
            hotel_full_Metsamor.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Metsamor.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Metsamor.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Metsamor.location[i])
    
    else:
        hotel_full_Metsamor.loc[i, 'location'] = None

# %%
for i in hotel_full_Metsamor.index:
    if "Check-in" in  hotel_full_Metsamor.check_in[i]:
        hotel_full_Metsamor.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Metsamor.check_in[i])
    else:
        hotel_full_Metsamor.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Metsamor.index:
    if "Value" in  hotel_full_Metsamor.value[i]:
        hotel_full_Metsamor.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Metsamor.value[i])
    else:
        hotel_full_Metsamor.loc[i, 'value'] = None

# %%
for i in hotel_full_Metsamor.index:
    if "No reviews (yet)" in  hotel_full_Metsamor.rating[i]:
        hotel_full_Metsamor.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Metsamor.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Metsamor.price = price_list

# %%
for i in hotel_full_Metsamor.index:
    if "Response rate" in  hotel_full_Metsamor.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Metsamor.host_response_rate[i])
        hotel_full_Metsamor.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Metsamor.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Metsamor = hotel_full_Metsamor.astype(convert_dict)

# %%
hotel_full_Metsamor.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Metsamor.to_csv("cleaned_hotel_full_Metsamor.csv", index=False)
hotel_full_Metsamor.to_excel("cleaned_hotel_full_Metsamor2.xlsx", index=False)
