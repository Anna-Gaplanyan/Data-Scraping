# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Gavar = pd.read_csv('hotel_full_Gavar.csv')
hotel_full_Gavar
# Out:
#                                            city  \
# 0                                           NaN
# 1          Sevan, Gegharkunik Province, Armenia
# 2        Noratus, Gegharkunik Province, Armenia
# 3         Tsaghkadzor, Kotayk Province, Armenia
# 4        Noratus, Gegharkunik Province, Armenia
# ..                                          ...
# 296       Tsaghkadzor, Kotayk Province, Armenia
# 297                  Цахкадзор, Котайк, Armenia
# 298  Tsaghkadzor, Цахкадзор,Tsaxkadzor, Armenia
# 299               Dzoraghbyur, Armenia, Armenia
# 300       Tsaghkadzor, Kotayk Province, Armenia
#
#                                         country  \
# 0                                           NaN
# 1          Sevan, Gegharkunik Province, Armenia
# 2        Noratus, Gegharkunik Province, Armenia
# 3         Tsaghkadzor, Kotayk Province, Armenia
# 4        Noratus, Gegharkunik Province, Armenia
# ..                                          ...
# ...

# %%
hotel_full_Gavar = hotel_full_Gavar.drop(labels = 0, axis = 0)
hotel_full_Gavar
# Out:
#                                            city  \
# 1          Sevan, Gegharkunik Province, Armenia
# 2        Noratus, Gegharkunik Province, Armenia
# 3         Tsaghkadzor, Kotayk Province, Armenia
# 4        Noratus, Gegharkunik Province, Armenia
# 5        Noratus, Gegharkunik Province, Armenia
# ..                                          ...
# 296       Tsaghkadzor, Kotayk Province, Armenia
# 297                  Цахкадзор, Котайк, Armenia
# 298  Tsaghkadzor, Цахкадзор,Tsaxkadzor, Armenia
# 299               Dzoraghbyur, Armenia, Armenia
# 300       Tsaghkadzor, Kotayk Province, Armenia
#
#                                         country  \
# 1          Sevan, Gegharkunik Province, Armenia
# 2        Noratus, Gegharkunik Province, Armenia
# 3         Tsaghkadzor, Kotayk Province, Armenia
# 4        Noratus, Gegharkunik Province, Armenia
# 5        Noratus, Gegharkunik Province, Armenia
# ..                                          ...
# ...

# %%
nan_value = float("Nan")
hotel_full_Gavar.replace("", nan_value, inplace = True)
hotel_full_Gavar.dropna(inplace= True)
hotel_full_Gavar
# Out:
#                                        city  \
# 2    Noratus, Gegharkunik Province, Armenia
# 3     Tsaghkadzor, Kotayk Province, Armenia
# 4    Noratus, Gegharkunik Province, Armenia
# 7           Garni, Kotayk Province, Armenia
# 8                            Գառնի, Armenia
# ..                                      ...
# 285            Dzoraxbyur , Kotayq, Armenia
# 287       Abovyan, Kotayk Province, Armenia
# 290   Tsaghkadzor, Kotayk Province, Armenia
# 291       Hrazdan, Kotayk Province, Armenia
# 297              Цахкадзор, Котайк, Armenia
#
#                                     country  \
# 2    Noratus, Gegharkunik Province, Armenia
# 3     Tsaghkadzor, Kotayk Province, Armenia
# 4    Noratus, Gegharkunik Province, Armenia
# 7           Garni, Kotayk Province, Armenia
# 8                            Գառնի, Armenia
# ..                                      ...
# 285            Dzoraxbyur , Kotayq, Armenia
# 287       Abovyan, Kotayk Province, Armenia
# ...

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Սևան, Գեղարքունիք, Armenia" : "Sevan, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Գառնի, Armenia" : "Garni, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Հրազդան, Կոտայք, Armenia" : "Hrazdan, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Սևան, Gegharkunik Province, Armenia" : "Sevan, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Ծաղկաձոր, Armenia" : "Tsaghkadzor, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Ծաղկաձոր, Կոտայք, Armenia" : "Tsaghkadzor, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Կալավան, Armenia" : "Kalavan, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Цахкадзор, Котайк, Armenia" : "Tsaghkadzor, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Սևան, Yerevan, Armenia" : "Sevan, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Дзорахпюр, Котайк, Armenia" : "Dzoraxbyur, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Արզնի, Կոտայք, Armenia" : "Arzni, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Գառնի, Կոտայք, Armenia" : "Garni, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Ծովազարդ, Armenia" : "Tsovazard, Armenia"})

# %%
hotel_full_Gavar["city"]= hotel_full_Gavar["city"].replace({"Цахкадзор , Армения, Armenia" : "Tsaghkadzor, Armenia"})

# %%
city_list = []
for i in hotel_full_Gavar.index:
    text = re.sub(",", "", hotel_full_Gavar["city"][i][:hotel_full_Gavar["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Gavar["city"]= city_list
hotel_full_Gavar
# Out:
#                               city                                 country  \
# 2    Noratus Gegharkunik Province   Noratus, Gegharkunik Province, Armenia
# 3     Tsaghkadzor Kotayk Province    Tsaghkadzor, Kotayk Province, Armenia
# 4    Noratus Gegharkunik Province   Noratus, Gegharkunik Province, Armenia
# 7           Garni Kotayk Province          Garni, Kotayk Province, Armenia
# 8                           Garni                           Գառնի, Armenia
# ..                             ...                                     ...
# 285            Dzoraxbyur  Kotayq             Dzoraxbyur , Kotayq, Armenia
# 287       Abovyan Kotayk Province        Abovyan, Kotayk Province, Armenia
# 290   Tsaghkadzor Kotayk Province    Tsaghkadzor, Kotayk Province, Armenia
# 291       Hrazdan Kotayk Province        Hrazdan, Kotayk Province, Armenia
# 297                   Tsaghkadzor               Цахкадзор, Котайк, Armenia
#
#                                                   name  \
# ...

# %%
nan_value = float("Nan")
hotel_full_Gavar.replace("", nan_value, inplace = True)
hotel_full_Gavar.dropna(inplace= True)
hotel_full_Gavar
# Out:
#                               city                                 country  \
# 2    Noratus Gegharkunik Province   Noratus, Gegharkunik Province, Armenia
# 3     Tsaghkadzor Kotayk Province    Tsaghkadzor, Kotayk Province, Armenia
# 4    Noratus Gegharkunik Province   Noratus, Gegharkunik Province, Armenia
# 7           Garni Kotayk Province          Garni, Kotayk Province, Armenia
# 8                           Garni                           Գառնի, Armenia
# ..                             ...                                     ...
# 285            Dzoraxbyur  Kotayq             Dzoraxbyur , Kotayq, Armenia
# 287       Abovyan Kotayk Province        Abovyan, Kotayk Province, Armenia
# 290   Tsaghkadzor Kotayk Province    Tsaghkadzor, Kotayk Province, Armenia
# 291       Hrazdan Kotayk Province        Hrazdan, Kotayk Province, Armenia
# 297                   Tsaghkadzor               Цахкадзор, Котайк, Armenia
#
#                                                   name  \
# ...

# %%
c_l = []    
for k in hotel_full_Gavar["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Gavar["city"]= c_l
hotel_full_Gavar
# Out:
#             city                                 country  \
# 2        Noratus  Noratus, Gegharkunik Province, Armenia
# 3    Tsaghkadzor   Tsaghkadzor, Kotayk Province, Armenia
# 4        Noratus  Noratus, Gegharkunik Province, Armenia
# 7          Garni         Garni, Kotayk Province, Armenia
# 8          Garni                          Գառնի, Armenia
# ..           ...                                     ...
# 285   Dzoraxbyur            Dzoraxbyur , Kotayq, Armenia
# 287      Abovyan       Abovyan, Kotayk Province, Armenia
# 290  Tsaghkadzor   Tsaghkadzor, Kotayk Province, Armenia
# 291      Hrazdan       Hrazdan, Kotayk Province, Armenia
# 297  Tsaghkadzor              Цахкадзор, Котайк, Armenia
#
#                                                   name  \
# 2           Oazis a place for a real holiday. Big room
# 3    Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4                            Room with Armenian spirit
# ...

# %%
country_list = []
for i in hotel_full_Gavar.index:
    text = re.search("Armenia", hotel_full_Gavar["country"][i]).group()
    country_list.append(text)

hotel_full_Gavar["country"] = country_list

# %%
hotel_full_Gavar
# Out:
#             city  country                                               name  \
# 2        Noratus  Armenia         Oazis a place for a real holiday. Big room
# 3    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4        Noratus  Armenia                          Room with Armenian spirit
# 7          Garni  Armenia                                    Cherry blossoms
# 8          Garni  Armenia                         It's CHERRY time, welcome!
# ..           ...      ...                                                ...
# 285   Dzoraxbyur  Armenia    Welcome to my sweet home full of art and love !
# 287      Abovyan  Armenia                                         Home dacha
# 290  Tsaghkadzor  Armenia              A Gorgeous Home in Viardo Tsakhkadzor
# 291      Hrazdan  Armenia        2 room apartment in Mori Plaza, Tzakhkadzor
# 297  Tsaghkadzor  Armenia                          daily home in tsakhkadzor
#
#                    host_since  \
# ...

# %%
host_since_list = []
for i in hotel_full_Gavar.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Gavar.host_since = hs 
hotel_full_Gavar.host_since
# Out:
# 2      2019
# 3      2016
# 4      2019
# 7      2017
# 8      2017
#        ...
# 285    2016
# 287    2016
# 290    2017
# 291    2015
# 297    2014
# Name: host_since, Length: 134, dtype: int64

# %%
hotel_full_Gavar
# Out:
#             city  country                                               name  \
# 2        Noratus  Armenia         Oazis a place for a real holiday. Big room
# 3    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4        Noratus  Armenia                          Room with Armenian spirit
# 7          Garni  Armenia                                    Cherry blossoms
# 8          Garni  Armenia                         It's CHERRY time, welcome!
# ..           ...      ...                                                ...
# 285   Dzoraxbyur  Armenia    Welcome to my sweet home full of art and love !
# 287      Abovyan  Armenia                                         Home dacha
# 290  Tsaghkadzor  Armenia              A Gorgeous Home in Viardo Tsakhkadzor
# 291      Hrazdan  Armenia        2 room apartment in Mori Plaza, Tzakhkadzor
# 297  Tsaghkadzor  Armenia                          daily home in tsakhkadzor
#
# ...

# %%
string = []
for i in hotel_full_Gavar.index:
    st = hotel_full_Gavar.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ['1 Review',
#  "239 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  '1 Review',
#  "98 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "98 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  'Identity verified',
#  "5 Reviews', 'Identity verified",
#  "2 Reviews', 'Identity verified",
#  "7 Reviews', 'Identity verified",
#  'Identity verified',
#  "24 Reviews', 'Identity verified",
#  "281 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  'Identity verified',
#  "18 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "24 Reviews', 'Identity verified",
#  "7 Reviews', 'Identity verified",
#  "6 Reviews', 'Identity verified",
#  "79 Reviews', 'Identity verified",
#  '28 Reviews',
#  "15 Reviews', 'Identity verified",
#  'Identity verified',
#  '7 Reviews',
#  'Identity verified',
#  'Identity verified',
#  "73 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  'Identity verified',
# ...

# %%
hotel_full_Gavar.host_identity_verified = string
hotel_full_Gavar.host_identity_verified
# Out:
# 2                                               1 Review
# 3      239 Reviews', 'Identity verified', '\U000f0003...
# 4                                               1 Review
# 7      98 Reviews', 'Identity verified', '\U000f0003'...
# 8      98 Reviews', 'Identity verified', '\U000f0003'...
#                              ...
# 285                                    Identity verified
# 287                                             1 Review
# 290    32 Reviews', 'Identity verified', 'Airbnb.org ...
# 291                      24 Reviews', 'Identity verified
# 297                        1 Review', 'Identity verified
# Name: host_identity_verified, Length: 134, dtype: object

# %%
for i in hotel_full_Gavar.index:
    if "Identity verified" in  hotel_full_Gavar.host_identity_verified[i]:
        hotel_full_Gavar.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Gavar.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Gavar
# Out:
#             city  country                                               name  \
# 2        Noratus  Armenia         Oazis a place for a real holiday. Big room
# 3    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4        Noratus  Armenia                          Room with Armenian spirit
# 7          Garni  Armenia                                    Cherry blossoms
# 8          Garni  Armenia                         It's CHERRY time, welcome!
# ..           ...      ...                                                ...
# 285   Dzoraxbyur  Armenia    Welcome to my sweet home full of art and love !
# 287      Abovyan  Armenia                                         Home dacha
# 290  Tsaghkadzor  Armenia              A Gorgeous Home in Viardo Tsakhkadzor
# 291      Hrazdan  Armenia        2 room apartment in Mori Plaza, Tzakhkadzor
# 297  Tsaghkadzor  Armenia                          daily home in tsakhkadzor
#
# ...

# %%
for i in hotel_full_Gavar.index:
    if "Review" in  hotel_full_Gavar.review[i]:
        hotel_full_Gavar.loc[i, 'review'] = re.search("(\d+)", hotel_full_Gavar.review[i]).group()
        
    else:
        hotel_full_Gavar.loc[i, 'review'] = 0

# %%
hotel_full_Gavar
# Out:
#             city  country                                               name  \
# 2        Noratus  Armenia         Oazis a place for a real holiday. Big room
# 3    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4        Noratus  Armenia                          Room with Armenian spirit
# 7          Garni  Armenia                                    Cherry blossoms
# 8          Garni  Armenia                         It's CHERRY time, welcome!
# ..           ...      ...                                                ...
# 285   Dzoraxbyur  Armenia    Welcome to my sweet home full of art and love !
# 287      Abovyan  Armenia                                         Home dacha
# 290  Tsaghkadzor  Armenia              A Gorgeous Home in Viardo Tsakhkadzor
# 291      Hrazdan  Armenia        2 room apartment in Mori Plaza, Tzakhkadzor
# 297  Tsaghkadzor  Armenia                          daily home in tsakhkadzor
#
# ...

# %%
for i in hotel_full_Gavar.index:
    if "Superhost" in  hotel_full_Gavar.superhost[i]:
        hotel_full_Gavar.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Gavar.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Gavar.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Room in hotel',
#  'Entire condominium (condo)',
#  'Room in hotel',
#  'Entire residential home',
#  'Entire residential home',
#  'Tent',
#  'Entire rental unit',
#  'Entire residential home',
#  'Entire rental unit',
#  'Private room in residential home',
#  'Room in boutique hotel',
#  'Entire residential home',
#  'Private room in resort',
#  'Entire cottage',
#  'Room in boutique hotel',
#  'Entire rental unit',
#  'Entire villa',
#  'Entire serviced apartment',
#  'Entire cottage',
#  'Private room in bed and breakfast',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire villa',
#  'Tent',
#  'Entire cottage',
#  'Entire cottage',
#  'Private room in cottage',
#  'Private room in residential home',
#  'Entire cottage',
#  'Entire residential home',
#  'Room in hotel',
#  'Entire rental unit',
#  'Private room in cottage',
#  'Entire bungalow',
#  'Entire villa',
#  'Private room in residential home',
#  'Private room in cottage',
#  'Private room in nature lodge',
# ...

# %%
hotel_full_Gavar.property_type =prop_list

# %%
hotel_full_Gavar
# Out:
#             city  country                                               name  \
# 2        Noratus  Armenia         Oazis a place for a real holiday. Big room
# 3    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4        Noratus  Armenia                          Room with Armenian spirit
# 7          Garni  Armenia                                    Cherry blossoms
# 8          Garni  Armenia                         It's CHERRY time, welcome!
# ..           ...      ...                                                ...
# 285   Dzoraxbyur  Armenia    Welcome to my sweet home full of art and love !
# 287      Abovyan  Armenia                                         Home dacha
# 290  Tsaghkadzor  Armenia              A Gorgeous Home in Viardo Tsakhkadzor
# 291      Hrazdan  Armenia        2 room apartment in Mori Plaza, Tzakhkadzor
# 297  Tsaghkadzor  Armenia                          daily home in tsakhkadzor
#
# ...

# %%
accomodates_list = []
for i in hotel_full_Gavar.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Gavar.accomodates = number

# %%
for i in hotel_full_Gavar.index:
    if "Shared half-bath" in  hotel_full_Gavar.number_bathroom[i]:
        hotel_full_Gavar.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Gavar.number_bathroom[i]:
        hotel_full_Gavar.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Gavar.number_bathroom[i]:
        hotel_full_Gavar.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Gavar.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Gavar.number_bedroom[i])
        hotel_full_Gavar.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Gavar.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Gavar.number_bedroom[i])
        hotel_full_Gavar.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Gavar.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Gavar.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Gavar.index:
    if "bed" in  hotel_full_Gavar.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Gavar.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Gavar.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['2',
#  '1',
#  '1',
#  '4',
#  '2',
#  '1',
#  '3',
#  '4',
#  '1',
#  '2',
#  '4',
#  '4',
#  '1',
#  '4',
#  '4',
#  '2',
#  '4',
#  '1',
#  '3',
#  '2',
#  '6',
#  '4',
#  '4',
#  '1',
#  '5',
#  '5',
#  '4',
#  '1',
#  '5',
#  '7',
#  '1',
#  '4',
#  '1',
#  '4',
#  '4',
#  '4',
#  '1',
#  '2',
#  '3',
#  '4',
#  '7',
#  '0',
#  '3',
#  '0',
#  '0',
#  '6',
#  '1',
#  '4',
#  '5',
#  '2',
#  '3',
#  '4',
#  '6',
#  '1',
#  '1',
#  '2',
#  '4',
#  '10',
#  '4',
#  '2',
#  '1',
#  '7',
#  '2',
#  '9',
#  '12',
#  '10',
#  '1',
#  '1',
#  '6',
#  '1',
#  '1',
#  '5',
#  '2',
#  '5',
#  '6',
#  '7',
#  '5',
#  '11',
#  '2',
#  '3',
#  '3',
#  '4',
#  '4',
#  '7',
#  '2',
#  '4',
#  '8',
#  '1',
#  '6',
#  '10',
#  '19',
#  '4',
#  '19',
#  '2',
#  '6',
#  '4',
#  '8',
#  '5',
#  '10',
#  '7',
#  '6',
#  '2',
#  '8',
#  '0',
#  '7',
#  '12',
#  '7',
#  '16',
#  '10',
#  '12',
#  '6',
#  '8',
#  '1',
#  '7',
#  '4',
#  '3',
#  '6',
#  '4',
#  '2',
#  '4',
#  '2',
#  '2',
#  '2',
# ...

# %%
len(hotel_full_Gavar.number_beds)
# Out:
# 134

# %%
len(number_beds_list)
# Out:
# 134

# %%
hotel_full_Gavar.number_beds = number_beds_list

# %%
hotel_full_Gavar.number_beds
# Out:
# 2       2
# 3       1
# 4       1
# 7       4
# 8       2
#        ..
# 285     3
# 287    10
# 290     3
# 291     1
# 297     4
# Name: number_beds, Length: 134, dtype: object

# %%
for i in hotel_full_Gavar.index:
    if "Studio" in  hotel_full_Gavar.number_bedroom[i]:
        hotel_full_Gavar.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Gavar.number_bedroom[i])
        hotel_full_Gavar.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Gavar.index:
    if "Cleanliness" in  hotel_full_Gavar.cleanliness[i]:
        hotel_full_Gavar.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Gavar.cleanliness[i])
    else:
        hotel_full_Gavar.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Gavar.index:
    if "Accuracy" in  hotel_full_Gavar.accuracy[i]:
        hotel_full_Gavar.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Gavar.accuracy[i])
    else:
        hotel_full_Gavar.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Gavar.index:
    if "Communication" in  hotel_full_Gavar.communication[i]:
        hotel_full_Gavar.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Gavar.communication[i])
    else:
        hotel_full_Gavar.loc[i, 'communication'] = None

# %%
for i in hotel_full_Gavar.index:
    if "Location" in  hotel_full_Gavar.location[i]:
        try:
            hotel_full_Gavar.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Gavar.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Gavar.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Gavar.location[i])
    
    else:
        hotel_full_Gavar.loc[i, 'location'] = None

# %%
for i in hotel_full_Gavar.index:
    if "Check-in" in  hotel_full_Gavar.check_in[i]:
        hotel_full_Gavar.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Gavar.check_in[i])
    else:
        hotel_full_Gavar.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Gavar.index:
    if "Value" in  hotel_full_Gavar.value[i]:
        hotel_full_Gavar.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Gavar.value[i])
    else:
        hotel_full_Gavar.loc[i, 'value'] = None

# %%
for i in hotel_full_Gavar.index:
    if "No reviews (yet)" in  hotel_full_Gavar.rating[i]:
        hotel_full_Gavar.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Gavar.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Gavar.price = price_list

# %%
for i in hotel_full_Gavar.index:
    if "Response rate" in  hotel_full_Gavar.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Gavar.host_response_rate[i])
        hotel_full_Gavar.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Gavar.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Gavar = hotel_full_Gavar.astype(convert_dict)

# %%
hotel_full_Gavar.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Gavar.to_csv("cleaned_hotel_full_Gavar.csv", index=False)
hotel_full_Gavar.to_excel("cleaned_hotel_full_Gavar2.xlsx", index=False)
