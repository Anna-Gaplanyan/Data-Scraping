# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Talin = pd.read_csv('hotel_full_Talin.csv')
hotel_full_Talin
# Out:
#                                         city  \
# 0                                        NaN
# 1         Dzorakap, Shirak Province, Armenia
# 2         Dzorakap, Shirak Province, Armenia
# 3                  Աշնակ, Արագածոտն, Armenia
# 4               Aragatsotn Province, Armenia
# 5            Artik, Shirak Province, Armenia
# 6            Artik, Shirak Province, Armenia
# 7   Aragatsotn, Aragatsotn Province, Armenia
# 8         Armavir, Armavir Province, Armenia
# 9                                    Armenia
# 10                    Kosh, Armenia, Armenia
# 11        Dzorakap, Shirak Province, Armenia
# 12  Aragatsotn, Aragatsotn Province, Armenia
# 13       Pemzashen, Shirak Province, Armenia
#
#                                      country  \
# 0                                        NaN
# 1         Dzorakap, Shirak Province, Armenia
# 2         Dzorakap, Shirak Province, Armenia
# 3                  Աշնակ, Արագածոտն, Armenia
# 4               Aragatsotn Province, Armenia
# ...

# %%
hotel_full_Talin = hotel_full_Talin.drop(labels = 0, axis = 0)
hotel_full_Talin
# Out:
#                                         city  \
# 1         Dzorakap, Shirak Province, Armenia
# 2         Dzorakap, Shirak Province, Armenia
# 3                  Աշնակ, Արագածոտն, Armenia
# 4               Aragatsotn Province, Armenia
# 5            Artik, Shirak Province, Armenia
# 6            Artik, Shirak Province, Armenia
# 7   Aragatsotn, Aragatsotn Province, Armenia
# 8         Armavir, Armavir Province, Armenia
# 9                                    Armenia
# 10                    Kosh, Armenia, Armenia
# 11        Dzorakap, Shirak Province, Armenia
# 12  Aragatsotn, Aragatsotn Province, Armenia
# 13       Pemzashen, Shirak Province, Armenia
#
#                                      country  \
# 1         Dzorakap, Shirak Province, Armenia
# 2         Dzorakap, Shirak Province, Armenia
# 3                  Աշնակ, Արագածոտն, Armenia
# 4               Aragatsotn Province, Armenia
# 5            Artik, Shirak Province, Armenia
# 6            Artik, Shirak Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Talin.replace("", nan_value, inplace = True)
hotel_full_Talin.dropna(inplace= True)
hotel_full_Talin
# Out:
#                                   city                             country  \
# 1   Dzorakap, Shirak Province, Armenia  Dzorakap, Shirak Province, Armenia
# 4         Aragatsotn Province, Armenia        Aragatsotn Province, Armenia
# 11  Dzorakap, Shirak Province, Armenia  Dzorakap, Shirak Province, Armenia
#
#                                       name              host_since  \
# 1   Apple Tree Family House(семейный люкс)      Joined in May 2019
# 4               Домик влюбленного гномика!  Joined in January 2015
# 11            Apple Tree Family Home (ECO)      Joined in May 2019
#
#                                    host_response_rate  \
# 1   Response rate: 100%\nResponse time: within an ...
# 4   Languages: English, Suomi, Русский, Українська...
# 11  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                             review  \
# 1   ['1 Review', 'Identity verified']  ['1 Review', 'Identity verified']
# ...

# %%
hotel_full_Talin["city"]= hotel_full_Talin["city"].replace({"Աշնակ, Արագածոտն, Armenia" : "Ashnak, Armenia"})

# %%
city_list = []
for i in hotel_full_Talin.index:
    text = re.sub(",", "", hotel_full_Talin["city"][i][:hotel_full_Talin["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Talin["city"]= city_list
hotel_full_Talin
# Out:
#                          city                             country  \
# 1   Dzorakap Shirak Province   Dzorakap, Shirak Province, Armenia
# 4        Aragatsotn Province         Aragatsotn Province, Armenia
# 11  Dzorakap Shirak Province   Dzorakap, Shirak Province, Armenia
#
#                                       name              host_since  \
# 1   Apple Tree Family House(семейный люкс)      Joined in May 2019
# 4               Домик влюбленного гномика!  Joined in January 2015
# 11            Apple Tree Family Home (ECO)      Joined in May 2019
#
#                                    host_response_rate  \
# 1   Response rate: 100%\nResponse time: within an ...
# 4   Languages: English, Suomi, Русский, Українська...
# 11  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                             review  \
# 1   ['1 Review', 'Identity verified']  ['1 Review', 'Identity verified']
# ...

# %%
nan_value = float("Nan")
hotel_full_Talin.replace("", nan_value, inplace = True)
hotel_full_Talin.dropna(inplace= True)
hotel_full_Talin
# Out:
#                          city                             country  \
# 1   Dzorakap Shirak Province   Dzorakap, Shirak Province, Armenia
# 4        Aragatsotn Province         Aragatsotn Province, Armenia
# 11  Dzorakap Shirak Province   Dzorakap, Shirak Province, Armenia
#
#                                       name              host_since  \
# 1   Apple Tree Family House(семейный люкс)      Joined in May 2019
# 4               Домик влюбленного гномика!  Joined in January 2015
# 11            Apple Tree Family Home (ECO)      Joined in May 2019
#
#                                    host_response_rate  \
# 1   Response rate: 100%\nResponse time: within an ...
# 4   Languages: English, Suomi, Русский, Українська...
# 11  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                             review  \
# 1   ['1 Review', 'Identity verified']  ['1 Review', 'Identity verified']
# ...

# %%
c_l = []    
for k in hotel_full_Talin["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Talin["city"]= c_l
hotel_full_Talin
# Out:
#           city                             country  \
# 1     Dzorakap  Dzorakap, Shirak Province, Armenia
# 4   Aragatsotn        Aragatsotn Province, Armenia
# 11    Dzorakap  Dzorakap, Shirak Province, Armenia
#
#                                       name              host_since  \
# 1   Apple Tree Family House(семейный люкс)      Joined in May 2019
# 4               Домик влюбленного гномика!  Joined in January 2015
# 11            Apple Tree Family Home (ECO)      Joined in May 2019
#
#                                    host_response_rate  \
# 1   Response rate: 100%\nResponse time: within an ...
# 4   Languages: English, Suomi, Русский, Українська...
# 11  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                             review  \
# 1   ['1 Review', 'Identity verified']  ['1 Review', 'Identity verified']
# 4                      ['26 Reviews']                     ['26 Reviews']
# ...

# %%
country_list = []
for i in hotel_full_Talin.index:
    text = re.search("Armenia", hotel_full_Talin["country"][i]).group()
    country_list.append(text)

hotel_full_Talin["country"] = country_list

# %%
hotel_full_Talin
# Out:
#           city  country                                    name  \
# 1     Dzorakap  Armenia  Apple Tree Family House(семейный люкс)
# 4   Aragatsotn  Armenia              Домик влюбленного гномика!
# 11    Dzorakap  Armenia            Apple Tree Family Home (ECO)
#
#                 host_since                                 host_response_rate  \
# 1       Joined in May 2019  Response rate: 100%\nResponse time: within an ...
# 4   Joined in January 2015  Languages: English, Suomi, Русский, Українська...
# 11      Joined in May 2019  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                             review  \
# 1   ['1 Review', 'Identity verified']  ['1 Review', 'Identity verified']
# 4                      ['26 Reviews']                     ['26 Reviews']
# 11  ['1 Review', 'Identity verified']  ['1 Review', 'Identity verified']
#
#                       superhost                               property_type  \
# ...

# %%
host_since_list = []
for i in hotel_full_Talin.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Talin.host_since = hs 
hotel_full_Talin.host_since
# Out:
# 1     2019
# 4     2015
# 11    2019
# Name: host_since, dtype: int64

# %%
hotel_full_Talin
# Out:
#           city  country                                    name  host_since  \
# 1     Dzorakap  Armenia  Apple Tree Family House(семейный люкс)        2019
# 4   Aragatsotn  Armenia              Домик влюбленного гномика!        2015
# 11    Dzorakap  Armenia            Apple Tree Family Home (ECO)        2019
#
#                                    host_response_rate  \
# 1   Response rate: 100%\nResponse time: within an ...
# 4   Languages: English, Suomi, Русский, Українська...
# 11  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                             review  \
# 1   ['1 Review', 'Identity verified']  ['1 Review', 'Identity verified']
# 4                      ['26 Reviews']                     ['26 Reviews']
# 11  ['1 Review', 'Identity verified']  ['1 Review', 'Identity verified']
#
#                       superhost                               property_type  \
# ...

# %%
string = []
for i in hotel_full_Talin.index:
    st = hotel_full_Talin.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["1 Review', 'Identity verified",
#  '26 Reviews',
#  "1 Review', 'Identity verified"]

# %%
hotel_full_Talin.host_identity_verified = string
hotel_full_Talin.host_identity_verified
# Out:
# 1     1 Review', 'Identity verified
# 4                        26 Reviews
# 11    1 Review', 'Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Talin.index:
    if "Identity verified" in  hotel_full_Talin.host_identity_verified[i]:
        hotel_full_Talin.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Talin.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Talin
# Out:
#           city  country                                    name  host_since  \
# 1     Dzorakap  Armenia  Apple Tree Family House(семейный люкс)        2019
# 4   Aragatsotn  Armenia              Домик влюбленного гномика!        2015
# 11    Dzorakap  Armenia            Apple Tree Family Home (ECO)        2019
#
#                                    host_response_rate host_identity_verified  \
# 1   Response rate: 100%\nResponse time: within an ...      Identity verified
# 4   Languages: English, Suomi, Русский, Українська...  Identity not verified
# 11  Response rate: 100%\nResponse time: within an ...      Identity verified
#
#                                review                    superhost  \
# 1   ['1 Review', 'Identity verified']  1 Review\nIdentity verified
# 4                      ['26 Reviews']                   26 Reviews
# 11  ['1 Review', 'Identity verified']  1 Review\nIdentity verified
#
#                                  property_type  \
# ...

# %%
for i in hotel_full_Talin.index:
    if "Review" in  hotel_full_Talin.review[i]:
        hotel_full_Talin.loc[i, 'review'] = re.search("(\d+)", hotel_full_Talin.review[i]).group()
        
    else:
        hotel_full_Talin.loc[i, 'review'] = 0

# %%
hotel_full_Talin
# Out:
#           city  country                                    name  host_since  \
# 1     Dzorakap  Armenia  Apple Tree Family House(семейный люкс)        2019
# 4   Aragatsotn  Armenia              Домик влюбленного гномика!        2015
# 11    Dzorakap  Armenia            Apple Tree Family Home (ECO)        2019
#
#                                    host_response_rate host_identity_verified  \
# 1   Response rate: 100%\nResponse time: within an ...      Identity verified
# 4   Languages: English, Suomi, Русский, Українська...  Identity not verified
# 11  Response rate: 100%\nResponse time: within an ...      Identity verified
#
#    review                    superhost  \
# 1       1  1 Review\nIdentity verified
# 4      26                   26 Reviews
# 11      1  1 Review\nIdentity verified
#
#                                  property_type  \
# 1   Entire residential home hosted by Qristine
# 4                          Hut hosted by Gagik
# ...

# %%
for i in hotel_full_Talin.index:
    if "Superhost" in  hotel_full_Talin.superhost[i]:
        hotel_full_Talin.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Talin.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Talin.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire residential home', 'Hut', 'Entire residential home']

# %%
hotel_full_Talin.property_type =prop_list

# %%
hotel_full_Talin
# Out:
#           city  country                                    name  host_since  \
# 1     Dzorakap  Armenia  Apple Tree Family House(семейный люкс)        2019
# 4   Aragatsotn  Armenia              Домик влюбленного гномика!        2015
# 11    Dzorakap  Armenia            Apple Tree Family Home (ECO)        2019
#
#                                    host_response_rate host_identity_verified  \
# 1   Response rate: 100%\nResponse time: within an ...      Identity verified
# 4   Languages: English, Suomi, Русский, Українська...  Identity not verified
# 11  Response rate: 100%\nResponse time: within an ...      Identity verified
#
#    review     superhost            property_type  \
# 1       1  regular host  Entire residential home
# 4      26  regular host                      Hut
# 11      1  regular host  Entire residential home
#
#                                           accomodates  ...  \
# 1   Entire residential home hosted by Qristine\n6 ...  ...
# ...

# %%
accomodates_list = []
for i in hotel_full_Talin.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Talin.accomodates = number

# %%
for i in hotel_full_Talin.index:
    if "Shared half-bath" in  hotel_full_Talin.number_bathroom[i]:
        hotel_full_Talin.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Talin.number_bathroom[i]:
        hotel_full_Talin.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Talin.number_bathroom[i]:
        hotel_full_Talin.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Talin.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Talin.number_bedroom[i])
        hotel_full_Talin.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Talin.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Talin.number_bedroom[i])
        hotel_full_Talin.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Talin.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Talin.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Talin.index:
    if "bed" in  hotel_full_Talin.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Talin.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Talin.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['8', '2', '2']

# %%
len(hotel_full_Talin.number_beds)
# Out:
# 3

# %%
len(number_beds_list)
# Out:
# 3

# %%
hotel_full_Talin.number_beds = number_beds_list

# %%
hotel_full_Talin.number_beds
# Out:
# 1     8
# 4     2
# 11    2
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Talin.index:
    if "Studio" in  hotel_full_Talin.number_bedroom[i]:
        hotel_full_Talin.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Talin.number_bedroom[i])
        hotel_full_Talin.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Talin.index:
    if "Cleanliness" in  hotel_full_Talin.cleanliness[i]:
        hotel_full_Talin.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Talin.cleanliness[i])
    else:
        hotel_full_Talin.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Talin.index:
    if "Accuracy" in  hotel_full_Talin.accuracy[i]:
        hotel_full_Talin.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Talin.accuracy[i])
    else:
        hotel_full_Talin.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Talin.index:
    if "Communication" in  hotel_full_Talin.communication[i]:
        hotel_full_Talin.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Talin.communication[i])
    else:
        hotel_full_Talin.loc[i, 'communication'] = None

# %%
for i in hotel_full_Talin.index:
    if "Location" in  hotel_full_Talin.location[i]:
        try:
            hotel_full_Talin.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Talin.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Talin.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Talin.location[i])
    
    else:
        hotel_full_Talin.loc[i, 'location'] = None

# %%
for i in hotel_full_Talin.index:
    if "Check-in" in  hotel_full_Talin.check_in[i]:
        hotel_full_Talin.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Talin.check_in[i])
    else:
        hotel_full_Talin.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Talin.index:
    if "Value" in  hotel_full_Talin.value[i]:
        hotel_full_Talin.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Talin.value[i])
    else:
        hotel_full_Talin.loc[i, 'value'] = None

# %%
for i in hotel_full_Talin.index:
    if "No reviews (yet)" in  hotel_full_Talin.rating[i]:
        hotel_full_Talin.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Talin.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Talin.price = price_list

# %%
for i in hotel_full_Talin.index:
    if "Response rate" in  hotel_full_Talin.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Talin.host_response_rate[i])
        hotel_full_Talin.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Talin.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Talin = hotel_full_Talin.astype(convert_dict)

# %%
hotel_full_Talin.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Talin.to_csv("cleaned_hotel_full_Talin.csv", index=False)
hotel_full_Talin.to_excel("cleaned_hotel_full_Talin2.xlsx", index=False)
