# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Ayrum = pd.read_csv('hotel_full_Ayrum.csv')
hotel_full_Ayrum
# Out:
#                                      city  \
# 0                                     NaN
# 1           Odzun, Lori Province, Armenia
# 2        Alaverdi, Lori Province, Armenia
# 3      Berdavan, Tavush Province, Armenia
# 4   Noyemberyan, Tavush Province, Armenia
# 5        Alaverdi, Lori Province, Armenia
# 6     Sarigyugh, Tavush Province, Armenia
# 7   Noyemberyan, Tavush Province, Armenia
# 8        Alaverdi, Lori Province, Armenia
# 9        Alaverdi, Lori Province, Armenia
# 10            Հաղպատ, Լոռու մարզ, Armenia
# 11       Alaverdi, Lori Province, Armenia
# 12                Алаверди, Лори, Armenia
# 13       Alaverdi, Lori Province, Armenia
# 14                         Օձուն, Armenia
# 15          Odzun, Lori Province, Armenia
# 16       Alaverdi, Lori Province, Armenia
# 17          Ալավերդի, Լոռու մարզ, Armenia
# 18        Haghpat, Lori Province, Armenia
# 19       Alaverdi, Lori Province, Armenia
# 20       Alaverdi, Lori Province, Armenia
# ...

# %%
hotel_full_Ayrum = hotel_full_Ayrum.drop(labels = 0, axis = 0)
hotel_full_Ayrum
# Out:
#                                      city  \
# 1           Odzun, Lori Province, Armenia
# 2        Alaverdi, Lori Province, Armenia
# 3      Berdavan, Tavush Province, Armenia
# 4   Noyemberyan, Tavush Province, Armenia
# 5        Alaverdi, Lori Province, Armenia
# 6     Sarigyugh, Tavush Province, Armenia
# 7   Noyemberyan, Tavush Province, Armenia
# 8        Alaverdi, Lori Province, Armenia
# 9        Alaverdi, Lori Province, Armenia
# 10            Հաղպատ, Լոռու մարզ, Armenia
# 11       Alaverdi, Lori Province, Armenia
# 12                Алаверди, Лори, Armenia
# 13       Alaverdi, Lori Province, Armenia
# 14                         Օձուն, Armenia
# 15          Odzun, Lori Province, Armenia
# 16       Alaverdi, Lori Province, Armenia
# 17          Ալավերդի, Լոռու մարզ, Armenia
# 18        Haghpat, Lori Province, Armenia
# 19       Alaverdi, Lori Province, Armenia
# 20       Alaverdi, Lori Province, Armenia
# 21       Alaverdi, Lori Province, Armenia
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Ayrum.replace("", nan_value, inplace = True)
hotel_full_Ayrum.dropna(inplace= True)
hotel_full_Ayrum
# Out:
#                                   city                             country  \
# 1        Odzun, Lori Province, Armenia       Odzun, Lori Province, Armenia
# 2     Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 3   Berdavan, Tavush Province, Armenia  Berdavan, Tavush Province, Armenia
# 5     Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 8     Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 12             Алаверди, Лори, Armenia             Алаверди, Лори, Armenia
# 13    Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 21    Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
#
#                                               name                host_since  \
# 1   Private Villa at Odzun Monastery | Առանձնատուն       Joined in June 2015
# 2                              ARMBEE Honey Farm 2        Joined in May 2019
# ...

# %%
hotel_full_Ayrum["city"]= hotel_full_Ayrum["city"].replace({"Алаверди, Лори, Armenia" : "Alaverdi, Lori Province, Armenia"})
hotel_full_Ayrum["city"]= hotel_full_Ayrum["city"].replace({"Հաղպատ, Լոռու մարզ, Armenia" : "Haghpat, Lori Province, Armenia"})

hotel_full_Ayrum["city"]= hotel_full_Ayrum["city"].replace({"Օձուն, Armenia" : "Odzun, Lori Province, Armeni"})

hotel_full_Ayrum["city"]= hotel_full_Ayrum["city"].replace({"Ալավերդի, Լոռու մարզ, Armenia" : "Alaverdi, Lori Province, Armenia"})


hotel_full_Ayrum
# Out:
#                                   city                             country  \
# 1        Odzun, Lori Province, Armenia       Odzun, Lori Province, Armenia
# 2     Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 3   Berdavan, Tavush Province, Armenia  Berdavan, Tavush Province, Armenia
# 5     Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 8     Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 12    Alaverdi, Lori Province, Armenia             Алаверди, Лори, Armenia
# 13    Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 21    Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
#
#                                               name                host_since  \
# 1   Private Villa at Odzun Monastery | Առանձնատուն       Joined in June 2015
# 2                              ARMBEE Honey Farm 2        Joined in May 2019
# ...

# %%
city_list = []
for i in hotel_full_Ayrum.index:
    text = re.sub(",", "", hotel_full_Ayrum["city"][i][:hotel_full_Ayrum["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Ayrum["city"]= city_list
hotel_full_Ayrum
# Out:
#                          city                             country  \
# 1        Odzun Lori Province        Odzun, Lori Province, Armenia
# 2     Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 3   Berdavan Tavush Province   Berdavan, Tavush Province, Armenia
# 5     Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 8     Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 12    Alaverdi Lori Province              Алаверди, Лори, Armenia
# 13    Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 21    Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
#
#                                               name                host_since  \
# 1   Private Villa at Odzun Monastery | Առանձնատուն       Joined in June 2015
# 2                              ARMBEE Honey Farm 2        Joined in May 2019
# 3                              Berdavan guesthouse     Joined in August 2019
# ...

# %%
nan_value = float("Nan")
hotel_full_Ayrum.replace("", nan_value, inplace = True)
hotel_full_Ayrum.dropna(inplace= True)
hotel_full_Ayrum
# Out:
#                          city                             country  \
# 1        Odzun Lori Province        Odzun, Lori Province, Armenia
# 2     Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 3   Berdavan Tavush Province   Berdavan, Tavush Province, Armenia
# 5     Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 8     Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 12    Alaverdi Lori Province              Алаверди, Лори, Armenia
# 13    Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 21    Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
#
#                                               name                host_since  \
# 1   Private Villa at Odzun Monastery | Առանձնատուն       Joined in June 2015
# 2                              ARMBEE Honey Farm 2        Joined in May 2019
# 3                              Berdavan guesthouse     Joined in August 2019
# ...

# %%
c_l = []    
for k in hotel_full_Ayrum["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Ayrum["city"]= c_l
hotel_full_Ayrum
# Out:
#         city                             country  \
# 1      Odzun       Odzun, Lori Province, Armenia
# 2   Alaverdi    Alaverdi, Lori Province, Armenia
# 3   Berdavan  Berdavan, Tavush Province, Armenia
# 5   Alaverdi    Alaverdi, Lori Province, Armenia
# 8   Alaverdi    Alaverdi, Lori Province, Armenia
# 12  Alaverdi             Алаверди, Лори, Armenia
# 13  Alaverdi    Alaverdi, Lori Province, Armenia
# 21  Alaverdi    Alaverdi, Lori Province, Armenia
#
#                                               name                host_since  \
# 1   Private Villa at Odzun Monastery | Առանձնատուն       Joined in June 2015
# 2                              ARMBEE Honey Farm 2        Joined in May 2019
# 3                              Berdavan guesthouse     Joined in August 2019
# 5                               Family Guest House       Joined in June 2016
# 8                          Old City Hotel Alaverdi    Joined in January 2019
# ...

# %%
country_list = []
for i in hotel_full_Ayrum.index:
    text = re.search("Armenia", hotel_full_Ayrum["country"][i]).group()
    country_list.append(text)

hotel_full_Ayrum["country"] = country_list

# %%
hotel_full_Ayrum
# Out:
#         city  country                                            name  \
# 1      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 2   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 3   Berdavan  Armenia                             Berdavan guesthouse
# 5   Alaverdi  Armenia                              Family Guest House
# 8   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 12  Alaverdi  Armenia                     Приезжайте к нам отдыхать!!
# 13  Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 21  Alaverdi  Armenia                                      Mini House
#
#                   host_since  \
# 1        Joined in June 2015
# 2         Joined in May 2019
# 3      Joined in August 2019
# 5        Joined in June 2016
# 8     Joined in January 2019
# 12       Joined in June 2014
# 13    Joined in January 2019
# 21  Joined in September 2017
#
#                                    host_response_rate  \
# ...

# %%
host_since_list = []
for i in hotel_full_Ayrum.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Ayrum.host_since = hs 
hotel_full_Ayrum.host_since
# Out:
# 1     2015
# 2     2019
# 3     2019
# 5     2016
# 8     2019
# 12    2014
# 13    2019
# 21    2017
# Name: host_since, dtype: int64

# %%
hotel_full_Ayrum
# Out:
#         city  country                                            name  \
# 1      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 2   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 3   Berdavan  Armenia                             Berdavan guesthouse
# 5   Alaverdi  Armenia                              Family Guest House
# 8   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 12  Alaverdi  Armenia                     Приезжайте к нам отдыхать!!
# 13  Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 21  Alaverdi  Armenia                                      Mini House
#
#     host_since                                 host_response_rate  \
# 1         2015  Languages: English, Deutsch, Русский\nResponse...
# 2         2019  Languages: English, Русский\nResponse rate: 10...
# 3         2019  Languages: English, Русский\nResponse rate: 10...
# 5         2016  Languages: English, Русский\nResponse rate: 10...
# ...

# %%
string = []
for i in hotel_full_Ayrum.index:
    st = hotel_full_Ayrum.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["27 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "5 Reviews', 'Identity verified",
#  'Identity verified',
#  "10 Reviews', 'Identity verified",
#  '8 Reviews',
#  '5 Reviews',
#  '8 Reviews',
#  '6 Reviews']

# %%
hotel_full_Ayrum.host_identity_verified = string
hotel_full_Ayrum.host_identity_verified
# Out:
# 1     27 Reviews', 'Identity verified', '\U000f0003'...
# 2                        5 Reviews', 'Identity verified
# 3                                     Identity verified
# 5                       10 Reviews', 'Identity verified
# 8                                             8 Reviews
# 12                                            5 Reviews
# 13                                            8 Reviews
# 21                                            6 Reviews
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Ayrum.index:
    if "Identity verified" in  hotel_full_Ayrum.host_identity_verified[i]:
        hotel_full_Ayrum.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Ayrum.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Ayrum
# Out:
#         city  country                                            name  \
# 1      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 2   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 3   Berdavan  Armenia                             Berdavan guesthouse
# 5   Alaverdi  Armenia                              Family Guest House
# 8   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 12  Alaverdi  Armenia                     Приезжайте к нам отдыхать!!
# 13  Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 21  Alaverdi  Armenia                                      Mini House
#
#     host_since                                 host_response_rate  \
# 1         2015  Languages: English, Deutsch, Русский\nResponse...
# 2         2019  Languages: English, Русский\nResponse rate: 10...
# 3         2019  Languages: English, Русский\nResponse rate: 10...
# 5         2016  Languages: English, Русский\nResponse rate: 10...
# ...

# %%
for i in hotel_full_Ayrum.index:
    if "Review" in  hotel_full_Ayrum.review[i]:
        hotel_full_Ayrum.loc[i, 'review'] = re.search("(\d+)", hotel_full_Ayrum.review[i]).group()
        
    else:
        hotel_full_Ayrum.loc[i, 'review'] = 0

# %%
hotel_full_Ayrum
# Out:
#         city  country                                            name  \
# 1      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 2   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 3   Berdavan  Armenia                             Berdavan guesthouse
# 5   Alaverdi  Armenia                              Family Guest House
# 8   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 12  Alaverdi  Armenia                     Приезжайте к нам отдыхать!!
# 13  Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 21  Alaverdi  Armenia                                      Mini House
#
#     host_since                                 host_response_rate  \
# 1         2015  Languages: English, Deutsch, Русский\nResponse...
# 2         2019  Languages: English, Русский\nResponse rate: 10...
# 3         2019  Languages: English, Русский\nResponse rate: 10...
# 5         2016  Languages: English, Русский\nResponse rate: 10...
# ...

# %%
for i in hotel_full_Ayrum.index:
    if "Superhost" in  hotel_full_Ayrum.superhost[i]:
        hotel_full_Ayrum.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Ayrum.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Ayrum.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire villa',
#  'Entire chalet',
#  'Private room in farm stay',
#  'Private room in guest suite  Hovasapyan',
#  'Room in hotel',
#  'Entire place',
#  'Private room in rental unit',
#  'Private room in bed and breakfast']

# %%
hotel_full_Ayrum.property_type =prop_list

# %%
hotel_full_Ayrum
# Out:
#         city  country                                            name  \
# 1      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 2   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 3   Berdavan  Armenia                             Berdavan guesthouse
# 5   Alaverdi  Armenia                              Family Guest House
# 8   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 12  Alaverdi  Armenia                     Приезжайте к нам отдыхать!!
# 13  Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 21  Alaverdi  Armenia                                      Mini House
#
#     host_since                                 host_response_rate  \
# 1         2015  Languages: English, Deutsch, Русский\nResponse...
# 2         2019  Languages: English, Русский\nResponse rate: 10...
# 3         2019  Languages: English, Русский\nResponse rate: 10...
# 5         2016  Languages: English, Русский\nResponse rate: 10...
# ...

# %%
accomodates_list = []
for i in hotel_full_Ayrum.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Ayrum.accomodates = number

# %%
for i in hotel_full_Ayrum.index:
    if "Shared half-bath" in  hotel_full_Ayrum.number_bathroom[i]:
        hotel_full_Ayrum.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Ayrum.number_bathroom[i]:
        hotel_full_Ayrum.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Ayrum.number_bathroom[i]:
        hotel_full_Ayrum.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Ayrum.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Ayrum.number_bedroom[i])
        hotel_full_Ayrum.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Ayrum.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Ayrum.number_bedroom[i])
        hotel_full_Ayrum.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Ayrum.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Ayrum.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Ayrum.index:
    if "bed" in  hotel_full_Ayrum.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Ayrum.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Ayrum.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['4', '2', '8', '7', '8', '16', '13', '9']

# %%
len(hotel_full_Ayrum.number_beds)
# Out:
# 8

# %%
len(number_beds_list)
# Out:
# 8

# %%
hotel_full_Ayrum.number_beds = number_beds_list

# %%
hotel_full_Ayrum.number_beds
# Out:
# 1      4
# 2      2
# 3      8
# 5      7
# 8      8
# 12    16
# 13    13
# 21     9
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Ayrum.index:
    if "Studio" in  hotel_full_Ayrum.number_bedroom[i]:
        hotel_full_Ayrum.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Ayrum.number_bedroom[i])
        hotel_full_Ayrum.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Ayrum.index:
    if "Cleanliness" in  hotel_full_Ayrum.cleanliness[i]:
        hotel_full_Ayrum.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Ayrum.cleanliness[i])
    else:
        hotel_full_Ayrum.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Ayrum.index:
    if "Accuracy" in  hotel_full_Ayrum.accuracy[i]:
        hotel_full_Ayrum.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Ayrum.accuracy[i])
    else:
        hotel_full_Ayrum.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Ayrum.index:
    if "Communication" in  hotel_full_Ayrum.communication[i]:
        hotel_full_Ayrum.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Ayrum.communication[i])
    else:
        hotel_full_Ayrum.loc[i, 'communication'] = None

# %%
for i in hotel_full_Ayrum.index:
    if "Location" in  hotel_full_Ayrum.location[i]:
        try:
            hotel_full_Ayrum.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Ayrum.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Ayrum.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Ayrum.location[i])
    
    else:
        hotel_full_Ayrum.loc[i, 'location'] = None

# %%
for i in hotel_full_Ayrum.index:
    if "Check-in" in  hotel_full_Ayrum.check_in[i]:
        hotel_full_Ayrum.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Ayrum.check_in[i])
    else:
        hotel_full_Ayrum.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Ayrum.index:
    if "Value" in  hotel_full_Ayrum.value[i]:
        hotel_full_Ayrum.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Ayrum.value[i])
    else:
        hotel_full_Ayrum.loc[i, 'value'] = None

# %%
for i in hotel_full_Ayrum.index:
    if "No reviews (yet)" in  hotel_full_Ayrum.rating[i]:
        hotel_full_Ayrum.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Ayrum.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Ayrum.price = price_list

# %%
for i in hotel_full_Ayrum.index:
    if "Response rate" in  hotel_full_Ayrum.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Ayrum.host_response_rate[i])
        hotel_full_Ayrum.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Ayrum.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Ayrum = hotel_full_Ayrum.astype(convert_dict)

# %%
hotel_full_Ayrum.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Ayrum.to_csv("cleaned_hotel_full_Ayrum.csv", index=False)
hotel_full_Ayrum.to_excel("cleaned_hotel_full_Ayrum2.xlsx", index=False)
