# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Kajaran = pd.read_csv('hotel_full_Kajaran.csv')
hotel_full_Kajaran
# Out:
#                                   city                              country  \
# 0                                  NaN                                  NaN
# 1                Капан, Сюник, Armenia                Капан, Сюник, Armenia
# 2               Kapan, Syunik, Armenia               Kapan, Syunik, Armenia
# 3       Tsav, Syunik Province, Armenia       Tsav, Syunik Province, Armenia
# 4      Kapan, Syunik Province, Armenia      Kapan, Syunik Province, Armenia
# 5      Kapan, Syunik Province, Armenia      Kapan, Syunik Province, Armenia
# 6       Tsav, Syunik Province, Armenia       Tsav, Syunik Province, Armenia
# 7  Tandzaver, Syunik Province, Armenia  Tandzaver, Syunik Province, Armenia
# 8      Kapan, Syunik Province, Armenia      Kapan, Syunik Province, Armenia
# 9      Kapan, Syunik Province, Armenia      Kapan, Syunik Province, Armenia
#
#                                               name                host_since  \
# ...

# %%
hotel_full_Kajaran = hotel_full_Kajaran.drop(labels = 0, axis = 0)
hotel_full_Kajaran
# Out:
#                                   city                              country  \
# 1                Капан, Сюник, Armenia                Капан, Сюник, Armenia
# 2               Kapan, Syunik, Armenia               Kapan, Syunik, Armenia
# 3       Tsav, Syunik Province, Armenia       Tsav, Syunik Province, Armenia
# 4      Kapan, Syunik Province, Armenia      Kapan, Syunik Province, Armenia
# 5      Kapan, Syunik Province, Armenia      Kapan, Syunik Province, Armenia
# 6       Tsav, Syunik Province, Armenia       Tsav, Syunik Province, Armenia
# 7  Tandzaver, Syunik Province, Armenia  Tandzaver, Syunik Province, Armenia
# 8      Kapan, Syunik Province, Armenia      Kapan, Syunik Province, Armenia
# 9      Kapan, Syunik Province, Armenia      Kapan, Syunik Province, Armenia
#
#                                               name                host_since  \
# 1               Country house overlooking Paradise       Joined in July 2014
# ...

# %%
nan_value = float("Nan")
hotel_full_Kajaran.replace("", nan_value, inplace = True)
hotel_full_Kajaran.dropna(inplace= True)
hotel_full_Kajaran
# Out:
#                      city                 country  \
# 1   Капан, Сюник, Armenia   Капан, Сюник, Armenia
# 2  Kapan, Syunik, Armenia  Kapan, Syunik, Armenia
#
#                                  name                host_since  \
# 1  Country house overlooking Paradise       Joined in July 2014
# 2          K7 Armenia Mountain Bunker  Joined in September 2015
#
#                                   host_response_rate  \
# 1                        Languages: English, Русский
# 2  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                              review  \
# 1  ['7 Reviews', 'Identity verified']  ['7 Reviews', 'Identity verified']
# 2  ['4 Reviews', 'Identity verified']  ['4 Reviews', 'Identity verified']
#
#                       superhost                               property_type  \
# 1  7 Reviews\nIdentity verified  Entire residential home hosted by Siranush
# ...

# %%
hotel_full_Kajaran["city"]= hotel_full_Kajaran["city"].replace({"Капан, Сюник, Armenia" : "Kapan, Armenia"})

# %%
city_list = []
for i in hotel_full_Kajaran.index:
    text = re.sub(",", "", hotel_full_Kajaran["city"][i][:hotel_full_Kajaran["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Kajaran["city"]= city_list
hotel_full_Kajaran
# Out:
#             city                 country                                name  \
# 1         Kapan    Капан, Сюник, Armenia  Country house overlooking Paradise
# 2  Kapan Syunik   Kapan, Syunik, Armenia          K7 Armenia Mountain Bunker
#
#                  host_since  \
# 1       Joined in July 2014
# 2  Joined in September 2015
#
#                                   host_response_rate  \
# 1                        Languages: English, Русский
# 2  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                              review  \
# 1  ['7 Reviews', 'Identity verified']  ['7 Reviews', 'Identity verified']
# 2  ['4 Reviews', 'Identity verified']  ['4 Reviews', 'Identity verified']
#
#                       superhost                               property_type  \
# 1  7 Reviews\nIdentity verified  Entire residential home hosted by Siranush
# 2  4 Reviews\nIdentity verified   Private room in tiny house hosted by Hayk
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Kajaran.replace("", nan_value, inplace = True)
hotel_full_Kajaran.dropna(inplace= True)
hotel_full_Kajaran
# Out:
#             city                 country                                name  \
# 1         Kapan    Капан, Сюник, Armenia  Country house overlooking Paradise
# 2  Kapan Syunik   Kapan, Syunik, Armenia          K7 Armenia Mountain Bunker
#
#                  host_since  \
# 1       Joined in July 2014
# 2  Joined in September 2015
#
#                                   host_response_rate  \
# 1                        Languages: English, Русский
# 2  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                              review  \
# 1  ['7 Reviews', 'Identity verified']  ['7 Reviews', 'Identity verified']
# 2  ['4 Reviews', 'Identity verified']  ['4 Reviews', 'Identity verified']
#
#                       superhost                               property_type  \
# 1  7 Reviews\nIdentity verified  Entire residential home hosted by Siranush
# 2  4 Reviews\nIdentity verified   Private room in tiny house hosted by Hayk
#
# ...

# %%
c_l = []    
for k in hotel_full_Kajaran["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Kajaran["city"]= c_l
hotel_full_Kajaran
# Out:
#     city                 country                                name  \
# 1  Kapan   Капан, Сюник, Armenia  Country house overlooking Paradise
# 2  Kapan  Kapan, Syunik, Armenia          K7 Armenia Mountain Bunker
#
#                  host_since  \
# 1       Joined in July 2014
# 2  Joined in September 2015
#
#                                   host_response_rate  \
# 1                        Languages: English, Русский
# 2  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                              review  \
# 1  ['7 Reviews', 'Identity verified']  ['7 Reviews', 'Identity verified']
# 2  ['4 Reviews', 'Identity verified']  ['4 Reviews', 'Identity verified']
#
#                       superhost                               property_type  \
# 1  7 Reviews\nIdentity verified  Entire residential home hosted by Siranush
# 2  4 Reviews\nIdentity verified   Private room in tiny house hosted by Hayk
#
# ...

# %%
country_list = []
for i in hotel_full_Kajaran.index:
    text = re.search("Armenia", hotel_full_Kajaran["country"][i]).group()
    country_list.append(text)

hotel_full_Kajaran["country"] = country_list

# %%
hotel_full_Kajaran
# Out:
#     city  country                                name  \
# 1  Kapan  Armenia  Country house overlooking Paradise
# 2  Kapan  Armenia          K7 Armenia Mountain Bunker
#
#                  host_since  \
# 1       Joined in July 2014
# 2  Joined in September 2015
#
#                                   host_response_rate  \
# 1                        Languages: English, Русский
# 2  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                              review  \
# 1  ['7 Reviews', 'Identity verified']  ['7 Reviews', 'Identity verified']
# 2  ['4 Reviews', 'Identity verified']  ['4 Reviews', 'Identity verified']
#
#                       superhost                               property_type  \
# 1  7 Reviews\nIdentity verified  Entire residential home hosted by Siranush
# 2  4 Reviews\nIdentity verified   Private room in tiny house hosted by Hayk
#
#                                          accomodates  ...  \
# ...

# %%
host_since_list = []
for i in hotel_full_Kajaran.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Kajaran.host_since = hs 
hotel_full_Kajaran.host_since
# Out:
# 1    2014
# 2    2015
# Name: host_since, dtype: int64

# %%
hotel_full_Kajaran
# Out:
#     city  country                                name  host_since  \
# 1  Kapan  Armenia  Country house overlooking Paradise        2014
# 2  Kapan  Armenia          K7 Armenia Mountain Bunker        2015
#
#                                   host_response_rate  \
# 1                        Languages: English, Русский
# 2  Response rate: 100%\nResponse time: within an ...
#
#                host_identity_verified                              review  \
# 1  ['7 Reviews', 'Identity verified']  ['7 Reviews', 'Identity verified']
# 2  ['4 Reviews', 'Identity verified']  ['4 Reviews', 'Identity verified']
#
#                       superhost                               property_type  \
# 1  7 Reviews\nIdentity verified  Entire residential home hosted by Siranush
# 2  4 Reviews\nIdentity verified   Private room in tiny house hosted by Hayk
#
#                                          accomodates  ...  \
# 1  Entire residential home hosted by Siranush\n7 ...  ...
# ...

# %%
string = []
for i in hotel_full_Kajaran.index:
    st = hotel_full_Kajaran.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["7 Reviews', 'Identity verified", "4 Reviews', 'Identity verified"]

# %%
hotel_full_Kajaran.host_identity_verified = string
hotel_full_Kajaran.host_identity_verified
# Out:
# 1    7 Reviews', 'Identity verified
# 2    4 Reviews', 'Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Kajaran.index:
    if "Identity verified" in  hotel_full_Kajaran.host_identity_verified[i]:
        hotel_full_Kajaran.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Kajaran.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Kajaran
# Out:
#     city  country                                name  host_since  \
# 1  Kapan  Armenia  Country house overlooking Paradise        2014
# 2  Kapan  Armenia          K7 Armenia Mountain Bunker        2015
#
#                                   host_response_rate host_identity_verified  \
# 1                        Languages: English, Русский      Identity verified
# 2  Response rate: 100%\nResponse time: within an ...      Identity verified
#
#                                review                     superhost  \
# 1  ['7 Reviews', 'Identity verified']  7 Reviews\nIdentity verified
# 2  ['4 Reviews', 'Identity verified']  4 Reviews\nIdentity verified
#
#                                 property_type  \
# 1  Entire residential home hosted by Siranush
# 2   Private room in tiny house hosted by Hayk
#
#                                          accomodates  ...  \
# 1  Entire residential home hosted by Siranush\n7 ...  ...
# 2  Private room in tiny house hosted by Hayk\n16 ...  ...
#
# ...

# %%
for i in hotel_full_Kajaran.index:
    if "Review" in  hotel_full_Kajaran.review[i]:
        hotel_full_Kajaran.loc[i, 'review'] = re.search("(\d+)", hotel_full_Kajaran.review[i]).group()
        
    else:
        hotel_full_Kajaran.loc[i, 'review'] = 0

# %%
hotel_full_Kajaran
# Out:
#     city  country                                name  host_since  \
# 1  Kapan  Armenia  Country house overlooking Paradise        2014
# 2  Kapan  Armenia          K7 Armenia Mountain Bunker        2015
#
#                                   host_response_rate host_identity_verified  \
# 1                        Languages: English, Русский      Identity verified
# 2  Response rate: 100%\nResponse time: within an ...      Identity verified
#
#   review                     superhost  \
# 1      7  7 Reviews\nIdentity verified
# 2      4  4 Reviews\nIdentity verified
#
#                                 property_type  \
# 1  Entire residential home hosted by Siranush
# 2   Private room in tiny house hosted by Hayk
#
#                                          accomodates  ...  \
# 1  Entire residential home hosted by Siranush\n7 ...  ...
# 2  Private room in tiny house hosted by Hayk\n16 ...  ...
#
#                                       number_bedroom  \
# ...

# %%
for i in hotel_full_Kajaran.index:
    if "Superhost" in  hotel_full_Kajaran.superhost[i]:
        hotel_full_Kajaran.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Kajaran.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Kajaran.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire residential home', 'Private room in tiny house']

# %%
hotel_full_Kajaran.property_type =prop_list

# %%
hotel_full_Kajaran
# Out:
#     city  country                                name  host_since  \
# 1  Kapan  Armenia  Country house overlooking Paradise        2014
# 2  Kapan  Armenia          K7 Armenia Mountain Bunker        2015
#
#                                   host_response_rate host_identity_verified  \
# 1                        Languages: English, Русский      Identity verified
# 2  Response rate: 100%\nResponse time: within an ...      Identity verified
#
#   review     superhost               property_type  \
# 1      7  regular host     Entire residential home
# 2      4  regular host  Private room in tiny house
#
#                                          accomodates  ...  \
# 1  Entire residential home hosted by Siranush\n7 ...  ...
# 2  Private room in tiny house hosted by Hayk\n16 ...  ...
#
#                                       number_bedroom  \
# 1  Entire residential home hosted by Siranush\n7 ...
# 2  Private room in tiny house hosted by Hayk\n16 ...
#
# ...

# %%
accomodates_list = []
for i in hotel_full_Kajaran.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Kajaran.accomodates = number

# %%
for i in hotel_full_Kajaran.index:
    if "Shared half-bath" in  hotel_full_Kajaran.number_bathroom[i]:
        hotel_full_Kajaran.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Kajaran.number_bathroom[i]:
        hotel_full_Kajaran.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Kajaran.number_bathroom[i]:
        hotel_full_Kajaran.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Kajaran.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Kajaran.number_bedroom[i])
        hotel_full_Kajaran.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Kajaran.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Kajaran.number_bedroom[i])
        hotel_full_Kajaran.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Kajaran.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Kajaran.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Kajaran.index:
    if "bed" in  hotel_full_Kajaran.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Kajaran.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Kajaran.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['6', '2']

# %%
len(hotel_full_Kajaran.number_beds)
# Out:
# 2

# %%
len(number_beds_list)
# Out:
# 2

# %%
hotel_full_Kajaran.number_beds = number_beds_list

# %%
hotel_full_Kajaran.number_beds
# Out:
# 1    6
# 2    2
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Kajaran.index:
    if "Studio" in  hotel_full_Kajaran.number_bedroom[i]:
        hotel_full_Kajaran.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Kajaran.number_bedroom[i])
        hotel_full_Kajaran.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Kajaran.index:
    if "Cleanliness" in  hotel_full_Kajaran.cleanliness[i]:
        hotel_full_Kajaran.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Kajaran.cleanliness[i])
    else:
        hotel_full_Kajaran.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Kajaran.index:
    if "Accuracy" in  hotel_full_Kajaran.accuracy[i]:
        hotel_full_Kajaran.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Kajaran.accuracy[i])
    else:
        hotel_full_Kajaran.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Kajaran.index:
    if "Communication" in  hotel_full_Kajaran.communication[i]:
        hotel_full_Kajaran.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Kajaran.communication[i])
    else:
        hotel_full_Kajaran.loc[i, 'communication'] = None

# %%
for i in hotel_full_Kajaran.index:
    if "Location" in  hotel_full_Kajaran.location[i]:
        try:
            hotel_full_Kajaran.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Kajaran.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Kajaran.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Kajaran.location[i])
    
    else:
        hotel_full_Kajaran.loc[i, 'location'] = None

# %%
for i in hotel_full_Kajaran.index:
    if "Check-in" in  hotel_full_Kajaran.check_in[i]:
        hotel_full_Kajaran.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Kajaran.check_in[i])
    else:
        hotel_full_Kajaran.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Kajaran.index:
    if "Value" in  hotel_full_Kajaran.value[i]:
        hotel_full_Kajaran.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Kajaran.value[i])
    else:
        hotel_full_Kajaran.loc[i, 'value'] = None

# %%
for i in hotel_full_Kajaran.index:
    if "No reviews (yet)" in  hotel_full_Kajaran.rating[i]:
        hotel_full_Kajaran.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Kajaran.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Kajaran.price = price_list

# %%
for i in hotel_full_Kajaran.index:
    if "Response rate" in  hotel_full_Kajaran.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Kajaran.host_response_rate[i])
        hotel_full_Kajaran.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Kajaran.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Kajaran = hotel_full_Kajaran.astype(convert_dict)

# %%
hotel_full_Kajaran.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Kajaran.to_csv("cleaned_hotel_full_Kajaran.csv", index=False)
hotel_full_Kajaran.to_excel("cleaned_hotel_full_Kajaran2.xlsx", index=False)
