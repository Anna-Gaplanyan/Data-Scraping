# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Vagharshapat = pd.read_csv('hotel_full_Vagharshapat.csv')
hotel_full_Vagharshapat
# Out:
#                                        city  \
# 0                                       NaN
# 1   Vagharshapat, Armavir Province, Armenia
# 2   Vagharshapat, Armavir Province, Armenia
# 3   Vagharshapat, Armavir Province, Armenia
# 4   Vagharshapat, Armavir Province, Armenia
# 5   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat, Armavir Province, Armenia
# 7   Vagharshapat, Armavir Province, Armenia
# 8   Vagharshapat, Armavir Province, Armenia
# 9   Vagharshapat, Armavir Province, Armenia
# 10  Vagharshapat, Armavir Province, Armenia
# 11  Vagharshapat, Armavir Province, Armenia
# 12           Vagharshapat, Armavir, Armenia
# 13  Vagharshapat, Armavir Province, Armenia
# 14           Vagharshapat, Armavir, Armenia
# 15  Vagharshapat, Armavir Province, Armenia
# 16  Vagharshapat, Armavir Province, Armenia
# 17  Vagharshapat, Armavir Province, Armenia
# 18  Vagharshapat, Armavir Province, Armenia
# 19  Vagharshapat, Armavir Province, Armenia
# ...

# %%
hotel_full_Vagharshapat = hotel_full_Vagharshapat.drop(labels = 0, axis = 0)
hotel_full_Vagharshapat
# Out:
#                                        city  \
# 1   Vagharshapat, Armavir Province, Armenia
# 2   Vagharshapat, Armavir Province, Armenia
# 3   Vagharshapat, Armavir Province, Armenia
# 4   Vagharshapat, Armavir Province, Armenia
# 5   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat, Armavir Province, Armenia
# 7   Vagharshapat, Armavir Province, Armenia
# 8   Vagharshapat, Armavir Province, Armenia
# 9   Vagharshapat, Armavir Province, Armenia
# 10  Vagharshapat, Armavir Province, Armenia
# 11  Vagharshapat, Armavir Province, Armenia
# 12           Vagharshapat, Armavir, Armenia
# 13  Vagharshapat, Armavir Province, Armenia
# 14           Vagharshapat, Armavir, Armenia
# 15  Vagharshapat, Armavir Province, Armenia
# 16  Vagharshapat, Armavir Province, Armenia
# 17  Vagharshapat, Armavir Province, Armenia
# 18  Vagharshapat, Armavir Province, Armenia
# 19  Vagharshapat, Armavir Province, Armenia
# 20           Vagharshapat, Armavir, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Vagharshapat.replace("", nan_value, inplace = True)
hotel_full_Vagharshapat.dropna(inplace= True)
hotel_full_Vagharshapat
# Out:
#                                        city  \
# 1   Vagharshapat, Armavir Province, Armenia
# 4   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat, Armavir Province, Armenia
# 8   Vagharshapat, Armavir Province, Armenia
# 10  Vagharshapat, Armavir Province, Armenia
# 15  Vagharshapat, Armavir Province, Armenia
# 16  Vagharshapat, Armavir Province, Armenia
#
#                                     country  \
# 1   Vagharshapat, Armavir Province, Armenia
# 4   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat, Armavir Province, Armenia
# 8   Vagharshapat, Armavir Province, Armenia
# 10  Vagharshapat, Armavir Province, Armenia
# 15  Vagharshapat, Armavir Province, Armenia
# 16  Vagharshapat, Armavir Province, Armenia
#
#                                          name               host_since  \
# 1                                    Art home       Joined in May 2019
# 4   RICHMIND HOTEL - in hormone with thoughts   Joined in October 2019
# ...

# %%
city_list = []
for i in hotel_full_Vagharshapat.index:
    text = re.sub(",", "", hotel_full_Vagharshapat["city"][i][:hotel_full_Vagharshapat["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Vagharshapat["city"]= city_list
hotel_full_Vagharshapat
# Out:
#                               city                                  country  \
# 1   Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 4   Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 8   Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 10  Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 15  Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 16  Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
#
#                                          name               host_since  \
# 1                                    Art home       Joined in May 2019
# 4   RICHMIND HOTEL - in hormone with thoughts   Joined in October 2019
# 6                       THE HEAVEN ECHMIADZIN  Joined in November 2014
# 8   RICHMIND HOTEL - in hormone with thoughts   Joined in October 2019
# ...

# %%
nan_value = float("Nan")
hotel_full_Vagharshapat.replace("", nan_value, inplace = True)
hotel_full_Vagharshapat.dropna(inplace= True)
hotel_full_Vagharshapat
# Out:
#                               city                                  country  \
# 1   Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 4   Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 8   Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 10  Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 15  Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# 16  Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
#
#                                          name               host_since  \
# 1                                    Art home       Joined in May 2019
# 4   RICHMIND HOTEL - in hormone with thoughts   Joined in October 2019
# 6                       THE HEAVEN ECHMIADZIN  Joined in November 2014
# 8   RICHMIND HOTEL - in hormone with thoughts   Joined in October 2019
# ...

# %%
c_l = []    
for k in hotel_full_Vagharshapat["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Vagharshapat["city"]= c_l
hotel_full_Vagharshapat
# Out:
#             city                                  country  \
# 1   Vagharshapat  Vagharshapat, Armavir Province, Armenia
# 4   Vagharshapat  Vagharshapat, Armavir Province, Armenia
# 6   Vagharshapat  Vagharshapat, Armavir Province, Armenia
# 8   Vagharshapat  Vagharshapat, Armavir Province, Armenia
# 10  Vagharshapat  Vagharshapat, Armavir Province, Armenia
# 15  Vagharshapat  Vagharshapat, Armavir Province, Armenia
# 16  Vagharshapat  Vagharshapat, Armavir Province, Armenia
#
#                                          name               host_since  \
# 1                                    Art home       Joined in May 2019
# 4   RICHMIND HOTEL - in hormone with thoughts   Joined in October 2019
# 6                       THE HEAVEN ECHMIADZIN  Joined in November 2014
# 8   RICHMIND HOTEL - in hormone with thoughts   Joined in October 2019
# 10  RICHMIND HOTEL - in hormone with thoughts   Joined in October 2019
# 15  RICHMIND HOTEL - in hormone with thoughts   Joined in October 2019
# ...

# %%
country_list = []
for i in hotel_full_Vagharshapat.index:
    text = re.search("Armenia", hotel_full_Vagharshapat["country"][i]).group()
    country_list.append(text)

hotel_full_Vagharshapat["country"] = country_list

# %%
hotel_full_Vagharshapat
# Out:
#             city  country                                       name  \
# 1   Vagharshapat  Armenia                                   Art home
# 4   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 6   Vagharshapat  Armenia                      THE HEAVEN ECHMIADZIN
# 8   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 10  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 15  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 16  Vagharshapat  Armenia   Large two-floor house with swimming pool
#
#                  host_since  \
# 1        Joined in May 2019
# 4    Joined in October 2019
# 6   Joined in November 2014
# 8    Joined in October 2019
# 10   Joined in October 2019
# 15   Joined in October 2019
# 16     Joined in April 2014
#
#                                    host_response_rate  \
# 1   Languages: English, Русский\nResponse rate: 89...
# 4                         Languages: English, Русский
# ...

# %%
host_since_list = []
for i in hotel_full_Vagharshapat.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Vagharshapat.host_since = hs 
hotel_full_Vagharshapat.host_since
# Out:
# 1     2019
# 4     2019
# 6     2014
# 8     2019
# 10    2019
# 15    2019
# 16    2014
# Name: host_since, dtype: int64

# %%
hotel_full_Vagharshapat
# Out:
#             city  country                                       name  \
# 1   Vagharshapat  Armenia                                   Art home
# 4   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 6   Vagharshapat  Armenia                      THE HEAVEN ECHMIADZIN
# 8   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 10  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 15  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 16  Vagharshapat  Armenia   Large two-floor house with swimming pool
#
#     host_since                                 host_response_rate  \
# 1         2019  Languages: English, Русский\nResponse rate: 89...
# 4         2019                        Languages: English, Русский
# 6         2014  Languages: English, Español\nResponse rate: 10...
# 8         2019                        Languages: English, Русский
# 10        2019                        Languages: English, Русский
# ...

# %%
string = []
for i in hotel_full_Vagharshapat.index:
    st = hotel_full_Vagharshapat.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["6 Reviews', 'Identity verified",
#  'Identity verified',
#  "7 Reviews', 'Identity verified",
#  'Identity verified',
#  'Identity verified',
#  'Identity verified',
#  'Identity verified']

# %%
hotel_full_Vagharshapat.host_identity_verified = string
hotel_full_Vagharshapat.host_identity_verified
# Out:
# 1     6 Reviews', 'Identity verified
# 4                  Identity verified
# 6     7 Reviews', 'Identity verified
# 8                  Identity verified
# 10                 Identity verified
# 15                 Identity verified
# 16                 Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Vagharshapat.index:
    if "Identity verified" in  hotel_full_Vagharshapat.host_identity_verified[i]:
        hotel_full_Vagharshapat.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Vagharshapat.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Vagharshapat
# Out:
#             city  country                                       name  \
# 1   Vagharshapat  Armenia                                   Art home
# 4   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 6   Vagharshapat  Armenia                      THE HEAVEN ECHMIADZIN
# 8   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 10  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 15  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 16  Vagharshapat  Armenia   Large two-floor house with swimming pool
#
#     host_since                                 host_response_rate  \
# 1         2019  Languages: English, Русский\nResponse rate: 89...
# 4         2019                        Languages: English, Русский
# 6         2014  Languages: English, Español\nResponse rate: 10...
# 8         2019                        Languages: English, Русский
# 10        2019                        Languages: English, Русский
# ...

# %%
for i in hotel_full_Vagharshapat.index:
    if "Review" in  hotel_full_Vagharshapat.review[i]:
        hotel_full_Vagharshapat.loc[i, 'review'] = re.search("(\d+)", hotel_full_Vagharshapat.review[i]).group()
        
    else:
        hotel_full_Vagharshapat.loc[i, 'review'] = 0

# %%
hotel_full_Vagharshapat
# Out:
#             city  country                                       name  \
# 1   Vagharshapat  Armenia                                   Art home
# 4   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 6   Vagharshapat  Armenia                      THE HEAVEN ECHMIADZIN
# 8   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 10  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 15  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 16  Vagharshapat  Armenia   Large two-floor house with swimming pool
#
#     host_since                                 host_response_rate  \
# 1         2019  Languages: English, Русский\nResponse rate: 89...
# 4         2019                        Languages: English, Русский
# 6         2014  Languages: English, Español\nResponse rate: 10...
# 8         2019                        Languages: English, Русский
# 10        2019                        Languages: English, Русский
# ...

# %%
for i in hotel_full_Vagharshapat.index:
    if "Superhost" in  hotel_full_Vagharshapat.superhost[i]:
        hotel_full_Vagharshapat.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Vagharshapat.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Vagharshapat.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire rental unit',
#  'Room in hotel',
#  'Entire residential home',
#  'Room in hotel',
#  'Room in hotel',
#  'Room in hotel',
#  'Entire villa']

# %%
hotel_full_Vagharshapat.property_type =prop_list

# %%
hotel_full_Vagharshapat
# Out:
#             city  country                                       name  \
# 1   Vagharshapat  Armenia                                   Art home
# 4   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 6   Vagharshapat  Armenia                      THE HEAVEN ECHMIADZIN
# 8   Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 10  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 15  Vagharshapat  Armenia  RICHMIND HOTEL - in hormone with thoughts
# 16  Vagharshapat  Armenia   Large two-floor house with swimming pool
#
#     host_since                                 host_response_rate  \
# 1         2019  Languages: English, Русский\nResponse rate: 89...
# 4         2019                        Languages: English, Русский
# 6         2014  Languages: English, Español\nResponse rate: 10...
# 8         2019                        Languages: English, Русский
# 10        2019                        Languages: English, Русский
# ...

# %%
accomodates_list = []
for i in hotel_full_Vagharshapat.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Vagharshapat.accomodates = number

# %%
for i in hotel_full_Vagharshapat.index:
    if "Shared half-bath" in  hotel_full_Vagharshapat.number_bathroom[i]:
        hotel_full_Vagharshapat.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Vagharshapat.number_bathroom[i]:
        hotel_full_Vagharshapat.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Vagharshapat.number_bathroom[i]:
        hotel_full_Vagharshapat.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Vagharshapat.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Vagharshapat.number_bedroom[i])
        hotel_full_Vagharshapat.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Vagharshapat.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Vagharshapat.number_bedroom[i])
        hotel_full_Vagharshapat.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Vagharshapat.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Vagharshapat.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Vagharshapat.index:
    if "bed" in  hotel_full_Vagharshapat.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Vagharshapat.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Vagharshapat.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['2', '1', '2', '0', '3', '2', '6']

# %%
len(hotel_full_Vagharshapat.number_beds)
# Out:
# 7

# %%
len(number_beds_list)
# Out:
# 7

# %%
hotel_full_Vagharshapat.number_beds = number_beds_list

# %%
hotel_full_Vagharshapat.number_beds
# Out:
# 1     2
# 4     1
# 6     2
# 8     0
# 10    3
# 15    2
# 16    6
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Vagharshapat.index:
    if "Studio" in  hotel_full_Vagharshapat.number_bedroom[i]:
        hotel_full_Vagharshapat.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Vagharshapat.number_bedroom[i])
        hotel_full_Vagharshapat.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Vagharshapat.index:
    if "Cleanliness" in  hotel_full_Vagharshapat.cleanliness[i]:
        hotel_full_Vagharshapat.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Vagharshapat.cleanliness[i])
    else:
        hotel_full_Vagharshapat.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Vagharshapat.index:
    if "Accuracy" in  hotel_full_Vagharshapat.accuracy[i]:
        hotel_full_Vagharshapat.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Vagharshapat.accuracy[i])
    else:
        hotel_full_Vagharshapat.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Vagharshapat.index:
    if "Communication" in  hotel_full_Vagharshapat.communication[i]:
        hotel_full_Vagharshapat.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Vagharshapat.communication[i])
    else:
        hotel_full_Vagharshapat.loc[i, 'communication'] = None

# %%
for i in hotel_full_Vagharshapat.index:
    if "Location" in  hotel_full_Vagharshapat.location[i]:
        try:
            hotel_full_Vagharshapat.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Vagharshapat.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Vagharshapat.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Vagharshapat.location[i])
    
    else:
        hotel_full_Vagharshapat.loc[i, 'location'] = None

# %%
for i in hotel_full_Vagharshapat.index:
    if "Check-in" in  hotel_full_Vagharshapat.check_in[i]:
        hotel_full_Vagharshapat.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Vagharshapat.check_in[i])
    else:
        hotel_full_Vagharshapat.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Vagharshapat.index:
    if "Value" in  hotel_full_Vagharshapat.value[i]:
        hotel_full_Vagharshapat.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Vagharshapat.value[i])
    else:
        hotel_full_Vagharshapat.loc[i, 'value'] = None

# %%
for i in hotel_full_Vagharshapat.index:
    if "No reviews (yet)" in  hotel_full_Vagharshapat.rating[i]:
        hotel_full_Vagharshapat.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Vagharshapat.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Vagharshapat.price = price_list

# %%
for i in hotel_full_Vagharshapat.index:
    if "Response rate" in  hotel_full_Vagharshapat.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Vagharshapat.host_response_rate[i])
        hotel_full_Vagharshapat.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Vagharshapat.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Vagharshapat = hotel_full_Vagharshapat.astype(convert_dict)

# %%
hotel_full_Vagharshapat.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Vagharshapat.to_csv("cleaned_hotel_full_Vagharshapat.csv", index=False)
hotel_full_Vagharshapat.to_excel("cleaned_hotel_full_Vagharshapat2.xlsx", index=False)
