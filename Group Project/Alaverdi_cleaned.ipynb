# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Alaverdi = pd.read_csv('hotel_full_Alaverdi.csv')
hotel_full_Alaverdi
# Out:
#                                 city                           country  \
# 0                                NaN                               NaN
# 1   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 2      Odzun, Lori Province, Armenia     Odzun, Lori Province, Armenia
# 3   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 4   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 5   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 6   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 7   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 8   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 9            Алаверди, Лори, Armenia           Алаверди, Лори, Armenia
# 10       Հաղպատ, Լոռու մարզ, Armenia       Հաղպատ, Լոռու մարզ, Armenia
# 11  Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# ...

# %%
hotel_full_Alaverdi = hotel_full_Alaverdi.drop(labels = 0, axis = 0)
hotel_full_Alaverdi
# Out:
#                                 city                           country  \
# 1   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 2      Odzun, Lori Province, Armenia     Odzun, Lori Province, Armenia
# 3   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 4   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 5   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 6   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 7   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 8   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 9            Алаверди, Лори, Armenia           Алаверди, Лори, Armenia
# 10       Հաղպատ, Լոռու մարզ, Armenia       Հաղպատ, Լոռու մարզ, Armenia
# 11  Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 12  Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Alaverdi.replace("", nan_value, inplace = True)
hotel_full_Alaverdi.dropna(inplace= True)
hotel_full_Alaverdi
# Out:
#                                 city                           country  \
# 1   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 2      Odzun, Lori Province, Armenia     Odzun, Lori Province, Armenia
# 4   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 6   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 8   Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 9            Алаверди, Лори, Armenia           Алаверди, Лори, Armenia
# 18     Odzun, Lori province, Armenia     Odzun, Lori province, Armenia
# 21  Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
#
#                                               name                host_since  \
# 1                              ARMBEE Honey Farm 2        Joined in May 2019
# 2   Private Villa at Odzun Monastery | Առանձնատուն       Joined in June 2015
# 4                               Family Guest House       Joined in June 2016
# ...

# %%
hotel_full_Alaverdi["city"]= hotel_full_Alaverdi["city"].replace({"Օձուն, Armenia" : "Odzun, Armenia"})

# %%
hotel_full_Alaverdi["city"]= hotel_full_Alaverdi["city"].replace({"Ալավերդի, Լոռու մարզ, Armenia" : "Alaverdi, Armenia"})

# %%
city_list = []
for i in hotel_full_Alaverdi.index:
    text = re.sub(",", "", hotel_full_Alaverdi["city"][i][:hotel_full_Alaverdi["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Alaverdi["city"]= city_list
hotel_full_Alaverdi
# Out:
#                        city                           country  \
# 1   Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
# 2      Odzun Lori Province      Odzun, Lori Province, Armenia
# 4   Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
# 6   Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
# 8   Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
# 9            Алаверди Лори            Алаверди, Лори, Armenia
# 18     Odzun Lori province      Odzun, Lori province, Armenia
# 21  Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
#
#                                               name                host_since  \
# 1                              ARMBEE Honey Farm 2        Joined in May 2019
# 2   Private Villa at Odzun Monastery | Առանձնատուն       Joined in June 2015
# 4                               Family Guest House       Joined in June 2016
# 6                          Old City Hotel Alaverdi    Joined in January 2019
# ...

# %%
nan_value = float("Nan")
hotel_full_Alaverdi.replace("", nan_value, inplace = True)
hotel_full_Alaverdi.dropna(inplace= True)
hotel_full_Alaverdi
# Out:
#                        city                           country  \
# 1   Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
# 2      Odzun Lori Province      Odzun, Lori Province, Armenia
# 4   Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
# 6   Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
# 8   Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
# 9            Алаверди Лори            Алаверди, Лори, Armenia
# 18     Odzun Lori province      Odzun, Lori province, Armenia
# 21  Alaverdi Lori Province   Alaverdi, Lori Province, Armenia
#
#                                               name                host_since  \
# 1                              ARMBEE Honey Farm 2        Joined in May 2019
# 2   Private Villa at Odzun Monastery | Առանձնատուն       Joined in June 2015
# 4                               Family Guest House       Joined in June 2016
# 6                          Old City Hotel Alaverdi    Joined in January 2019
# ...

# %%
c_l = []    
for k in hotel_full_Alaverdi["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Alaverdi["city"]= c_l
hotel_full_Alaverdi
# Out:
#         city                           country  \
# 1   Alaverdi  Alaverdi, Lori Province, Armenia
# 2      Odzun     Odzun, Lori Province, Armenia
# 4   Alaverdi  Alaverdi, Lori Province, Armenia
# 6   Alaverdi  Alaverdi, Lori Province, Armenia
# 8   Alaverdi  Alaverdi, Lori Province, Armenia
# 9   Алаверди           Алаверди, Лори, Armenia
# 18     Odzun     Odzun, Lori province, Armenia
# 21  Alaverdi  Alaverdi, Lori Province, Armenia
#
#                                               name                host_since  \
# 1                              ARMBEE Honey Farm 2        Joined in May 2019
# 2   Private Villa at Odzun Monastery | Առանձնատուն       Joined in June 2015
# 4                               Family Guest House       Joined in June 2016
# 6                          Old City Hotel Alaverdi    Joined in January 2019
# 8                 Низкая цена за комфорт и чистоту    Joined in January 2019
# ...

# %%
country_list = []
for i in hotel_full_Alaverdi.index:
    text = re.search("Armenia", hotel_full_Alaverdi["country"][i]).group()
    country_list.append(text)

hotel_full_Alaverdi["country"] = country_list

# %%
hotel_full_Alaverdi
# Out:
#         city  country                                            name  \
# 1   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 2      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 4   Alaverdi  Armenia                              Family Guest House
# 6   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 8   Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 9   Алаверди  Armenia                     Приезжайте к нам отдыхать!!
# 18     Odzun  Armenia                             Em & Ri Guest House
# 21  Alaverdi  Armenia                                      Mini House
#
#                   host_since  \
# 1         Joined in May 2019
# 2        Joined in June 2015
# 4        Joined in June 2016
# 6     Joined in January 2019
# 8     Joined in January 2019
# 9        Joined in June 2014
# 18       Joined in July 2017
# 21  Joined in September 2017
#
#                                    host_response_rate  \
# ...

# %%
host_since_list = []
for i in hotel_full_Alaverdi.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Alaverdi.host_since = hs 
hotel_full_Alaverdi.host_since
# Out:
# 1     2019
# 2     2015
# 4     2016
# 6     2019
# 8     2019
# 9     2014
# 18    2017
# 21    2017
# Name: host_since, dtype: int64

# %%
hotel_full_Alaverdi
# Out:
#         city  country                                            name  \
# 1   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 2      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 4   Alaverdi  Armenia                              Family Guest House
# 6   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 8   Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 9   Алаверди  Armenia                     Приезжайте к нам отдыхать!!
# 18     Odzun  Armenia                             Em & Ri Guest House
# 21  Alaverdi  Armenia                                      Mini House
#
#     host_since                                 host_response_rate  \
# 1         2019  Languages: English, Русский\nResponse rate: 10...
# 2         2015  Languages: English, Deutsch, Русский\nResponse...
# 4         2016  Languages: English, Русский\nResponse rate: 10...
# 6         2019  Languages: العربية, English, עברית, Русский\nR...
# ...

# %%
string = []
for i in hotel_full_Alaverdi.index:
    st = hotel_full_Alaverdi.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["5 Reviews', 'Identity verified",
#  "27 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "10 Reviews', 'Identity verified",
#  '8 Reviews',
#  '8 Reviews',
#  '5 Reviews',
#  "1 Review', 'Identity verified",
#  '6 Reviews']

# %%
hotel_full_Alaverdi.host_identity_verified = string
hotel_full_Alaverdi.host_identity_verified
# Out:
# 1                        5 Reviews', 'Identity verified
# 2     27 Reviews', 'Identity verified', '\U000f0003'...
# 4                       10 Reviews', 'Identity verified
# 6                                             8 Reviews
# 8                                             8 Reviews
# 9                                             5 Reviews
# 18                        1 Review', 'Identity verified
# 21                                            6 Reviews
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Alaverdi.index:
    if "Identity verified" in  hotel_full_Alaverdi.host_identity_verified[i]:
        hotel_full_Alaverdi.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Alaverdi.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Alaverdi
# Out:
#         city  country                                            name  \
# 1   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 2      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 4   Alaverdi  Armenia                              Family Guest House
# 6   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 8   Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 9   Алаверди  Armenia                     Приезжайте к нам отдыхать!!
# 18     Odzun  Armenia                             Em & Ri Guest House
# 21  Alaverdi  Armenia                                      Mini House
#
#     host_since                                 host_response_rate  \
# 1         2019  Languages: English, Русский\nResponse rate: 10...
# 2         2015  Languages: English, Deutsch, Русский\nResponse...
# 4         2016  Languages: English, Русский\nResponse rate: 10...
# 6         2019  Languages: العربية, English, עברית, Русский\nR...
# ...

# %%
for i in hotel_full_Alaverdi.index:
    if "Review" in  hotel_full_Alaverdi.review[i]:
        hotel_full_Alaverdi.loc[i, 'review'] = re.search("(\d+)", hotel_full_Alaverdi.review[i]).group()
        
    else:
        hotel_full_Alaverdi.loc[i, 'review'] = 0

# %%
hotel_full_Alaverdi
# Out:
#         city  country                                            name  \
# 1   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 2      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 4   Alaverdi  Armenia                              Family Guest House
# 6   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 8   Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 9   Алаверди  Armenia                     Приезжайте к нам отдыхать!!
# 18     Odzun  Armenia                             Em & Ri Guest House
# 21  Alaverdi  Armenia                                      Mini House
#
#     host_since                                 host_response_rate  \
# 1         2019  Languages: English, Русский\nResponse rate: 10...
# 2         2015  Languages: English, Deutsch, Русский\nResponse...
# 4         2016  Languages: English, Русский\nResponse rate: 10...
# 6         2019  Languages: العربية, English, עברית, Русский\nR...
# ...

# %%
for i in hotel_full_Alaverdi.index:
    if "Superhost" in  hotel_full_Alaverdi.superhost[i]:
        hotel_full_Alaverdi.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Alaverdi.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Alaverdi.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire chalet',
#  'Entire villa',
#  'Private room in guest suite  Hovasapyan',
#  'Room in hotel',
#  'Private room in rental unit',
#  'Entire place',
#  'Private room in residential home  & Ri',
#  'Private room in bed and breakfast']

# %%
hotel_full_Alaverdi.property_type =prop_list

# %%
hotel_full_Alaverdi
# Out:
#         city  country                                            name  \
# 1   Alaverdi  Armenia                             ARMBEE Honey Farm 2
# 2      Odzun  Armenia  Private Villa at Odzun Monastery | Առանձնատուն
# 4   Alaverdi  Armenia                              Family Guest House
# 6   Alaverdi  Armenia                         Old City Hotel Alaverdi
# 8   Alaverdi  Armenia                Низкая цена за комфорт и чистоту
# 9   Алаверди  Armenia                     Приезжайте к нам отдыхать!!
# 18     Odzun  Armenia                             Em & Ri Guest House
# 21  Alaverdi  Armenia                                      Mini House
#
#     host_since                                 host_response_rate  \
# 1         2019  Languages: English, Русский\nResponse rate: 10...
# 2         2015  Languages: English, Deutsch, Русский\nResponse...
# 4         2016  Languages: English, Русский\nResponse rate: 10...
# 6         2019  Languages: العربية, English, עברית, Русский\nR...
# ...

# %%
accomodates_list = []
for i in hotel_full_Alaverdi.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Alaverdi.accomodates = number

# %%
for i in hotel_full_Alaverdi.index:
    if "Shared half-bath" in  hotel_full_Alaverdi.number_bathroom[i]:
        hotel_full_Alaverdi.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Alaverdi.number_bathroom[i]:
        hotel_full_Alaverdi.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Alaverdi.number_bathroom[i]:
        hotel_full_Alaverdi.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Alaverdi.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Alaverdi.number_bedroom[i])
        hotel_full_Alaverdi.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Alaverdi.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Alaverdi.number_bedroom[i])
        hotel_full_Alaverdi.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Alaverdi.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Alaverdi.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Alaverdi.index:
    if "bed" in  hotel_full_Alaverdi.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Alaverdi.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Alaverdi.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['2', '4', '7', '8', '13', '16', '9', '9']

# %%
len(hotel_full_Alaverdi.number_beds)
# Out:
# 8

# %%
len(number_beds_list)
# Out:
# 8

# %%
hotel_full_Alaverdi.number_beds = number_beds_list

# %%
hotel_full_Alaverdi.number_beds
# Out:
# 1      2
# 2      4
# 4      7
# 6      8
# 8     13
# 9     16
# 18     9
# 21     9
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Alaverdi.index:
    if "Studio" in  hotel_full_Alaverdi.number_bedroom[i]:
        hotel_full_Alaverdi.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Alaverdi.number_bedroom[i])
        hotel_full_Alaverdi.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Alaverdi.index:
    if "Cleanliness" in  hotel_full_Alaverdi.cleanliness[i]:
        hotel_full_Alaverdi.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Alaverdi.cleanliness[i])
    else:
        hotel_full_Alaverdi.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Alaverdi.index:
    if "Accuracy" in  hotel_full_Alaverdi.accuracy[i]:
        hotel_full_Alaverdi.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Alaverdi.accuracy[i])
    else:
        hotel_full_Alaverdi.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Alaverdi.index:
    if "Communication" in  hotel_full_Alaverdi.communication[i]:
        hotel_full_Alaverdi.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Alaverdi.communication[i])
    else:
        hotel_full_Alaverdi.loc[i, 'communication'] = None

# %%
for i in hotel_full_Alaverdi.index:
    if "Location" in  hotel_full_Alaverdi.location[i]:
        try:
            hotel_full_Alaverdi.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Alaverdi.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Alaverdi.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Alaverdi.location[i])
    
    else:
        hotel_full_Alaverdi.loc[i, 'location'] = None

# %%
for i in hotel_full_Alaverdi.index:
    if "Check-in" in  hotel_full_Alaverdi.check_in[i]:
        hotel_full_Alaverdi.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Alaverdi.check_in[i])
    else:
        hotel_full_Alaverdi.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Alaverdi.index:
    if "Value" in  hotel_full_Alaverdi.value[i]:
        hotel_full_Alaverdi.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Alaverdi.value[i])
    else:
        hotel_full_Alaverdi.loc[i, 'value'] = None

# %%
for i in hotel_full_Alaverdi.index:
    if "No reviews (yet)" in  hotel_full_Alaverdi.rating[i]:
        hotel_full_Alaverdi.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Alaverdi.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Alaverdi.price = price_list

# %%
for i in hotel_full_Alaverdi.index:
    if "Response rate" in  hotel_full_Alaverdi.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Alaverdi.host_response_rate[i])
        hotel_full_Alaverdi.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Alaverdi.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Alaverdi = hotel_full_Alaverdi.astype(convert_dict)

# %%
hotel_full_Alaverdi.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Alaverdi.to_csv("cleaned_hotel_full_Alaverdi.csv", index=False)
hotel_full_Alaverdi.to_excel("cleaned_hotel_full_Alaverdi2.xlsx", index=False)
