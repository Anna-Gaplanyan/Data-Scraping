# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Nor_Hachn = pd.read_csv('hotel_full_Nor_Hachn.csv')
hotel_full_Nor_Hachn
# Out:
#                                      city  \
# 0                                     NaN
# 1                  Արզնի, Կոտայք, Armenia
# 2       Yerevan, Kotayk Province, Armenia
# 3     Nor Hachn, Kotayk Province, Armenia
# 4     Nor Hachn, Kotayk Province, Armenia
# 5                Kotayk Province, Armenia
# 6       Getamej, Kotayk Province, Armenia
# 7       Abovyan, Kotayk Province, Armenia
# 8                        Yerevan, Armenia
# 9        Ptghni, Kotayk Province, Armenia
# 10                Pthgni, Kotayk, Armenia
# 11                       Yerevan, Armenia
# 12                       Yerevan, Armenia
# 13  Byureghavan, Kotayk Province, Armenia
# 14        Arzni, Kotayk Province, Armenia
# 15                       Yerevan, Armenia
# 16                       Yerevan, Armenia
# 17      Abovyan, Kotayk Province, Armenia
# 18      Getamej, Kotayk Province, Armenia
# 19                       Yerevan, Armenia
# 20        Arzni, Kotayk Province, Armenia
# ...

# %%
hotel_full_Nor_Hachn = hotel_full_Nor_Hachn.drop(labels = 0, axis = 0)
hotel_full_Nor_Hachn
# Out:
#                                      city  \
# 1                  Արզնի, Կոտայք, Armenia
# 2       Yerevan, Kotayk Province, Armenia
# 3     Nor Hachn, Kotayk Province, Armenia
# 4     Nor Hachn, Kotayk Province, Armenia
# 5                Kotayk Province, Armenia
# 6       Getamej, Kotayk Province, Armenia
# 7       Abovyan, Kotayk Province, Armenia
# 8                        Yerevan, Armenia
# 9        Ptghni, Kotayk Province, Armenia
# 10                Pthgni, Kotayk, Armenia
# 11                       Yerevan, Armenia
# 12                       Yerevan, Armenia
# 13  Byureghavan, Kotayk Province, Armenia
# 14        Arzni, Kotayk Province, Armenia
# 15                       Yerevan, Armenia
# 16                       Yerevan, Armenia
# 17      Abovyan, Kotayk Province, Armenia
# 18      Getamej, Kotayk Province, Armenia
# 19                       Yerevan, Armenia
# 20        Arzni, Kotayk Province, Armenia
# 21  Byureghavan, Kotayk Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Nor_Hachn.replace("", nan_value, inplace = True)
hotel_full_Nor_Hachn.dropna(inplace= True)
hotel_full_Nor_Hachn
# Out:
#                                  city                            country  \
# 2   Yerevan, Kotayk Province, Armenia  Yerevan, Kotayk Province, Armenia
# 12                   Yerevan, Armenia                   Yerevan, Armenia
# 18  Getamej, Kotayk Province, Armenia  Getamej, Kotayk Province, Armenia
# 24                   Yerevan, Armenia                   Yerevan, Armenia
# 27  Abovyan, Kotayk Province, Armenia  Abovyan, Kotayk Province, Armenia
#
#                                                name               host_since  \
# 2                                  Yerkir eco house      Joined in June 2016
# 12                                       Sweet home  Joined in December 2019
# 18  La Maison HAYA, Chill out 20mn from Yerevan, #1      Joined in June 2013
# 24                               Квартира суперская      Joined in June 2018
# 27                                       Home dacha  Joined in November 2016
#
#                                    host_response_rate  \
# ...

# %%
hotel_full_Nor_Hachn["city"]= hotel_full_Nor_Hachn["city"].replace({"Արզնի, Կոտայք, Armenia" : "Arzni, Armenia"})

# %%
city_list = []
for i in hotel_full_Nor_Hachn.index:
    text = re.sub(",", "", hotel_full_Nor_Hachn["city"][i][:hotel_full_Nor_Hachn["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Nor_Hachn["city"]= city_list
hotel_full_Nor_Hachn
# Out:
#                         city                            country  \
# 2   Yerevan Kotayk Province   Yerevan, Kotayk Province, Armenia
# 12                  Yerevan                    Yerevan, Armenia
# 18  Getamej Kotayk Province   Getamej, Kotayk Province, Armenia
# 24                  Yerevan                    Yerevan, Armenia
# 27  Abovyan Kotayk Province   Abovyan, Kotayk Province, Armenia
#
#                                                name               host_since  \
# 2                                  Yerkir eco house      Joined in June 2016
# 12                                       Sweet home  Joined in December 2019
# 18  La Maison HAYA, Chill out 20mn from Yerevan, #1      Joined in June 2013
# 24                               Квартира суперская      Joined in June 2018
# 27                                       Home dacha  Joined in November 2016
#
#                                    host_response_rate  \
# 2   Languages: English, Русский\nResponse rate: 10...
# ...

# %%
nan_value = float("Nan")
hotel_full_Nor_Hachn.replace("", nan_value, inplace = True)
hotel_full_Nor_Hachn.dropna(inplace= True)
hotel_full_Nor_Hachn
# Out:
#                         city                            country  \
# 2   Yerevan Kotayk Province   Yerevan, Kotayk Province, Armenia
# 12                  Yerevan                    Yerevan, Armenia
# 18  Getamej Kotayk Province   Getamej, Kotayk Province, Armenia
# 24                  Yerevan                    Yerevan, Armenia
# 27  Abovyan Kotayk Province   Abovyan, Kotayk Province, Armenia
#
#                                                name               host_since  \
# 2                                  Yerkir eco house      Joined in June 2016
# 12                                       Sweet home  Joined in December 2019
# 18  La Maison HAYA, Chill out 20mn from Yerevan, #1      Joined in June 2013
# 24                               Квартира суперская      Joined in June 2018
# 27                                       Home dacha  Joined in November 2016
#
#                                    host_response_rate  \
# 2   Languages: English, Русский\nResponse rate: 10...
# ...

# %%
c_l = []    
for k in hotel_full_Nor_Hachn["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Nor_Hachn["city"]= c_l
hotel_full_Nor_Hachn
# Out:
#        city                            country  \
# 2   Yerevan  Yerevan, Kotayk Province, Armenia
# 12  Yerevan                   Yerevan, Armenia
# 18  Getamej  Getamej, Kotayk Province, Armenia
# 24  Yerevan                   Yerevan, Armenia
# 27  Abovyan  Abovyan, Kotayk Province, Armenia
#
#                                                name               host_since  \
# 2                                  Yerkir eco house      Joined in June 2016
# 12                                       Sweet home  Joined in December 2019
# 18  La Maison HAYA, Chill out 20mn from Yerevan, #1      Joined in June 2013
# 24                               Квартира суперская      Joined in June 2018
# 27                                       Home dacha  Joined in November 2016
#
#                                    host_response_rate  \
# 2   Languages: English, Русский\nResponse rate: 10...
# 12  Response rate: 81%\nResponse time: within a fe...
# ...

# %%
hotel_full_Nor_Hachn["city"]= hotel_full_Nor_Hachn["city"].replace({"Nor" : "Nor Hachn"})

# %%
country_list = []
for i in hotel_full_Nor_Hachn.index:
    text = re.search("Armenia", hotel_full_Nor_Hachn["country"][i]).group()
    country_list.append(text)

hotel_full_Nor_Hachn["country"] = country_list

# %%
hotel_full_Nor_Hachn
# Out:
#        city  country                                             name  \
# 2   Yerevan  Armenia                                 Yerkir eco house
# 12  Yerevan  Armenia                                       Sweet home
# 18  Getamej  Armenia  La Maison HAYA, Chill out 20mn from Yerevan, #1
# 24  Yerevan  Armenia                               Квартира суперская
# 27  Abovyan  Armenia                                       Home dacha
#
#                  host_since  \
# 2       Joined in June 2016
# 12  Joined in December 2019
# 18      Joined in June 2013
# 24      Joined in June 2018
# 27  Joined in November 2016
#
#                                    host_response_rate  \
# 2   Languages: English, Русский\nResponse rate: 10...
# 12  Response rate: 81%\nResponse time: within a fe...
# 18                       Languages: English, Français
# 24  Response rate: 100%\nResponse time: within an ...
# 27  Language: Русский\nResponse rate: 0%\nResponse...
#
# ...

# %%
host_since_list = []
for i in hotel_full_Nor_Hachn.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Nor_Hachn.host_since = hs 
hotel_full_Nor_Hachn.host_since
# Out:
# 2     2016
# 12    2019
# 18    2013
# 24    2018
# 27    2016
# Name: host_since, dtype: int64

# %%
hotel_full_Nor_Hachn
# Out:
#        city  country                                             name  \
# 2   Yerevan  Armenia                                 Yerkir eco house
# 12  Yerevan  Armenia                                       Sweet home
# 18  Getamej  Armenia  La Maison HAYA, Chill out 20mn from Yerevan, #1
# 24  Yerevan  Armenia                               Квартира суперская
# 27  Abovyan  Armenia                                       Home dacha
#
#     host_since                                 host_response_rate  \
# 2         2016  Languages: English, Русский\nResponse rate: 10...
# 12        2019  Response rate: 81%\nResponse time: within a fe...
# 18        2013                       Languages: English, Français
# 24        2018  Response rate: 100%\nResponse time: within an ...
# 27        2016  Language: Русский\nResponse rate: 0%\nResponse...
#
#                                host_identity_verified  \
# 2   ['281 Reviews', 'Identity verified', '\U000f00...
# ...

# %%
string = []
for i in hotel_full_Nor_Hachn.index:
    st = hotel_full_Nor_Hachn.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["281 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "1 Review', 'Identity verified",
#  "27 Reviews', 'Identity verified",
#  "6 Reviews', 'Identity verified",
#  '1 Review']

# %%
hotel_full_Nor_Hachn.host_identity_verified = string
hotel_full_Nor_Hachn.host_identity_verified
# Out:
# 2     281 Reviews', 'Identity verified', '\U000f0003...
# 12                        1 Review', 'Identity verified
# 18                      27 Reviews', 'Identity verified
# 24                       6 Reviews', 'Identity verified
# 27                                             1 Review
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Identity verified" in  hotel_full_Nor_Hachn.host_identity_verified[i]:
        hotel_full_Nor_Hachn.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Nor_Hachn.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Nor_Hachn
# Out:
#        city  country                                             name  \
# 2   Yerevan  Armenia                                 Yerkir eco house
# 12  Yerevan  Armenia                                       Sweet home
# 18  Getamej  Armenia  La Maison HAYA, Chill out 20mn from Yerevan, #1
# 24  Yerevan  Armenia                               Квартира суперская
# 27  Abovyan  Armenia                                       Home dacha
#
#     host_since                                 host_response_rate  \
# 2         2016  Languages: English, Русский\nResponse rate: 10...
# 12        2019  Response rate: 81%\nResponse time: within a fe...
# 18        2013                       Languages: English, Français
# 24        2018  Response rate: 100%\nResponse time: within an ...
# 27        2016  Language: Русский\nResponse rate: 0%\nResponse...
#
#    host_identity_verified                                             review  \
# ...

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Review" in  hotel_full_Nor_Hachn.review[i]:
        hotel_full_Nor_Hachn.loc[i, 'review'] = re.search("(\d+)", hotel_full_Nor_Hachn.review[i]).group()
        
    else:
        hotel_full_Nor_Hachn.loc[i, 'review'] = 0

# %%
hotel_full_Nor_Hachn
# Out:
#        city  country                                             name  \
# 2   Yerevan  Armenia                                 Yerkir eco house
# 12  Yerevan  Armenia                                       Sweet home
# 18  Getamej  Armenia  La Maison HAYA, Chill out 20mn from Yerevan, #1
# 24  Yerevan  Armenia                               Квартира суперская
# 27  Abovyan  Armenia                                       Home dacha
#
#     host_since                                 host_response_rate  \
# 2         2016  Languages: English, Русский\nResponse rate: 10...
# 12        2019  Response rate: 81%\nResponse time: within a fe...
# 18        2013                       Languages: English, Français
# 24        2018  Response rate: 100%\nResponse time: within an ...
# 27        2016  Language: Русский\nResponse rate: 0%\nResponse...
#
#    host_identity_verified review  \
# 2       Identity verified    281
# 12      Identity verified      1
# 18      Identity verified     27
# ...

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Superhost" in  hotel_full_Nor_Hachn.superhost[i]:
        hotel_full_Nor_Hachn.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Nor_Hachn.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Nor_Hachn.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire residential home',
#  'Entire residential home',
#  'Private room in bed and breakfast',
#  'Entire rental unit',
#  'Private room in residential home']

# %%
hotel_full_Nor_Hachn.property_type =prop_list

# %%
hotel_full_Nor_Hachn
# Out:
#        city  country                                             name  \
# 2   Yerevan  Armenia                                 Yerkir eco house
# 12  Yerevan  Armenia                                       Sweet home
# 18  Getamej  Armenia  La Maison HAYA, Chill out 20mn from Yerevan, #1
# 24  Yerevan  Armenia                               Квартира суперская
# 27  Abovyan  Armenia                                       Home dacha
#
#     host_since                                 host_response_rate  \
# 2         2016  Languages: English, Русский\nResponse rate: 10...
# 12        2019  Response rate: 81%\nResponse time: within a fe...
# 18        2013                       Languages: English, Français
# 24        2018  Response rate: 100%\nResponse time: within an ...
# 27        2016  Language: Русский\nResponse rate: 0%\nResponse...
#
#    host_identity_verified review     superhost  \
# 2       Identity verified    281    Super host
# 12      Identity verified      1  regular host
# ...

# %%
accomodates_list = []
for i in hotel_full_Nor_Hachn.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Nor_Hachn.accomodates = number

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Shared half-bath" in  hotel_full_Nor_Hachn.number_bathroom[i]:
        hotel_full_Nor_Hachn.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Nor_Hachn.number_bathroom[i]:
        hotel_full_Nor_Hachn.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Nor_Hachn.number_bathroom[i]:
        hotel_full_Nor_Hachn.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Nor_Hachn.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Nor_Hachn.number_bedroom[i])
        hotel_full_Nor_Hachn.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Nor_Hachn.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Nor_Hachn.number_bedroom[i])
        hotel_full_Nor_Hachn.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Nor_Hachn.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Nor_Hachn.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Nor_Hachn.index:
    if "bed" in  hotel_full_Nor_Hachn.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Nor_Hachn.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Nor_Hachn.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['4', '6', '2', '3', '10']

# %%
len(hotel_full_Nor_Hachn.number_beds)
# Out:
# 5

# %%
len(number_beds_list)
# Out:
# 5

# %%
hotel_full_Nor_Hachn.number_beds = number_beds_list

# %%
hotel_full_Nor_Hachn.number_beds
# Out:
# 2      4
# 12     6
# 18     2
# 24     3
# 27    10
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Studio" in  hotel_full_Nor_Hachn.number_bedroom[i]:
        hotel_full_Nor_Hachn.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Nor_Hachn.number_bedroom[i])
        hotel_full_Nor_Hachn.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Cleanliness" in  hotel_full_Nor_Hachn.cleanliness[i]:
        hotel_full_Nor_Hachn.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Nor_Hachn.cleanliness[i])
    else:
        hotel_full_Nor_Hachn.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Accuracy" in  hotel_full_Nor_Hachn.accuracy[i]:
        hotel_full_Nor_Hachn.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Nor_Hachn.accuracy[i])
    else:
        hotel_full_Nor_Hachn.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Communication" in  hotel_full_Nor_Hachn.communication[i]:
        hotel_full_Nor_Hachn.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Nor_Hachn.communication[i])
    else:
        hotel_full_Nor_Hachn.loc[i, 'communication'] = None

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Location" in  hotel_full_Nor_Hachn.location[i]:
        try:
            hotel_full_Nor_Hachn.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Nor_Hachn.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Nor_Hachn.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Nor_Hachn.location[i])
    
    else:
        hotel_full_Nor_Hachn.loc[i, 'location'] = None

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Check-in" in  hotel_full_Nor_Hachn.check_in[i]:
        hotel_full_Nor_Hachn.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Nor_Hachn.check_in[i])
    else:
        hotel_full_Nor_Hachn.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Value" in  hotel_full_Nor_Hachn.value[i]:
        hotel_full_Nor_Hachn.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Nor_Hachn.value[i])
    else:
        hotel_full_Nor_Hachn.loc[i, 'value'] = None

# %%
for i in hotel_full_Nor_Hachn.index:
    if "No reviews (yet)" in  hotel_full_Nor_Hachn.rating[i]:
        hotel_full_Nor_Hachn.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Nor_Hachn.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Nor_Hachn.price = price_list

# %%
for i in hotel_full_Nor_Hachn.index:
    if "Response rate" in  hotel_full_Nor_Hachn.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Nor_Hachn.host_response_rate[i])
        hotel_full_Nor_Hachn.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Nor_Hachn.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Nor_Hachn = hotel_full_Nor_Hachn.astype(convert_dict)

# %%
hotel_full_Nor_Hachn.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Nor_Hachn.to_csv("cleaned_hotel_full_Nor_Hachn.csv", index=False)
hotel_full_Nor_Hachn.to_excel("cleaned_hotel_full_Nor_Hachn2.xlsx", index=False)
