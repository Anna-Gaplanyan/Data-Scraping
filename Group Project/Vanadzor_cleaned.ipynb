# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Vanadzor = pd.read_csv('hotel_full_Vanadzor.csv')
hotel_full_Vanadzor
# Out:
#                                 city                           country  \
# 0                                NaN                               NaN
# 1   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 2   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 3   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 4   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 5   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 6   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 7   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 8   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 9   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 10  Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 11  Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# ...

# %%
hotel_full_Vanadzor = hotel_full_Vanadzor.drop(labels = 0, axis = 0)
hotel_full_Vanadzor
# Out:
#                                 city                           country  \
# 1   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 2   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 3   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 4   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 5   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 6   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 7   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 8   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 9   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 10  Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 11  Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 12  Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Vanadzor.replace("", nan_value, inplace = True)
hotel_full_Vanadzor.dropna(inplace= True)
hotel_full_Vanadzor
# Out:
#                                 city                           country  \
# 1   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 3   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 4   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 5   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 6   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 7   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 8   Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 10  Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 19  Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
# 20    Pambak, Lori Province, Armenia    Pambak, Lori Province, Armenia
# 21  Vanadzor, Lori Province, Armenia  Vanadzor, Lori Province, Armenia
#
#                                name              host_since  \
# ...

# %%
city_list = []
for i in hotel_full_Vanadzor.index:
    text = re.sub(",", "", hotel_full_Vanadzor["city"][i][:hotel_full_Vanadzor["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Vanadzor["city"]= city_list
hotel_full_Vanadzor
# Out:
#                        city                           country  \
# 1   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 3   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 4   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 5   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 6   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 7   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 8   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 10  Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 19  Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 20    Pambak Lori Province     Pambak, Lori Province, Armenia
# 21  Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
#
#                                name              host_since  \
# 1                            Artery   Joined in August 2019
# 3         Vanadzor Family Art House   Joined in August 2015
# ...

# %%
nan_value = float("Nan")
hotel_full_Vanadzor.replace("", nan_value, inplace = True)
hotel_full_Vanadzor.dropna(inplace= True)
hotel_full_Vanadzor
# Out:
#                        city                           country  \
# 1   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 3   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 4   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 5   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 6   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 7   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 8   Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 10  Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 19  Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
# 20    Pambak Lori Province     Pambak, Lori Province, Armenia
# 21  Vanadzor Lori Province   Vanadzor, Lori Province, Armenia
#
#                                name              host_since  \
# 1                            Artery   Joined in August 2019
# 3         Vanadzor Family Art House   Joined in August 2015
# ...

# %%
c_l = []    
for k in hotel_full_Vanadzor["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Vanadzor["city"]= c_l
hotel_full_Vanadzor
# Out:
#         city                           country  \
# 1   Vanadzor  Vanadzor, Lori Province, Armenia
# 3   Vanadzor  Vanadzor, Lori Province, Armenia
# 4   Vanadzor  Vanadzor, Lori Province, Armenia
# 5   Vanadzor  Vanadzor, Lori Province, Armenia
# 6   Vanadzor  Vanadzor, Lori Province, Armenia
# 7   Vanadzor  Vanadzor, Lori Province, Armenia
# 8   Vanadzor  Vanadzor, Lori Province, Armenia
# 10  Vanadzor  Vanadzor, Lori Province, Armenia
# 19  Vanadzor  Vanadzor, Lori Province, Armenia
# 20    Pambak    Pambak, Lori Province, Armenia
# 21  Vanadzor  Vanadzor, Lori Province, Armenia
#
#                                name              host_since  \
# 1                            Artery   Joined in August 2019
# 3         Vanadzor Family Art House   Joined in August 2015
# 4          Room #1 Lori Guest House     Joined in June 2017
# 5          Room #2 Lori Guest House     Joined in June 2017
# 6              Vanadzor Guest House    Joined in March 2018
# ...

# %%
country_list = []
for i in hotel_full_Vanadzor.index:
    text = re.search("Armenia", hotel_full_Vanadzor["country"][i]).group()
    country_list.append(text)

hotel_full_Vanadzor["country"] = country_list

# %%
hotel_full_Vanadzor
# Out:
#         city  country                             name  \
# 1   Vanadzor  Armenia                           Artery
# 3   Vanadzor  Armenia        Vanadzor Family Art House
# 4   Vanadzor  Armenia         Room #1 Lori Guest House
# 5   Vanadzor  Armenia         Room #2 Lori Guest House
# 6   Vanadzor  Armenia             Vanadzor Guest House
# 7   Vanadzor  Armenia                Bubble Park Hotel
# 8   Vanadzor  Armenia  Hostel Room in Lori Guest House
# 10  Vanadzor  Armenia         Guest Hause and Vanadzor
# 19  Vanadzor  Armenia          Lori travel Guest house
# 20    Pambak  Armenia              guest house, Pambak
# 21  Vanadzor  Armenia         Room #3 Lori Guest House
#
#                 host_since                                 host_response_rate  \
# 1    Joined in August 2019  Response rate: 100%\nResponse time: within a f...
# 3    Joined in August 2015  Languages: English, Русский\nResponse rate: 10...
# ...

# %%
host_since_list = []
for i in hotel_full_Vanadzor.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Vanadzor.host_since = hs 
hotel_full_Vanadzor.host_since
# Out:
# 1     2019
# 3     2015
# 4     2017
# 5     2017
# 6     2018
# 7     2019
# 8     2017
# 10    2019
# 19    2014
# 20    2019
# 21    2017
# Name: host_since, dtype: int64

# %%
hotel_full_Vanadzor
# Out:
#         city  country                             name  host_since  \
# 1   Vanadzor  Armenia                           Artery        2019
# 3   Vanadzor  Armenia        Vanadzor Family Art House        2015
# 4   Vanadzor  Armenia         Room #1 Lori Guest House        2017
# 5   Vanadzor  Armenia         Room #2 Lori Guest House        2017
# 6   Vanadzor  Armenia             Vanadzor Guest House        2018
# 7   Vanadzor  Armenia                Bubble Park Hotel        2019
# 8   Vanadzor  Armenia  Hostel Room in Lori Guest House        2017
# 10  Vanadzor  Armenia         Guest Hause and Vanadzor        2019
# 19  Vanadzor  Armenia          Lori travel Guest house        2014
# 20    Pambak  Armenia              guest house, Pambak        2019
# 21  Vanadzor  Armenia         Room #3 Lori Guest House        2017
#
#                                    host_response_rate host_identity_verified  \
# 1   Response rate: 100%\nResponse time: within a f...          ['3 Reviews']
# ...

# %%
string = []
for i in hotel_full_Vanadzor.index:
    st = hotel_full_Vanadzor.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ['3 Reviews',
#  '12 Reviews',
#  'Identity verified',
#  'Identity verified',
#  '5 Reviews',
#  '3 Reviews',
#  'Identity verified',
#  'Identity verified',
#  '5 Reviews',
#  'Identity verified',
#  'Identity verified']

# %%
hotel_full_Vanadzor.host_identity_verified = string
hotel_full_Vanadzor.host_identity_verified
# Out:
# 1             3 Reviews
# 3            12 Reviews
# 4     Identity verified
# 5     Identity verified
# 6             5 Reviews
# 7             3 Reviews
# 8     Identity verified
# 10    Identity verified
# 19            5 Reviews
# 20    Identity verified
# 21    Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Vanadzor.index:
    if "Identity verified" in  hotel_full_Vanadzor.host_identity_verified[i]:
        hotel_full_Vanadzor.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Vanadzor.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Vanadzor
# Out:
#         city  country                             name  host_since  \
# 1   Vanadzor  Armenia                           Artery        2019
# 3   Vanadzor  Armenia        Vanadzor Family Art House        2015
# 4   Vanadzor  Armenia         Room #1 Lori Guest House        2017
# 5   Vanadzor  Armenia         Room #2 Lori Guest House        2017
# 6   Vanadzor  Armenia             Vanadzor Guest House        2018
# 7   Vanadzor  Armenia                Bubble Park Hotel        2019
# 8   Vanadzor  Armenia  Hostel Room in Lori Guest House        2017
# 10  Vanadzor  Armenia         Guest Hause and Vanadzor        2019
# 19  Vanadzor  Armenia          Lori travel Guest house        2014
# 20    Pambak  Armenia              guest house, Pambak        2019
# 21  Vanadzor  Armenia         Room #3 Lori Guest House        2017
#
#                                    host_response_rate host_identity_verified  \
# 1   Response rate: 100%\nResponse time: within a f...  Identity not verified
# ...

# %%
for i in hotel_full_Vanadzor.index:
    if "Review" in  hotel_full_Vanadzor.review[i]:
        hotel_full_Vanadzor.loc[i, 'review'] = re.search("(\d+)", hotel_full_Vanadzor.review[i]).group()
        
    else:
        hotel_full_Vanadzor.loc[i, 'review'] = 0

# %%
hotel_full_Vanadzor
# Out:
#         city  country                             name  host_since  \
# 1   Vanadzor  Armenia                           Artery        2019
# 3   Vanadzor  Armenia        Vanadzor Family Art House        2015
# 4   Vanadzor  Armenia         Room #1 Lori Guest House        2017
# 5   Vanadzor  Armenia         Room #2 Lori Guest House        2017
# 6   Vanadzor  Armenia             Vanadzor Guest House        2018
# 7   Vanadzor  Armenia                Bubble Park Hotel        2019
# 8   Vanadzor  Armenia  Hostel Room in Lori Guest House        2017
# 10  Vanadzor  Armenia         Guest Hause and Vanadzor        2019
# 19  Vanadzor  Armenia          Lori travel Guest house        2014
# 20    Pambak  Armenia              guest house, Pambak        2019
# 21  Vanadzor  Armenia         Room #3 Lori Guest House        2017
#
#                                    host_response_rate host_identity_verified  \
# 1   Response rate: 100%\nResponse time: within a f...  Identity not verified
# ...

# %%
for i in hotel_full_Vanadzor.index:
    if "Superhost" in  hotel_full_Vanadzor.superhost[i]:
        hotel_full_Vanadzor.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Vanadzor.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Vanadzor.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire rental unit',
#  'Private room in residential home',
#  'Room in boutique hotel',
#  'Room in boutique hotel',
#  'Private room in bed and breakfast',
#  'Private room in tent',
#  'Shared room in hostel',
#  'Entire residential home',
#  'Private room in bed and breakfast',
#  'Private room in guesthouse',
#  'Room in boutique hotel']

# %%
hotel_full_Vanadzor.property_type =prop_list

# %%
hotel_full_Vanadzor
# Out:
#         city  country                             name  host_since  \
# 1   Vanadzor  Armenia                           Artery        2019
# 3   Vanadzor  Armenia        Vanadzor Family Art House        2015
# 4   Vanadzor  Armenia         Room #1 Lori Guest House        2017
# 5   Vanadzor  Armenia         Room #2 Lori Guest House        2017
# 6   Vanadzor  Armenia             Vanadzor Guest House        2018
# 7   Vanadzor  Armenia                Bubble Park Hotel        2019
# 8   Vanadzor  Armenia  Hostel Room in Lori Guest House        2017
# 10  Vanadzor  Armenia         Guest Hause and Vanadzor        2019
# 19  Vanadzor  Armenia          Lori travel Guest house        2014
# 20    Pambak  Armenia              guest house, Pambak        2019
# 21  Vanadzor  Armenia         Room #3 Lori Guest House        2017
#
#                                    host_response_rate host_identity_verified  \
# 1   Response rate: 100%\nResponse time: within a f...  Identity not verified
# ...

# %%
accomodates_list = []
for i in hotel_full_Vanadzor.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Vanadzor.accomodates = number

# %%
for i in hotel_full_Vanadzor.index:
    if "Shared half-bath" in  hotel_full_Vanadzor.number_bathroom[i]:
        hotel_full_Vanadzor.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Vanadzor.number_bathroom[i]:
        hotel_full_Vanadzor.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Vanadzor.number_bathroom[i]:
        hotel_full_Vanadzor.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Vanadzor.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Vanadzor.number_bedroom[i])
        hotel_full_Vanadzor.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Vanadzor.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Vanadzor.number_bedroom[i])
        hotel_full_Vanadzor.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Vanadzor.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Vanadzor.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Vanadzor.index:
    if "bed" in  hotel_full_Vanadzor.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Vanadzor.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Vanadzor.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['1', '4', '2', '2', '9', '0', '4', '4', '6', None, '4']

# %%
len(hotel_full_Vanadzor.number_beds)
# Out:
# 11

# %%
len(number_beds_list)
# Out:
# 11

# %%
hotel_full_Vanadzor.number_beds = number_beds_list

# %%
hotel_full_Vanadzor.number_beds
# Out:
# 1        1
# 3        4
# 4        2
# 5        2
# 6        9
# 7        0
# 8        4
# 10       4
# 19       6
# 20    None
# 21       4
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Vanadzor.index:
    if "Studio" in  hotel_full_Vanadzor.number_bedroom[i]:
        hotel_full_Vanadzor.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Vanadzor.number_bedroom[i])
        hotel_full_Vanadzor.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Vanadzor.index:
    if "Cleanliness" in  hotel_full_Vanadzor.cleanliness[i]:
        hotel_full_Vanadzor.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Vanadzor.cleanliness[i])
    else:
        hotel_full_Vanadzor.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Vanadzor.index:
    if "Accuracy" in  hotel_full_Vanadzor.accuracy[i]:
        hotel_full_Vanadzor.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Vanadzor.accuracy[i])
    else:
        hotel_full_Vanadzor.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Vanadzor.index:
    if "Communication" in  hotel_full_Vanadzor.communication[i]:
        hotel_full_Vanadzor.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Vanadzor.communication[i])
    else:
        hotel_full_Vanadzor.loc[i, 'communication'] = None

# %%
for i in hotel_full_Vanadzor.index:
    if "Location" in  hotel_full_Vanadzor.location[i]:
        try:
            hotel_full_Vanadzor.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Vanadzor.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Vanadzor.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Vanadzor.location[i])
    
    else:
        hotel_full_Vanadzor.loc[i, 'location'] = None

# %%
for i in hotel_full_Vanadzor.index:
    if "Check-in" in  hotel_full_Vanadzor.check_in[i]:
        hotel_full_Vanadzor.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Vanadzor.check_in[i])
    else:
        hotel_full_Vanadzor.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Vanadzor.index:
    if "Value" in  hotel_full_Vanadzor.value[i]:
        hotel_full_Vanadzor.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Vanadzor.value[i])
    else:
        hotel_full_Vanadzor.loc[i, 'value'] = None

# %%
for i in hotel_full_Vanadzor.index:
    if "No reviews (yet)" in  hotel_full_Vanadzor.rating[i]:
        hotel_full_Vanadzor.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Vanadzor.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Vanadzor.price = price_list

# %%
for i in hotel_full_Vanadzor.index:
    if "Response rate" in  hotel_full_Vanadzor.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Vanadzor.host_response_rate[i])
        hotel_full_Vanadzor.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Vanadzor.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Vanadzor = hotel_full_Vanadzor.astype(convert_dict)

# %%
hotel_full_Vanadzor.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Vanadzor.to_csv("cleaned_hotel_full_Vanadzor.csv", index=False)
hotel_full_Vanadzor.to_excel("cleaned_hotel_full_Vanadzor2.xlsx", index=False)
