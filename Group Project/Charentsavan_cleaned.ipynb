hotel_full_Charentsavan["city"]= hotel_full_Charentsavan["city"].replace({"Nor" : "Nor Geghi"})

# %%
country_list = []
for i in hotel_full_Charentsavan.index:
    text = re.search("Armenia", hotel_full_Charentsavan["country"][i]).group()
    country_list.append(text)

hotel_full_Charentsavan["country"] = country_list

# %%
hotel_full_Charentsavan
# Out:
#          city  country                             name  \
# 1   Nor Geghi  Armenia       House in Armenia, Lusakert
# 8      Fantan  Armenia  Fantan Farms - Organic Farmstay
# 9      Jraber  Armenia   Peaceful getaway in the nature
# 11  Karashamb  Armenia       Pool and BBQ in cozy place
# 13   Aghveran  Armenia      GARDEN VINTAGE HOUSE/HEAVEN
# 20    Arzakan  Armenia    Your dream cottage in forest.
# 25    Abovyan  Armenia           Holiday home in Nurnus
# 28    Abovyan  Armenia                       Home dacha
#
#                   host_since  \
# 1       Joined in April 2018
# 8    Joined in February 2012
# 9   Joined in September 2016
# 11       Joined in June 2017
# 13   Joined in February 2012
# 20    Joined in January 2021
# 25       Joined in June 2016
# 28   Joined in November 2016
#
#                                    host_response_rate  \
# 1   Languages: English, Русский\nResponse rate: 10...
# 8   Response rate: 100%\nResponse time: within a f...
# ...

# %%
host_since_list = []
for i in hotel_full_Charentsavan.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Charentsavan.host_since = hs 
hotel_full_Charentsavan.host_since
# Out:
# 1     2018
# 8     2012
# 9     2016
# 11    2017
# 13    2012
# 20    2021
# 25    2016
# 28    2016
# Name: host_since, dtype: int64

# %%
hotel_full_Charentsavan
# Out:
#          city  country                             name  host_since  \
# 1   Nor Geghi  Armenia       House in Armenia, Lusakert        2018
# 8      Fantan  Armenia  Fantan Farms - Organic Farmstay        2012
# 9      Jraber  Armenia   Peaceful getaway in the nature        2016
# 11  Karashamb  Armenia       Pool and BBQ in cozy place        2017
# 13   Aghveran  Armenia      GARDEN VINTAGE HOUSE/HEAVEN        2012
# 20    Arzakan  Armenia    Your dream cottage in forest.        2021
# 25    Abovyan  Armenia           Holiday home in Nurnus        2016
# 28    Abovyan  Armenia                       Home dacha        2016
#
#                                    host_response_rate  \
# 1   Languages: English, Русский\nResponse rate: 10...
# 8   Response rate: 100%\nResponse time: within a f...
# 9   Languages: English, Français, Deutsch, 日本語, Ру...
# 11  Response rate: 100%\nResponse time: within an ...
# 13  Response rate: 100%\nResponse time: within an ...
# ...

# %%
string = []
for i in hotel_full_Charentsavan.index:
    st = hotel_full_Charentsavan.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["14 Reviews', '\\U000f0003', 'Superhost",
#  "38 Reviews', 'Identity verified",
#  "85 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  'Identity verified',
#  "1 Review', 'Identity verified",
#  'Identity verified',
#  'Identity verified',
#  '1 Review']

# %%
hotel_full_Charentsavan.host_identity_verified = string
hotel_full_Charentsavan.host_identity_verified
# Out:
# 1                 14 Reviews', '\U000f0003', 'Superhost
# 8                       38 Reviews', 'Identity verified
# 9     85 Reviews', 'Identity verified', '\U000f0003'...
# 11                                    Identity verified
# 13                        1 Review', 'Identity verified
# 20                                    Identity verified
# 25                                    Identity verified
# 28                                             1 Review
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Charentsavan.index:
    if "Identity verified" in  hotel_full_Charentsavan.host_identity_verified[i]:
        hotel_full_Charentsavan.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Charentsavan.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Charentsavan
# Out:
#          city  country                             name  host_since  \
# 1   Nor Geghi  Armenia       House in Armenia, Lusakert        2018
# 8      Fantan  Armenia  Fantan Farms - Organic Farmstay        2012
# 9      Jraber  Armenia   Peaceful getaway in the nature        2016
# 11  Karashamb  Armenia       Pool and BBQ in cozy place        2017
# 13   Aghveran  Armenia      GARDEN VINTAGE HOUSE/HEAVEN        2012
# 20    Arzakan  Armenia    Your dream cottage in forest.        2021
# 25    Abovyan  Armenia           Holiday home in Nurnus        2016
# 28    Abovyan  Armenia                       Home dacha        2016
#
#                                    host_response_rate host_identity_verified  \
# 1   Languages: English, Русский\nResponse rate: 10...  Identity not verified
# 8   Response rate: 100%\nResponse time: within a f...      Identity verified
# 9   Languages: English, Français, Deutsch, 日本語, Ру...      Identity verified
# ...

# %%
for i in hotel_full_Charentsavan.index:
    if "Review" in  hotel_full_Charentsavan.review[i]:
        hotel_full_Charentsavan.loc[i, 'review'] = re.search("(\d+)", hotel_full_Charentsavan.review[i]).group()
        
    else:
        hotel_full_Charentsavan.loc[i, 'review'] = 0

# %%
hotel_full_Charentsavan
# Out:
#          city  country                             name  host_since  \
# 1   Nor Geghi  Armenia       House in Armenia, Lusakert        2018
# 8      Fantan  Armenia  Fantan Farms - Organic Farmstay        2012
# 9      Jraber  Armenia   Peaceful getaway in the nature        2016
# 11  Karashamb  Armenia       Pool and BBQ in cozy place        2017
# 13   Aghveran  Armenia      GARDEN VINTAGE HOUSE/HEAVEN        2012
# 20    Arzakan  Armenia    Your dream cottage in forest.        2021
# 25    Abovyan  Armenia           Holiday home in Nurnus        2016
# 28    Abovyan  Armenia                       Home dacha        2016
#
#                                    host_response_rate host_identity_verified  \
# 1   Languages: English, Русский\nResponse rate: 10...  Identity not verified
# 8   Response rate: 100%\nResponse time: within a f...      Identity verified
# 9   Languages: English, Français, Deutsch, 日本語, Ру...      Identity verified
# ...

# %%
for i in hotel_full_Charentsavan.index:
    if "Superhost" in  hotel_full_Charentsavan.superhost[i]:
        hotel_full_Charentsavan.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Charentsavan.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Charentsavan.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire villa',
#  'Private room in residential home',
#  'Private room in cottage',
#  'Entire villa',
#  'Entire villa',
#  'Private room in nature lodge',
#  'Entire residential home',
#  'Private room in residential home']

# %%
hotel_full_Charentsavan.property_type =prop_list

# %%
hotel_full_Charentsavan
# Out:
#          city  country                             name  host_since  \
# 1   Nor Geghi  Armenia       House in Armenia, Lusakert        2018
# 8      Fantan  Armenia  Fantan Farms - Organic Farmstay        2012
# 9      Jraber  Armenia   Peaceful getaway in the nature        2016
# 11  Karashamb  Armenia       Pool and BBQ in cozy place        2017
# 13   Aghveran  Armenia      GARDEN VINTAGE HOUSE/HEAVEN        2012
# 20    Arzakan  Armenia    Your dream cottage in forest.        2021
# 25    Abovyan  Armenia           Holiday home in Nurnus        2016
# 28    Abovyan  Armenia                       Home dacha        2016
#
#                                    host_response_rate host_identity_verified  \
# 1   Languages: English, Русский\nResponse rate: 10...  Identity not verified
# 8   Response rate: 100%\nResponse time: within a f...      Identity verified
# 9   Languages: English, Français, Deutsch, 日本語, Ру...      Identity verified
# ...

# %%
accomodates_list = []
for i in hotel_full_Charentsavan.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Charentsavan.accomodates = number

# %%
for i in hotel_full_Charentsavan.index:
    if "Shared half-bath" in  hotel_full_Charentsavan.number_bathroom[i]:
        hotel_full_Charentsavan.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Charentsavan.number_bathroom[i]:
        hotel_full_Charentsavan.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Charentsavan.number_bathroom[i]:
        hotel_full_Charentsavan.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Charentsavan.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Charentsavan.number_bedroom[i])
        hotel_full_Charentsavan.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Charentsavan.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Charentsavan.number_bedroom[i])
        hotel_full_Charentsavan.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Charentsavan.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Charentsavan.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Charentsavan.index:
    if "bed" in  hotel_full_Charentsavan.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Charentsavan.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Charentsavan.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['2', '4', '4', '7', '4', '2', '7', '10']

# %%
len(hotel_full_Charentsavan.number_beds)
# Out:
# 8

# %%
len(number_beds_list)
# Out:
# 8

# %%
hotel_full_Charentsavan.number_beds = number_beds_list

# %%
hotel_full_Charentsavan.number_beds
# Out:
# 1      2
# 8      4
# 9      4
# 11     7
# 13     4
# 20     2
# 25     7
# 28    10
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Charentsavan.index:
    if "Studio" in  hotel_full_Charentsavan.number_bedroom[i]:
        hotel_full_Charentsavan.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Charentsavan.number_bedroom[i])
        hotel_full_Charentsavan.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Charentsavan.index:
    if "Cleanliness" in  hotel_full_Charentsavan.cleanliness[i]:
        hotel_full_Charentsavan.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Charentsavan.cleanliness[i])
    else:
        hotel_full_Charentsavan.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Charentsavan.index:
    if "Accuracy" in  hotel_full_Charentsavan.accuracy[i]:
        hotel_full_Charentsavan.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Charentsavan.accuracy[i])
    else:
        hotel_full_Charentsavan.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Charentsavan.index:
    if "Communication" in  hotel_full_Charentsavan.communication[i]:
        hotel_full_Charentsavan.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Charentsavan.communication[i])
    else:
        hotel_full_Charentsavan.loc[i, 'communication'] = None

# %%
for i in hotel_full_Charentsavan.index:
    if "Location" in  hotel_full_Charentsavan.location[i]:
        try:
            hotel_full_Charentsavan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Charentsavan.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Charentsavan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Charentsavan.location[i])
    
    else:
        hotel_full_Charentsavan.loc[i, 'location'] = None

# %%
for i in hotel_full_Charentsavan.index:
    if "Check-in" in  hotel_full_Charentsavan.check_in[i]:
        hotel_full_Charentsavan.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Charentsavan.check_in[i])
    else:
        hotel_full_Charentsavan.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Charentsavan.index:
    if "Value" in  hotel_full_Charentsavan.value[i]:
        hotel_full_Charentsavan.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Charentsavan.value[i])
    else:
        hotel_full_Charentsavan.loc[i, 'value'] = None

# %%
for i in hotel_full_Charentsavan.index:
    if "No reviews (yet)" in  hotel_full_Charentsavan.rating[i]:
        hotel_full_Charentsavan.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Charentsavan.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Charentsavan.price = price_list

# %%
for i in hotel_full_Charentsavan.index:
    if "Response rate" in  hotel_full_Charentsavan.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Charentsavan.host_response_rate[i])
        hotel_full_Charentsavan.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Charentsavan.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Charentsavan = hotel_full_Charentsavan.astype(convert_dict)

# %%
hotel_full_Charentsavan.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Charentsavan.to_csv("cleaned_hotel_full_Charentsavan.csv", index=False)
hotel_full_Charentsavan.to_excel("cleaned_hotel_full_Charentsavan2.xlsx", index=False)
