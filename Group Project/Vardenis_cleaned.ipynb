# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Vardenis = pd.read_csv('hotel_full_Vardenis.csv')
hotel_full_Vardenis
# Out:
#                                       city  \
# 0                                      NaN
# 1  Vardenis, Gegharkunik Province, Armenia
# 2  Vardenis, Gegharkunik Province, Armenia
# 3          Tsapatagh, Gegharkunik, Armenia
# 4      Vayk, Vayots Dzor Province, Armenia
# 5           Vardenis, Gegharkunik, Armenia
#
#                                    country  \
# 0                                      NaN
# 1  Vardenis, Gegharkunik Province, Armenia
# 2  Vardenis, Gegharkunik Province, Armenia
# 3          Tsapatagh, Gegharkunik, Armenia
# 4      Vayk, Vayots Dzor Province, Armenia
# 5           Vardenis, Gegharkunik, Armenia
#
#                                           name               host_since  \
# 0                                          NaN                      NaN
# 1                                 Anna`S House   Joined in October 2019
# 2                                        Hotel    Joined in August 2019
# ...

# %%
hotel_full_Vardenis = hotel_full_Vardenis.drop(labels = 0, axis = 0)
hotel_full_Vardenis
# Out:
#                                       city  \
# 1  Vardenis, Gegharkunik Province, Armenia
# 2  Vardenis, Gegharkunik Province, Armenia
# 3          Tsapatagh, Gegharkunik, Armenia
# 4      Vayk, Vayots Dzor Province, Armenia
# 5           Vardenis, Gegharkunik, Armenia
#
#                                    country  \
# 1  Vardenis, Gegharkunik Province, Armenia
# 2  Vardenis, Gegharkunik Province, Armenia
# 3          Tsapatagh, Gegharkunik, Armenia
# 4      Vayk, Vayots Dzor Province, Armenia
# 5           Vardenis, Gegharkunik, Armenia
#
#                                           name               host_since  \
# 1                                 Anna`S House   Joined in October 2019
# 2                                        Hotel    Joined in August 2019
# 3           Уютный дом с видом на озеро Севан.    Joined in August 2016
# 4  Cozy house in wonderful nature of Karvachar      Joined in July 2018
# 5                       Guest haus in Vardenis  Joined in November 2014
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Vardenis.replace("", nan_value, inplace = True)
hotel_full_Vardenis.dropna(inplace= True)
hotel_full_Vardenis
# Out:
#                                   city                              country  \
# 3      Tsapatagh, Gegharkunik, Armenia      Tsapatagh, Gegharkunik, Armenia
# 4  Vayk, Vayots Dzor Province, Armenia  Vayk, Vayots Dzor Province, Armenia
#
#                                           name             host_since  \
# 3           Уютный дом с видом на озеро Севан.  Joined in August 2016
# 4  Cozy house in wonderful nature of Karvachar    Joined in July 2018
#
#                                   host_response_rate host_identity_verified  \
# 3  Language: English\nResponse rate: 100%\nRespon...          ['4 Reviews']
# 4              Languages: English, Italiano, Русский          ['5 Reviews']
#
#           review  superhost  \
# 3  ['4 Reviews']  4 Reviews
# 4  ['5 Reviews']  5 Reviews
#
#                                        property_type  \
# 3  Private room in bed and breakfast hosted by Алина
# 4   Shared room in residential home hosted by Tamara
#
# ...

# %%
city_list = []
for i in hotel_full_Vardenis.index:
    text = re.sub(",", "", hotel_full_Vardenis["city"][i][:hotel_full_Vardenis["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Vardenis["city"]= city_list
hotel_full_Vardenis
# Out:
#                          city                              country  \
# 3      Tsapatagh Gegharkunik       Tsapatagh, Gegharkunik, Armenia
# 4  Vayk Vayots Dzor Province   Vayk, Vayots Dzor Province, Armenia
#
#                                           name             host_since  \
# 3           Уютный дом с видом на озеро Севан.  Joined in August 2016
# 4  Cozy house in wonderful nature of Karvachar    Joined in July 2018
#
#                                   host_response_rate host_identity_verified  \
# 3  Language: English\nResponse rate: 100%\nRespon...          ['4 Reviews']
# 4              Languages: English, Italiano, Русский          ['5 Reviews']
#
#           review  superhost  \
# 3  ['4 Reviews']  4 Reviews
# 4  ['5 Reviews']  5 Reviews
#
#                                        property_type  \
# 3  Private room in bed and breakfast hosted by Алина
# 4   Shared room in residential home hosted by Tamara
#
#                                          accomodates  ...  \
# ...

# %%
nan_value = float("Nan")
hotel_full_Vardenis.replace("", nan_value, inplace = True)
hotel_full_Vardenis.dropna(inplace= True)
hotel_full_Vardenis
# Out:
#                          city                              country  \
# 3      Tsapatagh Gegharkunik       Tsapatagh, Gegharkunik, Armenia
# 4  Vayk Vayots Dzor Province   Vayk, Vayots Dzor Province, Armenia
#
#                                           name             host_since  \
# 3           Уютный дом с видом на озеро Севан.  Joined in August 2016
# 4  Cozy house in wonderful nature of Karvachar    Joined in July 2018
#
#                                   host_response_rate host_identity_verified  \
# 3  Language: English\nResponse rate: 100%\nRespon...          ['4 Reviews']
# 4              Languages: English, Italiano, Русский          ['5 Reviews']
#
#           review  superhost  \
# 3  ['4 Reviews']  4 Reviews
# 4  ['5 Reviews']  5 Reviews
#
#                                        property_type  \
# 3  Private room in bed and breakfast hosted by Алина
# 4   Shared room in residential home hosted by Tamara
#
#                                          accomodates  ...  \
# ...

# %%
c_l = []    
for k in hotel_full_Vardenis["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Vardenis["city"]= c_l
hotel_full_Vardenis
# Out:
#         city                              country  \
# 3  Tsapatagh      Tsapatagh, Gegharkunik, Armenia
# 4       Vayk  Vayk, Vayots Dzor Province, Armenia
#
#                                           name             host_since  \
# 3           Уютный дом с видом на озеро Севан.  Joined in August 2016
# 4  Cozy house in wonderful nature of Karvachar    Joined in July 2018
#
#                                   host_response_rate host_identity_verified  \
# 3  Language: English\nResponse rate: 100%\nRespon...          ['4 Reviews']
# 4              Languages: English, Italiano, Русский          ['5 Reviews']
#
#           review  superhost  \
# 3  ['4 Reviews']  4 Reviews
# 4  ['5 Reviews']  5 Reviews
#
#                                        property_type  \
# 3  Private room in bed and breakfast hosted by Алина
# 4   Shared room in residential home hosted by Tamara
#
#                                          accomodates  ...  \
# ...

# %%
country_list = []
for i in hotel_full_Vardenis.index:
    text = re.search("Armenia", hotel_full_Vardenis["country"][i]).group()
    country_list.append(text)

hotel_full_Vardenis["country"] = country_list

# %%
hotel_full_Vardenis
# Out:
#         city  country                                         name  \
# 3  Tsapatagh  Armenia           Уютный дом с видом на озеро Севан.
# 4       Vayk  Armenia  Cozy house in wonderful nature of Karvachar
#
#               host_since                                 host_response_rate  \
# 3  Joined in August 2016  Language: English\nResponse rate: 100%\nRespon...
# 4    Joined in July 2018              Languages: English, Italiano, Русский
#
#   host_identity_verified         review  superhost  \
# 3          ['4 Reviews']  ['4 Reviews']  4 Reviews
# 4          ['5 Reviews']  ['5 Reviews']  5 Reviews
#
#                                        property_type  \
# 3  Private room in bed and breakfast hosted by Алина
# 4   Shared room in residential home hosted by Tamara
#
#                                          accomodates  ...  \
# 3  Private room in bed and breakfast hosted by Ал...  ...
# 4  Shared room in residential home hosted by Tama...  ...
#
# ...

# %%
host_since_list = []
for i in hotel_full_Vardenis.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Vardenis.host_since = hs 
hotel_full_Vardenis.host_since
# Out:
# 3    2016
# 4    2018
# Name: host_since, dtype: int64

# %%
hotel_full_Vardenis
# Out:
#         city  country                                         name  \
# 3  Tsapatagh  Armenia           Уютный дом с видом на озеро Севан.
# 4       Vayk  Armenia  Cozy house in wonderful nature of Karvachar
#
#    host_since                                 host_response_rate  \
# 3        2016  Language: English\nResponse rate: 100%\nRespon...
# 4        2018              Languages: English, Italiano, Русский
#
#   host_identity_verified         review  superhost  \
# 3          ['4 Reviews']  ['4 Reviews']  4 Reviews
# 4          ['5 Reviews']  ['5 Reviews']  5 Reviews
#
#                                        property_type  \
# 3  Private room in bed and breakfast hosted by Алина
# 4   Shared room in residential home hosted by Tamara
#
#                                          accomodates  ...  \
# 3  Private room in bed and breakfast hosted by Ал...  ...
# 4  Shared room in residential home hosted by Tama...  ...
#
#                                       number_bedroom  \
# ...

# %%
string = []
for i in hotel_full_Vardenis.index:
    st = hotel_full_Vardenis.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ['4 Reviews', '5 Reviews']

# %%
hotel_full_Vardenis.host_identity_verified = string
hotel_full_Vardenis.host_identity_verified
# Out:
# 3    4 Reviews
# 4    5 Reviews
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Vardenis.index:
    if "Identity verified" in  hotel_full_Vardenis.host_identity_verified[i]:
        hotel_full_Vardenis.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Vardenis.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Vardenis
# Out:
#         city  country                                         name  \
# 3  Tsapatagh  Armenia           Уютный дом с видом на озеро Севан.
# 4       Vayk  Armenia  Cozy house in wonderful nature of Karvachar
#
#    host_since                                 host_response_rate  \
# 3        2016  Language: English\nResponse rate: 100%\nRespon...
# 4        2018              Languages: English, Italiano, Русский
#
#   host_identity_verified         review  superhost  \
# 3  Identity not verified  ['4 Reviews']  4 Reviews
# 4  Identity not verified  ['5 Reviews']  5 Reviews
#
#                                        property_type  \
# 3  Private room in bed and breakfast hosted by Алина
# 4   Shared room in residential home hosted by Tamara
#
#                                          accomodates  ...  \
# 3  Private room in bed and breakfast hosted by Ал...  ...
# 4  Shared room in residential home hosted by Tama...  ...
#
#                                       number_bedroom  \
# ...

# %%
for i in hotel_full_Vardenis.index:
    if "Review" in  hotel_full_Vardenis.review[i]:
        hotel_full_Vardenis.loc[i, 'review'] = re.search("(\d+)", hotel_full_Vardenis.review[i]).group()
        
    else:
        hotel_full_Vardenis.loc[i, 'review'] = 0

# %%
hotel_full_Vardenis
# Out:
#         city  country                                         name  \
# 3  Tsapatagh  Armenia           Уютный дом с видом на озеро Севан.
# 4       Vayk  Armenia  Cozy house in wonderful nature of Karvachar
#
#    host_since                                 host_response_rate  \
# 3        2016  Language: English\nResponse rate: 100%\nRespon...
# 4        2018              Languages: English, Italiano, Русский
#
#   host_identity_verified review  superhost  \
# 3  Identity not verified      4  4 Reviews
# 4  Identity not verified      5  5 Reviews
#
#                                        property_type  \
# 3  Private room in bed and breakfast hosted by Алина
# 4   Shared room in residential home hosted by Tamara
#
#                                          accomodates  ...  \
# 3  Private room in bed and breakfast hosted by Ал...  ...
# 4  Shared room in residential home hosted by Tama...  ...
#
#                                       number_bedroom  \
# ...

# %%
for i in hotel_full_Vardenis.index:
    if "Superhost" in  hotel_full_Vardenis.superhost[i]:
        hotel_full_Vardenis.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Vardenis.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Vardenis.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Private room in bed and breakfast', 'Shared room in residential home']

# %%
hotel_full_Vardenis.property_type =prop_list

# %%
hotel_full_Vardenis
# Out:
#         city  country                                         name  \
# 3  Tsapatagh  Armenia           Уютный дом с видом на озеро Севан.
# 4       Vayk  Armenia  Cozy house in wonderful nature of Karvachar
#
#    host_since                                 host_response_rate  \
# 3        2016  Language: English\nResponse rate: 100%\nRespon...
# 4        2018              Languages: English, Italiano, Русский
#
#   host_identity_verified review     superhost  \
# 3  Identity not verified      4  regular host
# 4  Identity not verified      5  regular host
#
#                        property_type  \
# 3  Private room in bed and breakfast
# 4    Shared room in residential home
#
#                                          accomodates  ...  \
# 3  Private room in bed and breakfast hosted by Ал...  ...
# 4  Shared room in residential home hosted by Tama...  ...
#
#                                       number_bedroom  \
# 3  Private room in bed and breakfast hosted by Ал...
# ...

# %%
accomodates_list = []
for i in hotel_full_Vardenis.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Vardenis.accomodates = number

# %%
for i in hotel_full_Vardenis.index:
    if "Shared half-bath" in  hotel_full_Vardenis.number_bathroom[i]:
        hotel_full_Vardenis.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Vardenis.number_bathroom[i]:
        hotel_full_Vardenis.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Vardenis.number_bathroom[i]:
        hotel_full_Vardenis.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Vardenis.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Vardenis.number_bedroom[i])
        hotel_full_Vardenis.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Vardenis.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Vardenis.number_bedroom[i])
        hotel_full_Vardenis.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Vardenis.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Vardenis.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Vardenis.index:
    if "bed" in  hotel_full_Vardenis.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Vardenis.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Vardenis.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['5', '2']

# %%
len(hotel_full_Vardenis.number_beds)
# Out:
# 2

# %%
len(number_beds_list)
# Out:
# 2

# %%
hotel_full_Vardenis.number_beds = number_beds_list

# %%
hotel_full_Vardenis.number_beds
# Out:
# 3    5
# 4    2
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Vardenis.index:
    if "Studio" in  hotel_full_Vardenis.number_bedroom[i]:
        hotel_full_Vardenis.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Vardenis.number_bedroom[i])
        hotel_full_Vardenis.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Vardenis.index:
    if "Cleanliness" in  hotel_full_Vardenis.cleanliness[i]:
        hotel_full_Vardenis.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Vardenis.cleanliness[i])
    else:
        hotel_full_Vardenis.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Vardenis.index:
    if "Accuracy" in  hotel_full_Vardenis.accuracy[i]:
        hotel_full_Vardenis.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Vardenis.accuracy[i])
    else:
        hotel_full_Vardenis.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Vardenis.index:
    if "Communication" in  hotel_full_Vardenis.communication[i]:
        hotel_full_Vardenis.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Vardenis.communication[i])
    else:
        hotel_full_Vardenis.loc[i, 'communication'] = None

# %%
for i in hotel_full_Vardenis.index:
    if "Location" in  hotel_full_Vardenis.location[i]:
        try:
            hotel_full_Vardenis.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Vardenis.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Vardenis.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Vardenis.location[i])
    
    else:
        hotel_full_Vardenis.loc[i, 'location'] = None

# %%
for i in hotel_full_Vardenis.index:
    if "Check-in" in  hotel_full_Vardenis.check_in[i]:
        hotel_full_Vardenis.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Vardenis.check_in[i])
    else:
        hotel_full_Vardenis.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Vardenis.index:
    if "Value" in  hotel_full_Vardenis.value[i]:
        hotel_full_Vardenis.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Vardenis.value[i])
    else:
        hotel_full_Vardenis.loc[i, 'value'] = None

# %%
for i in hotel_full_Vardenis.index:
    if "No reviews (yet)" in  hotel_full_Vardenis.rating[i]:
        hotel_full_Vardenis.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Vardenis.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Vardenis.price = price_list

# %%
for i in hotel_full_Vardenis.index:
    if "Response rate" in  hotel_full_Vardenis.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Vardenis.host_response_rate[i])
        hotel_full_Vardenis.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Vardenis.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Vardenis = hotel_full_Vardenis.astype(convert_dict)

# %%
hotel_full_Vardenis.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Vardenis.to_csv("cleaned_hotel_full_Vardenis.csv", index=False)
hotel_full_Vardenis.to_excel("cleaned_hotel_full_Vardenis2.xlsx", index=False)
