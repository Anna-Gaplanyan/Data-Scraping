# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Tumanyan = pd.read_csv('hotel_full_Tumanyan.csv')
hotel_full_Tumanyan
# Out:
#                                    city                              country  \
# 0                                   NaN                                  NaN
# 1         Odzun, Lori Province, Armenia        Odzun, Lori Province, Armenia
# 2      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 3      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 4      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 5        Tsater, Lori Province, Armenia       Tsater, Lori Province, Armenia
# 6      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 7    Dzoragyugh, Lori Province, Armenia   Dzoragyugh, Lori Province, Armenia
# 8               Алаверди, Лори, Armenia              Алаверди, Лори, Armenia
# 9    Stepanavan, Lori Province, Armenia   Stepanavan, Lori Province, Armenia
# 10     Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# ...

# %%
hotel_full_Tumanyan = hotel_full_Tumanyan.drop(labels = 0, axis = 0)
hotel_full_Tumanyan
# Out:
#                                    city                              country  \
# 1         Odzun, Lori Province, Armenia        Odzun, Lori Province, Armenia
# 2      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 3      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 4      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 5        Tsater, Lori Province, Armenia       Tsater, Lori Province, Armenia
# 6      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 7    Dzoragyugh, Lori Province, Armenia   Dzoragyugh, Lori Province, Armenia
# 8               Алаверди, Лори, Armenia              Алаверди, Лори, Armenia
# 9    Stepanavan, Lori Province, Armenia   Stepanavan, Lori Province, Armenia
# 10     Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 11     Pushkino, Lori Province, Armenia     Pushkino, Lori Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Tumanyan.replace("", nan_value, inplace = True)
hotel_full_Tumanyan.dropna(inplace= True)
hotel_full_Tumanyan
# Out:
#                                    city                              country  \
# 1         Odzun, Lori Province, Armenia        Odzun, Lori Province, Armenia
# 2      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 3      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 8               Алаверди, Лори, Armenia              Алаверди, Лори, Armenia
# 9    Stepanavan, Lori Province, Armenia   Stepanavan, Lori Province, Armenia
# 12     Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 13                  Stepanavan, Armenia                  Stepanavan, Armenia
# 17   Stepanavan, Lori Province, Armenia   Stepanavan, Lori Province, Armenia
# 22   Stepanavan, Lori Province, Armenia   Stepanavan, Lori Province, Armenia
# 26     Գյուլագարակ, Լոռու մարզ, Armenia     Գյուլագարակ, Լոռու մարզ, Armenia
# 30  Vahagnadzor, Lori Province, Armenia  Vahagnadzor, Lori Province, Armenia
# ...

# %%
hotel_full_Tumanyan["city"]= hotel_full_Tumanyan["city"].replace({"Алаверди, Лори, Armenia" : "Alaverdi, Lori Province, Armenia"})

hotel_full_Tumanyan["city"]= hotel_full_Tumanyan["city"].replace({"Հաղպատ, Լոռու մարզ, Armenia" : "Haghpat, Lori Province, Armenia"})

hotel_full_Tumanyan["city"]= hotel_full_Tumanyan["city"].replace({"Գյուլագարակ, Լոռու մարզ, Armenia" : "Gyulagarak, Lori Province, Armenia"})

hotel_full_Tumanyan["city"]= hotel_full_Tumanyan["city"].replace({"Ալավերդի, Լոռու մարզ, Armenia" : "Alaverdi, Lori Province, Armenia"})
hotel_full_Tumanyan
# Out:
#                                    city                              country  \
# 1         Odzun, Lori Province, Armenia        Odzun, Lori Province, Armenia
# 2      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 3      Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 8      Alaverdi, Lori Province, Armenia              Алаверди, Лори, Armenia
# 9    Stepanavan, Lori Province, Armenia   Stepanavan, Lori Province, Armenia
# 12     Alaverdi, Lori Province, Armenia     Alaverdi, Lori Province, Armenia
# 13                  Stepanavan, Armenia                  Stepanavan, Armenia
# 17   Stepanavan, Lori Province, Armenia   Stepanavan, Lori Province, Armenia
# 22   Stepanavan, Lori Province, Armenia   Stepanavan, Lori Province, Armenia
# 26   Gyulagarak, Lori Province, Armenia     Գյուլագարակ, Լոռու մարզ, Armenia
# 30  Vahagnadzor, Lori Province, Armenia  Vahagnadzor, Lori Province, Armenia
# ...

# %%
city_list = []
for i in hotel_full_Tumanyan.index:
    text = re.sub(",", "", hotel_full_Tumanyan["city"][i][:hotel_full_Tumanyan["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Tumanyan["city"]= city_list
hotel_full_Tumanyan
# Out:
#                           city                              country  \
# 1         Odzun Lori Province         Odzun, Lori Province, Armenia
# 2      Alaverdi Lori Province      Alaverdi, Lori Province, Armenia
# 3      Alaverdi Lori Province      Alaverdi, Lori Province, Armenia
# 8      Alaverdi Lori Province               Алаверди, Лори, Armenia
# 9    Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# 12     Alaverdi Lori Province      Alaverdi, Lori Province, Armenia
# 13                 Stepanavan                   Stepanavan, Armenia
# 17   Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# 22   Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# 26   Gyulagarak Lori Province      Գյուլագարակ, Լոռու մարզ, Armenia
# 30  Vahagnadzor Lori Province   Vahagnadzor, Lori Province, Armenia
# 32   Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# 37   Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Tumanyan.replace("", nan_value, inplace = True)
hotel_full_Tumanyan.dropna(inplace= True)
hotel_full_Tumanyan
# Out:
#                           city                              country  \
# 1         Odzun Lori Province         Odzun, Lori Province, Armenia
# 2      Alaverdi Lori Province      Alaverdi, Lori Province, Armenia
# 3      Alaverdi Lori Province      Alaverdi, Lori Province, Armenia
# 8      Alaverdi Lori Province               Алаверди, Лори, Armenia
# 9    Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# 12     Alaverdi Lori Province      Alaverdi, Lori Province, Armenia
# 13                 Stepanavan                   Stepanavan, Armenia
# 17   Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# 22   Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# 26   Gyulagarak Lori Province      Գյուլագարակ, Լոռու մարզ, Armenia
# 30  Vahagnadzor Lori Province   Vahagnadzor, Lori Province, Armenia
# 32   Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# 37   Stepanavan Lori Province    Stepanavan, Lori Province, Armenia
# ...

# %%
c_l = []    
for k in hotel_full_Tumanyan["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Tumanyan["city"]= c_l
hotel_full_Tumanyan
# Out:
#            city                              country  \
# 1         Odzun        Odzun, Lori Province, Armenia
# 2      Alaverdi     Alaverdi, Lori Province, Armenia
# 3      Alaverdi     Alaverdi, Lori Province, Armenia
# 8      Alaverdi              Алаверди, Лори, Armenia
# 9    Stepanavan   Stepanavan, Lori Province, Armenia
# 12     Alaverdi     Alaverdi, Lori Province, Armenia
# 13   Stepanavan                  Stepanavan, Armenia
# 17   Stepanavan   Stepanavan, Lori Province, Armenia
# 22   Stepanavan   Stepanavan, Lori Province, Armenia
# 26   Gyulagarak     Գյուլագարակ, Լոռու մարզ, Armenia
# 30  Vahagnadzor  Vahagnadzor, Lori Province, Armenia
# 32   Stepanavan   Stepanavan, Lori Province, Armenia
# 37   Stepanavan   Stepanavan, Lori Province, Armenia
# 39     Alaverdi     Alaverdi, Lori Province, Armenia
# 41     Alaverdi     Alaverdi, Lori Province, Armenia
# 43        Odzun        Odzun, Lori province, Armenia
# 44       Gargar                Gargar, Lori, Armenia
# ...

# %%
country_list = []
for i in hotel_full_Tumanyan.index:
    text = re.search("Armenia", hotel_full_Tumanyan["country"][i]).group()
    country_list.append(text)

hotel_full_Tumanyan["country"] = country_list

# %%
hotel_full_Tumanyan
# Out:
#            city  country                                               name  \
# 1         Odzun  Armenia     Private Villa at Odzun Monastery | Առանձնատուն
# 2      Alaverdi  Armenia                                ARMBEE Honey Farm 2
# 3      Alaverdi  Armenia                                 Family Guest House
# 8      Alaverdi  Armenia                             Come and have a rest!!
# 9    Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 12     Alaverdi  Armenia                            Old City Hotel Alaverdi
# 13   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 17   Stepanavan  Armenia                          Private house with garden
# 22   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 26   Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 30  Vahagnadzor  Armenia     Two bedroom with living room in Gugark Retreat
# ...

# %%
host_since_list = []
for i in hotel_full_Tumanyan.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Tumanyan.host_since = hs 
hotel_full_Tumanyan.host_since
# Out:
# 1     2015
# 2     2019
# 3     2016
# 8     2014
# 9     2021
# 12    2019
# 13    2018
# 17    2017
# 22    2021
# 26    2020
# 30    2019
# 32    2021
# 37    2018
# 39    2019
# 41    2019
# 43    2017
# 44    2015
# 45    2021
# 50    2017
# 51    2017
# Name: host_since, dtype: int64

# %%
hotel_full_Tumanyan
# Out:
#            city  country                                               name  \
# 1         Odzun  Armenia     Private Villa at Odzun Monastery | Առանձնատուն
# 2      Alaverdi  Armenia                                ARMBEE Honey Farm 2
# 3      Alaverdi  Armenia                                 Family Guest House
# 8      Alaverdi  Armenia                             Come and have a rest!!
# 9    Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 12     Alaverdi  Armenia                            Old City Hotel Alaverdi
# 13   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 17   Stepanavan  Armenia                          Private house with garden
# 22   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 26   Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 30  Vahagnadzor  Armenia     Two bedroom with living room in Gugark Retreat
# ...

# %%
string = []
for i in hotel_full_Tumanyan.index:
    st = hotel_full_Tumanyan.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["27 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "5 Reviews', 'Identity verified",
#  "10 Reviews', 'Identity verified",
#  '5 Reviews',
#  'Identity verified',
#  '8 Reviews',
#  "3 Reviews', 'Identity verified",
#  "3 Reviews', 'Identity verified",
#  'Identity verified',
#  "1 Review', 'Identity verified",
#  'Identity verified',
#  'Identity verified',
#  "3 Reviews', 'Identity verified",
#  '8 Reviews',
#  '8 Reviews',
#  "1 Review', 'Identity verified",
#  '3 Reviews',
#  'Identity verified',
#  "3 Reviews', 'Identity verified",
#  '6 Reviews']

# %%
hotel_full_Tumanyan.host_identity_verified = string
hotel_full_Tumanyan.host_identity_verified
# Out:
# 1     27 Reviews', 'Identity verified', '\U000f0003'...
# 2                        5 Reviews', 'Identity verified
# 3                       10 Reviews', 'Identity verified
# 8                                             5 Reviews
# 9                                     Identity verified
# 12                                            8 Reviews
# 13                       3 Reviews', 'Identity verified
# 17                       3 Reviews', 'Identity verified
# 22                                    Identity verified
# 26                        1 Review', 'Identity verified
# 30                                    Identity verified
# 32                                    Identity verified
# 37                       3 Reviews', 'Identity verified
# 39                                            8 Reviews
# 41                                            8 Reviews
# 43                        1 Review', 'Identity verified
# 44                                            3 Reviews
# ...

# %%
for i in hotel_full_Tumanyan.index:
    if "Identity verified" in  hotel_full_Tumanyan.host_identity_verified[i]:
        hotel_full_Tumanyan.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Tumanyan.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Tumanyan
# Out:
#            city  country                                               name  \
# 1         Odzun  Armenia     Private Villa at Odzun Monastery | Առանձնատուն
# 2      Alaverdi  Armenia                                ARMBEE Honey Farm 2
# 3      Alaverdi  Armenia                                 Family Guest House
# 8      Alaverdi  Armenia                             Come and have a rest!!
# 9    Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 12     Alaverdi  Armenia                            Old City Hotel Alaverdi
# 13   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 17   Stepanavan  Armenia                          Private house with garden
# 22   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 26   Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 30  Vahagnadzor  Armenia     Two bedroom with living room in Gugark Retreat
# ...

# %%
for i in hotel_full_Tumanyan.index:
    if "Review" in  hotel_full_Tumanyan.review[i]:
        hotel_full_Tumanyan.loc[i, 'review'] = re.search("(\d+)", hotel_full_Tumanyan.review[i]).group()
        
    else:
        hotel_full_Tumanyan.loc[i, 'review'] = 0

# %%
hotel_full_Tumanyan
# Out:
#            city  country                                               name  \
# 1         Odzun  Armenia     Private Villa at Odzun Monastery | Առանձնատուն
# 2      Alaverdi  Armenia                                ARMBEE Honey Farm 2
# 3      Alaverdi  Armenia                                 Family Guest House
# 8      Alaverdi  Armenia                             Come and have a rest!!
# 9    Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 12     Alaverdi  Armenia                            Old City Hotel Alaverdi
# 13   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 17   Stepanavan  Armenia                          Private house with garden
# 22   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 26   Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 30  Vahagnadzor  Armenia     Two bedroom with living room in Gugark Retreat
# ...

# %%
for i in hotel_full_Tumanyan.index:
    if "Superhost" in  hotel_full_Tumanyan.superhost[i]:
        hotel_full_Tumanyan.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Tumanyan.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Tumanyan.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire villa',
#  'Entire chalet',
#  'Private room in guest suite  Hovasapyan',
#  'Entire place',
#  'Room in boutique hotel',
#  'Room in hotel',
#  'Entire residential home',
#  'Entire residential home',
#  'Room in boutique hotel',
#  'Entire villa',
#  'Private room in rental unit',
#  'Entire residential home',
#  'Private room in residential home',
#  'Private room in rental unit',
#  'Private room in rental unit',
#  'Private room in residential home  & Ri',
#  'Private room in residential home',
#  'Entire residential home',
#  'Private room in guest suite',
#  'Private room in bed and breakfast']

# %%
hotel_full_Tumanyan.property_type =prop_list

# %%
hotel_full_Tumanyan
# Out:
#            city  country                                               name  \
# 1         Odzun  Armenia     Private Villa at Odzun Monastery | Առանձնատուն
# 2      Alaverdi  Armenia                                ARMBEE Honey Farm 2
# 3      Alaverdi  Armenia                                 Family Guest House
# 8      Alaverdi  Armenia                             Come and have a rest!!
# 9    Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 12     Alaverdi  Armenia                            Old City Hotel Alaverdi
# 13   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 17   Stepanavan  Armenia                          Private house with garden
# 22   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 26   Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 30  Vahagnadzor  Armenia     Two bedroom with living room in Gugark Retreat
# ...

# %%
accomodates_list = []
for i in hotel_full_Tumanyan.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Tumanyan.accomodates = number

# %%
for i in hotel_full_Tumanyan.index:
    if "Shared half-bath" in  hotel_full_Tumanyan.number_bathroom[i]:
        hotel_full_Tumanyan.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Tumanyan.number_bathroom[i]:
        hotel_full_Tumanyan.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Tumanyan.number_bathroom[i]:
        hotel_full_Tumanyan.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Tumanyan.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Tumanyan.number_bedroom[i])
        hotel_full_Tumanyan.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Tumanyan.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Tumanyan.number_bedroom[i])
        hotel_full_Tumanyan.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Tumanyan.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Tumanyan.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Tumanyan.index:
    if "bed" in  hotel_full_Tumanyan.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Tumanyan.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Tumanyan.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['4',
#  '2',
#  '7',
#  '16',
#  '1',
#  '8',
#  '4',
#  '5',
#  '2',
#  '4',
#  '4',
#  '11',
#  '0',
#  '13',
#  '13',
#  '9',
#  '4',
#  '6',
#  '2',
#  '9']

# %%
len(hotel_full_Tumanyan.number_beds)
# Out:
# 20

# %%
len(number_beds_list)
# Out:
# 20

# %%
hotel_full_Tumanyan.number_beds = number_beds_list

# %%
hotel_full_Tumanyan.number_beds
# Out:
# 1      4
# 2      2
# 3      7
# 8     16
# 9      1
# 12     8
# 13     4
# 17     5
# 22     2
# 26     4
# 30     4
# 32    11
# 37     0
# 39    13
# 41    13
# 43     9
# 44     4
# 45     6
# 50     2
# 51     9
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Tumanyan.index:
    if "Studio" in  hotel_full_Tumanyan.number_bedroom[i]:
        hotel_full_Tumanyan.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Tumanyan.number_bedroom[i])
        hotel_full_Tumanyan.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Tumanyan.index:
    if "Cleanliness" in  hotel_full_Tumanyan.cleanliness[i]:
        hotel_full_Tumanyan.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Tumanyan.cleanliness[i])
    else:
        hotel_full_Tumanyan.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Tumanyan.index:
    if "Accuracy" in  hotel_full_Tumanyan.accuracy[i]:
        hotel_full_Tumanyan.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Tumanyan.accuracy[i])
    else:
        hotel_full_Tumanyan.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Tumanyan.index:
    if "Communication" in  hotel_full_Tumanyan.communication[i]:
        hotel_full_Tumanyan.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Tumanyan.communication[i])
    else:
        hotel_full_Tumanyan.loc[i, 'communication'] = None

# %%
for i in hotel_full_Tumanyan.index:
    if "Location" in  hotel_full_Tumanyan.location[i]:
        try:
            hotel_full_Tumanyan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Tumanyan.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Tumanyan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Tumanyan.location[i])
    
    else:
        hotel_full_Tumanyan.loc[i, 'location'] = None

# %%
for i in hotel_full_Tumanyan.index:
    if "Check-in" in  hotel_full_Tumanyan.check_in[i]:
        hotel_full_Tumanyan.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Tumanyan.check_in[i])
    else:
        hotel_full_Tumanyan.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Tumanyan.index:
    if "Value" in  hotel_full_Tumanyan.value[i]:
        hotel_full_Tumanyan.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Tumanyan.value[i])
    else:
        hotel_full_Tumanyan.loc[i, 'value'] = None

# %%
for i in hotel_full_Tumanyan.index:
    if "No reviews (yet)" in  hotel_full_Tumanyan.rating[i]:
        hotel_full_Tumanyan.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Tumanyan.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Tumanyan.price = price_list

# %%
for i in hotel_full_Tumanyan.index:
    if "Response rate" in  hotel_full_Tumanyan.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Tumanyan.host_response_rate[i])
        hotel_full_Tumanyan.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Tumanyan.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Tumanyan = hotel_full_Tumanyan.astype(convert_dict)

# %%
hotel_full_Tumanyan.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Tumanyan.to_csv("cleaned_hotel_full_Tumanyan.csv", index=False)
hotel_full_Tumanyan.to_excel("cleaned_hotel_full_Tumanyan2.xlsx", index=False)
