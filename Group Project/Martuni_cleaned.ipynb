# 13    Noratus, Gegharkunik Province, Armenia
# 16    Martuni, Gegharkunik Province, Armenia
# 17      Gavar, Gegharkunik Province, Armenia
# ...

# %%
hotel_full_Martuni["city"]= hotel_full_Martuni["city"].replace({"Севан, Gegharkunik Province, Armenia" : "Sevan, Armenia"})

# %%
hotel_full_Martuni["city"]= hotel_full_Martuni["city"].replace({"Եղեգնաձոր, Վայոց Ձոր, Armenia" : "Yeghegnadzor, Armenia"})

# %%
city_list = []
for i in hotel_full_Martuni.index:
    text = re.sub(",", "", hotel_full_Martuni["city"][i][:hotel_full_Martuni["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Martuni["city"]= city_list
hotel_full_Martuni
# Out:
#                                city                                   country  \
# 5             Gegharkunik Province              Gegharkunik Province, Armenia
# 9   Vaghashen Gegharkunik Province   Vaghashen, Gegharkunik Province, Armenia
# 10    Martuni Gegharkunik Province     Martuni, Gegharkunik Province, Armenia
# 11           Tsapatagh Gegharkunik            Tsapatagh, Gegharkunik, Armenia
# 12    Noratus Gegharkunik Province     Noratus, Gegharkunik Province, Armenia
# 13    Noratus Gegharkunik Province     Noratus, Gegharkunik Province, Armenia
# 16    Martuni Gegharkunik Province     Martuni, Gegharkunik Province, Armenia
# 17      Gavar Gegharkunik Province       Gavar, Gegharkunik Province, Armenia
# 19                                                                    Armenia
# 24                                                                    Armenia
# 29    Martuni Gegharkunik Province     Martuni, Gegharkunik Province, Armenia
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Martuni.replace("", nan_value, inplace = True)
hotel_full_Martuni.dropna(inplace= True)
hotel_full_Martuni
# Out:
#                                city                                   country  \
# 5             Gegharkunik Province              Gegharkunik Province, Armenia
# 9   Vaghashen Gegharkunik Province   Vaghashen, Gegharkunik Province, Armenia
# 10    Martuni Gegharkunik Province     Martuni, Gegharkunik Province, Armenia
# 11           Tsapatagh Gegharkunik            Tsapatagh, Gegharkunik, Armenia
# 12    Noratus Gegharkunik Province     Noratus, Gegharkunik Province, Armenia
# 13    Noratus Gegharkunik Province     Noratus, Gegharkunik Province, Armenia
# 16    Martuni Gegharkunik Province     Martuni, Gegharkunik Province, Armenia
# 17      Gavar Gegharkunik Province       Gavar, Gegharkunik Province, Armenia
# 29    Martuni Gegharkunik Province     Martuni, Gegharkunik Province, Armenia
#
#                                                name               host_since  \
# 5                                   Holiday cottage  Joined in February 2019
# ...

# %%
c_l = []    
for k in hotel_full_Martuni["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Martuni["city"]= c_l
hotel_full_Martuni
# Out:
#            city                                   country  \
# 5   Gegharkunik             Gegharkunik Province, Armenia
# 9     Vaghashen  Vaghashen, Gegharkunik Province, Armenia
# 10      Martuni    Martuni, Gegharkunik Province, Armenia
# 11    Tsapatagh           Tsapatagh, Gegharkunik, Armenia
# 12      Noratus    Noratus, Gegharkunik Province, Armenia
# 13      Noratus    Noratus, Gegharkunik Province, Armenia
# 16      Martuni    Martuni, Gegharkunik Province, Armenia
# 17        Gavar      Gavar, Gegharkunik Province, Armenia
# 29      Martuni    Martuni, Gegharkunik Province, Armenia
#
#                                                name               host_since  \
# 5                                   Holiday cottage  Joined in February 2019
# 9              2 story house with garden in Martuni  Joined in December 2010
# 10  New and clean private bedroom. Security parking      Joined in July 2019
# ...

# %%
country_list = []
for i in hotel_full_Martuni.index:
    text = re.search("Armenia", hotel_full_Martuni["country"][i]).group()
    country_list.append(text)

hotel_full_Martuni["country"] = country_list

# %%
hotel_full_Martuni
# Out:
#            city  country                                             name  \
# 5   Gegharkunik  Armenia                                  Holiday cottage
# 9     Vaghashen  Armenia             2 story house with garden in Martuni
# 10      Martuni  Armenia  New and clean private bedroom. Security parking
# 11    Tsapatagh  Armenia               Cozy lodge overlooking Lake Sevan.
# 12      Noratus  Armenia       Oazis a place for a real holiday. Big room
# 13      Noratus  Armenia                        Room with Armenian spirit
# 16      Martuni  Armenia     New guest house 2 bedrooms. Security parking
# 17        Gavar  Armenia                Mountain dweller or Cattle farmer
# 29      Martuni  Armenia                     Fresh air and amazing nature
#
#                  host_since  \
# 5   Joined in February 2019
# 9   Joined in December 2010
# 10      Joined in July 2019
# 11    Joined in August 2016
# 12       Joined in May 2019
# 13       Joined in May 2019
# ...

# %%
host_since_list = []
for i in hotel_full_Martuni.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Martuni.host_since = hs 
hotel_full_Martuni.host_since
# Out:
# 5     2019
# 9     2010
# 10    2019
# 11    2016
# 12    2019
# 13    2019
# 16    2019
# 17    2018
# 29    2019
# Name: host_since, dtype: int64

# %%
hotel_full_Martuni
# Out:
#            city  country                                             name  \
# 5   Gegharkunik  Armenia                                  Holiday cottage
# 9     Vaghashen  Armenia             2 story house with garden in Martuni
# 10      Martuni  Armenia  New and clean private bedroom. Security parking
# 11    Tsapatagh  Armenia               Cozy lodge overlooking Lake Sevan.
# 12      Noratus  Armenia       Oazis a place for a real holiday. Big room
# 13      Noratus  Armenia                        Room with Armenian spirit
# 16      Martuni  Armenia     New guest house 2 bedrooms. Security parking
# 17        Gavar  Armenia                Mountain dweller or Cattle farmer
# 29      Martuni  Armenia                     Fresh air and amazing nature
#
#     host_since                                 host_response_rate  \
# 5         2019  Response rate: 0%\nResponse time: a few days o...
# 9         2010                        Languages: English, Русский
# ...

# %%
string = []
for i in hotel_full_Martuni.index:
    st = hotel_full_Martuni.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ['Identity verified',
#  '72 Reviews',
#  '8 Reviews',
#  '4 Reviews',
#  '1 Review',
#  '1 Review',
#  '8 Reviews',
#  'Identity verified',
#  '1 Review']

# %%
hotel_full_Martuni.host_identity_verified = string
hotel_full_Martuni.host_identity_verified
# Out:
# 5     Identity verified
# 9            72 Reviews
# 10            8 Reviews
# 11            4 Reviews
# 12             1 Review
# 13             1 Review
# 16            8 Reviews
# 17    Identity verified
# 29             1 Review
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Martuni.index:
    if "Identity verified" in  hotel_full_Martuni.host_identity_verified[i]:
        hotel_full_Martuni.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Martuni.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Martuni
# Out:
#            city  country                                             name  \
# 5   Gegharkunik  Armenia                                  Holiday cottage
# 9     Vaghashen  Armenia             2 story house with garden in Martuni
# 10      Martuni  Armenia  New and clean private bedroom. Security parking
# 11    Tsapatagh  Armenia               Cozy lodge overlooking Lake Sevan.
# 12      Noratus  Armenia       Oazis a place for a real holiday. Big room
# 13      Noratus  Armenia                        Room with Armenian spirit
# 16      Martuni  Armenia     New guest house 2 bedrooms. Security parking
# 17        Gavar  Armenia                Mountain dweller or Cattle farmer
# 29      Martuni  Armenia                     Fresh air and amazing nature
#
#     host_since                                 host_response_rate  \
# 5         2019  Response rate: 0%\nResponse time: a few days o...
# 9         2010                        Languages: English, Русский
# ...

# %%
for i in hotel_full_Martuni.index:
    if "Review" in  hotel_full_Martuni.review[i]:
        hotel_full_Martuni.loc[i, 'review'] = re.search("(\d+)", hotel_full_Martuni.review[i]).group()
        
    else:
        hotel_full_Martuni.loc[i, 'review'] = 0

# %%
hotel_full_Martuni
# Out:
#            city  country                                             name  \
# 5   Gegharkunik  Armenia                                  Holiday cottage
# 9     Vaghashen  Armenia             2 story house with garden in Martuni
# 10      Martuni  Armenia  New and clean private bedroom. Security parking
# 11    Tsapatagh  Armenia               Cozy lodge overlooking Lake Sevan.
# 12      Noratus  Armenia       Oazis a place for a real holiday. Big room
# 13      Noratus  Armenia                        Room with Armenian spirit
# 16      Martuni  Armenia     New guest house 2 bedrooms. Security parking
# 17        Gavar  Armenia                Mountain dweller or Cattle farmer
# 29      Martuni  Armenia                     Fresh air and amazing nature
#
#     host_since                                 host_response_rate  \
# 5         2019  Response rate: 0%\nResponse time: a few days o...
# 9         2010                        Languages: English, Русский
# ...

# %%
for i in hotel_full_Martuni.index:
    if "Superhost" in  hotel_full_Martuni.superhost[i]:
        hotel_full_Martuni.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Martuni.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Martuni.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Private room in resort',
#  'Entire residential home',
#  'Private room in guesthouse',
#  'Private room in bed and breakfast',
#  'Room in hotel',
#  'Room in hotel',
#  'Entire guesthouse',
#  'Tent',
#  'Entire residential home']

# %%
hotel_full_Martuni.property_type =prop_list

# %%
hotel_full_Martuni
# Out:
#            city  country                                             name  \
# 5   Gegharkunik  Armenia                                  Holiday cottage
# 9     Vaghashen  Armenia             2 story house with garden in Martuni
# 10      Martuni  Armenia  New and clean private bedroom. Security parking
# 11    Tsapatagh  Armenia               Cozy lodge overlooking Lake Sevan.
# 12      Noratus  Armenia       Oazis a place for a real holiday. Big room
# 13      Noratus  Armenia                        Room with Armenian spirit
# 16      Martuni  Armenia     New guest house 2 bedrooms. Security parking
# 17        Gavar  Armenia                Mountain dweller or Cattle farmer
# 29      Martuni  Armenia                     Fresh air and amazing nature
#
#     host_since                                 host_response_rate  \
# 5         2019  Response rate: 0%\nResponse time: a few days o...
# 9         2010                        Languages: English, Русский
# ...

# %%
accomodates_list = []
for i in hotel_full_Martuni.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Martuni.accomodates = number

# %%
for i in hotel_full_Martuni.index:
    if "Shared half-bath" in  hotel_full_Martuni.number_bathroom[i]:
        hotel_full_Martuni.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Martuni.number_bathroom[i]:
        hotel_full_Martuni.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Martuni.number_bathroom[i]:
        hotel_full_Martuni.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Martuni.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Martuni.number_bedroom[i])
        hotel_full_Martuni.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Martuni.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Martuni.number_bedroom[i])
        hotel_full_Martuni.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Martuni.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Martuni.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Martuni.index:
    if "bed" in  hotel_full_Martuni.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Martuni.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Martuni.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['1', '10', '2', '5', '2', '1', '4', '1', '2']

# %%
len(hotel_full_Martuni.number_beds)
# Out:
# 9

# %%
len(number_beds_list)
# Out:
# 9

# %%
hotel_full_Martuni.number_beds = number_beds_list

# %%
hotel_full_Martuni.number_beds
# Out:
# 5      1
# 9     10
# 10     2
# 11     5
# 12     2
# 13     1
# 16     4
# 17     1
# 29     2
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Martuni.index:
    if "Studio" in  hotel_full_Martuni.number_bedroom[i]:
        hotel_full_Martuni.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Martuni.number_bedroom[i])
        hotel_full_Martuni.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Martuni.index:
    if "Cleanliness" in  hotel_full_Martuni.cleanliness[i]:
        hotel_full_Martuni.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Martuni.cleanliness[i])
    else:
        hotel_full_Martuni.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Martuni.index:
    if "Accuracy" in  hotel_full_Martuni.accuracy[i]:
        hotel_full_Martuni.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Martuni.accuracy[i])
    else:
        hotel_full_Martuni.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Martuni.index:
    if "Communication" in  hotel_full_Martuni.communication[i]:
        hotel_full_Martuni.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Martuni.communication[i])
    else:
        hotel_full_Martuni.loc[i, 'communication'] = None

# %%
for i in hotel_full_Martuni.index:
    if "Location" in  hotel_full_Martuni.location[i]:
        try:
            hotel_full_Martuni.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Martuni.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Martuni.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Martuni.location[i])
    
    else:
        hotel_full_Martuni.loc[i, 'location'] = None

# %%
for i in hotel_full_Martuni.index:
    if "Check-in" in  hotel_full_Martuni.check_in[i]:
        hotel_full_Martuni.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Martuni.check_in[i])
    else:
        hotel_full_Martuni.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Martuni.index:
    if "Value" in  hotel_full_Martuni.value[i]:
        hotel_full_Martuni.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Martuni.value[i])
    else:
        hotel_full_Martuni.loc[i, 'value'] = None

# %%
for i in hotel_full_Martuni.index:
    if "No reviews (yet)" in  hotel_full_Martuni.rating[i]:
        hotel_full_Martuni.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Martuni.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Martuni.price = price_list

# %%
for i in hotel_full_Martuni.index:
    if "Response rate" in  hotel_full_Martuni.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Martuni.host_response_rate[i])
        hotel_full_Martuni.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Martuni.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Martuni = hotel_full_Martuni.astype(convert_dict)

# %%
hotel_full_Martuni.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Martuni.to_csv("cleaned_hotel_full_Martuni.csv", index=False)
hotel_full_Martuni.to_excel("cleaned_hotel_full_Martuni2.xlsx", index=False)
