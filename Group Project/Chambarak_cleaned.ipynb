# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Chambarak = pd.read_csv('hotel_full_Chambarak.csv')
hotel_full_Chambarak
# Out:
#                                         city  \
# 0                                        NaN
# 1   Chambarak, Gegharkunik Province, Armenia
# 2      Aghavnavank, Tavush Province, Armenia
# 3                 Սևան, Գեղարքունիք, Armenia
# 4   Chambarak, Gegharkunik Province, Armenia
# ..                                       ...
# 76          Ijevan, Tavush Province, Armenia
# 77                          Yerevan, Armenia
# 78         Dilijan, Tavush Province, Armenia
# 79      Sevan, Gegharkunik Province, Armenia
# 80       Севан, Gegarkunik Province, Armenia
#
#                                      country  \
# 0                                        NaN
# 1   Chambarak, Gegharkunik Province, Armenia
# 2      Aghavnavank, Tavush Province, Armenia
# 3                 Սևան, Գեղարքունիք, Armenia
# 4   Chambarak, Gegharkunik Province, Armenia
# ..                                       ...
# 76          Ijevan, Tavush Province, Armenia
# 77                          Yerevan, Armenia
# ...

# %%
hotel_full_Chambarak = hotel_full_Chambarak.drop(labels = 0, axis = 0)
hotel_full_Chambarak
# Out:
#                                         city  \
# 1   Chambarak, Gegharkunik Province, Armenia
# 2      Aghavnavank, Tavush Province, Armenia
# 3                 Սևան, Գեղարքունիք, Armenia
# 4   Chambarak, Gegharkunik Province, Armenia
# 5     Kalavan, Gegharkunik Province, Armenia
# ..                                       ...
# 76          Ijevan, Tavush Province, Armenia
# 77                          Yerevan, Armenia
# 78         Dilijan, Tavush Province, Armenia
# 79      Sevan, Gegharkunik Province, Armenia
# 80       Севан, Gegarkunik Province, Armenia
#
#                                      country  \
# 1   Chambarak, Gegharkunik Province, Armenia
# 2      Aghavnavank, Tavush Province, Armenia
# 3                 Սևան, Գեղարքունիք, Armenia
# 4   Chambarak, Gegharkunik Province, Armenia
# 5     Kalavan, Gegharkunik Province, Armenia
# ..                                       ...
# 76          Ijevan, Tavush Province, Armenia
# 77                          Yerevan, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Chambarak.replace("", nan_value, inplace = True)
hotel_full_Chambarak.dropna(inplace= True)
hotel_full_Chambarak
# Out:
#                                        city  \
# 2     Aghavnavank, Tavush Province, Armenia
# 3                Սևան, Գեղարքունիք, Armenia
# 6      Севан, Gegharkunik Province, Armenia
# 10     Sevan, Gegharkunik Province, Armenia
# 12           Севан, Гегаркунткская, Armenia
# 13                         Kalavan, Armenia
# 14     Sevan, Gegharkunik Province, Armenia
# 19   Kalavan, Gegharkunik Province, Armenia
# 20                  Yerevan, Sevan, Armenia
# 22   Kalavan, Gegharkunik Province, Armenia
# 25           Gosh, Tavush Province, Armenia
# 30           Gosh, Tavush Province, Armenia
# 32                         Կալավան, Armenia
# 33         Ijevan, Tavush Province, Armenia
# 34  Norashen, Gegharkunik Province, Armenia
# 37      Getahovit, Tavush Province, Armenia
# 38   Noratus, Gegharkunik Province, Armenia
# 41      Getahovit, Tavush Province, Armenia
# 42   Noratus, Gegharkunik Province, Armenia
# 43   Noratus, Gegharkunik Province, Armenia
# ...

# %%
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Սևան, Գեղարքունիք, Armenia" : "Sevan, Gegharkunik Province, Armenia"})

hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Սևան, Գեղարքունիք, Armenia" : "Sevan, Gegharkunik Province, Armenia"})
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Gegharkunik Province, Armenia" : "Sevan, Gegharkunik Province, Armenia"})
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Севан, Гегаркунткская, Armenia" : "Sevan, Gegharkunik Province, Armenia"})
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Կալավան, Armenia" : "Kalavan, Gegharkunik Province, Armenia"})
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Սևան, Yerevan, Armenia" : "Sevan, Gegharkunik Province, Armenia"})
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Иджеван, Тавуш, Armenia" : "Ijevan, Tavush Province, Armenia"})
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Ծովազարդ, Armenia" : "Tsovazard, Gegharkunik Province, Armenia"})
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Yerevan, Armenia" : "Yerevan,Armavir, Armenia"})
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Севан, Gegarkunik Province, Armenia" : "Sevan, Gegharkunik Province, Armenia"})
hotel_full_Chambarak
# Out:
#                                        city  \
# 2     Aghavnavank, Tavush Province, Armenia
# 3      Sevan, Gegharkunik Province, Armenia
# 6      Севан, Gegharkunik Province, Armenia
# 10     Sevan, Gegharkunik Province, Armenia
# 12     Sevan, Gegharkunik Province, Armenia
# 13                         Kalavan, Armenia
# 14     Sevan, Gegharkunik Province, Armenia
# 19   Kalavan, Gegharkunik Province, Armenia
# 20                  Yerevan, Sevan, Armenia
# 22   Kalavan, Gegharkunik Province, Armenia
# 25           Gosh, Tavush Province, Armenia
# 30           Gosh, Tavush Province, Armenia
# 32   Kalavan, Gegharkunik Province, Armenia
# 33         Ijevan, Tavush Province, Armenia
# 34  Norashen, Gegharkunik Province, Armenia
# 37      Getahovit, Tavush Province, Armenia
# 38   Noratus, Gegharkunik Province, Armenia
# 41      Getahovit, Tavush Province, Armenia
# 42   Noratus, Gegharkunik Province, Armenia
# 43   Noratus, Gegharkunik Province, Armenia
# ...

# %%
city_list = []
for i in hotel_full_Chambarak.index:
    text = re.sub(",", "", hotel_full_Chambarak["city"][i][:hotel_full_Chambarak["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Chambarak["city"]= city_list
hotel_full_Chambarak
# Out:
#                               city                                  country  \
# 2     Aghavnavank Tavush Province     Aghavnavank, Tavush Province, Armenia
# 3      Sevan Gegharkunik Province                Սևան, Գեղարքունիք, Armenia
# 6      Севан Gegharkunik Province      Севан, Gegharkunik Province, Armenia
# 10     Sevan Gegharkunik Province      Sevan, Gegharkunik Province, Armenia
# 12     Sevan Gegharkunik Province            Севан, Гегаркунткская, Armenia
# 13                        Kalavan                          Kalavan, Armenia
# 14     Sevan Gegharkunik Province      Sevan, Gegharkunik Province, Armenia
# 19   Kalavan Gegharkunik Province    Kalavan, Gegharkunik Province, Armenia
# 20                  Yerevan Sevan                   Yerevan, Sevan, Armenia
# 22   Kalavan Gegharkunik Province    Kalavan, Gegharkunik Province, Armenia
# 25           Gosh Tavush Province            Gosh, Tavush Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Chambarak.replace("", nan_value, inplace = True)
hotel_full_Chambarak.dropna(inplace= True)
hotel_full_Chambarak
# Out:
#                               city                                  country  \
# 2     Aghavnavank Tavush Province     Aghavnavank, Tavush Province, Armenia
# 3      Sevan Gegharkunik Province                Սևան, Գեղարքունիք, Armenia
# 6      Севан Gegharkunik Province      Севан, Gegharkunik Province, Armenia
# 10     Sevan Gegharkunik Province      Sevan, Gegharkunik Province, Armenia
# 12     Sevan Gegharkunik Province            Севан, Гегаркунткская, Armenia
# 13                        Kalavan                          Kalavan, Armenia
# 14     Sevan Gegharkunik Province      Sevan, Gegharkunik Province, Armenia
# 19   Kalavan Gegharkunik Province    Kalavan, Gegharkunik Province, Armenia
# 20                  Yerevan Sevan                   Yerevan, Sevan, Armenia
# 22   Kalavan Gegharkunik Province    Kalavan, Gegharkunik Province, Armenia
# 25           Gosh Tavush Province            Gosh, Tavush Province, Armenia
# ...

# %%
c_l = []    
for k in hotel_full_Chambarak["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Chambarak["city"]= c_l
hotel_full_Chambarak
# Out:
#            city                                  country  \
# 2   Aghavnavank    Aghavnavank, Tavush Province, Armenia
# 3         Sevan               Սևան, Գեղարքունիք, Armenia
# 6         Севан     Севан, Gegharkunik Province, Armenia
# 10        Sevan     Sevan, Gegharkunik Province, Armenia
# 12        Sevan           Севан, Гегаркунткская, Armenia
# 13      Kalavan                         Kalavan, Armenia
# 14        Sevan     Sevan, Gegharkunik Province, Armenia
# 19      Kalavan   Kalavan, Gegharkunik Province, Armenia
# 20      Yerevan                  Yerevan, Sevan, Armenia
# 22      Kalavan   Kalavan, Gegharkunik Province, Armenia
# 25         Gosh           Gosh, Tavush Province, Armenia
# 30         Gosh           Gosh, Tavush Province, Armenia
# 32      Kalavan                         Կալավան, Armenia
# 33       Ijevan         Ijevan, Tavush Province, Armenia
# 34     Norashen  Norashen, Gegharkunik Province, Armenia
# ...

# %%
hotel_full_Chambarak["city"]= hotel_full_Chambarak["city"].replace({"Севан" : "Sevan"})

# %%
country_list = []
for i in hotel_full_Chambarak.index:
    text = re.search("Armenia", hotel_full_Chambarak["country"][i]).group()
    country_list.append(text)

hotel_full_Chambarak["country"] = country_list

# %%
hotel_full_Chambarak
# Out:
#            city  country                                               name  \
# 2   Aghavnavank  Armenia                                         Forest hut
# 3         Sevan  Armenia                      Rest in Sevan geghama ashxarh
# 6         Sevan  Armenia                              Sevan Shore Apartment
# 10        Sevan  Armenia           Aurum Trip Guest House with a great view
# 12        Sevan  Armenia            Writers' Holiday Home (Sevan Peninsula)
# 13      Kalavan  Armenia  Large Country House with lovely views for 6 pe...
# 14        Sevan  Armenia  Modern cottage in the national park and near Lake
# 19      Kalavan  Armenia          Private room for couple with magical view
# 20      Yerevan  Armenia             Charming cottage by the lake Sevan 6/6
# 22      Kalavan  Armenia          Private room for couple with magical view
# 25         Gosh  Armenia                               GoshDream Guesthouse
# ...

# %%
host_since_list = []
for i in hotel_full_Chambarak.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Chambarak.host_since = hs 
hotel_full_Chambarak.host_since
# Out:
# 2     2019
# 3     2020
# 6     2018
# 10    2020
# 12    2017
# 13    2016
# 14    2018
# 19    2019
# 20    2015
# 22    2019
# 25    2018
# 30    2019
# 32    2016
# 33    2018
# 34    2021
# 37    2018
# 38    2019
# 41    2018
# 42    2019
# 43    2019
# 44    2018
# 47    2018
# 48    2018
# 49    2014
# 50    2018
# 54    2016
# 57    2019
# 61    2019
# 65    2019
# 66    2017
# 69    2019
# 72    2014
# 75    2019
# 76    2016
# 79    2020
# Name: host_since, dtype: int64

# %%
hotel_full_Chambarak
# Out:
#            city  country                                               name  \
# 2   Aghavnavank  Armenia                                         Forest hut
# 3         Sevan  Armenia                      Rest in Sevan geghama ashxarh
# 6         Sevan  Armenia                              Sevan Shore Apartment
# 10        Sevan  Armenia           Aurum Trip Guest House with a great view
# 12        Sevan  Armenia            Writers' Holiday Home (Sevan Peninsula)
# 13      Kalavan  Armenia  Large Country House with lovely views for 6 pe...
# 14        Sevan  Armenia  Modern cottage in the national park and near Lake
# 19      Kalavan  Armenia          Private room for couple with magical view
# 20      Yerevan  Armenia             Charming cottage by the lake Sevan 6/6
# 22      Kalavan  Armenia          Private room for couple with magical view
# 25         Gosh  Armenia                               GoshDream Guesthouse
# ...

# %%
string = []
for i in hotel_full_Chambarak.index:
    st = hotel_full_Chambarak.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["12 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  '2 Reviews',
#  '7 Reviews',
#  'Identity verified',
#  "24 Reviews', 'Identity verified",
#  "9 Reviews', 'Identity verified",
#  "2 Reviews', 'Identity verified",
#  "3 Reviews', 'Identity verified",
#  '28 Reviews',
#  "3 Reviews', 'Identity verified",
#  '5 Reviews',
#  '3 Reviews',
#  "9 Reviews', 'Identity verified",
#  '9 Reviews',
#  'Identity verified',
#  '4 Reviews',
#  '1 Review',
#  '4 Reviews',
#  '1 Review',
#  '1 Review',
#  '9 Reviews',
#  'Identity verified',
#  '5 Reviews',
#  '12 Reviews',
#  '4 Reviews',
#  "19 Reviews', 'Identity verified",
#  "2 Reviews', 'Identity verified",
#  '3 Reviews',
#  '3 Reviews',
#  'Identity verified',
#  "12 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  '12 Reviews',
#  '3 Reviews',
#  'Identity verified',
#  'Identity verified']

# %%
hotel_full_Chambarak.host_identity_verified = string
hotel_full_Chambarak.host_identity_verified
# Out:
# 2     12 Reviews', 'Identity verified', '\U000f0003'...
# 3                                             2 Reviews
# 6                                             7 Reviews
# 10                                    Identity verified
# 12                      24 Reviews', 'Identity verified
# 13                       9 Reviews', 'Identity verified
# 14                       2 Reviews', 'Identity verified
# 19                       3 Reviews', 'Identity verified
# 20                                           28 Reviews
# 22                       3 Reviews', 'Identity verified
# 25                                            5 Reviews
# 30                                            3 Reviews
# 32                       9 Reviews', 'Identity verified
# 33                                            9 Reviews
# 34                                    Identity verified
# 37                                            4 Reviews
# 38                                             1 Review
# ...

# %%
for i in hotel_full_Chambarak.index:
    if "Identity verified" in  hotel_full_Chambarak.host_identity_verified[i]:
        hotel_full_Chambarak.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Chambarak.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Chambarak
# Out:
#            city  country                                               name  \
# 2   Aghavnavank  Armenia                                         Forest hut
# 3         Sevan  Armenia                      Rest in Sevan geghama ashxarh
# 6         Sevan  Armenia                              Sevan Shore Apartment
# 10        Sevan  Armenia           Aurum Trip Guest House with a great view
# 12        Sevan  Armenia            Writers' Holiday Home (Sevan Peninsula)
# 13      Kalavan  Armenia  Large Country House with lovely views for 6 pe...
# 14        Sevan  Armenia  Modern cottage in the national park and near Lake
# 19      Kalavan  Armenia          Private room for couple with magical view
# 20      Yerevan  Armenia             Charming cottage by the lake Sevan 6/6
# 22      Kalavan  Armenia          Private room for couple with magical view
# 25         Gosh  Armenia                               GoshDream Guesthouse
# ...

# %%
for i in hotel_full_Chambarak.index:
    if "Review" in  hotel_full_Chambarak.review[i]:
        hotel_full_Chambarak.loc[i, 'review'] = re.search("(\d+)", hotel_full_Chambarak.review[i]).group()
        
    else:
        hotel_full_Chambarak.loc[i, 'review'] = 0

# %%
hotel_full_Chambarak
# Out:
#            city  country                                               name  \
# 2   Aghavnavank  Armenia                                         Forest hut
# 3         Sevan  Armenia                      Rest in Sevan geghama ashxarh
# 6         Sevan  Armenia                              Sevan Shore Apartment
# 10        Sevan  Armenia           Aurum Trip Guest House with a great view
# 12        Sevan  Armenia            Writers' Holiday Home (Sevan Peninsula)
# 13      Kalavan  Armenia  Large Country House with lovely views for 6 pe...
# 14        Sevan  Armenia  Modern cottage in the national park and near Lake
# 19      Kalavan  Armenia          Private room for couple with magical view
# 20      Yerevan  Armenia             Charming cottage by the lake Sevan 6/6
# 22      Kalavan  Armenia          Private room for couple with magical view
# 25         Gosh  Armenia                               GoshDream Guesthouse
# ...

# %%
for i in hotel_full_Chambarak.index:
    if "Superhost" in  hotel_full_Chambarak.superhost[i]:
        hotel_full_Chambarak.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Chambarak.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Chambarak.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire cabin',
#  'Entire villa',
#  'Entire rental unit',
#  'Private room in residential home',
#  'Room in boutique hotel',
#  'Entire residential home',
#  'Entire residential home',
#  'Private room in residential home',
#  'Entire cottage',
#  'Private room in residential home',
#  'Private room in villa',
#  'Room in hotel',
#  'Private room in residential home',
#  'Entire residential home',
#  'Entire cottage',
#  'Treehouse',
#  'Room in hotel',
#  'Treehouse',
#  'Room in hotel',
#  'Room in hotel',
#  'Entire residential home',
#  'Tent',
#  'Private room in villa',
#  'Private room in residential home',
#  'Shared room in treehouse',
#  'Private room in residential home',
#  'Room in hotel',
#  'Room in hotel',
#  'Room in hotel',
#  'Private room in residential home',
#  'Campsite',
#  'Private room in guesthouse',
#  'Room in hotel',
#  'Room in hotel',
#  'Entire home/apt  Սիթի']

# %%
hotel_full_Chambarak.property_type =prop_list

# %%
hotel_full_Chambarak
# Out:
#            city  country                                               name  \
# 2   Aghavnavank  Armenia                                         Forest hut
# 3         Sevan  Armenia                      Rest in Sevan geghama ashxarh
# 6         Sevan  Armenia                              Sevan Shore Apartment
# 10        Sevan  Armenia           Aurum Trip Guest House with a great view
# 12        Sevan  Armenia            Writers' Holiday Home (Sevan Peninsula)
# 13      Kalavan  Armenia  Large Country House with lovely views for 6 pe...
# 14        Sevan  Armenia  Modern cottage in the national park and near Lake
# 19      Kalavan  Armenia          Private room for couple with magical view
# 20      Yerevan  Armenia             Charming cottage by the lake Sevan 6/6
# 22      Kalavan  Armenia          Private room for couple with magical view
# 25         Gosh  Armenia                               GoshDream Guesthouse
# ...

# %%
accomodates_list = []
for i in hotel_full_Chambarak.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Chambarak.accomodates = number

# %%
for i in hotel_full_Chambarak.index:
    if "Shared half-bath" in  hotel_full_Chambarak.number_bathroom[i]:
        hotel_full_Chambarak.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Chambarak.number_bathroom[i]:
        hotel_full_Chambarak.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Chambarak.number_bathroom[i]:
        hotel_full_Chambarak.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Chambarak.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Chambarak.number_bedroom[i])
        hotel_full_Chambarak.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Chambarak.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Chambarak.number_bedroom[i])
        hotel_full_Chambarak.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Chambarak.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Chambarak.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Chambarak.index:
    if "bed" not in hotel_full_Chambarak.number_beds[i]:
        k = None
        number_beds_list.append(k) 
        
    elif "bed" in  hotel_full_Chambarak.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Chambarak.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Chambarak.number_beds[i])
    
        number_beds_list.append(k)

# %%
len(hotel_full_Chambarak.number_beds)
# Out:
# 35

# %%
len(number_beds_list)
# Out:
# 35

# %%
hotel_full_Chambarak.number_beds = number_beds_list

# %%
for i in hotel_full_Chambarak.index:
    if "Studio" in  hotel_full_Chambarak.number_bedroom[i]:
        hotel_full_Chambarak.loc[i, 'number_bedroom'] = 0
    else:
        try:
            hotel_full_Chambarak.loc[i, 'number_bedroom']=re.search("(\d+)\sbedroom", hotel_full_Chambarak.number_bedroom[i]).group(1)
        
        except AttributeError:
            hotel_full_Chambarak.loc[i, 'number_bedroom'] = re.search("(\d+)\sbedroom", hotel_full_Chambarak.number_bedroom[i])

# %%
for i in hotel_full_Chambarak.index:
    if "Cleanliness" in  hotel_full_Chambarak.cleanliness[i]:
        hotel_full_Chambarak.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Chambarak.cleanliness[i])
    else:
        hotel_full_Chambarak.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Chambarak.index:
    if "Accuracy" in  hotel_full_Chambarak.accuracy[i]:
        hotel_full_Chambarak.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Chambarak.accuracy[i])
    else:
        hotel_full_Chambarak.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Chambarak.index:
    if "Communication" in  hotel_full_Chambarak.communication[i]:
        hotel_full_Chambarak.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Chambarak.communication[i])
    else:
        hotel_full_Chambarak.loc[i, 'communication'] = None

# %%
for i in hotel_full_Chambarak.index:
    if "Location" in  hotel_full_Chambarak.location[i]:
        try:
            hotel_full_Chambarak.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Chambarak.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Chambarak.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Chambarak.location[i])
    
    else:
        hotel_full_Chambarak.loc[i, 'location'] = None

# %%
for i in hotel_full_Chambarak.index:
    if "Check-in" in  hotel_full_Chambarak.check_in[i]:
        hotel_full_Chambarak.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Chambarak.check_in[i])
    else:
        hotel_full_Chambarak.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Chambarak.index:
    if "Value" in  hotel_full_Chambarak.value[i]:
        hotel_full_Chambarak.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Chambarak.value[i])
    else:
        hotel_full_Chambarak.loc[i, 'value'] = None

# %%
for i in hotel_full_Chambarak.index:
    if "No reviews (yet)" in  hotel_full_Chambarak.rating[i]:
        hotel_full_Chambarak.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Chambarak.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Chambarak.price = price_list

# %%
for i in hotel_full_Chambarak.index:
    if "Response rate" in  hotel_full_Chambarak.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Chambarak.host_response_rate[i])
        hotel_full_Chambarak.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Chambarak.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Chambarak = hotel_full_Chambarak.astype(convert_dict)

# %%
hotel_full_Chambarak.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Chambarak.to_csv("cleaned_hotel_full_Chambarak.csv", index=False)
hotel_full_Chambarak.to_excel("cleaned_hotel_full_Chambarak2.xlsx", index=False)
