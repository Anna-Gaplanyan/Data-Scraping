# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Sevan = pd.read_csv('hotel_full_Sevan.csv')
hotel_full_Sevan
# Out:
#                                     city  \
# 0                                    NaN
# 1   Sevan, Gegharkunik Province, Armenia
# 2   Sevan, Gegharkunik Province, Armenia
# 3   Севан, Gegharkunik Province, Armenia
# 4   Sevan, Gegharkunik Province, Armenia
# 5         Севан, Гегаркунткская, Armenia
# 6   Sevan, Gegharkunik Province, Armenia
# 7   Sevan, Gegharkunik Province, Armenia
# 8   Sevan, Gegharkunik Province, Armenia
# 9   Sevan, Gegharkunik Province, Armenia
# 10   Սևան, Gegharkunik Province, Armenia
# 11               Yerevan, Sevan, Armenia
# 12  Sevan, Gegharkunik Province, Armenia
# 13            Սևան, Գեղարքունիք, Armenia
# 14  Sevan, Gegharkunik Province, Armenia
# 15  Sevan, Gegharkunik Province, Armenia
# 16  Sevan, Gegharkunik Province, Armenia
# 17           Sevan, Gegharkunik, Armenia
# 18  Sevan, Gegharkunik Province, Armenia
# 19  Sevan, Gegharkunik Province, Armenia
# 20  Севан, Gegharkunik Province, Armenia
# 21  Sevan, Gegharkunik Province, Armenia
# ...

# %%
hotel_full_Sevan = hotel_full_Sevan.drop(labels = 0, axis = 0)
hotel_full_Sevan
# Out:
#                                     city  \
# 1   Sevan, Gegharkunik Province, Armenia
# 2   Sevan, Gegharkunik Province, Armenia
# 3   Севан, Gegharkunik Province, Armenia
# 4   Sevan, Gegharkunik Province, Armenia
# 5         Севан, Гегаркунткская, Armenia
# 6   Sevan, Gegharkunik Province, Armenia
# 7   Sevan, Gegharkunik Province, Armenia
# 8   Sevan, Gegharkunik Province, Armenia
# 9   Sevan, Gegharkunik Province, Armenia
# 10   Սևան, Gegharkunik Province, Armenia
# 11               Yerevan, Sevan, Armenia
# 12  Sevan, Gegharkunik Province, Armenia
# 13            Սևան, Գեղարքունիք, Armenia
# 14  Sevan, Gegharkunik Province, Armenia
# 15  Sevan, Gegharkunik Province, Armenia
# 16  Sevan, Gegharkunik Province, Armenia
# 17           Sevan, Gegharkunik, Armenia
# 18  Sevan, Gegharkunik Province, Armenia
# 19  Sevan, Gegharkunik Province, Armenia
# 20  Севан, Gegharkunik Province, Armenia
# 21  Sevan, Gegharkunik Province, Armenia
# 22  Sevan, Gegharkunik Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Sevan.replace("", nan_value, inplace = True)
hotel_full_Sevan.dropna(inplace= True)
hotel_full_Sevan
# Out:
#                                     city  \
# 2   Sevan, Gegharkunik Province, Armenia
# 3   Севан, Gegharkunik Province, Armenia
# 4   Sevan, Gegharkunik Province, Armenia
# 5         Севан, Гегаркунткская, Armenia
# 6   Sevan, Gegharkunik Province, Armenia
# 7   Sevan, Gegharkunik Province, Armenia
# 8   Sevan, Gegharkunik Province, Armenia
# 9   Sevan, Gegharkunik Province, Armenia
# 11               Yerevan, Sevan, Armenia
# 12  Sevan, Gegharkunik Province, Armenia
# 14  Sevan, Gegharkunik Province, Armenia
# 15  Sevan, Gegharkunik Province, Armenia
# 19  Sevan, Gegharkunik Province, Armenia
# 21  Sevan, Gegharkunik Province, Armenia
# 23  Sevan, Gegharkunik Province, Armenia
# 24  Sevan, Gegharkunik Province, Armenia
# 25  Sevan, Gegharkunik Province, Armenia
# 26  Sevan, Gegharkunik Province, Armenia
# 28  Sevan, Gegharkunik Province, Armenia
# 30  Sevan, Gegharkunik Province, Armenia
#
#                                  country  \
# 2   Sevan, Gegharkunik Province, Armenia
# ...

# %%
hotel_full_Sevan["city"]= hotel_full_Sevan["city"].replace({"Սևան, Գեղարքունիք, Armenia" : "Sevan, Armenia"})

# %%
hotel_full_Sevan["city"]= hotel_full_Sevan["city"].replace({"Севан, Gegharkunik Province, Armenia" : "Sevan, Armenia"})

# %%
hotel_full_Sevan["city"]= hotel_full_Sevan["city"].replace({"Севан, Гегаркунткская, Armenia" : "Sevan, Armenia"})

# %%
hotel_full_Sevan["city"]= hotel_full_Sevan["city"].replace({"Սևան, Gegharkunik Province, Armenia" : "Sevan, Armenia"})

# %%
hotel_full_Sevan["city"]= hotel_full_Sevan["city"].replace({"Yerevan, Sevan, Armenia" : "Sevan, Armenia"})

# %%
hotel_full_Sevan["city"]= hotel_full_Sevan["city"].replace({"Yerevan, Sevan, Armenia" : "Sevan, Armenia"})

# %%
city_list = []
for i in hotel_full_Sevan.index:
    text = re.sub(",", "", hotel_full_Sevan["city"][i][:hotel_full_Sevan["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Sevan["city"]= city_list
hotel_full_Sevan
# Out:
#                            city                               country  \
# 2   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 3                        Sevan   Севан, Gegharkunik Province, Armenia
# 4   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 5                        Sevan         Севан, Гегаркунткская, Armenia
# 6   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 7   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 8   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 9   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 11                       Sevan                Yerevan, Sevan, Armenia
# 12  Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 14  Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 15  Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Sevan.replace("", nan_value, inplace = True)
hotel_full_Sevan.dropna(inplace= True)
hotel_full_Sevan
# Out:
#                            city                               country  \
# 2   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 3                        Sevan   Севан, Gegharkunik Province, Armenia
# 4   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 5                        Sevan         Севан, Гегаркунткская, Armenia
# 6   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 7   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 8   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 9   Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 11                       Sevan                Yerevan, Sevan, Armenia
# 12  Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 14  Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# 15  Sevan Gegharkunik Province   Sevan, Gegharkunik Province, Armenia
# ...

# %%
c_l = []    
for k in hotel_full_Sevan["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Sevan["city"]= c_l
hotel_full_Sevan
# Out:
#      city                               country  \
# 2   Sevan  Sevan, Gegharkunik Province, Armenia
# 3   Sevan  Севан, Gegharkunik Province, Armenia
# 4   Sevan  Sevan, Gegharkunik Province, Armenia
# 5   Sevan        Севан, Гегаркунткская, Armenia
# 6   Sevan  Sevan, Gegharkunik Province, Armenia
# 7   Sevan  Sevan, Gegharkunik Province, Armenia
# 8   Sevan  Sevan, Gegharkunik Province, Armenia
# 9   Sevan  Sevan, Gegharkunik Province, Armenia
# 11  Sevan               Yerevan, Sevan, Armenia
# 12  Sevan  Sevan, Gegharkunik Province, Armenia
# 14  Sevan  Sevan, Gegharkunik Province, Armenia
# 15  Sevan  Sevan, Gegharkunik Province, Armenia
# 19  Sevan  Sevan, Gegharkunik Province, Armenia
# 21  Sevan  Sevan, Gegharkunik Province, Armenia
# 23  Sevan  Sevan, Gegharkunik Province, Armenia
# 24  Sevan  Sevan, Gegharkunik Province, Armenia
# 25  Sevan  Sevan, Gegharkunik Province, Armenia
# 26  Sevan  Sevan, Gegharkunik Province, Armenia
# ...

# %%
country_list = []
for i in hotel_full_Sevan.index:
    text = re.search("Armenia", hotel_full_Sevan["country"][i]).group()
    country_list.append(text)

hotel_full_Sevan["country"] = country_list

# %%
hotel_full_Sevan
# Out:
#      city  country                                               name  \
# 2   Sevan  Armenia                           Sevan Home on the center
# 3   Sevan  Armenia                           Central Studio Apartment
# 4   Sevan  Armenia           Aurum Trip Guest House with a great view
# 5   Sevan  Armenia            Дом отдыха писателей (Севан полуостров)
# 6   Sevan  Armenia             Guest House + Transfer to Sevan lake 2
# 7   Sevan  Armenia                  Mountain Lake Villa, Premium room
# 8   Sevan  Armenia  Modern cottage in the national park and near Lake
# 9   Sevan  Armenia       House for rent in <Home Inn> near Lake Sevan
# 11  Sevan  Armenia             Charming cottage by the lake Sevan 6/6
# 12  Sevan  Armenia                                   Mama Mia - Sevan
# 14  Sevan  Armenia               Guest House + Transfer to Sevan lake
# 15  Sevan  Armenia     USSR guest house-discover the life of ancients
# ...

# %%
host_since_list = []
for i in hotel_full_Sevan.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Sevan.host_since = hs 
hotel_full_Sevan.host_since
# Out:
# 2     2020
# 3     2016
# 4     2020
# 5     2017
# 6     2017
# 7     2018
# 8     2018
# 9     2019
# 11    2015
# 12    2017
# 14    2017
# 15    2019
# 19    2019
# 21    2019
# 23    2020
# 24    2017
# 25    2018
# 26    2017
# 28    2018
# 30    2019
# Name: host_since, dtype: int64

# %%
hotel_full_Sevan
# Out:
#      city  country                                               name  \
# 2   Sevan  Armenia                           Sevan Home on the center
# 3   Sevan  Armenia                           Central Studio Apartment
# 4   Sevan  Armenia           Aurum Trip Guest House with a great view
# 5   Sevan  Armenia            Дом отдыха писателей (Севан полуостров)
# 6   Sevan  Armenia             Guest House + Transfer to Sevan lake 2
# 7   Sevan  Armenia                  Mountain Lake Villa, Premium room
# 8   Sevan  Armenia  Modern cottage in the national park and near Lake
# 9   Sevan  Armenia       House for rent in <Home Inn> near Lake Sevan
# 11  Sevan  Armenia             Charming cottage by the lake Sevan 6/6
# 12  Sevan  Armenia                                   Mama Mia - Sevan
# 14  Sevan  Armenia               Guest House + Transfer to Sevan lake
# 15  Sevan  Armenia     USSR guest house-discover the life of ancients
# ...

# %%
string = []
for i in hotel_full_Sevan.index:
    st = hotel_full_Sevan.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["5 Reviews', 'Identity verified",
#  "7 Reviews', 'Identity verified",
#  'Identity verified',
#  "24 Reviews', 'Identity verified",
#  "15 Reviews', 'Identity verified",
#  "18 Reviews', 'Identity verified",
#  "2 Reviews', 'Identity verified",
#  'Identity verified',
#  '28 Reviews',
#  "38 Reviews', 'Identity verified",
#  "15 Reviews', 'Identity verified",
#  "5 Reviews', 'Identity verified",
#  'Identity verified',
#  'Identity verified',
#  'Identity verified',
#  "38 Reviews', 'Identity verified",
#  "18 Reviews', 'Identity verified",
#  "38 Reviews', 'Identity verified",
#  "18 Reviews', 'Identity verified",
#  "1 Review', 'Identity verified"]

# %%
hotel_full_Sevan.host_identity_verified = string
hotel_full_Sevan.host_identity_verified
# Out:
# 2      5 Reviews', 'Identity verified
# 3      7 Reviews', 'Identity verified
# 4                   Identity verified
# 5     24 Reviews', 'Identity verified
# 6     15 Reviews', 'Identity verified
# 7     18 Reviews', 'Identity verified
# 8      2 Reviews', 'Identity verified
# 9                   Identity verified
# 11                         28 Reviews
# 12    38 Reviews', 'Identity verified
# 14    15 Reviews', 'Identity verified
# 15     5 Reviews', 'Identity verified
# 19                  Identity verified
# 21                  Identity verified
# 23                  Identity verified
# 24    38 Reviews', 'Identity verified
# 25    18 Reviews', 'Identity verified
# 26    38 Reviews', 'Identity verified
# 28    18 Reviews', 'Identity verified
# 30      1 Review', 'Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Sevan.index:
    if "Identity verified" in  hotel_full_Sevan.host_identity_verified[i]:
        hotel_full_Sevan.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Sevan.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Sevan
# Out:
#      city  country                                               name  \
# 2   Sevan  Armenia                           Sevan Home on the center
# 3   Sevan  Armenia                           Central Studio Apartment
# 4   Sevan  Armenia           Aurum Trip Guest House with a great view
# 5   Sevan  Armenia            Дом отдыха писателей (Севан полуостров)
# 6   Sevan  Armenia             Guest House + Transfer to Sevan lake 2
# 7   Sevan  Armenia                  Mountain Lake Villa, Premium room
# 8   Sevan  Armenia  Modern cottage in the national park and near Lake
# 9   Sevan  Armenia       House for rent in <Home Inn> near Lake Sevan
# 11  Sevan  Armenia             Charming cottage by the lake Sevan 6/6
# 12  Sevan  Armenia                                   Mama Mia - Sevan
# 14  Sevan  Armenia               Guest House + Transfer to Sevan lake
# 15  Sevan  Armenia     USSR guest house-discover the life of ancients
# ...

# %%
for i in hotel_full_Sevan.index:
    if "Review" in  hotel_full_Sevan.review[i]:
        hotel_full_Sevan.loc[i, 'review'] = re.search("(\d+)", hotel_full_Sevan.review[i]).group()
        
    else:
        hotel_full_Sevan.loc[i, 'review'] = 0

# %%
hotel_full_Sevan
# Out:
#      city  country                                               name  \
# 2   Sevan  Armenia                           Sevan Home on the center
# 3   Sevan  Armenia                           Central Studio Apartment
# 4   Sevan  Armenia           Aurum Trip Guest House with a great view
# 5   Sevan  Armenia            Дом отдыха писателей (Севан полуостров)
# 6   Sevan  Armenia             Guest House + Transfer to Sevan lake 2
# 7   Sevan  Armenia                  Mountain Lake Villa, Premium room
# 8   Sevan  Armenia  Modern cottage in the national park and near Lake
# 9   Sevan  Armenia       House for rent in <Home Inn> near Lake Sevan
# 11  Sevan  Armenia             Charming cottage by the lake Sevan 6/6
# 12  Sevan  Armenia                                   Mama Mia - Sevan
# 14  Sevan  Armenia               Guest House + Transfer to Sevan lake
# 15  Sevan  Armenia     USSR guest house-discover the life of ancients
# ...

# %%
for i in hotel_full_Sevan.index:
    if "Superhost" in  hotel_full_Sevan.superhost[i]:
        hotel_full_Sevan.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Sevan.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Sevan.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire rental unit',
#  'Entire rental unit',
#  'Private room in residential home',
#  'Room in boutique hotel',
#  'Private room in bed and breakfast',
#  'Private room in villa',
#  'Entire residential home',
#  'Entire residential home',
#  'Entire cottage',
#  'Entire serviced apartment',
#  'Private room in bed and breakfast',
#  'Private room in townhouse',
#  'Private room in bed and breakfast',
#  'Private room in bed and breakfast',
#  'Entire rental unit',
#  'Private room in residential home',
#  'Private room in villa',
#  'Room in aparthotel',
#  'Private room in villa',
#  'Shared room in bed and breakfast']

# %%
hotel_full_Sevan.property_type =prop_list

# %%
hotel_full_Sevan
# Out:
#      city  country                                               name  \
# 2   Sevan  Armenia                           Sevan Home on the center
# 3   Sevan  Armenia                           Central Studio Apartment
# 4   Sevan  Armenia           Aurum Trip Guest House with a great view
# 5   Sevan  Armenia            Дом отдыха писателей (Севан полуостров)
# 6   Sevan  Armenia             Guest House + Transfer to Sevan lake 2
# 7   Sevan  Armenia                  Mountain Lake Villa, Premium room
# 8   Sevan  Armenia  Modern cottage in the national park and near Lake
# 9   Sevan  Armenia       House for rent in <Home Inn> near Lake Sevan
# 11  Sevan  Armenia             Charming cottage by the lake Sevan 6/6
# 12  Sevan  Armenia                                   Mama Mia - Sevan
# 14  Sevan  Armenia               Guest House + Transfer to Sevan lake
# 15  Sevan  Armenia     USSR guest house-discover the life of ancients
# ...

# %%
accomodates_list = []
for i in hotel_full_Sevan.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Sevan.accomodates = number

# %%
for i in hotel_full_Sevan.index:
    if "Shared half-bath" in  hotel_full_Sevan.number_bathroom[i]:
        hotel_full_Sevan.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Sevan.number_bathroom[i]:
        hotel_full_Sevan.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Sevan.number_bathroom[i]:
        hotel_full_Sevan.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Sevan.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Sevan.number_bedroom[i])
        hotel_full_Sevan.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Sevan.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Sevan.number_bedroom[i])
        hotel_full_Sevan.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Sevan.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Sevan.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Sevan.index:
    if "bed" in  hotel_full_Sevan.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Sevan.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Sevan.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['3',
#  '2',
#  '2',
#  '4',
#  '2',
#  '1',
#  '4',
#  '0',
#  '3',
#  '1',
#  '7',
#  '7',
#  '7',
#  '7',
#  '4',
#  '1',
#  '2',
#  '2',
#  '2',
#  '5']

# %%
len(hotel_full_Sevan.number_beds)
# Out:
# 20

# %%
len(number_beds_list)
# Out:
# 20

# %%
hotel_full_Sevan.number_beds = number_beds_list

# %%
hotel_full_Sevan.number_beds
# Out:
# 2     3
# 3     2
# 4     2
# 5     4
# 6     2
# 7     1
# 8     4
# 9     0
# 11    3
# 12    1
# 14    7
# 15    7
# 19    7
# 21    7
# 23    4
# 24    1
# 25    2
# 26    2
# 28    2
# 30    5
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Sevan.index:
    if "Studio" in  hotel_full_Sevan.number_bedroom[i]:
        hotel_full_Sevan.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Sevan.number_bedroom[i])
        hotel_full_Sevan.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Sevan.index:
    if "Cleanliness" in  hotel_full_Sevan.cleanliness[i]:
        hotel_full_Sevan.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Sevan.cleanliness[i])
    else:
        hotel_full_Sevan.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Sevan.index:
    if "Accuracy" in  hotel_full_Sevan.accuracy[i]:
        hotel_full_Sevan.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Sevan.accuracy[i])
    else:
        hotel_full_Sevan.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Sevan.index:
    if "Communication" in  hotel_full_Sevan.communication[i]:
        hotel_full_Sevan.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Sevan.communication[i])
    else:
        hotel_full_Sevan.loc[i, 'communication'] = None

# %%
for i in hotel_full_Sevan.index:
    if "Location" in  hotel_full_Sevan.location[i]:
        try:
            hotel_full_Sevan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Sevan.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Sevan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Sevan.location[i])
    
    else:
        hotel_full_Sevan.loc[i, 'location'] = None

# %%
for i in hotel_full_Sevan.index:
    if "Check-in" in  hotel_full_Sevan.check_in[i]:
        hotel_full_Sevan.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Sevan.check_in[i])
    else:
        hotel_full_Sevan.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Sevan.index:
    if "Value" in  hotel_full_Sevan.value[i]:
        hotel_full_Sevan.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Sevan.value[i])
    else:
        hotel_full_Sevan.loc[i, 'value'] = None

# %%
for i in hotel_full_Sevan.index:
    if "No reviews (yet)" in  hotel_full_Sevan.rating[i]:
        hotel_full_Sevan.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Sevan.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Sevan.price = price_list

# %%
for i in hotel_full_Sevan.index:
    if "Response rate" in  hotel_full_Sevan.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Sevan.host_response_rate[i])
        hotel_full_Sevan.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Sevan.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Sevan = hotel_full_Sevan.astype(convert_dict)

# %%
hotel_full_Sevan.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Sevan.to_csv("cleaned_hotel_full_Sevan.csv", index=False)
hotel_full_Sevan.to_excel("cleaned_hotel_full_Sevan2.xlsx", index=False)
