# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Tashir = pd.read_csv('hotel_full_Tashir.csv')
hotel_full_Tashir
# Out:
#                                         city  \
# 0                                        NaN
# 1         Stepanavan, Lori Province, Armenia
# 2                        Stepanavan, Armenia
# 3         Stepanavan, Lori Province, Armenia
# 4         Stepanavan, Lori Province, Armenia
# 5           Pushkino, Lori Province, Armenia
# 6         Stepanavan, Lori Province, Armenia
# 7         Stepanavan, Lori Province, Armenia
# 8         Stepanavan, Lori Province, Armenia
# 9   Село Медовка, Лорийская область, Armenia
# 10        Stepanavan, Lori Province, Armenia
# 11         Lori Berd, Lori Province, Armenia
# 12        Stepanavan, Lori Province, Armenia
# 13        Stepanavan, Lori Province, Armenia
# 14        Stepanavan, Lori Province, Armenia
# 15          Գյուլագարակ, Լոռու մարզ, Armenia
# 16        Stepanavan, Lori Province, Armenia
# 17                     Gargar, Lori, Armenia
# 18          Գյուլագարակ, Լոռու մարզ, Armenia
# 19            Gargar, Lori Province, Armenia
# ...

# %%
hotel_full_Tashir = hotel_full_Tashir.drop(labels = 0, axis = 0)
hotel_full_Tashir
# Out:
#                                         city  \
# 1         Stepanavan, Lori Province, Armenia
# 2                        Stepanavan, Armenia
# 3         Stepanavan, Lori Province, Armenia
# 4         Stepanavan, Lori Province, Armenia
# 5           Pushkino, Lori Province, Armenia
# 6         Stepanavan, Lori Province, Armenia
# 7         Stepanavan, Lori Province, Armenia
# 8         Stepanavan, Lori Province, Armenia
# 9   Село Медовка, Лорийская область, Armenia
# 10        Stepanavan, Lori Province, Armenia
# 11         Lori Berd, Lori Province, Armenia
# 12        Stepanavan, Lori Province, Armenia
# 13        Stepanavan, Lori Province, Armenia
# 14        Stepanavan, Lori Province, Armenia
# 15          Գյուլագարակ, Լոռու մարզ, Armenia
# 16        Stepanavan, Lori Province, Armenia
# 17                     Gargar, Lori, Armenia
# 18          Գյուլագարակ, Լոռու մարզ, Armenia
# 19            Gargar, Lori Province, Armenia
# 20        Stepanavan, Lori Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Tashir.replace("", nan_value, inplace = True)
hotel_full_Tashir.dropna(inplace= True)
hotel_full_Tashir
# Out:
#                                   city                             country  \
# 1   Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 2                  Stepanavan, Armenia                 Stepanavan, Armenia
# 4   Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 8   Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 13  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 17               Gargar, Lori, Armenia               Gargar, Lori, Armenia
# 18    Գյուլագարակ, Լոռու մարզ, Armenia    Գյուլագարակ, Լոռու մարզ, Armenia
# 20  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 21  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 23  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 24  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# ...

# %%
hotel_full_Tashir["city"]= hotel_full_Tashir["city"].replace({"Село Медовка, Лорийская область, Armenia" : "Medovka, Lori Province, Armenia"})

hotel_full_Tashir["city"]= hotel_full_Tashir["city"].replace({"Գյուլագարակ, Լոռու մարզ, Armenia" : "Gyulagarak, Lori Province, Armenia"})

hotel_full_Tashir
# Out:
#                                   city                             country  \
# 1   Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 2                  Stepanavan, Armenia                 Stepanavan, Armenia
# 4   Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 8   Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 13  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 17               Gargar, Lori, Armenia               Gargar, Lori, Armenia
# 18  Gyulagarak, Lori Province, Armenia    Գյուլագարակ, Լոռու մարզ, Armenia
# 20  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 21  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 23  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# 24  Stepanavan, Lori Province, Armenia  Stepanavan, Lori Province, Armenia
# ...

# %%
city_list = []
for i in hotel_full_Tashir.index:
    text = re.sub(",", "", hotel_full_Tashir["city"][i][:hotel_full_Tashir["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Tashir["city"]= city_list
hotel_full_Tashir
# Out:
#                          city                             country  \
# 1   Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 2                 Stepanavan                  Stepanavan, Armenia
# 4   Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 8   Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 13  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 17               Gargar Lori                Gargar, Lori, Armenia
# 18  Gyulagarak Lori Province     Գյուլագարակ, Լոռու մարզ, Armenia
# 20  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 21  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 23  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 24  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 25  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 27  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Tashir.replace("", nan_value, inplace = True)
hotel_full_Tashir.dropna(inplace= True)
hotel_full_Tashir
# Out:
#                          city                             country  \
# 1   Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 2                 Stepanavan                  Stepanavan, Armenia
# 4   Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 8   Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 13  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 17               Gargar Lori                Gargar, Lori, Armenia
# 18  Gyulagarak Lori Province     Գյուլագարակ, Լոռու մարզ, Armenia
# 20  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 21  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 23  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 24  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 25  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
# 27  Stepanavan Lori Province   Stepanavan, Lori Province, Armenia
#
# ...

# %%
c_l = []    
for k in hotel_full_Tashir["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Tashir["city"]= c_l
hotel_full_Tashir
# Out:
#           city                             country  \
# 1   Stepanavan  Stepanavan, Lori Province, Armenia
# 2   Stepanavan                 Stepanavan, Armenia
# 4   Stepanavan  Stepanavan, Lori Province, Armenia
# 8   Stepanavan  Stepanavan, Lori Province, Armenia
# 13  Stepanavan  Stepanavan, Lori Province, Armenia
# 17      Gargar               Gargar, Lori, Armenia
# 18  Gyulagarak    Գյուլագարակ, Լոռու մարզ, Armenia
# 20  Stepanavan  Stepanavan, Lori Province, Armenia
# 21  Stepanavan  Stepanavan, Lori Province, Armenia
# 23  Stepanavan  Stepanavan, Lori Province, Armenia
# 24  Stepanavan  Stepanavan, Lori Province, Armenia
# 25  Stepanavan  Stepanavan, Lori Province, Armenia
# 27  Stepanavan  Stepanavan, Lori Province, Armenia
#
#                                                  name  \
# 1          Major's House Boutique Hotel in Stepanavan
# 2   Hametsek - comfortable stay and cultural immer...
# 4                           Private house with garden
# ...

# %%
country_list = []
for i in hotel_full_Tashir.index:
    text = re.search("Armenia", hotel_full_Tashir["country"][i]).group()
    country_list.append(text)

hotel_full_Tashir["country"] = country_list

# %%
hotel_full_Tashir
# Out:
#           city  country                                               name  \
# 1   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 2   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 4   Stepanavan  Armenia                          Private house with garden
# 8   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 13  Stepanavan  Armenia                                Barseghyan's resort
# 17      Gargar  Armenia                                Healthy and healthy
# 18  Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 20  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 21  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 23  Stepanavan  Armenia           Hametsek - Private Room with Garden View
# 24  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# ...

# %%
host_since_list = []
for i in hotel_full_Tashir.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Tashir.host_since = hs 
hotel_full_Tashir.host_since
# Out:
# 1     2021
# 2     2018
# 4     2017
# 8     2021
# 13    2021
# 17    2015
# 18    2020
# 20    2021
# 21    2021
# 23    2018
# 24    2021
# 25    2018
# 27    2017
# Name: host_since, dtype: int64

# %%
hotel_full_Tashir
# Out:
#           city  country                                               name  \
# 1   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 2   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 4   Stepanavan  Armenia                          Private house with garden
# 8   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 13  Stepanavan  Armenia                                Barseghyan's resort
# 17      Gargar  Armenia                                Healthy and healthy
# 18  Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 20  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 21  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 23  Stepanavan  Armenia           Hametsek - Private Room with Garden View
# 24  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# ...

# %%
string = []
for i in hotel_full_Tashir.index:
    st = hotel_full_Tashir.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ['Identity verified',
#  "3 Reviews', 'Identity verified",
#  "3 Reviews', 'Identity verified",
#  'Identity verified',
#  'Identity verified',
#  '3 Reviews',
#  "1 Review', 'Identity verified",
#  'Identity verified',
#  'Identity verified',
#  "3 Reviews', 'Identity verified",
#  'Identity verified',
#  "3 Reviews', 'Identity verified",
#  "3 Reviews', 'Identity verified"]

# %%
hotel_full_Tashir.host_identity_verified = string
hotel_full_Tashir.host_identity_verified
# Out:
# 1                  Identity verified
# 2     3 Reviews', 'Identity verified
# 4     3 Reviews', 'Identity verified
# 8                  Identity verified
# 13                 Identity verified
# 17                         3 Reviews
# 18     1 Review', 'Identity verified
# 20                 Identity verified
# 21                 Identity verified
# 23    3 Reviews', 'Identity verified
# 24                 Identity verified
# 25    3 Reviews', 'Identity verified
# 27    3 Reviews', 'Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Tashir.index:
    if "Identity verified" in  hotel_full_Tashir.host_identity_verified[i]:
        hotel_full_Tashir.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Tashir.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Tashir
# Out:
#           city  country                                               name  \
# 1   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 2   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 4   Stepanavan  Armenia                          Private house with garden
# 8   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 13  Stepanavan  Armenia                                Barseghyan's resort
# 17      Gargar  Armenia                                Healthy and healthy
# 18  Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 20  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 21  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 23  Stepanavan  Armenia           Hametsek - Private Room with Garden View
# 24  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# ...

# %%
for i in hotel_full_Tashir.index:
    if "Review" in  hotel_full_Tashir.review[i]:
        hotel_full_Tashir.loc[i, 'review'] = re.search("(\d+)", hotel_full_Tashir.review[i]).group()
        
    else:
        hotel_full_Tashir.loc[i, 'review'] = 0

# %%
hotel_full_Tashir
# Out:
#           city  country                                               name  \
# 1   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 2   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 4   Stepanavan  Armenia                          Private house with garden
# 8   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 13  Stepanavan  Armenia                                Barseghyan's resort
# 17      Gargar  Armenia                                Healthy and healthy
# 18  Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 20  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 21  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 23  Stepanavan  Armenia           Hametsek - Private Room with Garden View
# 24  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# ...

# %%
for i in hotel_full_Tashir.index:
    if "Superhost" in  hotel_full_Tashir.superhost[i]:
        hotel_full_Tashir.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Tashir.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Tashir.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Room in boutique hotel',
#  'Entire residential home',
#  'Entire residential home',
#  'Room in boutique hotel',
#  'Entire residential home',
#  'Private room in residential home',
#  'Entire villa',
#  'Room in boutique hotel',
#  'Room in boutique hotel',
#  'Private room in residential home',
#  'Entire residential home',
#  'Private room in residential home',
#  'Private room in guest suite']

# %%
hotel_full_Tashir.property_type =prop_list

# %%
hotel_full_Tashir
# Out:
#           city  country                                               name  \
# 1   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 2   Stepanavan  Armenia  Hametsek - comfortable stay and cultural immer...
# 4   Stepanavan  Armenia                          Private house with garden
# 8   Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 13  Stepanavan  Armenia                                Barseghyan's resort
# 17      Gargar  Armenia                                Healthy and healthy
# 18  Gyulagarak  Armenia                               V&V HOTEL, COTTAGE 2
# 20  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 21  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# 23  Stepanavan  Armenia           Hametsek - Private Room with Garden View
# 24  Stepanavan  Armenia         Major's House Boutique Hotel in Stepanavan
# ...

# %%
accomodates_list = []
for i in hotel_full_Tashir.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Tashir.accomodates = number

# %%
for i in hotel_full_Tashir.index:
    if "Shared half-bath" in  hotel_full_Tashir.number_bathroom[i]:
        hotel_full_Tashir.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Tashir.number_bathroom[i]:
        hotel_full_Tashir.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Tashir.number_bathroom[i]:
        hotel_full_Tashir.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Tashir.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Tashir.number_bedroom[i])
        hotel_full_Tashir.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Tashir.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Tashir.number_bedroom[i])
        hotel_full_Tashir.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Tashir.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Tashir.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Tashir.index:
    if "bed" in  hotel_full_Tashir.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Tashir.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Tashir.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['1', '4', '5', '1', '6', '4', '4', '2', '2', '0', '11', '0', '2']

# %%
len(hotel_full_Tashir.number_beds)
# Out:
# 13

# %%
len(number_beds_list)
# Out:
# 13

# %%
hotel_full_Tashir.number_beds = number_beds_list

# %%
hotel_full_Tashir.number_beds
# Out:
# 1      1
# 2      4
# 4      5
# 8      1
# 13     6
# 17     4
# 18     4
# 20     2
# 21     2
# 23     0
# 24    11
# 25     0
# 27     2
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Tashir.index:
    if "Studio" in  hotel_full_Tashir.number_bedroom[i]:
        hotel_full_Tashir.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Tashir.number_bedroom[i])
        hotel_full_Tashir.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Tashir.index:
    if "Cleanliness" in  hotel_full_Tashir.cleanliness[i]:
        hotel_full_Tashir.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Tashir.cleanliness[i])
    else:
        hotel_full_Tashir.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Tashir.index:
    if "Accuracy" in  hotel_full_Tashir.accuracy[i]:
        hotel_full_Tashir.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Tashir.accuracy[i])
    else:
        hotel_full_Tashir.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Tashir.index:
    if "Communication" in  hotel_full_Tashir.communication[i]:
        hotel_full_Tashir.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Tashir.communication[i])
    else:
        hotel_full_Tashir.loc[i, 'communication'] = None

# %%
for i in hotel_full_Tashir.index:
    if "Location" in  hotel_full_Tashir.location[i]:
        try:
            hotel_full_Tashir.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Tashir.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Tashir.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Tashir.location[i])
    
    else:
        hotel_full_Tashir.loc[i, 'location'] = None

# %%
for i in hotel_full_Tashir.index:
    if "Check-in" in  hotel_full_Tashir.check_in[i]:
        hotel_full_Tashir.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Tashir.check_in[i])
    else:
        hotel_full_Tashir.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Tashir.index:
    if "Value" in  hotel_full_Tashir.value[i]:
        hotel_full_Tashir.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Tashir.value[i])
    else:
        hotel_full_Tashir.loc[i, 'value'] = None

# %%
for i in hotel_full_Tashir.index:
    if "No reviews (yet)" in  hotel_full_Tashir.rating[i]:
        hotel_full_Tashir.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Tashir.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Tashir.price = price_list

# %%
for i in hotel_full_Tashir.index:
    if "Response rate" in  hotel_full_Tashir.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Tashir.host_response_rate[i])
        hotel_full_Tashir.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Tashir.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Tashir = hotel_full_Tashir.astype(convert_dict)

# %%
hotel_full_Tashir.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Tashir.to_csv("cleaned_hotel_full_Tashir.csv", index=False)
hotel_full_Tashir.to_excel("cleaned_hotel_full_Tashir2.xlsx", index=False)
