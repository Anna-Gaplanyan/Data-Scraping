# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import re
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")
import regex

# %% [markdown]
# # **Reading data**

# %%
properties_Artashat = pd.read_csv('properties_Artashat.csv')
properties_Artashat
# Out:
#                                     city                              country  \
# 0                                    NaN                                  NaN
# 1              Artashat, Ararat, Armenia            Artashat, Ararat, Armenia
# 2        Garni, Kotayk Province, Armenia      Garni, Kotayk Province, Armenia
# 3    Shahumyan, Ararat Province, Armenia  Shahumyan, Ararat Province, Armenia
# 4                         Գառնի, Armenia                       Գառնի, Armenia
# ..                                   ...                                  ...
# 294                     Yerevan, Armenia                     Yerevan, Armenia
# 295                     Yerevan, Armenia                     Yerevan, Armenia
# 296                     Yerevan, Armenia                     Yerevan, Armenia
# 297                     Yerevan, Armenia                     Yerevan, Armenia
# 298                     Yerevan, Armenia                     Yerevan, Armenia
#
# ...

# %%
properties_Artashat = properties_Artashat.drop(labels = 0, axis = 0)
properties_Artashat
# Out:
#                                     city                              country  \
# 1              Artashat, Ararat, Armenia            Artashat, Ararat, Armenia
# 2        Garni, Kotayk Province, Armenia      Garni, Kotayk Province, Armenia
# 3    Shahumyan, Ararat Province, Armenia  Shahumyan, Ararat Province, Armenia
# 4                         Գառնի, Armenia                       Գառնի, Armenia
# 5                       Yerevan, Armenia                     Yerevan, Armenia
# ..                                   ...                                  ...
# 294                     Yerevan, Armenia                     Yerevan, Armenia
# 295                     Yerevan, Armenia                     Yerevan, Armenia
# 296                     Yerevan, Armenia                     Yerevan, Armenia
# 297                     Yerevan, Armenia                     Yerevan, Armenia
# 298                     Yerevan, Armenia                     Yerevan, Armenia
#
# ...

# %%
properties_Artashat["city"]= properties_Artashat["city"].replace({"Գառնի, Armenia" : "Garni, Armenia"})

# %%
properties_Artashat["city"]= properties_Artashat["city"].replace({"Երևան, Armenia" : "Yerevan, Armenia"})

# %%
properties_Artashat["city"]= properties_Artashat["city"].replace({"Ереван, United States" : "Yerevan, Armenia"})

# %%
properties_Artashat["city"]= properties_Artashat["city"].replace({"Երևան, Yerevan, Armenia" : "Yerevan, Armenia"})

# %%
properties_Artashat["city"]= properties_Artashat["city"].replace({"Yerevan, Armenia, Armenia" : "Yerevan, Armenia"})

# %%
properties_Artashat["city"]= properties_Artashat["city"].replace({"Yerevan, Armenia, Armenia" : "Yerevan, Armenia"})

# %%
properties_Artashat["city"]= properties_Artashat["city"].replace({"Ереван, Armenia" : "Yerevan, Armenia"})

# %%
city_list = []
for i in properties_Artashat.index:
    text = re.sub(",", "", properties_Artashat["city"][i][:properties_Artashat["city"][i].index("Armenia")])
    city_list.append(text)
properties_Artashat["city"]= city_list
properties_Artashat["city"]
# Out:
# 1                Artashat Ararat
# 2          Garni Kotayk Province
# 3      Shahumyan Ararat Province
# 4                          Garni
# 5                        Yerevan
#                   ...
# 294                      Yerevan
# 295                      Yerevan
# 296                      Yerevan
# 297                      Yerevan
# 298                      Yerevan
# Name: city, Length: 298, dtype: object

# %%
nan_value = float("Nan")
properties_Artashat.replace("", nan_value, inplace = True)
properties_Artashat.dropna(inplace= True)
properties_Artashat
# Out:
#                            city                              country  \
# 1              Artashat Ararat             Artashat, Ararat, Armenia
# 2        Garni Kotayk Province       Garni, Kotayk Province, Armenia
# 3    Shahumyan Ararat Province   Shahumyan, Ararat Province, Armenia
# 4                        Garni                        Գառնի, Armenia
# 5                      Yerevan                      Yerevan, Armenia
# ..                          ...                                  ...
# 294                    Yerevan                      Yerevan, Armenia
# 295                    Yerevan                      Yerevan, Armenia
# 296                    Yerevan                      Yerevan, Armenia
# 297                    Yerevan                      Yerevan, Armenia
# 298                    Yerevan                      Yerevan, Armenia
#
#                                                name  \
# 1                    Дом в древней столице Армении!
# ...

# %%
c_l = []    
for k in properties_Artashat["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
properties_Artashat["city"]= c_l
properties_Artashat
# Out:
#           city                              country  \
# 1     Artashat            Artashat, Ararat, Armenia
# 2        Garni      Garni, Kotayk Province, Armenia
# 3    Shahumyan  Shahumyan, Ararat Province, Armenia
# 4        Garni                       Գառնի, Armenia
# 5      Yerevan                     Yerevan, Armenia
# ..         ...                                  ...
# 294    Yerevan                     Yerevan, Armenia
# 295    Yerevan                     Yerevan, Armenia
# 296    Yerevan                     Yerevan, Armenia
# 297    Yerevan                     Yerevan, Armenia
# 298    Yerevan                     Yerevan, Armenia
#
#                                                name  \
# 1                    Дом в древней столице Армении!
# 2                                   Cherry blossoms
# 3    ДОМ С БАССЕЙНОМ в 6км от Хор Вирап! Три этажа.
# 4                          Guest house in art place
# 5            Your Cozy Home in Тhe Heart of Yerevan
# ...

# %%
for i in properties_Artashat.index:
    properties_Artashat["country"][i]= "Armenia"

# %%
properties_Artashat
# Out:
#           city  country                                            name  \
# 1     Artashat  Armenia                  Дом в древней столице Армении!
# 2        Garni  Armenia                                 Cherry blossoms
# 3    Shahumyan  Armenia  ДОМ С БАССЕЙНОМ в 6км от Хор Вирап! Три этажа.
# 4        Garni  Armenia                        Guest house in art place
# 5      Yerevan  Armenia          Your Cozy Home in Тhe Heart of Yerevan
# ..         ...      ...                                             ...
# 294    Yerevan  Armenia             Уютная квартира около станции метро
# 295    Yerevan  Armenia                                   #4 apartment!
# 296    Yerevan  Armenia                    ➤ 2 BDR on Yekmalyan Str. #1
# 297    Yerevan  Armenia        Moscow House Hotel (Premium Double Room)
# 298    Yerevan  Armenia     Exquisite apartment in the heart of Yerevan
#
#                                             properties
# ...

# %%
property_list = []
for i in properties_Artashat.index:
    tex= re.sub("\n", " ",properties_Artashat["properties"][i].split("Not included")[0])
    property_list.append(tex)
property_list
# Out:
# ['What this place offers Bathroom Hair dryer Shampoo Hot water Shower gel Bedroom and laundry Washer Dryer Essentials Towels, bed sheets, soap, and toilet paper Hangers Room-darkening shades Iron Entertainment Ethernet connection TV with standard cable Game console Family Children’s books and toys Baby bath Baby monitor Window guards Heating and cooling Air conditioning Heating Home safety Smoke alarm Carbon monoxide alarm Fire extinguisher First aid kit Internet and office Wifi Available throughout the listing Dedicated workspace Pocket wifi Kitchen and dining Kitchen Space where guests can cook their own meals Location features Lake access Guests can get to a lake using a path or dock Private entrance Separate street or building entrance Parking and facilities Free parking on premises Pool Services Smoking allowed Long term stays allowed Allow stay for 28 days or more ',
# ...

# %%
properties_Artashat["properties"] = property_list

# %%
for i in properties_Artashat.index:
    if "Air conditioning" in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Air conditioning'] = 1
    else:
        properties_Artashat.loc[i, 'Air conditioning'] = 0

# %%
for i in properties_Artashat.index:
    if "BBQ grill" in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'BBQ grill'] = 1
    else:
        properties_Artashat.loc[i, 'BBQ grill'] = 0

# %%
for i in properties_Artashat.index:
    if 'Baby safety gates' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Baby safety gates'] = 1
    else:
        properties_Artashat.loc[i, 'Baby safety gates'] = 0

# %%
for i in properties_Artashat.index:
    if 'Backyard' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Backyard'] = 1
    else:
        properties_Artashat.loc[i, 'Backyard'] = 0

# %%
for i in properties_Artashat.index:
    if 'Baking sheet' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Baking sheet'] = 1
    else:
        properties_Artashat.loc[i, 'Baking sheet'] = 0

# %%
for i in properties_Artashat.index:
    if 'Bathtub' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Bathtub'] = 1
    else:
        properties_Artashat.loc[i, 'Bathtub'] = 0

# %%
for i in properties_Artashat.index:
    if 'Bed linens' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Bed linens'] = 1
    else:
        properties_Artashat.loc[i, 'Bed linens'] = 0

# %%
for i in properties_Artashat.index:
    if 'Bidet' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Bidet'] = 1
    else:
        properties_Artashat.loc[i, 'Bidet'] = 0

# %%
for i in properties_Artashat.index:
    if 'Body soap' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Body soap'] = 1
    else:
        properties_Artashat.loc[i, 'Body soap'] = 0

# %%
for i in properties_Artashat.index:
    if 'Books and reading material' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Books and reading material'] = 1
    else:
        properties_Artashat.loc[i, 'Books and reading material'] = 0

# %%
for i in properties_Artashat.index:
    if 'Breakfast' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Breakfast'] = 1
    else:
        properties_Artashat.loc[i, 'Breakfast'] = 0

# %%
for i in properties_Artashat.index:
    if 'Carbon monoxide alarm' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Carbon monoxide alarm'] = 1
    else:
        properties_Artashat.loc[i, 'Carbon monoxide alarm'] = 0

# %%
for i in properties_Artashat.index:
    if 'Ceiling fan' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Ceiling fan'] = 1
    else:
        properties_Artashat.loc[i, 'Ceiling fan'] = 0

# %%
for i in properties_Artashat.index:
    if 'Central heating' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Central heating'] = 1
    else:
        properties_Artashat.loc[i, 'Central heating'] = 0

# %%
for i in properties_Artashat.index:
    if 'Children’s books and toys' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Children’s books and toys'] = 1
    else:
        properties_Artashat.loc[i, 'Children’s books and toys'] = 0

# %%
for i in properties_Artashat.index:
    if 'Cleaning products' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Cleaning products'] = 1
    else:
        properties_Artashat.loc[i, 'Cleaning products'] = 0

# %%
for i in properties_Artashat.index:
    if 'Clothing storage' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Clothing storage'] = 1
    else:
        properties_Artashat.loc[i, 'Clothing storage'] = 0

# %%
for i in properties_Artashat.index:
    if 'Coffee' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Coffee'] = 1
    else:
        properties_Artashat.loc[i, 'Coffee'] = 0

# %%
for i in properties_Artashat.index:
    if 'Coffee maker' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Coffee maker'] = 1
    else:
        properties_Artashat.loc[i, 'Coffee maker'] = 0

# %%
for i in properties_Artashat.index:
    if 'Conditioner' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Conditioner'] = 1
    else:
        properties_Artashat.loc[i, 'Conditioner'] = 0

# %%
for i in properties_Artashat.index:
    if 'Cooking basics' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Cooking basics'] = 1
    else:
        properties_Artashat.loc[i, 'Cooking basics'] = 0

# %%
for i in properties_Artashat.index:
    if 'Crib' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Crib'] = 1
    else:
        properties_Artashat.loc[i, 'Crib'] = 0

# %%
for i in properties_Artashat.index:
    if 'Dedicated workspace' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Dedicated workspace'] = 1
    else:
        properties_Artashat.loc[i, 'Dedicated workspace'] = 0

# %%
for i in properties_Artashat.index:
    if 'Dining table' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Dining table'] = 1
    else:
        properties_Artashat.loc[i, 'Dining table'] = 0

# %%
for i in properties_Artashat.index:
    if 'Dishes and silverware' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Dishes and silverware'] = 1
    else:
        properties_Artashat.loc[i, 'Dishes and silverware'] = 0

# %%
for i in properties_Artashat.index:
    if 'Dishwasher' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Dishwasher'] = 1
    else:
        properties_Artashat.loc[i, 'Dishwasher'] = 0

# %%
for i in properties_Artashat.index:
    if 'Dryer' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Dryer'] = 1
    else:
        properties_Artashat.loc[i, 'Dryer'] = 0

# %%
for i in properties_Artashat.index:
    if 'Drying rack for clothing' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Drying rack for clothing'] = 1
    else:
        properties_Artashat.loc[i, 'Drying rack for clothing'] = 0

# %%
for i in properties_Artashat.index:
    if 'Elevator' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Elevator'] = 1
    else:
        properties_Artashat.loc[i, 'Elevator'] = 0

# %%
for i in properties_Artashat.index:
    if 'Essentials' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Essentials'] = 1
    else:
        properties_Artashat.loc[i, 'Essentials'] = 0

# %%
for i in properties_Artashat.index:
    if 'Ethernet connection' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Ethernet connection'] = 1
    else:
        properties_Artashat.loc[i, 'Ethernet connection'] = 0

# %%
for i in properties_Artashat.index:
    if 'Extra pillows and blankets' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Extra pillows and blankets'] = 1
    else:
        properties_Artashat.loc[i, 'Extra pillows and blankets'] = 0

# %%
for i in properties_Artashat.index:
    if 'Fire extinguisher' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Fire extinguisher'] = 1
    else:
        properties_Artashat.loc[i, 'Fire extinguisher'] = 0

# %%
for i in properties_Artashat.index:
    if 'First aid kit' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'First aid kit'] = 1
    else:
        properties_Artashat.loc[i, 'First aid kit'] = 0

# %%
for i in properties_Artashat.index:
    if 'Free driveway parking on premises' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Free driveway parking on premises'] = 1
    else:
        properties_Artashat.loc[i, 'Free driveway parking on premises'] = 0

# %%
for i in properties_Artashat.index:
    if 'Free street parking' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Free street parking'] = 1
    else:
        properties_Artashat.loc[i, 'Free street parking'] = 0

# %%
for i in properties_Artashat.index:
    if 'Freezer' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Freezer'] = 1
    else:
        properties_Artashat.loc[i, 'Freezer'] = 0

# %%
for i in properties_Artashat.index:
    if 'HDTV with Netflix, standard cable' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'HDTV with Netflix, standard cable'] = 1
    else:
        properties_Artashat.loc[i, 'HDTV with Netflix, standard cable'] = 0

# %%
for i in properties_Artashat.index:
    if 'Hair dryer' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Hair dryer'] = 1
    else:
        properties_Artashat.loc[i, 'Hair dryer'] = 0

# %%
for i in properties_Artashat.index:
    if 'Hangers' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Hangers'] = 1
    else:
        properties_Artashat.loc[i, 'Hangers'] = 0

# %%
for i in properties_Artashat.index:
    if 'Heating' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Heating'] = 1
    else:
        properties_Artashat.loc[i, 'Heating'] = 0

# %%
for i in properties_Artashat.index:
    if 'High chair' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'High chair'] = 1
    else:
        properties_Artashat.loc[i, 'High chair'] = 0

# %%
for i in properties_Artashat.index:
    if 'Hot water' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Hot water'] = 1
    else:
        properties_Artashat.loc[i, 'Hot water'] = 0

# %%
for i in properties_Artashat.index:
    if 'Hot water kettle' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Hot water kettle'] = 1
    else:
        properties_Artashat.loc[i, 'Hot water kettle'] = 0

# %%
for i in properties_Artashat.index:
    if 'Indoor fireplace' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Indoor fireplace'] = 1
    else:
        properties_Artashat.loc[i, 'Indoor fireplace'] = 0

# %%
for i in properties_Artashat.index:
    if 'Iron' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Iron'] = 1
    else:
        properties_Artashat.loc[i, 'Iron'] = 0

# %%
for i in properties_Artashat.index:
    if 'Kitchen' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Kitchen'] = 1
    else:
        properties_Artashat.loc[i, 'Kitchen'] = 0

# %%
for i in properties_Artashat.index:
    if 'Laundromat nearby' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Laundromat nearby'] = 1
    else:
        properties_Artashat.loc[i, 'Laundromat nearby'] = 0

# %%
for i in properties_Artashat.index:
    if 'Lockbox' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Lockbox'] = 1
    else:
        properties_Artashat.loc[i, 'Lockbox'] = 0

# %%
for i in properties_Artashat.index:
    if 'Long term stays allowed' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Long term stays allowed'] = 1
    else:
        properties_Artashat.loc[i, 'Long term stays allowed'] = 0

# %%
for i in properties_Artashat.index:
    if 'Luggage dropoff allowed' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Luggage dropoff allowed'] = 1
    else:
        properties_Artashat.loc[i, 'Luggage dropoff allowed'] = 0

# %%
for i in properties_Artashat.index:
    if 'Microwave' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Microwave'] = 1
    else:
        properties_Artashat.loc[i, 'Microwave'] = 0

# %%
for i in properties_Artashat.index:
    if 'Mini fridge' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Mini fridge'] = 1
    else:
        properties_Artashat.loc[i, 'Mini fridge'] = 0

# %%
for i in properties_Artashat.index:
    if 'Mosquito net' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Mosquito net'] = 1
    else:
        properties_Artashat.loc[i, 'Mosquito net'] = 0

# %%
for i in properties_Artashat.index:
    if 'Outdoor furniture' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Outdoor furniture'] = 1
    else:
        properties_Artashat.loc[i, 'Outdoor furniture'] = 0

# %%
for i in properties_Artashat.index:
    if 'Outlet covers' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Outlet covers'] = 1
    else:
        properties_Artashat.loc[i, 'Outlet covers'] = 0

# %%
for i in properties_Artashat.index:
    if 'Oven' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Oven'] = 1
    else:
        properties_Artashat.loc[i, 'Oven'] = 0

# %%
for i in properties_Artashat.index:
    if 'Paid parking off premises' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Paid parking off premises'] = 1
    else:
        properties_Artashat.loc[i, 'Paid parking off premises'] = 0

# %%
for i in properties_Artashat.index:
    if 'Paid parking on premises' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Paid parking on premises'] = 1
    else:
        properties_Artashat.loc[i, 'Paid parking on premises'] = 0

# %%
for i in properties_Artashat.index:
    if 'Patio or balcony' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Patio or balcony'] = 1
    else:
        properties_Artashat.loc[i, 'Patio or balcony'] = 0

# %%
for i in properties_Artashat.index:
    if 'Portable fans' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Portable fans'] = 1
    else:
        properties_Artashat.loc[i, 'Portable fans'] = 0

# %%
for i in properties_Artashat.index:
    if 'Private entrance' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Private entrance'] = 1
    else:
        properties_Artashat.loc[i, 'Private entrance'] = 0

# %%
for i in properties_Artashat.index:
    if 'Radiant heating' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Radiant heating'] = 1
    else:
        properties_Artashat.loc[i, 'Radiant heating'] = 0

# %%
for i in properties_Artashat.index:
    if 'Refrigerator' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Refrigerator'] = 1
    else:
        properties_Artashat.loc[i, 'Refrigerator'] = 0

# %%
for i in properties_Artashat.index:
    if 'Room-darkening shades' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Room-darkening shades'] = 1
    else:
        properties_Artashat.loc[i, 'Room-darkening shades'] = 0

# %%
for i in properties_Artashat.index:
    if 'Security cameras on property' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Security cameras on property'] = 1
    else:
        properties_Artashat.loc[i, 'Security cameras on property'] = 0

# %%
for i in properties_Artashat.index:
    if 'Self check-in' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Self check-in'] = 1
    else:
        properties_Artashat.loc[i, 'Self check-in'] = 0

# %%
for i in properties_Artashat.index:
    if 'Shampoo' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Shampoo'] = 1
    else:
        properties_Artashat.loc[i, 'Shampoo'] = 0

# %%
for i in properties_Artashat.index:
    if 'Shower gel' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Shower gel'] = 1
    else:
        properties_Artashat.loc[i, 'Shower gel'] = 0

# %%
for i in properties_Artashat.index:
    if 'Single level home' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Single level home'] = 1
    else:
        properties_Artashat.loc[i, 'Single level home'] = 0

# %%
for i in properties_Artashat.index:
    if 'Smoke alarm' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Smoke alarm'] = 1
    else:
        properties_Artashat.loc[i, 'Smoke alarm'] = 0

# %%
for i in properties_Artashat.index:
    if 'Smoking allowed' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Smoking allowed'] = 1
    else:
        properties_Artashat.loc[i, 'Smoking allowed'] = 0

# %%
for i in properties_Artashat.index:
    if 'Sound system with aux' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Sound system with aux'] = 1
    else:
        properties_Artashat.loc[i, 'Sound system with aux'] = 0

# %%
for i in properties_Artashat.index:
    if 'Stove' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Stove'] = 1
    else:
        properties_Artashat.loc[i, 'Stove'] = 0

# %%
for i in properties_Artashat.index:
    if 'Suitable for events' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Suitable for events'] = 1
    else:
        properties_Artashat.loc[i, 'Suitable for events'] = 0

# %%
for i in properties_Artashat.index:
    if 'TV' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'TV'] = 1
    else:
        properties_Artashat.loc[i, 'TV'] = 0

# %%
for i in properties_Artashat.index:
    if 'Trash compactor' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Trash compactor'] = 1
    else:
        properties_Artashat.loc[i, 'Trash compactor'] = 0

# %%
for i in properties_Artashat.index:
    if 'Washer' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Washer'] = 1
    else:
        properties_Artashat.loc[i, 'Washer'] = 0

# %%
for i in properties_Artashat.index:
    if 'Wifi' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Wifi'] = 1
    else:
        properties_Artashat.loc[i, 'Wifi'] = 0

# %%
for i in properties_Artashat.index:
    if 'Wine glasses' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'Wine glasses'] = 1
    else:
        properties_Artashat.loc[i, 'Wine glasses'] = 0

# %%
for i in properties_Artashat.index:
    if 'geneva green conditioner' in  properties_Artashat.properties[i]:
        properties_Artashat.loc[i, 'geneva green conditioner'] = 1
    else:
        properties_Artashat.loc[i, 'geneva green conditioner'] = 0

# %%
del properties_Artashat['properties']

# %%
properties_Artashat
# Out:
#           city  country                                            name  \
# 1     Artashat  Armenia                  Дом в древней столице Армении!
# 2        Garni  Armenia                                 Cherry blossoms
# 3    Shahumyan  Armenia  ДОМ С БАССЕЙНОМ в 6км от Хор Вирап! Три этажа.
# 4        Garni  Armenia                        Guest house in art place
# 5      Yerevan  Armenia          Your Cozy Home in Тhe Heart of Yerevan
# ..         ...      ...                                             ...
# 294    Yerevan  Armenia             Уютная квартира около станции метро
# 295    Yerevan  Armenia                                   #4 apartment!
# 296    Yerevan  Armenia                    ➤ 2 BDR on Yekmalyan Str. #1
# 297    Yerevan  Armenia        Moscow House Hotel (Premium Double Room)
# 298    Yerevan  Armenia     Exquisite apartment in the heart of Yerevan
#
#      Air conditioning  BBQ grill  Baby safety gates  Backyard  Baking sheet  \
# ...

# %%
properties_Artashat.to_csv("Cleaned_Artashat_properties.csv", index=False)
properties_Artashat.to_excel("Cleaned_Artashat_properties.xlsx", index=False)
