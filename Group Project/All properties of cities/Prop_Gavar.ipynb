# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import re
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")
import regex

# %% [markdown]
# # **Reading data**

# %%
properties_Gavar = pd.read_csv('properties_Gavar.csv')
properties_Gavar
# Out:
#                                        city  \
# 0                                       NaN
# 1      Sevan, Gegharkunik Province, Armenia
# 2    Noratus, Gegharkunik Province, Armenia
# 3     Tsaghkadzor, Kotayk Province, Armenia
# 4                Սևան, Գեղարքունիք, Armenia
# ..                                      ...
# 296                                 Armenia
# 297   Tsaghkadzor, Kotayk Province, Armenia
# 298                ариения, ереван, Armenia
# 299       Abovyan, Kotayk Province, Armenia
# 300   Tsaghkadzor, Kotayk Province, Armenia
#
#                                     country  \
# 0                                       NaN
# 1      Sevan, Gegharkunik Province, Armenia
# 2    Noratus, Gegharkunik Province, Armenia
# 3     Tsaghkadzor, Kotayk Province, Armenia
# 4                Սևան, Գեղարքունիք, Armenia
# ..                                      ...
# 296                                 Armenia
# 297   Tsaghkadzor, Kotayk Province, Armenia
# ...

# %%
properties_Gavar = properties_Gavar.drop(labels = 0, axis = 0)
properties_Gavar
# Out:
#                                        city  \
# 1      Sevan, Gegharkunik Province, Armenia
# 2    Noratus, Gegharkunik Province, Armenia
# 3     Tsaghkadzor, Kotayk Province, Armenia
# 4                Սևան, Գեղարքունիք, Armenia
# 5    Noratus, Gegharkunik Province, Armenia
# ..                                      ...
# 296                                 Armenia
# 297   Tsaghkadzor, Kotayk Province, Armenia
# 298                ариения, ереван, Armenia
# 299       Abovyan, Kotayk Province, Armenia
# 300   Tsaghkadzor, Kotayk Province, Armenia
#
#                                     country  \
# 1      Sevan, Gegharkunik Province, Armenia
# 2    Noratus, Gegharkunik Province, Armenia
# 3     Tsaghkadzor, Kotayk Province, Armenia
# 4                Սևան, Գեղարքունիք, Armenia
# 5    Noratus, Gegharkunik Province, Armenia
# ..                                      ...
# 296                                 Armenia
# 297   Tsaghkadzor, Kotayk Province, Armenia
# ...

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Սևան, Գեղարքունիք, Armenia" : "Sevan, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Գառնի, Armenia" : "Garni, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Հրազդան, Կոտայք, Armenia" : "Hrazdan, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Սևան, Gegharkunik Province, Armenia" : "Sevan, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Ծաղկաձոր, Armenia" : "Tsaghkadzor, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Ծաղկաձոր, Կոտայք, Armenia" : "Tsaghkadzor, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Կալավան, Armenia" : "Kalavan, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Цахкадзор, Котайк, Armenia" : "Tsaghkadzor, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Սևան, Yerevan, Armenia" : "Sevan, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Дзорахпюр, Котайк, Armenia" : "Dzoraxbyur, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Արզնի, Կոտայք, Armenia" : "Arzni, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Գառնի, Կոտայք, Armenia" : "Garni, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Ծովազարդ, Armenia" : "Tsovazard, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"Цахкадзор , Армения, Armenia" : "Tsaghkadzor, Armenia"})

# %%
properties_Gavar["city"]= properties_Gavar["city"].replace({"ариения, ереван, Armenia" : "Yerevan, Armenia"})

# %%
city_list = []
for i in properties_Gavar.index:
    text = re.sub(",", "", properties_Gavar["city"][i][:properties_Gavar["city"][i].index("Armenia")])
    city_list.append(text)
properties_Gavar["city"]= city_list
properties_Gavar["city"]
# Out:
# 1        Sevan Gegharkunik Province
# 2      Noratus Gegharkunik Province
# 3       Tsaghkadzor Kotayk Province
# 4                             Sevan
# 5      Noratus Gegharkunik Province
#                    ...
# 296
# 297     Tsaghkadzor Kotayk Province
# 298                         Yerevan
# 299         Abovyan Kotayk Province
# 300     Tsaghkadzor Kotayk Province
# Name: city, Length: 300, dtype: object

# %%
nan_value = float("Nan")
properties_Gavar.replace("", nan_value, inplace = True)
properties_Gavar.dropna(inplace= True)
properties_Gavar
# Out:
#                               city                                 country  \
# 1      Sevan Gegharkunik Province     Sevan, Gegharkunik Province, Armenia
# 2    Noratus Gegharkunik Province   Noratus, Gegharkunik Province, Armenia
# 3     Tsaghkadzor Kotayk Province    Tsaghkadzor, Kotayk Province, Armenia
# 4                           Sevan               Սևան, Գեղարքունիք, Armenia
# 5    Noratus Gegharkunik Province   Noratus, Gegharkunik Province, Armenia
# ..                             ...                                     ...
# 295   Tsaghkadzor Kotayk Province    Tsaghkadzor, Kotayk Province, Armenia
# 297   Tsaghkadzor Kotayk Province    Tsaghkadzor, Kotayk Province, Armenia
# 298                       Yerevan                 ариения, ереван, Armenia
# 299       Abovyan Kotayk Province        Abovyan, Kotayk Province, Armenia
# 300   Tsaghkadzor Kotayk Province    Tsaghkadzor, Kotayk Province, Armenia
#
#                                                   name  \
# ...

# %%
c_l = []    
for k in properties_Gavar["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
properties_Gavar["city"]= c_l
properties_Gavar
# Out:
#             city                                 country  \
# 1          Sevan    Sevan, Gegharkunik Province, Armenia
# 2        Noratus  Noratus, Gegharkunik Province, Armenia
# 3    Tsaghkadzor   Tsaghkadzor, Kotayk Province, Armenia
# 4          Sevan              Սևան, Գեղարքունիք, Armenia
# 5        Noratus  Noratus, Gegharkunik Province, Armenia
# ..           ...                                     ...
# 295  Tsaghkadzor   Tsaghkadzor, Kotayk Province, Armenia
# 297  Tsaghkadzor   Tsaghkadzor, Kotayk Province, Armenia
# 298      Yerevan                ариения, ереван, Armenia
# 299      Abovyan       Abovyan, Kotayk Province, Armenia
# 300  Tsaghkadzor   Tsaghkadzor, Kotayk Province, Armenia
#
#                                                   name  \
# 1               Brand NEW apartment in Sevan city. VIP
# 2           Oazis a place for a real holiday. Big room
# 3    Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# ...

# %%
country_list = []
for i in properties_Gavar.index:
    text = re.search("Armenia", properties_Gavar["country"][i]).group(0)
    country_list.append(text)

properties_Gavar["country"] = country_list

# %%
property_list = []
for i in properties_Gavar.index:
    tex= re.sub("\n", " ",properties_Gavar["properties"][i].split("Not included")[0])
    property_list.append(tex)
property_list
# Out:
# ['What this place offers Bathroom Hair dryer Shampoo Bedroom and laundry Washer Essentials Towels, bed sheets, soap, and toilet paper Hangers Iron Entertainment TV Heating and cooling Heating Home safety Carbon monoxide alarm Fire extinguisher First aid kit Internet and office Wifi Available throughout the listing Kitchen and dining Kitchen Space where guests can cook their own meals Location features Lake access Guests can get to a lake using a path or dock Parking and facilities Free parking on premises Services Long term stays allowed Allow stay for 28 days or more ',
# ...

# %%
properties_Gavar["properties"] = property_list

# %%
for i in properties_Gavar.index:
    if "Air conditioning" in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Air conditioning'] = 1
    else:
        properties_Gavar.loc[i, 'Air conditioning'] = 0

# %%
for i in properties_Gavar.index:
    if "BBQ grill" in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'BBQ grill'] = 1
    else:
        properties_Gavar.loc[i, 'BBQ grill'] = 0

# %%
for i in properties_Gavar.index:
    if 'Baby safety gates' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Baby safety gates'] = 1
    else:
        properties_Gavar.loc[i, 'Baby safety gates'] = 0

# %%
for i in properties_Gavar.index:
    if 'Backyard' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Backyard'] = 1
    else:
        properties_Gavar.loc[i, 'Backyard'] = 0

# %%
for i in properties_Gavar.index:
    if 'Baking sheet' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Baking sheet'] = 1
    else:
        properties_Gavar.loc[i, 'Baking sheet'] = 0

# %%
for i in properties_Gavar.index:
    if 'Bathtub' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Bathtub'] = 1
    else:
        properties_Gavar.loc[i, 'Bathtub'] = 0

# %%
for i in properties_Gavar.index:
    if 'Bed linens' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Bed linens'] = 1
    else:
        properties_Gavar.loc[i, 'Bed linens'] = 0

# %%
for i in properties_Gavar.index:
    if 'Bidet' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Bidet'] = 1
    else:
        properties_Gavar.loc[i, 'Bidet'] = 0

# %%
for i in properties_Gavar.index:
    if 'Body soap' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Body soap'] = 1
    else:
        properties_Gavar.loc[i, 'Body soap'] = 0

# %%
for i in properties_Gavar.index:
    if 'Books and reading material' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Books and reading material'] = 1
    else:
        properties_Gavar.loc[i, 'Books and reading material'] = 0

# %%
for i in properties_Gavar.index:
    if 'Breakfast' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Breakfast'] = 1
    else:
        properties_Gavar.loc[i, 'Breakfast'] = 0

# %%
for i in properties_Gavar.index:
    if 'Carbon monoxide alarm' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Carbon monoxide alarm'] = 1
    else:
        properties_Gavar.loc[i, 'Carbon monoxide alarm'] = 0

# %%
for i in properties_Gavar.index:
    if 'Ceiling fan' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Ceiling fan'] = 1
    else:
        properties_Gavar.loc[i, 'Ceiling fan'] = 0

# %%
for i in properties_Gavar.index:
    if 'Central heating' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Central heating'] = 1
    else:
        properties_Gavar.loc[i, 'Central heating'] = 0

# %%
for i in properties_Gavar.index:
    if 'Children’s books and toys' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Children’s books and toys'] = 1
    else:
        properties_Gavar.loc[i, 'Children’s books and toys'] = 0

# %%
for i in properties_Gavar.index:
    if 'Cleaning products' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Cleaning products'] = 1
    else:
        properties_Gavar.loc[i, 'Cleaning products'] = 0

# %%
for i in properties_Gavar.index:
    if 'Clothing storage' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Clothing storage'] = 1
    else:
        properties_Gavar.loc[i, 'Clothing storage'] = 0

# %%
for i in properties_Gavar.index:
    if 'Coffee' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Coffee'] = 1
    else:
        properties_Gavar.loc[i, 'Coffee'] = 0

# %%
for i in properties_Gavar.index:
    if 'Coffee maker' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Coffee maker'] = 1
    else:
        properties_Gavar.loc[i, 'Coffee maker'] = 0

# %%
for i in properties_Gavar.index:
    if 'Conditioner' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Conditioner'] = 1
    else:
        properties_Gavar.loc[i, 'Conditioner'] = 0

# %%
for i in properties_Gavar.index:
    if 'Cooking basics' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Cooking basics'] = 1
    else:
        properties_Gavar.loc[i, 'Cooking basics'] = 0

# %%
for i in properties_Gavar.index:
    if 'Crib' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Crib'] = 1
    else:
        properties_Gavar.loc[i, 'Crib'] = 0

# %%
for i in properties_Gavar.index:
    if 'Dedicated workspace' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Dedicated workspace'] = 1
    else:
        properties_Gavar.loc[i, 'Dedicated workspace'] = 0

# %%
for i in properties_Gavar.index:
    if 'Dining table' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Dining table'] = 1
    else:
        properties_Gavar.loc[i, 'Dining table'] = 0

# %%
for i in properties_Gavar.index:
    if 'Dishes and silverware' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Dishes and silverware'] = 1
    else:
        properties_Gavar.loc[i, 'Dishes and silverware'] = 0

# %%
for i in properties_Gavar.index:
    if 'Dishwasher' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Dishwasher'] = 1
    else:
        properties_Gavar.loc[i, 'Dishwasher'] = 0

# %%
for i in properties_Gavar.index:
    if 'Dryer' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Dryer'] = 1
    else:
        properties_Gavar.loc[i, 'Dryer'] = 0

# %%
for i in properties_Gavar.index:
    if 'Drying rack for clothing' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Drying rack for clothing'] = 1
    else:
        properties_Gavar.loc[i, 'Drying rack for clothing'] = 0

# %%
for i in properties_Gavar.index:
    if 'Elevator' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Elevator'] = 1
    else:
        properties_Gavar.loc[i, 'Elevator'] = 0

# %%
for i in properties_Gavar.index:
    if 'Essentials' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Essentials'] = 1
    else:
        properties_Gavar.loc[i, 'Essentials'] = 0

# %%
for i in properties_Gavar.index:
    if 'Ethernet connection' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Ethernet connection'] = 1
    else:
        properties_Gavar.loc[i, 'Ethernet connection'] = 0

# %%
for i in properties_Gavar.index:
    if 'Extra pillows and blankets' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Extra pillows and blankets'] = 1
    else:
        properties_Gavar.loc[i, 'Extra pillows and blankets'] = 0

# %%
for i in properties_Gavar.index:
    if 'Fire extinguisher' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Fire extinguisher'] = 1
    else:
        properties_Gavar.loc[i, 'Fire extinguisher'] = 0

# %%
for i in properties_Gavar.index:
    if 'First aid kit' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'First aid kit'] = 1
    else:
        properties_Gavar.loc[i, 'First aid kit'] = 0

# %%
for i in properties_Gavar.index:
    if 'Free driveway parking on premises' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Free driveway parking on premises'] = 1
    else:
        properties_Gavar.loc[i, 'Free driveway parking on premises'] = 0

# %%
for i in properties_Gavar.index:
    if 'Free street parking' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Free street parking'] = 1
    else:
        properties_Gavar.loc[i, 'Free street parking'] = 0

# %%
for i in properties_Gavar.index:
    if 'Freezer' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Freezer'] = 1
    else:
        properties_Gavar.loc[i, 'Freezer'] = 0

# %%
for i in properties_Gavar.index:
    if 'HDTV with Netflix, standard cable' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'HDTV with Netflix, standard cable'] = 1
    else:
        properties_Gavar.loc[i, 'HDTV with Netflix, standard cable'] = 0

# %%
for i in properties_Gavar.index:
    if 'Hair dryer' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Hair dryer'] = 1
    else:
        properties_Gavar.loc[i, 'Hair dryer'] = 0

# %%
for i in properties_Gavar.index:
    if 'Hangers' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Hangers'] = 1
    else:
        properties_Gavar.loc[i, 'Hangers'] = 0

# %%
for i in properties_Gavar.index:
    if 'Heating' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Heating'] = 1
    else:
        properties_Gavar.loc[i, 'Heating'] = 0

# %%
for i in properties_Gavar.index:
    if 'High chair' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'High chair'] = 1
    else:
        properties_Gavar.loc[i, 'High chair'] = 0

# %%
for i in properties_Gavar.index:
    if 'Hot water' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Hot water'] = 1
    else:
        properties_Gavar.loc[i, 'Hot water'] = 0

# %%
for i in properties_Gavar.index:
    if 'Hot water kettle' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Hot water kettle'] = 1
    else:
        properties_Gavar.loc[i, 'Hot water kettle'] = 0

# %%
for i in properties_Gavar.index:
    if 'Indoor fireplace' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Indoor fireplace'] = 1
    else:
        properties_Gavar.loc[i, 'Indoor fireplace'] = 0

# %%
for i in properties_Gavar.index:
    if 'Iron' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Iron'] = 1
    else:
        properties_Gavar.loc[i, 'Iron'] = 0

# %%
for i in properties_Gavar.index:
    if 'Kitchen' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Kitchen'] = 1
    else:
        properties_Gavar.loc[i, 'Kitchen'] = 0

# %%
for i in properties_Gavar.index:
    if 'Laundromat nearby' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Laundromat nearby'] = 1
    else:
        properties_Gavar.loc[i, 'Laundromat nearby'] = 0

# %%
for i in properties_Gavar.index:
    if 'Lockbox' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Lockbox'] = 1
    else:
        properties_Gavar.loc[i, 'Lockbox'] = 0

# %%
for i in properties_Gavar.index:
    if 'Long term stays allowed' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Long term stays allowed'] = 1
    else:
        properties_Gavar.loc[i, 'Long term stays allowed'] = 0

# %%
for i in properties_Gavar.index:
    if 'Luggage dropoff allowed' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Luggage dropoff allowed'] = 1
    else:
        properties_Gavar.loc[i, 'Luggage dropoff allowed'] = 0

# %%
for i in properties_Gavar.index:
    if 'Microwave' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Microwave'] = 1
    else:
        properties_Gavar.loc[i, 'Microwave'] = 0

# %%
for i in properties_Gavar.index:
    if 'Mini fridge' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Mini fridge'] = 1
    else:
        properties_Gavar.loc[i, 'Mini fridge'] = 0

# %%
for i in properties_Gavar.index:
    if 'Mosquito net' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Mosquito net'] = 1
    else:
        properties_Gavar.loc[i, 'Mosquito net'] = 0

# %%
for i in properties_Gavar.index:
    if 'Outdoor furniture' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Outdoor furniture'] = 1
    else:
        properties_Gavar.loc[i, 'Outdoor furniture'] = 0

# %%
for i in properties_Gavar.index:
    if 'Outlet covers' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Outlet covers'] = 1
    else:
        properties_Gavar.loc[i, 'Outlet covers'] = 0

# %%
for i in properties_Gavar.index:
    if 'Oven' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Oven'] = 1
    else:
        properties_Gavar.loc[i, 'Oven'] = 0

# %%
for i in properties_Gavar.index:
    if 'Paid parking off premises' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Paid parking off premises'] = 1
    else:
        properties_Gavar.loc[i, 'Paid parking off premises'] = 0

# %%
for i in properties_Gavar.index:
    if 'Paid parking on premises' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Paid parking on premises'] = 1
    else:
        properties_Gavar.loc[i, 'Paid parking on premises'] = 0

# %%
for i in properties_Gavar.index:
    if 'Patio or balcony' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Patio or balcony'] = 1
    else:
        properties_Gavar.loc[i, 'Patio or balcony'] = 0

# %%
for i in properties_Gavar.index:
    if 'Portable fans' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Portable fans'] = 1
    else:
        properties_Gavar.loc[i, 'Portable fans'] = 0

# %%
for i in properties_Gavar.index:
    if 'Private entrance' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Private entrance'] = 1
    else:
        properties_Gavar.loc[i, 'Private entrance'] = 0

# %%
for i in properties_Gavar.index:
    if 'Radiant heating' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Radiant heating'] = 1
    else:
        properties_Gavar.loc[i, 'Radiant heating'] = 0

# %%
for i in properties_Gavar.index:
    if 'Refrigerator' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Refrigerator'] = 1
    else:
        properties_Gavar.loc[i, 'Refrigerator'] = 0

# %%
for i in properties_Gavar.index:
    if 'Room-darkening shades' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Room-darkening shades'] = 1
    else:
        properties_Gavar.loc[i, 'Room-darkening shades'] = 0

# %%
for i in properties_Gavar.index:
    if 'Security cameras on property' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Security cameras on property'] = 1
    else:
        properties_Gavar.loc[i, 'Security cameras on property'] = 0

# %%
for i in properties_Gavar.index:
    if 'Self check-in' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Self check-in'] = 1
    else:
        properties_Gavar.loc[i, 'Self check-in'] = 0

# %%
for i in properties_Gavar.index:
    if 'Shampoo' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Shampoo'] = 1
    else:
        properties_Gavar.loc[i, 'Shampoo'] = 0

# %%
for i in properties_Gavar.index:
    if 'Shower gel' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Shower gel'] = 1
    else:
        properties_Gavar.loc[i, 'Shower gel'] = 0

# %%
for i in properties_Gavar.index:
    if 'Single level home' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Single level home'] = 1
    else:
        properties_Gavar.loc[i, 'Single level home'] = 0

# %%
for i in properties_Gavar.index:
    if 'Smoke alarm' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Smoke alarm'] = 1
    else:
        properties_Gavar.loc[i, 'Smoke alarm'] = 0

# %%
for i in properties_Gavar.index:
    if 'Smoking allowed' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Smoking allowed'] = 1
    else:
        properties_Gavar.loc[i, 'Smoking allowed'] = 0

# %%
for i in properties_Gavar.index:
    if 'Sound system with aux' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Sound system with aux'] = 1
    else:
        properties_Gavar.loc[i, 'Sound system with aux'] = 0

# %%
for i in properties_Gavar.index:
    if 'Stove' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Stove'] = 1
    else:
        properties_Gavar.loc[i, 'Stove'] = 0

# %%
for i in properties_Gavar.index:
    if 'Suitable for events' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Suitable for events'] = 1
    else:
        properties_Gavar.loc[i, 'Suitable for events'] = 0

# %%
for i in properties_Gavar.index:
    if 'TV' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'TV'] = 1
    else:
        properties_Gavar.loc[i, 'TV'] = 0

# %%
for i in properties_Gavar.index:
    if 'Trash compactor' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Trash compactor'] = 1
    else:
        properties_Gavar.loc[i, 'Trash compactor'] = 0

# %%
for i in properties_Gavar.index:
    if 'Washer' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Washer'] = 1
    else:
        properties_Gavar.loc[i, 'Washer'] = 0

# %%
for i in properties_Gavar.index:
    if 'Wifi' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Wifi'] = 1
    else:
        properties_Gavar.loc[i, 'Wifi'] = 0

# %%
for i in properties_Gavar.index:
    if 'Wine glasses' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'Wine glasses'] = 1
    else:
        properties_Gavar.loc[i, 'Wine glasses'] = 0

# %%
for i in properties_Gavar.index:
    if 'geneva green conditioner' in  properties_Gavar.properties[i]:
        properties_Gavar.loc[i, 'geneva green conditioner'] = 1
    else:
        properties_Gavar.loc[i, 'geneva green conditioner'] = 0

# %%
del properties_Gavar['properties']

# %%
properties_Gavar
# Out:
#             city  country                                               name  \
# 1          Sevan  Armenia             Brand NEW apartment in Sevan city. VIP
# 2        Noratus  Armenia         Oazis a place for a real holiday. Big room
# 3    Tsaghkadzor  Armenia  Snowdrop ❤ of Tsaghkadzor ✔ Self Checkin ✔ Bal...
# 4          Sevan  Armenia                      Rest in Sevan geghama ashxarh
# 5        Noratus  Armenia                          Room with Armenian spirit
# ..           ...      ...                                                ...
# 295  Tsaghkadzor  Armenia                               Richard Villa Garden
# 297  Tsaghkadzor  Armenia                                        Royal Black
# 298      Yerevan  Armenia                                           dlya vas
# 299      Abovyan  Armenia    It's a private house with outdoor swimming pool
# 300  Tsaghkadzor  Armenia                  Best apartment in the Tsaghkadzor
#
# ...

# %%
properties_Gavar.to_csv("Cleaned_Gavar_properties.csv", index=False)
properties_Gavar.to_excel("Cleaned_Gavar_properties.xlsx", index=False)
