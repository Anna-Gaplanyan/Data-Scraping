# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import re
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")
import regex

# %% [markdown]
# # **Reading data**

# %%
properties_Ashtarak = pd.read_csv('properties_Ashtarak.csv')
properties_Ashtarak
# Out:
#                                        city  \
# 0                                       NaN
# 1    Ashtarak, Aragatsotn Province, Armenia
# 2      Tegher, Aragatsotn Province, Armenia
# 3     Baghramyan, Armavir Province, Armenia
# 4    Ashtarak, Aragatsotn Province, Armenia
# ..                                      ...
# 294        Kotayk, Kotayk Province, Armenia
# 295                        Yerevan, Armenia
# 296          Vagharshapat, Armavir, Armenia
# 297                        Yerevan, Armenia
# 298                        Yerevan, Armenia
#
#                                     country  \
# 0                                       NaN
# 1    Ashtarak, Aragatsotn Province, Armenia
# 2      Tegher, Aragatsotn Province, Armenia
# 3     Baghramyan, Armavir Province, Armenia
# 4    Ashtarak, Aragatsotn Province, Armenia
# ..                                      ...
# 294        Kotayk, Kotayk Province, Armenia
# 295                        Yerevan, Armenia
# ...

# %%
properties_Ashtarak = properties_Ashtarak.drop(labels = 0, axis = 0)
properties_Ashtarak
# Out:
#                                        city  \
# 1    Ashtarak, Aragatsotn Province, Armenia
# 2      Tegher, Aragatsotn Province, Armenia
# 3     Baghramyan, Armavir Province, Armenia
# 4    Ashtarak, Aragatsotn Province, Armenia
# 5    Ashtarak, Aragatsotn Province, Armenia
# ..                                      ...
# 294        Kotayk, Kotayk Province, Armenia
# 295                        Yerevan, Armenia
# 296          Vagharshapat, Armavir, Armenia
# 297                        Yerevan, Armenia
# 298                        Yerevan, Armenia
#
#                                     country  \
# 1    Ashtarak, Aragatsotn Province, Armenia
# 2      Tegher, Aragatsotn Province, Armenia
# 3     Baghramyan, Armavir Province, Armenia
# 4    Ashtarak, Aragatsotn Province, Armenia
# 5    Ashtarak, Aragatsotn Province, Armenia
# ..                                      ...
# 294        Kotayk, Kotayk Province, Armenia
# 295                        Yerevan, Armenia
# ...

# %%
properties_Ashtarak["city"]= properties_Ashtarak["city"].replace({"Երևան, Armenia" : "Yerevan, Armenia"})

# %%
properties_Ashtarak["city"]= properties_Ashtarak["city"].replace({"Երևան, Yerevan, Armenia" : "Yerevan, Armenia"})

# %%
properties_Ashtarak["city"]= properties_Ashtarak["city"].replace({"Ереван , Ереван, Armenia" : "Yerevan, Armenia"})

# %%
properties_Ashtarak["city"]= properties_Ashtarak["city"].replace({"Աջափնյակ, Երևան, Armenia" : "Yerevan, Armenia"})

# %%
properties_Ashtarak["city"]= properties_Ashtarak["city"].replace({"Երևան, Արմավիրի մարզ, Armenia" : "Yerevan, Armenia"})

# %%
properties_Ashtarak["city"]= properties_Ashtarak["city"].replace({"Ереван, Кентрон, Armenia" : "Yerevan, Armenia"})

# %%
city_list = []
for i in properties_Ashtarak.index:
    text = re.sub(",", "", properties_Ashtarak["city"][i][:properties_Ashtarak["city"][i].index("Armenia")])
    city_list.append(text)
properties_Ashtarak["city"]= city_list
properties_Ashtarak["city"]
# Out:
# 1      Ashtarak Aragatsotn Province
# 2        Tegher Aragatsotn Province
# 3       Baghramyan Armavir Province
# 4      Ashtarak Aragatsotn Province
# 5      Ashtarak Aragatsotn Province
#                    ...
# 294          Kotayk Kotayk Province
# 295                         Yerevan
# 296            Vagharshapat Armavir
# 297                         Yerevan
# 298                         Yerevan
# Name: city, Length: 298, dtype: object

# %%
nan_value = float("Nan")
properties_Ashtarak.replace("", nan_value, inplace = True)
properties_Ashtarak.dropna(inplace= True)
properties_Ashtarak
# Out:
#                               city                                 country  \
# 1    Ashtarak Aragatsotn Province   Ashtarak, Aragatsotn Province, Armenia
# 2      Tegher Aragatsotn Province     Tegher, Aragatsotn Province, Armenia
# 3     Baghramyan Armavir Province    Baghramyan, Armavir Province, Armenia
# 4    Ashtarak Aragatsotn Province   Ashtarak, Aragatsotn Province, Armenia
# 5    Ashtarak Aragatsotn Province   Ashtarak, Aragatsotn Province, Armenia
# ..                             ...                                     ...
# 294        Kotayk Kotayk Province         Kotayk, Kotayk Province, Armenia
# 295                       Yerevan                         Yerevan, Armenia
# 296          Vagharshapat Armavir           Vagharshapat, Armavir, Armenia
# 297                       Yerevan                         Yerevan, Armenia
# 298                       Yerevan                         Yerevan, Armenia
#
#                                                   name  \
# ...

# %%
c_l = []    
for k in properties_Ashtarak["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
properties_Ashtarak["city"]= c_l
properties_Ashtarak
# Out:
#              city                                 country  \
# 1        Ashtarak  Ashtarak, Aragatsotn Province, Armenia
# 2          Tegher    Tegher, Aragatsotn Province, Armenia
# 3      Baghramyan   Baghramyan, Armavir Province, Armenia
# 4        Ashtarak  Ashtarak, Aragatsotn Province, Armenia
# 5        Ashtarak  Ashtarak, Aragatsotn Province, Armenia
# ..            ...                                     ...
# 294        Kotayk        Kotayk, Kotayk Province, Armenia
# 295       Yerevan                        Yerevan, Armenia
# 296  Vagharshapat          Vagharshapat, Armavir, Armenia
# 297       Yerevan                        Yerevan, Armenia
# 298       Yerevan                        Yerevan, Armenia
#
#                                                   name  \
# 1                                   Beautiful Ashtarak
# 2                   Гостьевой домик в горах села Тегер
# 3    Green paradise near Yerevan,free transfer,SIM ...
# ...

# %%
country_list = []
for i in properties_Ashtarak.index:
    text = re.search("Armenia", properties_Ashtarak["country"][i]).group(0)
    country_list.append(text)

properties_Ashtarak["country"] = country_list

# %%
properties_Ashtarak.to_excel("safas.xlsx", index=False)

# %%
property_list = []
for i in properties_Ashtarak.index:
    tex= re.sub("\n", " ",properties_Ashtarak["properties"][i].split("Not included")[0])
    property_list.append(tex)
property_list
# Out:
# ['What this place offers Bedroom and laundry Washer Essentials Towels, bed sheets, soap, and toilet paper Hangers Entertainment TV Suitable for events The listing can accommodate a gathering of 25 or more attendees Internet and office Wifi Available throughout the listing Kitchen and dining Kitchen Space where guests can cook their own meals ',
# ...

# %%
properties_Ashtarak["properties"] = property_list

# %%
for i in properties_Ashtarak.index:
    if "Air conditioning" in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Air conditioning'] = 1
    else:
        properties_Ashtarak.loc[i, 'Air conditioning'] = 0

# %%
for i in properties_Ashtarak.index:
    if "BBQ grill" in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'BBQ grill'] = 1
    else:
        properties_Ashtarak.loc[i, 'BBQ grill'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Baby safety gates' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Baby safety gates'] = 1
    else:
        properties_Ashtarak.loc[i, 'Baby safety gates'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Backyard' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Backyard'] = 1
    else:
        properties_Ashtarak.loc[i, 'Backyard'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Baking sheet' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Baking sheet'] = 1
    else:
        properties_Ashtarak.loc[i, 'Baking sheet'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Bathtub' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Bathtub'] = 1
    else:
        properties_Ashtarak.loc[i, 'Bathtub'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Bed linens' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Bed linens'] = 1
    else:
        properties_Ashtarak.loc[i, 'Bed linens'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Bidet' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Bidet'] = 1
    else:
        properties_Ashtarak.loc[i, 'Bidet'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Body soap' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Body soap'] = 1
    else:
        properties_Ashtarak.loc[i, 'Body soap'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Books and reading material' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Books and reading material'] = 1
    else:
        properties_Ashtarak.loc[i, 'Books and reading material'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Breakfast' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Breakfast'] = 1
    else:
        properties_Ashtarak.loc[i, 'Breakfast'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Carbon monoxide alarm' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Carbon monoxide alarm'] = 1
    else:
        properties_Ashtarak.loc[i, 'Carbon monoxide alarm'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Ceiling fan' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Ceiling fan'] = 1
    else:
        properties_Ashtarak.loc[i, 'Ceiling fan'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Central heating' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Central heating'] = 1
    else:
        properties_Ashtarak.loc[i, 'Central heating'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Children’s books and toys' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Children’s books and toys'] = 1
    else:
        properties_Ashtarak.loc[i, 'Children’s books and toys'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Cleaning products' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Cleaning products'] = 1
    else:
        properties_Ashtarak.loc[i, 'Cleaning products'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Clothing storage' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Clothing storage'] = 1
    else:
        properties_Ashtarak.loc[i, 'Clothing storage'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Coffee' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Coffee'] = 1
    else:
        properties_Ashtarak.loc[i, 'Coffee'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Coffee maker' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Coffee maker'] = 1
    else:
        properties_Ashtarak.loc[i, 'Coffee maker'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Conditioner' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Conditioner'] = 1
    else:
        properties_Ashtarak.loc[i, 'Conditioner'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Cooking basics' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Cooking basics'] = 1
    else:
        properties_Ashtarak.loc[i, 'Cooking basics'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Crib' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Crib'] = 1
    else:
        properties_Ashtarak.loc[i, 'Crib'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Dedicated workspace' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Dedicated workspace'] = 1
    else:
        properties_Ashtarak.loc[i, 'Dedicated workspace'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Dining table' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Dining table'] = 1
    else:
        properties_Ashtarak.loc[i, 'Dining table'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Dishes and silverware' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Dishes and silverware'] = 1
    else:
        properties_Ashtarak.loc[i, 'Dishes and silverware'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Dishwasher' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Dishwasher'] = 1
    else:
        properties_Ashtarak.loc[i, 'Dishwasher'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Dryer' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Dryer'] = 1
    else:
        properties_Ashtarak.loc[i, 'Dryer'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Drying rack for clothing' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Drying rack for clothing'] = 1
    else:
        properties_Ashtarak.loc[i, 'Drying rack for clothing'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Elevator' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Elevator'] = 1
    else:
        properties_Ashtarak.loc[i, 'Elevator'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Essentials' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Essentials'] = 1
    else:
        properties_Ashtarak.loc[i, 'Essentials'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Ethernet connection' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Ethernet connection'] = 1
    else:
        properties_Ashtarak.loc[i, 'Ethernet connection'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Extra pillows and blankets' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Extra pillows and blankets'] = 1
    else:
        properties_Ashtarak.loc[i, 'Extra pillows and blankets'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Fire extinguisher' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Fire extinguisher'] = 1
    else:
        properties_Ashtarak.loc[i, 'Fire extinguisher'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'First aid kit' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'First aid kit'] = 1
    else:
        properties_Ashtarak.loc[i, 'First aid kit'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Free driveway parking on premises' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Free driveway parking on premises'] = 1
    else:
        properties_Ashtarak.loc[i, 'Free driveway parking on premises'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Free street parking' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Free street parking'] = 1
    else:
        properties_Ashtarak.loc[i, 'Free street parking'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Freezer' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Freezer'] = 1
    else:
        properties_Ashtarak.loc[i, 'Freezer'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'HDTV with Netflix, standard cable' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'HDTV with Netflix, standard cable'] = 1
    else:
        properties_Ashtarak.loc[i, 'HDTV with Netflix, standard cable'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Hair dryer' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Hair dryer'] = 1
    else:
        properties_Ashtarak.loc[i, 'Hair dryer'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Hangers' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Hangers'] = 1
    else:
        properties_Ashtarak.loc[i, 'Hangers'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Heating' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Heating'] = 1
    else:
        properties_Ashtarak.loc[i, 'Heating'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'High chair' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'High chair'] = 1
    else:
        properties_Ashtarak.loc[i, 'High chair'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Hot water' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Hot water'] = 1
    else:
        properties_Ashtarak.loc[i, 'Hot water'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Hot water kettle' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Hot water kettle'] = 1
    else:
        properties_Ashtarak.loc[i, 'Hot water kettle'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Indoor fireplace' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Indoor fireplace'] = 1
    else:
        properties_Ashtarak.loc[i, 'Indoor fireplace'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Iron' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Iron'] = 1
    else:
        properties_Ashtarak.loc[i, 'Iron'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Kitchen' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Kitchen'] = 1
    else:
        properties_Ashtarak.loc[i, 'Kitchen'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Laundromat nearby' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Laundromat nearby'] = 1
    else:
        properties_Ashtarak.loc[i, 'Laundromat nearby'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Lockbox' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Lockbox'] = 1
    else:
        properties_Ashtarak.loc[i, 'Lockbox'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Long term stays allowed' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Long term stays allowed'] = 1
    else:
        properties_Ashtarak.loc[i, 'Long term stays allowed'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Luggage dropoff allowed' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Luggage dropoff allowed'] = 1
    else:
        properties_Ashtarak.loc[i, 'Luggage dropoff allowed'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Microwave' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Microwave'] = 1
    else:
        properties_Ashtarak.loc[i, 'Microwave'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Mini fridge' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Mini fridge'] = 1
    else:
        properties_Ashtarak.loc[i, 'Mini fridge'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Mosquito net' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Mosquito net'] = 1
    else:
        properties_Ashtarak.loc[i, 'Mosquito net'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Outdoor furniture' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Outdoor furniture'] = 1
    else:
        properties_Ashtarak.loc[i, 'Outdoor furniture'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Outlet covers' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Outlet covers'] = 1
    else:
        properties_Ashtarak.loc[i, 'Outlet covers'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Oven' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Oven'] = 1
    else:
        properties_Ashtarak.loc[i, 'Oven'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Paid parking off premises' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Paid parking off premises'] = 1
    else:
        properties_Ashtarak.loc[i, 'Paid parking off premises'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Paid parking on premises' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Paid parking on premises'] = 1
    else:
        properties_Ashtarak.loc[i, 'Paid parking on premises'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Patio or balcony' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Patio or balcony'] = 1
    else:
        properties_Ashtarak.loc[i, 'Patio or balcony'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Portable fans' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Portable fans'] = 1
    else:
        properties_Ashtarak.loc[i, 'Portable fans'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Private entrance' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Private entrance'] = 1
    else:
        properties_Ashtarak.loc[i, 'Private entrance'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Radiant heating' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Radiant heating'] = 1
    else:
        properties_Ashtarak.loc[i, 'Radiant heating'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Refrigerator' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Refrigerator'] = 1
    else:
        properties_Ashtarak.loc[i, 'Refrigerator'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Room-darkening shades' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Room-darkening shades'] = 1
    else:
        properties_Ashtarak.loc[i, 'Room-darkening shades'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Security cameras on property' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Security cameras on property'] = 1
    else:
        properties_Ashtarak.loc[i, 'Security cameras on property'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Self check-in' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Self check-in'] = 1
    else:
        properties_Ashtarak.loc[i, 'Self check-in'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Shampoo' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Shampoo'] = 1
    else:
        properties_Ashtarak.loc[i, 'Shampoo'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Shower gel' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Shower gel'] = 1
    else:
        properties_Ashtarak.loc[i, 'Shower gel'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Single level home' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Single level home'] = 1
    else:
        properties_Ashtarak.loc[i, 'Single level home'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Smoke alarm' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Smoke alarm'] = 1
    else:
        properties_Ashtarak.loc[i, 'Smoke alarm'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Smoking allowed' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Smoking allowed'] = 1
    else:
        properties_Ashtarak.loc[i, 'Smoking allowed'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Sound system with aux' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Sound system with aux'] = 1
    else:
        properties_Ashtarak.loc[i, 'Sound system with aux'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Stove' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Stove'] = 1
    else:
        properties_Ashtarak.loc[i, 'Stove'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Suitable for events' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Suitable for events'] = 1
    else:
        properties_Ashtarak.loc[i, 'Suitable for events'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'TV' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'TV'] = 1
    else:
        properties_Ashtarak.loc[i, 'TV'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Trash compactor' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Trash compactor'] = 1
    else:
        properties_Ashtarak.loc[i, 'Trash compactor'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Washer' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Washer'] = 1
    else:
        properties_Ashtarak.loc[i, 'Washer'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Wifi' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Wifi'] = 1
    else:
        properties_Ashtarak.loc[i, 'Wifi'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'Wine glasses' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'Wine glasses'] = 1
    else:
        properties_Ashtarak.loc[i, 'Wine glasses'] = 0

# %%
for i in properties_Ashtarak.index:
    if 'geneva green conditioner' in  properties_Ashtarak.properties[i]:
        properties_Ashtarak.loc[i, 'geneva green conditioner'] = 1
    else:
        properties_Ashtarak.loc[i, 'geneva green conditioner'] = 0

# %%
del properties_Ashtarak['properties']

# %%
properties_Ashtarak
# Out:
#              city  country                                               name  \
# 1        Ashtarak  Armenia                                 Beautiful Ashtarak
# 2          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# 3      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 4        Ashtarak  Armenia        ECO-RESORT LORRET, LUX Green apartment-room
# 5        Ashtarak  Armenia                     Double Room in Ashtarak Garden
# ..            ...      ...                                                ...
# 294        Kotayk  Armenia                 Роскошная вилла на окраине Еревана
# 295       Yerevan  Armenia      Modern 2 Bed Apartment Flat in Garegin Nzhdeh
# 296  Vagharshapat  Armenia                   Room in the heart of UNESCO city
# 297       Yerevan  Armenia                                      GOOD HOLIDAYS
# 298       Yerevan  Armenia              ДОМ С ПРЕКРАСНЫМ ВИДОМ В город ЕРЕВАН
#
# ...

# %%
properties_Ashtarak.to_csv("Cleaned_Ashtarak_properties.csv", index=False)
properties_Ashtarak.to_excel("Cleaned_Ashtarak_properties.xlsx", index=False)
