# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import re
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")
import regex

# %% [markdown]
# # **Reading data**

# %%
properties_Charentsavan = pd.read_csv('properties_Charentsavan.csv')
properties_Charentsavan
# Out:
#                                      city  \
# 0                                     NaN
# 1     Nor Geghi, Kotayk Province, Armenia
# 2                                 Armenia
# 3       Arzakan, Kotayk Province, Armenia
# 4     Karashamb, Kotayk Province, Armenia
# 5          Bjni, Kotayk Province, Armenia
# 6         Argel, Kotayk Province, Armenia
# 7                 Fantan, Kotayk, Armenia
# 8        Jraber, Kotayk Province, Armenia
# 9     Karashamb, Kotayk Province, Armenia
# 10    Karashamb, Kotayk Province, Armenia
# 11      Arzakan, Kotayk Province, Armenia
# 12    Nor Geghi, Kotayk Province, Armenia
# 13     Aghveran, Kotayk Province, Armenia
# 14         Bjni, Kotayk Province, Armenia
# 15                                Armenia
# 16        Argel, Kotayk Province, Armenia
# 17      Arzakan, Kotayk Province, Armenia
# 18    Karashamb, Kotayk Province, Armenia
# 19               Арзакан, Котаик, Armenia
# 20         Bjni, Kotayk Province, Armenia
# ...

# %%
properties_Charentsavan = properties_Charentsavan.drop(labels = 0, axis = 0)
properties_Charentsavan
# Out:
#                                      city  \
# 1     Nor Geghi, Kotayk Province, Armenia
# 2                                 Armenia
# 3       Arzakan, Kotayk Province, Armenia
# 4     Karashamb, Kotayk Province, Armenia
# 5          Bjni, Kotayk Province, Armenia
# 6         Argel, Kotayk Province, Armenia
# 7                 Fantan, Kotayk, Armenia
# 8        Jraber, Kotayk Province, Armenia
# 9     Karashamb, Kotayk Province, Armenia
# 10    Karashamb, Kotayk Province, Armenia
# 11      Arzakan, Kotayk Province, Armenia
# 12    Nor Geghi, Kotayk Province, Armenia
# 13     Aghveran, Kotayk Province, Armenia
# 14         Bjni, Kotayk Province, Armenia
# 15                                Armenia
# 16        Argel, Kotayk Province, Armenia
# 17      Arzakan, Kotayk Province, Armenia
# 18    Karashamb, Kotayk Province, Armenia
# 19               Арзакан, Котаик, Armenia
# 20         Bjni, Kotayk Province, Armenia
# 21               Арзакан, Котаик, Armenia
# ...

# %%
city_list = []
for i in properties_Charentsavan.index:
    text = re.sub(",", "", properties_Charentsavan["city"][i][:properties_Charentsavan["city"][i].index("Armenia")])
    city_list.append(text)
properties_Charentsavan["city"]= city_list
properties_Charentsavan["city"]
# Out:
# 1       Nor Geghi Kotayk Province
# 2
# 3         Arzakan Kotayk Province
# 4       Karashamb Kotayk Province
# 5            Bjni Kotayk Province
# 6           Argel Kotayk Province
# 7                   Fantan Kotayk
# 8          Jraber Kotayk Province
# 9       Karashamb Kotayk Province
# 10      Karashamb Kotayk Province
# 11        Arzakan Kotayk Province
# 12      Nor Geghi Kotayk Province
# 13       Aghveran Kotayk Province
# 14           Bjni Kotayk Province
# 15
# 16          Argel Kotayk Province
# 17        Arzakan Kotayk Province
# 18      Karashamb Kotayk Province
# 19                 Арзакан Котаик
# 20           Bjni Kotayk Province
# 21                 Арзакан Котаик
# 22        Abovyan Kotayk Province
# 23
# 24        Abovyan Kotayk Province
# 25    Byureghavan Kotayk Province
# 26        Abovyan Kotayk Province
# 27      Karashamb Kotayk Province
# 28       Armavir Armavir Province
# Name: city, dtype: object

# %%
nan_value = float("Nan")
properties_Charentsavan.replace("", nan_value, inplace = True)
properties_Charentsavan.dropna(inplace= True)
properties_Charentsavan
# Out:
#                             city                                country  \
# 1     Nor Geghi Kotayk Province     Nor Geghi, Kotayk Province, Armenia
# 3       Arzakan Kotayk Province       Arzakan, Kotayk Province, Armenia
# 4     Karashamb Kotayk Province     Karashamb, Kotayk Province, Armenia
# 5          Bjni Kotayk Province          Bjni, Kotayk Province, Armenia
# 6         Argel Kotayk Province         Argel, Kotayk Province, Armenia
# 7                 Fantan Kotayk                 Fantan, Kotayk, Armenia
# 8        Jraber Kotayk Province        Jraber, Kotayk Province, Armenia
# 9     Karashamb Kotayk Province     Karashamb, Kotayk Province, Armenia
# 10    Karashamb Kotayk Province     Karashamb, Kotayk Province, Armenia
# 11      Arzakan Kotayk Province       Arzakan, Kotayk Province, Armenia
# 12    Nor Geghi Kotayk Province     Nor Geghi, Kotayk Province, Armenia
# 13     Aghveran Kotayk Province      Aghveran, Kotayk Province, Armenia
# ...

# %%
properties_Charentsavan["city"]= properties_Charentsavan["city"].replace({"Арзакан Котаик" : "Arzakan, Armenia"})

# %%
c_l = []    
for k in properties_Charentsavan["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
properties_Charentsavan["city"]= c_l
properties_Charentsavan
# Out:
#            city                                country  \
# 1           Nor    Nor Geghi, Kotayk Province, Armenia
# 3       Arzakan      Arzakan, Kotayk Province, Armenia
# 4     Karashamb    Karashamb, Kotayk Province, Armenia
# 5          Bjni         Bjni, Kotayk Province, Armenia
# 6         Argel        Argel, Kotayk Province, Armenia
# 7        Fantan                Fantan, Kotayk, Armenia
# 8        Jraber       Jraber, Kotayk Province, Armenia
# 9     Karashamb    Karashamb, Kotayk Province, Armenia
# 10    Karashamb    Karashamb, Kotayk Province, Armenia
# 11      Arzakan      Arzakan, Kotayk Province, Armenia
# 12          Nor    Nor Geghi, Kotayk Province, Armenia
# 13     Aghveran     Aghveran, Kotayk Province, Armenia
# 14         Bjni         Bjni, Kotayk Province, Armenia
# 16        Argel        Argel, Kotayk Province, Armenia
# 17      Arzakan      Arzakan, Kotayk Province, Armenia
# 18    Karashamb    Karashamb, Kotayk Province, Armenia
# ...

# %%
properties_Charentsavan["city"]= properties_Charentsavan["city"].replace({"Nor" : "Nor Geghi"})

# %%
properties_Charentsavan
# Out:
#            city                                country  \
# 1     Nor Geghi    Nor Geghi, Kotayk Province, Armenia
# 3       Arzakan      Arzakan, Kotayk Province, Armenia
# 4     Karashamb    Karashamb, Kotayk Province, Armenia
# 5          Bjni         Bjni, Kotayk Province, Armenia
# 6         Argel        Argel, Kotayk Province, Armenia
# 7        Fantan                Fantan, Kotayk, Armenia
# 8        Jraber       Jraber, Kotayk Province, Armenia
# 9     Karashamb    Karashamb, Kotayk Province, Armenia
# 10    Karashamb    Karashamb, Kotayk Province, Armenia
# 11      Arzakan      Arzakan, Kotayk Province, Armenia
# 12    Nor Geghi    Nor Geghi, Kotayk Province, Armenia
# 13     Aghveran     Aghveran, Kotayk Province, Armenia
# 14         Bjni         Bjni, Kotayk Province, Armenia
# 16        Argel        Argel, Kotayk Province, Armenia
# 17      Arzakan      Arzakan, Kotayk Province, Armenia
# 18    Karashamb    Karashamb, Kotayk Province, Armenia
# ...

# %%
country_list = []
for i in properties_Charentsavan.index:
    text = re.findall("Armenia", properties_Charentsavan["country"][i])
    country_list.append(text)
country_list = [item for sublist in country_list for item in sublist]
properties_Charentsavan["country"] = country_list

# %%
property_list = []
for i in properties_Charentsavan.index:
    tex= re.sub("\n", " ",properties_Charentsavan["properties"][i].split("Not included")[0])
    property_list.append(tex)
property_list
# Out:
# ["What this place offers Bathroom Hair dryer Shampoo Hot water Bedroom and laundry Washer Essentials Towels, bed sheets, soap, and toilet paper Hangers Iron Entertainment TV Suitable for events The listing can accommodate a gathering of 25 or more attendees Family Pack ’n Play/travel crib Children’s books and toys Heating and cooling Indoor fireplace Heating Home safety Smoke alarm Carbon monoxide alarm Fire extinguisher First aid kit Internet and office Wifi Available throughout the listing Dedicated workspace Kitchen and dining Kitchen Space where guests can cook their own meals Refrigerator Cooking basics Pots and pans, oil, salt and pepper Dishes and silverware Stove Oven Location features Private entrance Separate street or building entrance Outdoor Patio or balcony Backyard An open space on the property usually covered in grass Fire pit Outdoor furniture BBQ grill Parking and facilities Free parking on premises Free street parking Services Pets allowed Assistance animals are al
# ...

# %%
properties_Charentsavan["properties"] = property_list

# %%
for i in properties_Charentsavan.index:
    if "Air conditioning" in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Air conditioning'] = 1
    else:
        properties_Charentsavan.loc[i, 'Air conditioning'] = 0

# %%
for i in properties_Charentsavan.index:
    if "BBQ grill" in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'BBQ grill'] = 1
    else:
        properties_Charentsavan.loc[i, 'BBQ grill'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Baby safety gates' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Baby safety gates'] = 1
    else:
        properties_Charentsavan.loc[i, 'Baby safety gates'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Backyard' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Backyard'] = 1
    else:
        properties_Charentsavan.loc[i, 'Backyard'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Baking sheet' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Baking sheet'] = 1
    else:
        properties_Charentsavan.loc[i, 'Baking sheet'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Bathtub' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Bathtub'] = 1
    else:
        properties_Charentsavan.loc[i, 'Bathtub'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Bed linens' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Bed linens'] = 1
    else:
        properties_Charentsavan.loc[i, 'Bed linens'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Bidet' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Bidet'] = 1
    else:
        properties_Charentsavan.loc[i, 'Bidet'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Body soap' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Body soap'] = 1
    else:
        properties_Charentsavan.loc[i, 'Body soap'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Books and reading material' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Books and reading material'] = 1
    else:
        properties_Charentsavan.loc[i, 'Books and reading material'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Breakfast' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Breakfast'] = 1
    else:
        properties_Charentsavan.loc[i, 'Breakfast'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Carbon monoxide alarm' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Carbon monoxide alarm'] = 1
    else:
        properties_Charentsavan.loc[i, 'Carbon monoxide alarm'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Ceiling fan' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Ceiling fan'] = 1
    else:
        properties_Charentsavan.loc[i, 'Ceiling fan'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Central heating' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Central heating'] = 1
    else:
        properties_Charentsavan.loc[i, 'Central heating'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Children’s books and toys' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Children’s books and toys'] = 1
    else:
        properties_Charentsavan.loc[i, 'Children’s books and toys'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Cleaning products' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Cleaning products'] = 1
    else:
        properties_Charentsavan.loc[i, 'Cleaning products'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Clothing storage' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Clothing storage'] = 1
    else:
        properties_Charentsavan.loc[i, 'Clothing storage'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Coffee' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Coffee'] = 1
    else:
        properties_Charentsavan.loc[i, 'Coffee'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Coffee maker' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Coffee maker'] = 1
    else:
        properties_Charentsavan.loc[i, 'Coffee maker'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Conditioner' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Conditioner'] = 1
    else:
        properties_Charentsavan.loc[i, 'Conditioner'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Cooking basics' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Cooking basics'] = 1
    else:
        properties_Charentsavan.loc[i, 'Cooking basics'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Crib' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Crib'] = 1
    else:
        properties_Charentsavan.loc[i, 'Crib'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Dedicated workspace' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Dedicated workspace'] = 1
    else:
        properties_Charentsavan.loc[i, 'Dedicated workspace'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Dining table' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Dining table'] = 1
    else:
        properties_Charentsavan.loc[i, 'Dining table'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Dishes and silverware' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Dishes and silverware'] = 1
    else:
        properties_Charentsavan.loc[i, 'Dishes and silverware'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Dishwasher' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Dishwasher'] = 1
    else:
        properties_Charentsavan.loc[i, 'Dishwasher'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Dryer' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Dryer'] = 1
    else:
        properties_Charentsavan.loc[i, 'Dryer'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Drying rack for clothing' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Drying rack for clothing'] = 1
    else:
        properties_Charentsavan.loc[i, 'Drying rack for clothing'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Elevator' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Elevator'] = 1
    else:
        properties_Charentsavan.loc[i, 'Elevator'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Essentials' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Essentials'] = 1
    else:
        properties_Charentsavan.loc[i, 'Essentials'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Ethernet connection' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Ethernet connection'] = 1
    else:
        properties_Charentsavan.loc[i, 'Ethernet connection'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Extra pillows and blankets' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Extra pillows and blankets'] = 1
    else:
        properties_Charentsavan.loc[i, 'Extra pillows and blankets'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Fire extinguisher' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Fire extinguisher'] = 1
    else:
        properties_Charentsavan.loc[i, 'Fire extinguisher'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'First aid kit' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'First aid kit'] = 1
    else:
        properties_Charentsavan.loc[i, 'First aid kit'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Free driveway parking on premises' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Free driveway parking on premises'] = 1
    else:
        properties_Charentsavan.loc[i, 'Free driveway parking on premises'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Free street parking' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Free street parking'] = 1
    else:
        properties_Charentsavan.loc[i, 'Free street parking'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Freezer' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Freezer'] = 1
    else:
        properties_Charentsavan.loc[i, 'Freezer'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'HDTV with Netflix, standard cable' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'HDTV with Netflix, standard cable'] = 1
    else:
        properties_Charentsavan.loc[i, 'HDTV with Netflix, standard cable'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Hair dryer' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Hair dryer'] = 1
    else:
        properties_Charentsavan.loc[i, 'Hair dryer'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Hangers' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Hangers'] = 1
    else:
        properties_Charentsavan.loc[i, 'Hangers'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Heating' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Heating'] = 1
    else:
        properties_Charentsavan.loc[i, 'Heating'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'High chair' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'High chair'] = 1
    else:
        properties_Charentsavan.loc[i, 'High chair'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Hot water' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Hot water'] = 1
    else:
        properties_Charentsavan.loc[i, 'Hot water'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Hot water kettle' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Hot water kettle'] = 1
    else:
        properties_Charentsavan.loc[i, 'Hot water kettle'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Indoor fireplace' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Indoor fireplace'] = 1
    else:
        properties_Charentsavan.loc[i, 'Indoor fireplace'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Iron' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Iron'] = 1
    else:
        properties_Charentsavan.loc[i, 'Iron'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Kitchen' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Kitchen'] = 1
    else:
        properties_Charentsavan.loc[i, 'Kitchen'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Laundromat nearby' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Laundromat nearby'] = 1
    else:
        properties_Charentsavan.loc[i, 'Laundromat nearby'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Lockbox' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Lockbox'] = 1
    else:
        properties_Charentsavan.loc[i, 'Lockbox'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Long term stays allowed' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Long term stays allowed'] = 1
    else:
        properties_Charentsavan.loc[i, 'Long term stays allowed'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Luggage dropoff allowed' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Luggage dropoff allowed'] = 1
    else:
        properties_Charentsavan.loc[i, 'Luggage dropoff allowed'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Microwave' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Microwave'] = 1
    else:
        properties_Charentsavan.loc[i, 'Microwave'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Mini fridge' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Mini fridge'] = 1
    else:
        properties_Charentsavan.loc[i, 'Mini fridge'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Mosquito net' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Mosquito net'] = 1
    else:
        properties_Charentsavan.loc[i, 'Mosquito net'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Outdoor furniture' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Outdoor furniture'] = 1
    else:
        properties_Charentsavan.loc[i, 'Outdoor furniture'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Outlet covers' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Outlet covers'] = 1
    else:
        properties_Charentsavan.loc[i, 'Outlet covers'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Oven' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Oven'] = 1
    else:
        properties_Charentsavan.loc[i, 'Oven'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Paid parking off premises' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Paid parking off premises'] = 1
    else:
        properties_Charentsavan.loc[i, 'Paid parking off premises'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Paid parking on premises' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Paid parking on premises'] = 1
    else:
        properties_Charentsavan.loc[i, 'Paid parking on premises'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Patio or balcony' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Patio or balcony'] = 1
    else:
        properties_Charentsavan.loc[i, 'Patio or balcony'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Portable fans' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Portable fans'] = 1
    else:
        properties_Charentsavan.loc[i, 'Portable fans'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Private entrance' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Private entrance'] = 1
    else:
        properties_Charentsavan.loc[i, 'Private entrance'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Radiant heating' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Radiant heating'] = 1
    else:
        properties_Charentsavan.loc[i, 'Radiant heating'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Refrigerator' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Refrigerator'] = 1
    else:
        properties_Charentsavan.loc[i, 'Refrigerator'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Room-darkening shades' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Room-darkening shades'] = 1
    else:
        properties_Charentsavan.loc[i, 'Room-darkening shades'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Security cameras on property' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Security cameras on property'] = 1
    else:
        properties_Charentsavan.loc[i, 'Security cameras on property'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Self check-in' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Self check-in'] = 1
    else:
        properties_Charentsavan.loc[i, 'Self check-in'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Shampoo' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Shampoo'] = 1
    else:
        properties_Charentsavan.loc[i, 'Shampoo'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Shower gel' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Shower gel'] = 1
    else:
        properties_Charentsavan.loc[i, 'Shower gel'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Single level home' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Single level home'] = 1
    else:
        properties_Charentsavan.loc[i, 'Single level home'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Smoke alarm' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Smoke alarm'] = 1
    else:
        properties_Charentsavan.loc[i, 'Smoke alarm'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Smoking allowed' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Smoking allowed'] = 1
    else:
        properties_Charentsavan.loc[i, 'Smoking allowed'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Sound system with aux' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Sound system with aux'] = 1
    else:
        properties_Charentsavan.loc[i, 'Sound system with aux'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Stove' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Stove'] = 1
    else:
        properties_Charentsavan.loc[i, 'Stove'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Suitable for events' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Suitable for events'] = 1
    else:
        properties_Charentsavan.loc[i, 'Suitable for events'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'TV' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'TV'] = 1
    else:
        properties_Charentsavan.loc[i, 'TV'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Trash compactor' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Trash compactor'] = 1
    else:
        properties_Charentsavan.loc[i, 'Trash compactor'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Washer' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Washer'] = 1
    else:
        properties_Charentsavan.loc[i, 'Washer'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Wifi' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Wifi'] = 1
    else:
        properties_Charentsavan.loc[i, 'Wifi'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'Wine glasses' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'Wine glasses'] = 1
    else:
        properties_Charentsavan.loc[i, 'Wine glasses'] = 0

# %%
for i in properties_Charentsavan.index:
    if 'geneva green conditioner' in  properties_Charentsavan.properties[i]:
        properties_Charentsavan.loc[i, 'geneva green conditioner'] = 1
    else:
        properties_Charentsavan.loc[i, 'geneva green conditioner'] = 0

# %%
del properties_Charentsavan['properties']

# %%
properties_Charentsavan
# Out:
#            city  country                                               name  \
# 1     Nor Geghi  Armenia                         House in Armenia, Lusakert
# 3       Arzakan  Armenia                                       Փայտյա Օազիս
# 4     Karashamb  Armenia  Villa Stefania (good balance of price and comf...
# 5          Bjni  Armenia     Bjnihouse B&B; Բջնիհաուզ ընտանեկան հյուրատուն,
# 6         Argel  Armenia                    House on the edge of the canyon
# 7        Fantan  Armenia                    Fantan Farms - Organic Farmstay
# 8        Jraber  Armenia                     Peaceful getaway in the nature
# 9     Karashamb  Armenia                                          Eco house
# 10    Karashamb  Armenia                         Pool and BBQ in cozy place
# 11      Arzakan  Armenia                                   Lyon Guest House
# 12    Nor Geghi  Armenia                      Village in Armenia, Nor Geghi
# ...

# %%
properties_Charentsavan.to_csv("Cleaned_Charentsavan_properties.csv", index=False)
properties_Charentsavan.to_excel("Cleaned_Charentsavan_properties.xlsx", index=False)
