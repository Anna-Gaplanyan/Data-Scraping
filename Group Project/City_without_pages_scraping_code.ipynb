# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import re
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %%
options = Options()
options.headlesse = True
options.add_argument("start-normal")
driver = webdriver.Chrome(options=options, executable_path=r"C:\Users\User\Downloads\chromedriver.exe")
driver.get('provide the city link on Airbnb website')

# %%
SLEEP = 7
 

data_hotel = pd.DataFrame({'city':[""], 'country':[""],'name':[""], 'host_since':[""], 'host_response_rate':[""], 'host_identity_verified':[""], 
                           'review':[""], 'superhost':[""],
                           'property_type':[""], 'accomodates':[""], 'number_bathroom':[""], 'number_bedroom':[""], 
                         'number_beds':[""], 'rating':[""], 'price':[""], 'cleanliness':[""], 'accuracy':[""], 'communication':[""], 
                           'location':[""], 'check_in':[""], 'value':[""]})
links = driver.find_elements_by_class_name('_8s3ctt')
time.sleep(1)
for i in links:
    i.click()
    time.sleep(15)
    driver.switch_to_window(driver.window_handles[1]);
    some_element = driver.find_element_by_tag_name("html")
    some_element.send_keys(Keys.END)
    time.sleep(SLEEP)
    try:
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('_pbq7fmm')).perform()
        time.sleep(1)
        city = driver.find_element_by_class_name('_pbq7fmm').text
        country = driver.find_element_by_class_name('_pbq7fmm').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('_1n81at5')).perform()
        time.sleep(1)
        name = driver.find_element_by_class_name('_1n81at5').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('ciubx2o')).perform()
        time.sleep(1)
        cleanliness = driver.find_element_by_class_name('ciubx2o').text
        accuracy = driver.find_element_by_class_name('ciubx2o').text
        communication = driver.find_element_by_class_name('ciubx2o').text
        location = driver.find_element_by_class_name('ciubx2o').text
        check_in = driver.find_element_by_class_name('ciubx2o').text
        value = driver.find_element_by_class_name('ciubx2o').text
        time.sleep(1)
        ActionChains(driver).move_to_element(driver.find_element_by_xpath('/html/body/div[5]/div/div[1]/div/div/div/div/div/div[1]/main/div/div[1]/div[4]/div/div/div/div[2]/div[1]/div/section/h2')).perform()
        time.sleep(1)
        if driver.find_element_by_xpath('/html/body/div[5]/div/div[1]/div/div/div/div/div/div[1]/main/div/div[1]/div[4]/div/div/div/div[2]/div[1]/div/section/h2').text == 'No reviews (yet)':
            ratings = 'No reviews (yet)' 
        else: 
            ActionChains(driver).move_to_element(driver.find_element_by_class_name('_1ne5r4rt')).perform()
            ratings = driver.find_element_by_class_name('_1ne5r4rt').text
            
        
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('s9fngse')).perform()
        time.sleep(1)
        host_since = driver.find_element_by_class_name('s9fngse').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('fhhmddr')).perform()
        time.sleep(1)
        host_response_rate = driver.find_element_by_class_name('fhhmddr').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('tq6hspd')).perform()
        time.sleep(1)
        Host_identity_verified = driver.find_element_by_class_name('tq6hspd').text.split('\n')
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('tq6hspd')).perform()
        time.sleep(1)
        review = driver.find_element_by_class_name('tq6hspd').text.split('\n')
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('tq6hspd')).perform()
        time.sleep(1)
        superhost = driver.find_element_by_class_name('tq6hspd').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('_xcsyj0')).perform()
        time.sleep(1)
        Property_type = driver.find_element_by_class_name('_xcsyj0').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('_tqmy57')).perform()
        time.sleep(1)
        Accomodates = driver.find_element_by_class_name('_tqmy57').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('_tqmy57')).perform()
        time.sleep(1)
        number_bathroom = driver.find_element_by_class_name('_tqmy57').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('_tqmy57')).perform()
        time.sleep(1)
        number_bedroom = driver.find_element_by_class_name('_tqmy57').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('_tqmy57')).perform()
        time.sleep(1)
        number_beds = driver.find_element_by_class_name('_tqmy57').text
        ActionChains(driver).move_to_element(driver.find_element_by_class_name('_1i2pljeb')).perform()
        time.sleep(1)
        price = driver.find_element_by_class_name('_1i2pljeb').text
        data_hotel = data_hotel.append({'city':city, 'country': country, 'name': name, 'host_since': host_since, 'host_response_rate': host_response_rate, 
                                        'host_identity_verified': Host_identity_verified, 'review': review, 'superhost': superhost,
                                        'property_type': Property_type, 'accomodates': Accomodates, 
                                        'number_bathroom': number_bathroom, 'number_bedroom': number_bedroom, 
                                        'number_beds': number_beds,'rating': ratings,  'price': price,
                                        'cleanliness': cleanliness, 'accuracy': accuracy, 'communication': communication, 
                           'location': location, 'check_in': check_in, 'value': value}, ignore_index=True)
    except:
        pass
        
        
    window_name = driver.window_handles[1]
    driver.switch_to_window(window_name = window_name)
    driver.close()
    driver.switch_to_window(driver.window_handles[0]);
    time.sleep(3)
    
data_hotel.to_excel("hotel_full_write the city name.xlsx", index = False)
data_hotel.to_csv("hotel_full_write the city name.csv", index = False)
