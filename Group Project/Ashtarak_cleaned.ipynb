# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Ashtarak = pd.read_csv('hotel_full_Ashtarak.csv')
hotel_full_Ashtarak
# Out:
#                                        city  \
# 0                                       NaN
# 1    Ashtarak, Aragatsotn Province, Armenia
# 2      Tegher, Aragatsotn Province, Armenia
# 3    Ashtarak, Aragatsotn Province, Armenia
# 4     Baghramyan, Armavir Province, Armenia
# ..                                      ...
# 293                        Yerevan, Armenia
# 294                        Yerevan, Armenia
# 295                        Yerevan, Armenia
# 296                        Yerevan, Armenia
# 297                Ереван, Кентрон, Armenia
#
#                                     country  \
# 0                                       NaN
# 1    Ashtarak, Aragatsotn Province, Armenia
# 2      Tegher, Aragatsotn Province, Armenia
# 3    Ashtarak, Aragatsotn Province, Armenia
# 4     Baghramyan, Armavir Province, Armenia
# ..                                      ...
# 293                        Yerevan, Armenia
# 294                        Yerevan, Armenia
# ...

# %%
hotel_full_Ashtarak = hotel_full_Ashtarak.drop(labels = 0, axis = 0)
hotel_full_Ashtarak
# Out:
#                                        city  \
# 1    Ashtarak, Aragatsotn Province, Armenia
# 2      Tegher, Aragatsotn Province, Armenia
# 3    Ashtarak, Aragatsotn Province, Armenia
# 4     Baghramyan, Armavir Province, Armenia
# 5    Ashtarak, Aragatsotn Province, Armenia
# ..                                      ...
# 293                        Yerevan, Armenia
# 294                        Yerevan, Armenia
# 295                        Yerevan, Armenia
# 296                        Yerevan, Armenia
# 297                Ереван, Кентрон, Armenia
#
#                                     country  \
# 1    Ashtarak, Aragatsotn Province, Armenia
# 2      Tegher, Aragatsotn Province, Armenia
# 3    Ashtarak, Aragatsotn Province, Armenia
# 4     Baghramyan, Armavir Province, Armenia
# 5    Ashtarak, Aragatsotn Province, Armenia
# ..                                      ...
# 293                        Yerevan, Armenia
# 294                        Yerevan, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Ashtarak.replace("", nan_value, inplace = True)
hotel_full_Ashtarak.dropna(inplace= True)
hotel_full_Ashtarak
# Out:
#                                         city  \
# 1     Ashtarak, Aragatsotn Province, Armenia
# 2       Tegher, Aragatsotn Province, Armenia
# 3     Ashtarak, Aragatsotn Province, Armenia
# 4      Baghramyan, Armavir Province, Armenia
# 7    Vagharshapat, Armavir Province, Armenia
# ..                                       ...
# 266                         Yerevan, Armenia
# 268                         Yerevan, Armenia
# 271                           Երևան, Armenia
# 285                         Yerevan, Armenia
# 293                         Yerevan, Armenia
#
#                                      country  \
# 1     Ashtarak, Aragatsotn Province, Armenia
# 2       Tegher, Aragatsotn Province, Armenia
# 3     Ashtarak, Aragatsotn Province, Armenia
# 4      Baghramyan, Armavir Province, Armenia
# 7    Vagharshapat, Armavir Province, Armenia
# ..                                       ...
# 266                         Yerevan, Armenia
# 268                         Yerevan, Armenia
# ...

# %%
hotel_full_Ashtarak["city"]= hotel_full_Ashtarak["city"].replace({"Երևան, Armenia" : "Yerevan, Armenia"})

# %%
hotel_full_Ashtarak["city"]= hotel_full_Ashtarak["city"].replace({"Երևան, Yerevan, Armenia" : "Yerevan, Armenia"})

# %%
hotel_full_Ashtarak["city"]= hotel_full_Ashtarak["city"].replace({"Ереван , Ереван, Armenia" : "Yerevan, Armenia"})

# %%
hotel_full_Ashtarak["city"]= hotel_full_Ashtarak["city"].replace({"Աջափնյակ, Երևան, Armenia" : "Yerevan, Armenia"})

# %%
hotel_full_Ashtarak["city"]= hotel_full_Ashtarak["city"].replace({"Երևան, Արմավիրի մարզ, Armenia" : "Yerevan, Armenia"})

# %%
hotel_full_Ashtarak["city"]= hotel_full_Ashtarak["city"].replace({"Ереван, Кентрон, Armenia" : "Yerevan, Armenia"})

# %%
city_list = []
for i in hotel_full_Ashtarak.index:
    text = re.sub(",", "", hotel_full_Ashtarak["city"][i][:hotel_full_Ashtarak["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Ashtarak["city"]= city_list
hotel_full_Ashtarak
# Out:
#                                city                                  country  \
# 1     Ashtarak Aragatsotn Province    Ashtarak, Aragatsotn Province, Armenia
# 2       Tegher Aragatsotn Province      Tegher, Aragatsotn Province, Armenia
# 3     Ashtarak Aragatsotn Province    Ashtarak, Aragatsotn Province, Armenia
# 4      Baghramyan Armavir Province     Baghramyan, Armavir Province, Armenia
# 7    Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# ..                              ...                                      ...
# 266                        Yerevan                          Yerevan, Armenia
# 268                        Yerevan                          Yerevan, Armenia
# 271                        Yerevan                            Երևան, Armenia
# 285                        Yerevan                          Yerevan, Armenia
# 293                        Yerevan                          Yerevan, Armenia
#
# ...

# %%
nan_value = float("Nan")
hotel_full_Ashtarak.replace("", nan_value, inplace = True)
hotel_full_Ashtarak.dropna(inplace= True)
hotel_full_Ashtarak
# Out:
#                                city                                  country  \
# 1     Ashtarak Aragatsotn Province    Ashtarak, Aragatsotn Province, Armenia
# 2       Tegher Aragatsotn Province      Tegher, Aragatsotn Province, Armenia
# 3     Ashtarak Aragatsotn Province    Ashtarak, Aragatsotn Province, Armenia
# 4      Baghramyan Armavir Province     Baghramyan, Armavir Province, Armenia
# 7    Vagharshapat Armavir Province   Vagharshapat, Armavir Province, Armenia
# ..                              ...                                      ...
# 266                        Yerevan                          Yerevan, Armenia
# 268                        Yerevan                          Yerevan, Armenia
# 271                        Yerevan                            Երևան, Armenia
# 285                        Yerevan                          Yerevan, Armenia
# 293                        Yerevan                          Yerevan, Armenia
#
# ...

# %%
c_l = []    
for k in hotel_full_Ashtarak["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Ashtarak["city"]= c_l
hotel_full_Ashtarak
# Out:
#              city                                  country  \
# 1        Ashtarak   Ashtarak, Aragatsotn Province, Armenia
# 2          Tegher     Tegher, Aragatsotn Province, Armenia
# 3        Ashtarak   Ashtarak, Aragatsotn Province, Armenia
# 4      Baghramyan    Baghramyan, Armavir Province, Armenia
# 7    Vagharshapat  Vagharshapat, Armavir Province, Armenia
# ..            ...                                      ...
# 266       Yerevan                         Yerevan, Armenia
# 268       Yerevan                         Yerevan, Armenia
# 271       Yerevan                           Երևան, Armenia
# 285       Yerevan                         Yerevan, Armenia
# 293       Yerevan                         Yerevan, Armenia
#
#                                                   name  \
# 1                                   Beautiful Ashtarak
# 2                   Гостьевой домик в горах села Тегер
# 3       The House with the Mezzanine - Дом с мезонином
# ...

# %%
country_list = []
for i in hotel_full_Ashtarak.index:
    text = re.search("Armenia", hotel_full_Ashtarak["country"][i]).group()
    country_list.append(text)

hotel_full_Ashtarak["country"] = country_list

# %%
hotel_full_Ashtarak
# Out:
#              city  country                                               name  \
# 1        Ashtarak  Armenia                                 Beautiful Ashtarak
# 2          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# 3        Ashtarak  Armenia     The House with the Mezzanine - Дом с мезонином
# 4      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 7    Vagharshapat  Armenia                                           Art home
# ..            ...      ...                                                ...
# 266       Yerevan  Armenia                                         Ara Hostel
# 268       Yerevan  Armenia                  Armenian Inn Hostel - Family Room
# 271       Yerevan  Armenia                                           Елитарка
# 285       Yerevan  Armenia  Armenian Inn Hostel - Bed in a dormitory male ...
# 293       Yerevan  Armenia                       Home where dreams come true)
#
#                    host_since  \
# ...

# %%
host_since_list = []
for i in hotel_full_Ashtarak.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Ashtarak.host_since = hs 
hotel_full_Ashtarak.host_since
# Out:
# 1      2020
# 2      2015
# 3      2017
# 4      2019
# 7      2019
#        ...
# 266    2019
# 268    2019
# 271    2018
# 285    2019
# 293    2017
# Name: host_since, Length: 117, dtype: int64

# %%
hotel_full_Ashtarak
# Out:
#              city  country                                               name  \
# 1        Ashtarak  Armenia                                 Beautiful Ashtarak
# 2          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# 3        Ashtarak  Armenia     The House with the Mezzanine - Дом с мезонином
# 4      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 7    Vagharshapat  Armenia                                           Art home
# ..            ...      ...                                                ...
# 266       Yerevan  Armenia                                         Ara Hostel
# 268       Yerevan  Armenia                  Armenian Inn Hostel - Family Room
# 271       Yerevan  Armenia                                           Елитарка
# 285       Yerevan  Armenia  Armenian Inn Hostel - Bed in a dormitory male ...
# 293       Yerevan  Armenia                       Home where dreams come true)
#
# ...

# %%
string = []
for i in hotel_full_Ashtarak.index:
    st = hotel_full_Ashtarak.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ['Identity verified',
#  '26 Reviews',
#  "5 Reviews', 'Identity verified', 'Airbnb.org supporter",
#  "13 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "6 Reviews', 'Identity verified",
#  '128 Reviews',
#  "395 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  '18 Reviews',
#  'Identity verified',
#  "39 Reviews', '\\U000f0003', 'Superhost",
#  "47 Reviews', 'Identity verified",
#  "8 Reviews', '\\U000f0003', 'Superhost",
#  "189 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "13 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "189 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "5 Reviews', 'Identity verified",
#  "11 Reviews', 'Identity verified",
#  "27 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "17 Reviews', 'Identity verified",
#  'Identity verified',
#  "7 Reviews', 'Identity verified",
#  "219 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
# ...

# %%
hotel_full_Ashtarak.host_identity_verified = string
hotel_full_Ashtarak.host_identity_verified
# Out:
# 1                                      Identity verified
# 2                                             26 Reviews
# 3      5 Reviews', 'Identity verified', 'Airbnb.org s...
# 4      13 Reviews', 'Identity verified', '\U000f0003'...
# 7                         6 Reviews', 'Identity verified
#                              ...
# 266                                    Identity verified
# 268                                    Identity verified
# 271                        1 Review', 'Identity verified
# 285                                    Identity verified
# 293                                            2 Reviews
# Name: host_identity_verified, Length: 117, dtype: object

# %%
for i in hotel_full_Ashtarak.index:
    if "Identity verified" in  hotel_full_Ashtarak.host_identity_verified[i]:
        hotel_full_Ashtarak.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Ashtarak.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Ashtarak
# Out:
#              city  country                                               name  \
# 1        Ashtarak  Armenia                                 Beautiful Ashtarak
# 2          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# 3        Ashtarak  Armenia     The House with the Mezzanine - Дом с мезонином
# 4      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 7    Vagharshapat  Armenia                                           Art home
# ..            ...      ...                                                ...
# 266       Yerevan  Armenia                                         Ara Hostel
# 268       Yerevan  Armenia                  Armenian Inn Hostel - Family Room
# 271       Yerevan  Armenia                                           Елитарка
# 285       Yerevan  Armenia  Armenian Inn Hostel - Bed in a dormitory male ...
# 293       Yerevan  Armenia                       Home where dreams come true)
#
# ...

# %%
for i in hotel_full_Ashtarak.index:
    if "Review" in  hotel_full_Ashtarak.review[i]:
        hotel_full_Ashtarak.loc[i, 'review'] = re.search("(\d+)", hotel_full_Ashtarak.review[i]).group()
        
    else:
        hotel_full_Ashtarak.loc[i, 'review'] = 0

# %%
hotel_full_Ashtarak
# Out:
#              city  country                                               name  \
# 1        Ashtarak  Armenia                                 Beautiful Ashtarak
# 2          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# 3        Ashtarak  Armenia     The House with the Mezzanine - Дом с мезонином
# 4      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 7    Vagharshapat  Armenia                                           Art home
# ..            ...      ...                                                ...
# 266       Yerevan  Armenia                                         Ara Hostel
# 268       Yerevan  Armenia                  Armenian Inn Hostel - Family Room
# 271       Yerevan  Armenia                                           Елитарка
# 285       Yerevan  Armenia  Armenian Inn Hostel - Bed in a dormitory male ...
# 293       Yerevan  Armenia                       Home where dreams come true)
#
# ...

# %%
for i in hotel_full_Ashtarak.index:
    if "Superhost" in  hotel_full_Ashtarak.superhost[i]:
        hotel_full_Ashtarak.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Ashtarak.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Ashtarak.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire rental unit',
#  'Entire guest suite',
#  'Private room in residential home',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire residential home  Apartment & Tours',
#  'Entire guesthouse',
#  'Entire rental unit',
#  'Private room in residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire condominium (condo)',
#  'Entire rental unit  Inn',
#  'Entire residential home',
#  'Entire rental unit  Inn',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire loft',
#  'Private room in residential home',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Private room in residential home',
#  'Entire residential home',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Private room in residential home',
#  'Entire chalet',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
# ...

# %%
hotel_full_Ashtarak.property_type =prop_list

# %%
hotel_full_Ashtarak
# Out:
#              city  country                                               name  \
# 1        Ashtarak  Armenia                                 Beautiful Ashtarak
# 2          Tegher  Armenia                 Гостьевой домик в горах села Тегер
# 3        Ashtarak  Armenia     The House with the Mezzanine - Дом с мезонином
# 4      Baghramyan  Armenia  Green paradise near Yerevan,free transfer,SIM ...
# 7    Vagharshapat  Armenia                                           Art home
# ..            ...      ...                                                ...
# 266       Yerevan  Armenia                                         Ara Hostel
# 268       Yerevan  Armenia                  Armenian Inn Hostel - Family Room
# 271       Yerevan  Armenia                                           Елитарка
# 285       Yerevan  Armenia  Armenian Inn Hostel - Bed in a dormitory male ...
# 293       Yerevan  Armenia                       Home where dreams come true)
#
# ...

# %%
accomodates_list = []
for i in hotel_full_Ashtarak.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Ashtarak.accomodates = number

# %%
for i in hotel_full_Ashtarak.index:
    if "Shared half-bath" in  hotel_full_Ashtarak.number_bathroom[i]:
        hotel_full_Ashtarak.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Ashtarak.number_bathroom[i]:
        hotel_full_Ashtarak.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Ashtarak.number_bathroom[i]:
        hotel_full_Ashtarak.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Ashtarak.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Ashtarak.number_bedroom[i])
        hotel_full_Ashtarak.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Ashtarak.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Ashtarak.number_bedroom[i])
        hotel_full_Ashtarak.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Ashtarak.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Ashtarak.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Ashtarak.index:
    if "bed" in  hotel_full_Ashtarak.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Ashtarak.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Ashtarak.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['2',
#  '2',
#  '4',
#  '3',
#  '2',
#  '6',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '4',
#  '2',
#  '2',
#  '1',
#  '3',
#  '2',
#  '2',
#  '2',
#  '4',
#  '3',
#  '2',
#  '2',
#  '5',
#  '2',
#  '3',
#  '0',
#  '5',
#  '1',
#  '4',
#  '2',
#  '2',
#  '2',
#  '1',
#  '3',
#  '2',
#  '1',
#  '2',
#  '7',
#  '3',
#  '3',
#  '6',
#  '1',
#  '1',
#  '3',
#  '0',
#  '5',
#  '1',
#  '15',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '3',
#  '3',
#  '1',
#  '1',
#  '2',
#  '0',
#  '1',
#  '2',
#  '3',
#  '1',
#  '1',
#  '1',
#  '7',
#  '1',
#  '1',
#  '3',
#  '2',
#  '5',
#  '2',
#  '3',
#  '3',
#  '1',
#  '1',
#  '1',
#  '2',
#  '2',
#  '1',
#  '4',
#  '3',
#  '1',
#  '2',
#  None,
#  '0',
#  '1',
#  '1',
#  '2',
#  '2',
#  '2',
#  '1',
#  '12',
#  '3',
#  '2',
#  '5',
#  '2',
#  '2',
#  '2',
#  None,
#  '1',
#  '2',
#  '4',
#  '2',
#  None,
#  '12',
#  '1',
#  '5',
#  '8',
#  '2',
#  '1',
#  None,
#  '2']

# %%
len(hotel_full_Ashtarak.number_beds)
# Out:
# 117

# %%
len(number_beds_list)
# Out:
# 117

# %%
hotel_full_Ashtarak.number_beds = number_beds_list

# %%
hotel_full_Ashtarak.number_beds
# Out:
# 1         2
# 2         2
# 3         4
# 4         3
# 7         2
#        ...
# 266       8
# 268       2
# 271       1
# 285    None
# 293       2
# Name: number_beds, Length: 117, dtype: object

# %%
for i in hotel_full_Ashtarak.index:
    if "Studio" in  hotel_full_Ashtarak.number_bedroom[i]:
        hotel_full_Ashtarak.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Ashtarak.number_bedroom[i])
        hotel_full_Ashtarak.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Ashtarak.index:
    if "Cleanliness" in  hotel_full_Ashtarak.cleanliness[i]:
        hotel_full_Ashtarak.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Ashtarak.cleanliness[i])
    else:
        hotel_full_Ashtarak.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Ashtarak.index:
    if "Accuracy" in  hotel_full_Ashtarak.accuracy[i]:
        hotel_full_Ashtarak.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Ashtarak.accuracy[i])
    else:
        hotel_full_Ashtarak.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Ashtarak.index:
    if "Communication" in  hotel_full_Ashtarak.communication[i]:
        hotel_full_Ashtarak.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Ashtarak.communication[i])
    else:
        hotel_full_Ashtarak.loc[i, 'communication'] = None

# %%
for i in hotel_full_Ashtarak.index:
    if "Location" in  hotel_full_Ashtarak.location[i]:
        try:
            hotel_full_Ashtarak.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Ashtarak.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Ashtarak.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Ashtarak.location[i])
    
    else:
        hotel_full_Ashtarak.loc[i, 'location'] = None

# %%
for i in hotel_full_Ashtarak.index:
    if "Check-in" in  hotel_full_Ashtarak.check_in[i]:
        hotel_full_Ashtarak.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Ashtarak.check_in[i])
    else:
        hotel_full_Ashtarak.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Ashtarak.index:
    if "Value" in  hotel_full_Ashtarak.value[i]:
        hotel_full_Ashtarak.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Ashtarak.value[i])
    else:
        hotel_full_Ashtarak.loc[i, 'value'] = None

# %%
for i in hotel_full_Ashtarak.index:
    if "No reviews (yet)" in  hotel_full_Ashtarak.rating[i]:
        hotel_full_Ashtarak.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Ashtarak.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Ashtarak.price = price_list

# %%
for i in hotel_full_Ashtarak.index:
    if "Response rate" in  hotel_full_Ashtarak.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Ashtarak.host_response_rate[i])
        hotel_full_Ashtarak.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Ashtarak.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Ashtarak = hotel_full_Ashtarak.astype(convert_dict)

# %%
hotel_full_Ashtarak.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Ashtarak.to_csv("cleaned_hotel_full_Ashtarak.csv", index=False)
hotel_full_Ashtarak.to_excel("cleaned_hotel_full_Ashtarak2.xlsx", index=False)
