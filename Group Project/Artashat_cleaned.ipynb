ВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 6                                    Comfort apartment
# ..                                                 ...
# 294        Exquisite apartment in the heart of Yerevan
# 295  Most elegant apartment Jacuzzi Luxe, North Avenue
# 296  Lovely new modern apartment in the city centre❤️🤩
# ...

# %%
for i in hotel_full_Artashat.index:
    hotel_full_Artashat["country"][i]= "Armenia"

# %%
hotel_full_Artashat
# Out:
#         city  country                                               name  \
# 2    Yerevan  Armenia  ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 3    Yerevan  Armenia    The loft apartment in front of the Central Bank
# 4    Yerevan  Armenia                     Cozy house close to the centre
# 5    Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 6    Yerevan  Armenia                                  Comfort apartment
# ..       ...      ...                                                ...
# 294  Yerevan  Armenia        Exquisite apartment in the heart of Yerevan
# 295  Yerevan  Armenia  Most elegant apartment Jacuzzi Luxe, North Avenue
# 296  Yerevan  Armenia  Lovely new modern apartment in the city centre❤️🤩
# 297  Yerevan  Armenia             Apartament in the center of Yerevan 27
# 298  Yerevan  Armenia    Bright Apartment in The Heart of Yerevan by RIS
#
#                    host_since  \
# 2         Joined in July 2020
# ...

# %%
host_since_list = []
for i in hotel_full_Artashat.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Artashat.host_since = hs 
hotel_full_Artashat.host_since
# Out:
# 2      2020
# 3      2015
# 4      2016
# 5      2018
# 6      2018
#        ...
# 294    2019
# 295    2020
# 296    2016
# 297    2018
# 298    2014
# Name: host_since, Length: 264, dtype: int64

# %%
hotel_full_Artashat
# Out:
#         city  country                                               name  \
# 2    Yerevan  Armenia  ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 3    Yerevan  Armenia    The loft apartment in front of the Central Bank
# 4    Yerevan  Armenia                     Cozy house close to the centre
# 5    Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 6    Yerevan  Armenia                                  Comfort apartment
# ..       ...      ...                                                ...
# 294  Yerevan  Armenia        Exquisite apartment in the heart of Yerevan
# 295  Yerevan  Armenia  Most elegant apartment Jacuzzi Luxe, North Avenue
# 296  Yerevan  Armenia  Lovely new modern apartment in the city centre❤️🤩
# 297  Yerevan  Armenia             Apartament in the center of Yerevan 27
# 298  Yerevan  Armenia    Bright Apartment in The Heart of Yerevan by RIS
#
#      host_since                                 host_response_rate  \
# ...

# %%
string = []
for i in hotel_full_Artashat.index:
    st = hotel_full_Artashat.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["191 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "152 Reviews', 'Identity verified",
#  "122 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "97 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "39 Reviews', '\\U000f0003', 'Superhost",
#  "74 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "69 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "110 Reviews', '\\U000f0003', 'Superhost",
#  "241 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "193 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "333 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "175 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "39 Reviews', '\\U000f0003', 'Superhost",
#  "395 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "241 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "241 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
# ...

# %%
hotel_full_Artashat.host_identity_verified = string
hotel_full_Artashat.host_identity_verified
# Out:
# 2      191 Reviews', 'Identity verified', '\U000f0003...
# 3                       152 Reviews', 'Identity verified
# 4      122 Reviews', 'Identity verified', '\U000f0003...
# 5      97 Reviews', 'Identity verified', '\U000f0003'...
# 6                  39 Reviews', '\U000f0003', 'Superhost
#                              ...
# 294    21 Reviews', 'Identity verified', '\U000f0003'...
# 295    15 Reviews', 'Identity verified', '\U000f0003'...
# 296                                    Identity verified
# 297                                           17 Reviews
# 298    536 Reviews', 'Identity verified', '\U000f0003...
# Name: host_identity_verified, Length: 264, dtype: object

# %%
for i in hotel_full_Artashat.index:
    if "Identity verified" in  hotel_full_Artashat.host_identity_verified[i]:
        hotel_full_Artashat.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Artashat.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Artashat
# Out:
#         city  country                                               name  \
# 2    Yerevan  Armenia  ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 3    Yerevan  Armenia    The loft apartment in front of the Central Bank
# 4    Yerevan  Armenia                     Cozy house close to the centre
# 5    Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 6    Yerevan  Armenia                                  Comfort apartment
# ..       ...      ...                                                ...
# 294  Yerevan  Armenia        Exquisite apartment in the heart of Yerevan
# 295  Yerevan  Armenia  Most elegant apartment Jacuzzi Luxe, North Avenue
# 296  Yerevan  Armenia  Lovely new modern apartment in the city centre❤️🤩
# 297  Yerevan  Armenia             Apartament in the center of Yerevan 27
# 298  Yerevan  Armenia    Bright Apartment in The Heart of Yerevan by RIS
#
#      host_since                                 host_response_rate  \
# ...

# %%
for i in hotel_full_Artashat.index:
    if "Review" in  hotel_full_Artashat.review[i]:
        hotel_full_Artashat.loc[i, 'review'] = re.search("(\d+)", hotel_full_Artashat.review[i]).group()
        
    else:
        hotel_full_Artashat.loc[i, 'review'] = 0

# %%
hotel_full_Artashat
# Out:
#         city  country                                               name  \
# 2    Yerevan  Armenia  ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 3    Yerevan  Armenia    The loft apartment in front of the Central Bank
# 4    Yerevan  Armenia                     Cozy house close to the centre
# 5    Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 6    Yerevan  Armenia                                  Comfort apartment
# ..       ...      ...                                                ...
# 294  Yerevan  Armenia        Exquisite apartment in the heart of Yerevan
# 295  Yerevan  Armenia  Most elegant apartment Jacuzzi Luxe, North Avenue
# 296  Yerevan  Armenia  Lovely new modern apartment in the city centre❤️🤩
# 297  Yerevan  Armenia             Apartament in the center of Yerevan 27
# 298  Yerevan  Armenia    Bright Apartment in The Heart of Yerevan by RIS
#
#      host_since                                 host_response_rate  \
# ...

# %%
for i in hotel_full_Artashat.index:
    if "Superhost" in  hotel_full_Artashat.superhost[i]:
        hotel_full_Artashat.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Artashat.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Artashat.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire rental unit  Inn',
#  'Entire loft',
#  'Entire residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Private room in residential home',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire guesthouse',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit  Inn',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire rental unit',
#  'Entire serviced apartment',
#  'Entire rental unit',
#  'Entire rental unit',
# ...

# %%
hotel_full_Artashat.property_type =prop_list

# %%
hotel_full_Artashat
# Out:
#         city  country                                               name  \
# 2    Yerevan  Armenia  ➤ One BDR apt. with balcony ★ on Moskovyan str...
# 3    Yerevan  Armenia    The loft apartment in front of the Central Bank
# 4    Yerevan  Armenia                     Cozy house close to the centre
# 5    Yerevan  Armenia           КВАРТИРА В ЭЛИТНОМ ДОМЕ. ELITE APARTMENT
# 6    Yerevan  Armenia                                  Comfort apartment
# ..       ...      ...                                                ...
# 294  Yerevan  Armenia        Exquisite apartment in the heart of Yerevan
# 295  Yerevan  Armenia  Most elegant apartment Jacuzzi Luxe, North Avenue
# 296  Yerevan  Armenia  Lovely new modern apartment in the city centre❤️🤩
# 297  Yerevan  Armenia             Apartament in the center of Yerevan 27
# 298  Yerevan  Armenia    Bright Apartment in The Heart of Yerevan by RIS
#
#      host_since                                 host_response_rate  \
# ...

# %%
accomodates_list = []
for i in hotel_full_Artashat.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Artashat.accomodates = number

# %%
for i in hotel_full_Artashat.index:
    if "Shared half-bath" in  hotel_full_Artashat.number_bathroom[i]:
        hotel_full_Artashat.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Artashat.number_bathroom[i]:
        hotel_full_Artashat.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Artashat.number_bathroom[i]:
        hotel_full_Artashat.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Artashat.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Artashat.number_bedroom[i])
        hotel_full_Artashat.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Artashat.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Artashat.number_bedroom[i])
        hotel_full_Artashat.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Artashat.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Artashat.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Artashat.index:
    if "bed" in  hotel_full_Artashat.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Artashat.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Artashat.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '1',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '3',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '1',
#  '2',
#  '1',
#  '3',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '3',
#  '1',
#  '4',
#  '2',
#  '1',
#  '4',
#  '1',
#  '3',
#  '1',
#  '3',
#  '1',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '1',
#  '2',
#  '1',
#  '0',
#  '3',
#  '1',
#  '2',
#  '3',
#  '2',
#  '1',
#  '2',
#  '1',
#  '2',
#  '1',
#  '4',
#  '4',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '4',
#  '1',
#  '2',
#  '2',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '3',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '3',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '3',
#  '2',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
# ...

# %%
len(hotel_full_Artashat.number_beds)
# Out:
# 264

# %%
len(number_beds_list)
# Out:
# 264

# %%
hotel_full_Artashat.number_beds = number_beds_list

# %%
hotel_full_Artashat.number_beds
# Out:
# 2      1
# 3      2
# 4      1
# 5      1
# 6      2
#       ..
# 294    3
# 295    2
# 296    2
# 297    3
# 298    2
# Name: number_beds, Length: 264, dtype: object

# %%
for i in hotel_full_Artashat.index:
    if "Studio" in  hotel_full_Artashat.number_bedroom[i]:
        hotel_full_Artashat.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Artashat.number_bedroom[i])
        hotel_full_Artashat.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Artashat.index:
    if "Cleanliness" in  hotel_full_Artashat.cleanliness[i]:
        hotel_full_Artashat.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Artashat.cleanliness[i])
    else:
        hotel_full_Artashat.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Artashat.index:
    if "Accuracy" in  hotel_full_Artashat.accuracy[i]:
        hotel_full_Artashat.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Artashat.accuracy[i])
    else:
        hotel_full_Artashat.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Artashat.index:
    if "Communication" in  hotel_full_Artashat.communication[i]:
        hotel_full_Artashat.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Artashat.communication[i])
    else:
        hotel_full_Artashat.loc[i, 'communication'] = None

# %%
for i in hotel_full_Artashat.index:
    if "Location" in  hotel_full_Artashat.location[i]:
        try:
            hotel_full_Artashat.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Artashat.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Artashat.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Artashat.location[i])
    
    else:
        hotel_full_Artashat.loc[i, 'location'] = None

# %%
for i in hotel_full_Artashat.index:
    if "Check-in" in  hotel_full_Artashat.check_in[i]:
        hotel_full_Artashat.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Artashat.check_in[i])
    else:
        hotel_full_Artashat.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Artashat.index:
    if "Value" in  hotel_full_Artashat.value[i]:
        hotel_full_Artashat.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Artashat.value[i])
    else:
        hotel_full_Artashat.loc[i, 'value'] = None

# %%
for i in hotel_full_Artashat.index:
    if "No reviews (yet)" in  hotel_full_Artashat.rating[i]:
        hotel_full_Artashat.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Artashat.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Artashat.price = price_list

# %%
for i in hotel_full_Artashat.index:
    if "Response rate" in  hotel_full_Artashat.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Artashat.host_response_rate[i])
        hotel_full_Artashat.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Artashat.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Artashat = hotel_full_Artashat.astype(convert_dict)

# %%
hotel_full_Artashat.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Artashat.to_csv("cleaned_hotel_full_Artashat.csv", index=False)
hotel_full_Artashat.to_excel("cleaned_hotel_full_Artashat2.xlsx", index=False)
