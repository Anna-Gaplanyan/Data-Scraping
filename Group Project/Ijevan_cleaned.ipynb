# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Ijevan = pd.read_csv('hotel_full_Ijevan.csv')
hotel_full_Ijevan
# Out:
#                                     city  \
# 0                                    NaN
# 1       Ijevan, Tavush Province, Armenia
# 2       Ijevan, Tavush Province, Armenia
# 3       Ijevan, Tavush Province, Armenia
# 4       Ijevan, Tavush Province, Armenia
# 5       Ijevan, Tavush Province, Armenia
# 6       Ijevan, Tavush Province, Armenia
# 7       Ijevan, Tavush Province, Armenia
# 8    Getahovit, Tavush Province, Armenia
# 9       Ijevan, Tavush Province, Armenia
# 10      Ijevan, Tavush Province, Armenia
# 11               Ijevan, Tavush, Armenia
# 12      Ijevan, Tavush Province, Armenia
# 13      Ijevan, Tavush Province, Armenia
# 14      Ijevan, Tavush Province, Armenia
# 15               Ijevan, Tavush, Armenia
# 16   Getahovit, Tavush Province, Armenia
# 17      Ijevan, Tavush Province, Armenia
# 18      Ijevan, Tavush Province, Armenia
# 19               Иджеван, Тавуш, Armenia
# 20               Иджеван, Тавуш, Armenia
# 21               Иджеван, Тавуш, Armenia
# ...

# %%
hotel_full_Ijevan = hotel_full_Ijevan.drop(labels = 0, axis = 0)
hotel_full_Ijevan
# Out:
#                                     city  \
# 1       Ijevan, Tavush Province, Armenia
# 2       Ijevan, Tavush Province, Armenia
# 3       Ijevan, Tavush Province, Armenia
# 4       Ijevan, Tavush Province, Armenia
# 5       Ijevan, Tavush Province, Armenia
# 6       Ijevan, Tavush Province, Armenia
# 7       Ijevan, Tavush Province, Armenia
# 8    Getahovit, Tavush Province, Armenia
# 9       Ijevan, Tavush Province, Armenia
# 10      Ijevan, Tavush Province, Armenia
# 11               Ijevan, Tavush, Armenia
# 12      Ijevan, Tavush Province, Armenia
# 13      Ijevan, Tavush Province, Armenia
# 14      Ijevan, Tavush Province, Armenia
# 15               Ijevan, Tavush, Armenia
# 16   Getahovit, Tavush Province, Armenia
# 17      Ijevan, Tavush Province, Armenia
# 18      Ijevan, Tavush Province, Armenia
# 19               Иджеван, Тавуш, Armenia
# 20               Иджеван, Тавуш, Armenia
# 21               Иджеван, Тавуш, Armenia
# 22               Иджеван, Тавуш, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Ijevan.replace("", nan_value, inplace = True)
hotel_full_Ijevan.dropna(inplace= True)
hotel_full_Ijevan
# Out:
#                                    city                              country  \
# 2      Ijevan, Tavush Province, Armenia     Ijevan, Tavush Province, Armenia
# 8   Getahovit, Tavush Province, Armenia  Getahovit, Tavush Province, Armenia
# 10     Ijevan, Tavush Province, Armenia     Ijevan, Tavush Province, Armenia
# 12     Ijevan, Tavush Province, Armenia     Ijevan, Tavush Province, Armenia
# 15              Ijevan, Tavush, Armenia              Ijevan, Tavush, Armenia
# 17     Ijevan, Tavush Province, Armenia     Ijevan, Tavush Province, Armenia
# 20              Иджеван, Тавуш, Armenia              Иджеван, Тавуш, Armenia
# 21              Иджеван, Тавуш, Armenia              Иджеван, Тавуш, Armenia
# 24     Ijevan, Tavush Province, Armenia     Ijevan, Tavush Province, Armenia
# 25     Ijevan, Tavush Province, Armenia     Ijevan, Tavush Province, Armenia
#
#                                name              host_since  \
# ...

# %%
hotel_full_Ijevan["city"]= hotel_full_Ijevan["city"].replace({"Иджеван, Тавуш, Armenia" : "Ijevan, Armenia"})

# %%
city_list = []
for i in hotel_full_Ijevan.index:
    text = re.sub(",", "", hotel_full_Ijevan["city"][i][:hotel_full_Ijevan["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Ijevan["city"]= city_list
hotel_full_Ijevan
# Out:
#                           city                              country  \
# 2      Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 8   Getahovit Tavush Province   Getahovit, Tavush Province, Armenia
# 10     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 12     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 15              Ijevan Tavush               Ijevan, Tavush, Armenia
# 17     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 20                     Ijevan               Иджеван, Тавуш, Armenia
# 21                     Ijevan               Иджеван, Тавуш, Armenia
# 24     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 25     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
#
#                                name              host_since  \
# 2               Apartment Kamar N26   Joined in August 2018
# 8           Лучший отдых на природе  Joined in October 2018
# ...

# %%
nan_value = float("Nan")
hotel_full_Ijevan.replace("", nan_value, inplace = True)
hotel_full_Ijevan.dropna(inplace= True)
hotel_full_Ijevan
# Out:
#                           city                              country  \
# 2      Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 8   Getahovit Tavush Province   Getahovit, Tavush Province, Armenia
# 10     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 12     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 15              Ijevan Tavush               Ijevan, Tavush, Armenia
# 17     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 20                     Ijevan               Иджеван, Тавуш, Armenia
# 21                     Ijevan               Иджеван, Тавуш, Armenia
# 24     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
# 25     Ijevan Tavush Province      Ijevan, Tavush Province, Armenia
#
#                                name              host_since  \
# 2               Apartment Kamar N26   Joined in August 2018
# 8           Лучший отдых на природе  Joined in October 2018
# ...

# %%
c_l = []    
for k in hotel_full_Ijevan["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Ijevan["city"]= c_l
hotel_full_Ijevan
# Out:
#          city                              country  \
# 2      Ijevan     Ijevan, Tavush Province, Armenia
# 8   Getahovit  Getahovit, Tavush Province, Armenia
# 10     Ijevan     Ijevan, Tavush Province, Armenia
# 12     Ijevan     Ijevan, Tavush Province, Armenia
# 15     Ijevan              Ijevan, Tavush, Armenia
# 17     Ijevan     Ijevan, Tavush Province, Armenia
# 20     Ijevan              Иджеван, Тавуш, Armenia
# 21     Ijevan              Иджеван, Тавуш, Armenia
# 24     Ijevan     Ijevan, Tavush Province, Armenia
# 25     Ijevan     Ijevan, Tavush Province, Armenia
#
#                                name              host_since  \
# 2               Apartment Kamar N26   Joined in August 2018
# 8           Лучший отдых на природе  Joined in October 2018
# 10               Guest House LEADER     Joined in June 2019
# 12        Аппартамент с 6 спальнями   Joined in August 2018
# 15  Enjoy warm Armenian Hospitality     Joined in July 2014
# ...

# %%
country_list = []
for i in hotel_full_Ijevan.index:
    text = re.search("Armenia", hotel_full_Ijevan["country"][i]).group()
    country_list.append(text)

hotel_full_Ijevan["country"] = country_list

# %%
hotel_full_Ijevan
# Out:
#          city  country                             name  \
# 2      Ijevan  Armenia              Apartment Kamar N26
# 8   Getahovit  Armenia          Лучший отдых на природе
# 10     Ijevan  Armenia               Guest House LEADER
# 12     Ijevan  Armenia        Аппартамент с 6 спальнями
# 15     Ijevan  Armenia  Enjoy warm Armenian Hospitality
# 17     Ijevan  Armenia           Kamar Hotel Ijevan N24
# 20     Ijevan  Armenia                    Вилла де люкс
# 21     Ijevan  Armenia                    Вилла де люкс
# 24     Ijevan  Armenia  Enjoy warm Armenian hospitality
# 25     Ijevan  Armenia                Qarvansara Resort
#
#                 host_since                                 host_response_rate  \
# 2    Joined in August 2018  Response rate: 100%\nResponse time: within an ...
# 8   Joined in October 2018  Languages: English, Français, Русский\nRespons...
# 10     Joined in June 2019  Language: Русский\nResponse rate: 100%\nRespon...
# ...

# %%
host_since_list = []
for i in hotel_full_Ijevan.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Ijevan.host_since = hs 
hotel_full_Ijevan.host_since
# Out:
# 2     2018
# 8     2018
# 10    2019
# 12    2018
# 15    2014
# 17    2018
# 20    2016
# 21    2016
# 24    2014
# 25    2016
# Name: host_since, dtype: int64

# %%
hotel_full_Ijevan
# Out:
#          city  country                             name  host_since  \
# 2      Ijevan  Armenia              Apartment Kamar N26        2018
# 8   Getahovit  Armenia          Лучший отдых на природе        2018
# 10     Ijevan  Armenia               Guest House LEADER        2019
# 12     Ijevan  Armenia        Аппартамент с 6 спальнями        2018
# 15     Ijevan  Armenia  Enjoy warm Armenian Hospitality        2014
# 17     Ijevan  Armenia           Kamar Hotel Ijevan N24        2018
# 20     Ijevan  Armenia                    Вилла де люкс        2016
# 21     Ijevan  Armenia                    Вилла де люкс        2016
# 24     Ijevan  Armenia  Enjoy warm Armenian hospitality        2014
# 25     Ijevan  Armenia                Qarvansara Resort        2016
#
#                                    host_response_rate  \
# 2   Response rate: 100%\nResponse time: within an ...
# 8   Languages: English, Français, Русский\nRespons...
# ...

# %%
string = []
for i in hotel_full_Ijevan.index:
    st = hotel_full_Ijevan.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ['9 Reviews',
#  '4 Reviews',
#  "2 Reviews', 'Identity verified",
#  '9 Reviews',
#  '12 Reviews',
#  '9 Reviews',
#  "19 Reviews', 'Identity verified",
#  "19 Reviews', 'Identity verified",
#  '12 Reviews',
#  'Identity verified']

# %%
hotel_full_Ijevan.host_identity_verified = string
hotel_full_Ijevan.host_identity_verified
# Out:
# 2                           9 Reviews
# 8                           4 Reviews
# 10     2 Reviews', 'Identity verified
# 12                          9 Reviews
# 15                         12 Reviews
# 17                          9 Reviews
# 20    19 Reviews', 'Identity verified
# 21    19 Reviews', 'Identity verified
# 24                         12 Reviews
# 25                  Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Ijevan.index:
    if "Identity verified" in  hotel_full_Ijevan.host_identity_verified[i]:
        hotel_full_Ijevan.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Ijevan.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Ijevan
# Out:
#          city  country                             name  host_since  \
# 2      Ijevan  Armenia              Apartment Kamar N26        2018
# 8   Getahovit  Armenia          Лучший отдых на природе        2018
# 10     Ijevan  Armenia               Guest House LEADER        2019
# 12     Ijevan  Armenia        Аппартамент с 6 спальнями        2018
# 15     Ijevan  Armenia  Enjoy warm Armenian Hospitality        2014
# 17     Ijevan  Armenia           Kamar Hotel Ijevan N24        2018
# 20     Ijevan  Armenia                    Вилла де люкс        2016
# 21     Ijevan  Armenia                    Вилла де люкс        2016
# 24     Ijevan  Armenia  Enjoy warm Armenian hospitality        2014
# 25     Ijevan  Armenia                Qarvansara Resort        2016
#
#                                    host_response_rate host_identity_verified  \
# 2   Response rate: 100%\nResponse time: within an ...  Identity not verified
# ...

# %%
for i in hotel_full_Ijevan.index:
    if "Review" in  hotel_full_Ijevan.review[i]:
        hotel_full_Ijevan.loc[i, 'review'] = re.search("(\d+)", hotel_full_Ijevan.review[i]).group()
        
    else:
        hotel_full_Ijevan.loc[i, 'review'] = 0

# %%
hotel_full_Ijevan
# Out:
#          city  country                             name  host_since  \
# 2      Ijevan  Armenia              Apartment Kamar N26        2018
# 8   Getahovit  Armenia          Лучший отдых на природе        2018
# 10     Ijevan  Armenia               Guest House LEADER        2019
# 12     Ijevan  Armenia        Аппартамент с 6 спальнями        2018
# 15     Ijevan  Armenia  Enjoy warm Armenian Hospitality        2014
# 17     Ijevan  Armenia           Kamar Hotel Ijevan N24        2018
# 20     Ijevan  Armenia                    Вилла де люкс        2016
# 21     Ijevan  Armenia                    Вилла де люкс        2016
# 24     Ijevan  Armenia  Enjoy warm Armenian hospitality        2014
# 25     Ijevan  Armenia                Qarvansara Resort        2016
#
#                                    host_response_rate host_identity_verified  \
# 2   Response rate: 100%\nResponse time: within an ...  Identity not verified
# ...

# %%
for i in hotel_full_Ijevan.index:
    if "Superhost" in  hotel_full_Ijevan.superhost[i]:
        hotel_full_Ijevan.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Ijevan.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Ijevan.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire residential home',
#  'Treehouse',
#  'Room in hotel',
#  'Room in serviced apartment',
#  'Private room in residential home',
#  'Entire residential home',
#  'Private room in residential home',
#  'Private room in residential home',
#  'Private room in guesthouse',
#  'Room in hotel']

# %%
hotel_full_Ijevan.property_type =prop_list

# %%
hotel_full_Ijevan
# Out:
#          city  country                             name  host_since  \
# 2      Ijevan  Armenia              Apartment Kamar N26        2018
# 8   Getahovit  Armenia          Лучший отдых на природе        2018
# 10     Ijevan  Armenia               Guest House LEADER        2019
# 12     Ijevan  Armenia        Аппартамент с 6 спальнями        2018
# 15     Ijevan  Armenia  Enjoy warm Armenian Hospitality        2014
# 17     Ijevan  Armenia           Kamar Hotel Ijevan N24        2018
# 20     Ijevan  Armenia                    Вилла де люкс        2016
# 21     Ijevan  Armenia                    Вилла де люкс        2016
# 24     Ijevan  Armenia  Enjoy warm Armenian hospitality        2014
# 25     Ijevan  Armenia                Qarvansara Resort        2016
#
#                                    host_response_rate host_identity_verified  \
# 2   Response rate: 100%\nResponse time: within an ...  Identity not verified
# ...

# %%
accomodates_list = []
for i in hotel_full_Ijevan.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Ijevan.accomodates = number

# %%
for i in hotel_full_Ijevan.index:
    if "Shared half-bath" in  hotel_full_Ijevan.number_bathroom[i]:
        hotel_full_Ijevan.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Ijevan.number_bathroom[i]:
        hotel_full_Ijevan.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Ijevan.number_bathroom[i]:
        hotel_full_Ijevan.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Ijevan.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Ijevan.number_bedroom[i])
        hotel_full_Ijevan.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Ijevan.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Ijevan.number_bedroom[i])
        hotel_full_Ijevan.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Ijevan.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Ijevan.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Ijevan.index:
    if "bed" in  hotel_full_Ijevan.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Ijevan.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Ijevan.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['2', '1', '2', '12', '14', '2', '6', '6', '4', '20']

# %%
len(hotel_full_Ijevan.number_beds)
# Out:
# 10

# %%
len(number_beds_list)
# Out:
# 10

# %%
hotel_full_Ijevan.number_beds = number_beds_list

# %%
hotel_full_Ijevan.number_beds
# Out:
# 2      2
# 8      1
# 10     2
# 12    12
# 15    14
# 17     2
# 20     6
# 21     6
# 24     4
# 25    20
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Ijevan.index:
    if "Studio" in  hotel_full_Ijevan.number_bedroom[i]:
        hotel_full_Ijevan.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Ijevan.number_bedroom[i])
        hotel_full_Ijevan.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Ijevan.index:
    if "Cleanliness" in  hotel_full_Ijevan.cleanliness[i]:
        hotel_full_Ijevan.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Ijevan.cleanliness[i])
    else:
        hotel_full_Ijevan.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Ijevan.index:
    if "Accuracy" in  hotel_full_Ijevan.accuracy[i]:
        hotel_full_Ijevan.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Ijevan.accuracy[i])
    else:
        hotel_full_Ijevan.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Ijevan.index:
    if "Communication" in  hotel_full_Ijevan.communication[i]:
        hotel_full_Ijevan.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Ijevan.communication[i])
    else:
        hotel_full_Ijevan.loc[i, 'communication'] = None

# %%
for i in hotel_full_Ijevan.index:
    if "Location" in  hotel_full_Ijevan.location[i]:
        try:
            hotel_full_Ijevan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Ijevan.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Ijevan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Ijevan.location[i])
    
    else:
        hotel_full_Ijevan.loc[i, 'location'] = None

# %%
for i in hotel_full_Ijevan.index:
    if "Check-in" in  hotel_full_Ijevan.check_in[i]:
        hotel_full_Ijevan.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Ijevan.check_in[i])
    else:
        hotel_full_Ijevan.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Ijevan.index:
    if "Value" in  hotel_full_Ijevan.value[i]:
        hotel_full_Ijevan.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Ijevan.value[i])
    else:
        hotel_full_Ijevan.loc[i, 'value'] = None

# %%
for i in hotel_full_Ijevan.index:
    if "No reviews (yet)" in  hotel_full_Ijevan.rating[i]:
        hotel_full_Ijevan.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Ijevan.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Ijevan.price = price_list

# %%
for i in hotel_full_Ijevan.index:
    if "Response rate" in  hotel_full_Ijevan.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Ijevan.host_response_rate[i])
        hotel_full_Ijevan.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Ijevan.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Ijevan = hotel_full_Ijevan.astype(convert_dict)

# %%
hotel_full_Ijevan.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Ijevan.to_csv("cleaned_hotel_full_Ijevan.csv", index=False)
hotel_full_Ijevan.to_excel("cleaned_hotel_full_Ijevan2.xlsx", index=False)
