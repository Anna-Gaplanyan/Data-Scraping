# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Noyemberyan = pd.read_csv('hotel_full_Noyemberyan.csv')
hotel_full_Noyemberyan
# Out:
#                                       city  \
# 0                                      NaN
# 1            Odzun, Lori Province, Armenia
# 2              T'bilisi, Georgia , Georgia
# 3    Noyemberyan, Tavush Province, Armenia
# 4    Noyemberyan, Tavush Province, Armenia
# ..                                     ...
# 289                       Tbilisi, Georgia
# 290                       Tbilisi, Georgia
# 291                       Tbilisi, Georgia
# 292                       Tbilisi, Georgia
# 293             T'bilisi, Tbilisi, Georgia
#
#                                    country  \
# 0                                      NaN
# 1            Odzun, Lori Province, Armenia
# 2              T'bilisi, Georgia , Georgia
# 3    Noyemberyan, Tavush Province, Armenia
# 4    Noyemberyan, Tavush Province, Armenia
# ..                                     ...
# 289                       Tbilisi, Georgia
# 290                       Tbilisi, Georgia
# 291                       Tbilisi, Georgia
# ...

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan.drop(labels = 0, axis = 0)
hotel_full_Noyemberyan
# Out:
#                                       city  \
# 1            Odzun, Lori Province, Armenia
# 2              T'bilisi, Georgia , Georgia
# 3    Noyemberyan, Tavush Province, Armenia
# 4    Noyemberyan, Tavush Province, Armenia
# 5         Alaverdi, Lori Province, Armenia
# ..                                     ...
# 289                       Tbilisi, Georgia
# 290                       Tbilisi, Georgia
# 291                       Tbilisi, Georgia
# 292                       Tbilisi, Georgia
# 293             T'bilisi, Tbilisi, Georgia
#
#                                    country  \
# 1            Odzun, Lori Province, Armenia
# 2              T'bilisi, Georgia , Georgia
# 3    Noyemberyan, Tavush Province, Armenia
# 4    Noyemberyan, Tavush Province, Armenia
# 5         Alaverdi, Lori Province, Armenia
# ..                                     ...
# 289                       Tbilisi, Georgia
# 290                       Tbilisi, Georgia
# 291                       Tbilisi, Georgia
# ...

# %%
nan_value = float("Nan")
hotel_full_Noyemberyan.replace("", nan_value, inplace = True)
hotel_full_Noyemberyan.dropna(inplace= True)
hotel_full_Noyemberyan
# Out:
#                                  city                           country  \
# 1       Odzun, Lori Province, Armenia     Odzun, Lori Province, Armenia
# 2         T'bilisi, Georgia , Georgia       T'bilisi, Georgia , Georgia
# 5    Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 6          T'bilisi, Tbilisi, Georgia        T'bilisi, Tbilisi, Georgia
# 7                    Tbilisi, Georgia                  Tbilisi, Georgia
# ..                                ...                               ...
# 289                  Tbilisi, Georgia                  Tbilisi, Georgia
# 290                  Tbilisi, Georgia                  Tbilisi, Georgia
# 291                  Tbilisi, Georgia                  Tbilisi, Georgia
# 292                  Tbilisi, Georgia                  Tbilisi, Georgia
# 293        T'bilisi, Tbilisi, Georgia        T'bilisi, Tbilisi, Georgia
#
#                                                 name  \
# ...

# %%
# Get names of indexes for which column Age has value 30
indexNames = hotel_full_Noyemberyan[ hotel_full_Noyemberyan['country'] == "T'bilisi, Tbilisi, Georgia" ].index
# Delete these row indexes from dataFrame
hotel_full_Noyemberyan.drop(indexNames , inplace=True)
hotel_full_Noyemberyan
# Out:
#                                  city                           country  \
# 1       Odzun, Lori Province, Armenia     Odzun, Lori Province, Armenia
# 2         T'bilisi, Georgia , Georgia       T'bilisi, Georgia , Georgia
# 5    Alaverdi, Lori Province, Armenia  Alaverdi, Lori Province, Armenia
# 7                    Tbilisi, Georgia                  Tbilisi, Georgia
# 9                    Tbilisi, Georgia                  Tbilisi, Georgia
# ..                                ...                               ...
# 288                  Tbilisi, Georgia                  Tbilisi, Georgia
# 289                  Tbilisi, Georgia                  Tbilisi, Georgia
# 290                  Tbilisi, Georgia                  Tbilisi, Georgia
# 291                  Tbilisi, Georgia                  Tbilisi, Georgia
# 292                  Tbilisi, Georgia                  Tbilisi, Georgia
#
#                                                   name  \
# ...

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != "T'bilisi, Georgia , Georgia"]

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != "T'bilisi, Tbilisi, Georgia"]

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != "Tbilisi, Georgia"]

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != "Tbilisi, Old Tbilisi, Georgia"]

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != "თბილისი, Georgia"]

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != "T'bilisi, Georgia, Georgia"]

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != "Тбилиси, Georgia"]

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != "Tbilisi, Mtskheta-Mtianeti, Georgia"]

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != 'Tbilisi , Tbilisi, Georgia']

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan[hotel_full_Noyemberyan.city != 'Tbilisi, Tbilisi, Georgia']

# %%
hotel_full_Noyemberyan
# Out:
#                                    city                             country  \
# 1         Odzun, Lori Province, Armenia       Odzun, Lori Province, Armenia
# 5      Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 10    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 12    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 20   Berdavan, Tavush Province, Armenia  Berdavan, Tavush Province, Armenia
# 35    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 44    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 93    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 198   Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 271   Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
#
#                                                  name              host_since  \
# ...

# %%
nan_value = float("Nan")
hotel_full_Noyemberyan.replace("", nan_value, inplace = True)
hotel_full_Noyemberyan.dropna(inplace= True)
hotel_full_Noyemberyan
# Out:
#                                    city                             country  \
# 1         Odzun, Lori Province, Armenia       Odzun, Lori Province, Armenia
# 5      Alaverdi, Lori Province, Armenia    Alaverdi, Lori Province, Armenia
# 10    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 12    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 20   Berdavan, Tavush Province, Armenia  Berdavan, Tavush Province, Armenia
# 35    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 44    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 93    Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 198   Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
# 271   Dilijan, Tavush Province, Armenia   Dilijan, Tavush Province, Armenia
#
#                                                  name              host_since  \
# ...

# %%
city_list = []
for i in hotel_full_Noyemberyan.index:
    text = re.sub(",", "", hotel_full_Noyemberyan["city"][i][:hotel_full_Noyemberyan["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Noyemberyan["city"]= city_list
hotel_full_Noyemberyan
# Out:
#                           city                             country  \
# 1         Odzun Lori Province        Odzun, Lori Province, Armenia
# 5      Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 10    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 12    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 20   Berdavan Tavush Province   Berdavan, Tavush Province, Armenia
# 35    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 44    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 93    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 198   Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 271   Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
#
#                                                  name              host_since  \
# 1      Private Villa at Odzun Monastery | Առանձնատուն     Joined in June 2015
# ...

# %%
nan_value = float("Nan")
hotel_full_Noyemberyan.replace("", nan_value, inplace = True)
hotel_full_Noyemberyan.dropna(inplace= True)
hotel_full_Noyemberyan
# Out:
#                           city                             country  \
# 1         Odzun Lori Province        Odzun, Lori Province, Armenia
# 5      Alaverdi Lori Province     Alaverdi, Lori Province, Armenia
# 10    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 12    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 20   Berdavan Tavush Province   Berdavan, Tavush Province, Armenia
# 35    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 44    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 93    Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 198   Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
# 271   Dilijan Tavush Province    Dilijan, Tavush Province, Armenia
#
#                                                  name              host_since  \
# 1      Private Villa at Odzun Monastery | Առանձնատուն     Joined in June 2015
# ...

# %%
c_l = []    
for k in hotel_full_Noyemberyan["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Noyemberyan["city"]= c_l
hotel_full_Noyemberyan
# Out:
#          city                             country  \
# 1       Odzun       Odzun, Lori Province, Armenia
# 5    Alaverdi    Alaverdi, Lori Province, Armenia
# 10    Dilijan   Dilijan, Tavush Province, Armenia
# 12    Dilijan   Dilijan, Tavush Province, Armenia
# 20   Berdavan  Berdavan, Tavush Province, Armenia
# 35    Dilijan   Dilijan, Tavush Province, Armenia
# 44    Dilijan   Dilijan, Tavush Province, Armenia
# 93    Dilijan   Dilijan, Tavush Province, Armenia
# 198   Dilijan   Dilijan, Tavush Province, Armenia
# 271   Dilijan   Dilijan, Tavush Province, Armenia
#
#                                                  name              host_since  \
# 1      Private Villa at Odzun Monastery | Առանձնատուն     Joined in June 2015
# 5                                 ARMBEE Honey Farm 2      Joined in May 2019
# 10                  Armenian village house in Dilijan      Joined in May 2019
# 12   Cosy and comfortable apartment with a great view    Joined in March 2018
# ...

# %%
country_list = []
for i in hotel_full_Noyemberyan.index:
    text = re.search("Armenia", hotel_full_Noyemberyan["country"][i]).group()
    country_list.append(text)

hotel_full_Noyemberyan["country"] = country_list

# %%
hotel_full_Noyemberyan
# Out:
#          city  country                                              name  \
# 1       Odzun  Armenia    Private Villa at Odzun Monastery | Առանձնատուն
# 5    Alaverdi  Armenia                               ARMBEE Honey Farm 2
# 10    Dilijan  Armenia                 Armenian village house in Dilijan
# 12    Dilijan  Armenia  Cosy and comfortable apartment with a great view
# 20   Berdavan  Armenia                               Berdavan guesthouse
# 35    Dilijan  Armenia                                    Guesthouse 121
# 44    Dilijan  Armenia                                    Guesthouse 121
# 93    Dilijan  Armenia                                  Dilijan Town Inn
# 198   Dilijan  Armenia                          "Petit Dilijan - Spring"
# 271   Dilijan  Armenia                              Dilijan Garden House
#
#                  host_since  \
# 1       Joined in June 2015
# 5        Joined in May 2019
# 10       Joined in May 2019
# 12     Joined in March 2018
# ...

# %%
host_since_list = []
for i in hotel_full_Noyemberyan.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Noyemberyan.host_since = hs 
hotel_full_Noyemberyan.host_since
# Out:
# 1      2015
# 5      2019
# 10     2019
# 12     2018
# 20     2019
# 35     2019
# 44     2019
# 93     2015
# 198    2014
# 271    2015
# Name: host_since, dtype: int64

# %%
hotel_full_Noyemberyan
# Out:
#          city  country                                              name  \
# 1       Odzun  Armenia    Private Villa at Odzun Monastery | Առանձնատուն
# 5    Alaverdi  Armenia                               ARMBEE Honey Farm 2
# 10    Dilijan  Armenia                 Armenian village house in Dilijan
# 12    Dilijan  Armenia  Cosy and comfortable apartment with a great view
# 20   Berdavan  Armenia                               Berdavan guesthouse
# 35    Dilijan  Armenia                                    Guesthouse 121
# 44    Dilijan  Armenia                                    Guesthouse 121
# 93    Dilijan  Armenia                                  Dilijan Town Inn
# 198   Dilijan  Armenia                          "Petit Dilijan - Spring"
# 271   Dilijan  Armenia                              Dilijan Garden House
#
#      host_since                                 host_response_rate  \
# 1          2015  Languages: English, Deutsch, Русский\nResponse...
# ...

# %%
string = []
for i in hotel_full_Noyemberyan.index:
    st = hotel_full_Noyemberyan.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ["27 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "5 Reviews', 'Identity verified",
#  "42 Reviews', 'Identity verified",
#  "26 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  'Identity verified',
#  "31 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "31 Reviews', 'Identity verified', '\\U000f0003', 'Superhost",
#  "85 Reviews', 'Identity verified",
#  '31 Reviews',
#  "85 Reviews', 'Identity verified"]

# %%
hotel_full_Noyemberyan.host_identity_verified = string
hotel_full_Noyemberyan.host_identity_verified
# Out:
# 1      27 Reviews', 'Identity verified', '\U000f0003'...
# 5                         5 Reviews', 'Identity verified
# 10                       42 Reviews', 'Identity verified
# 12     26 Reviews', 'Identity verified', '\U000f0003'...
# 20                                     Identity verified
# 35     31 Reviews', 'Identity verified', '\U000f0003'...
# 44     31 Reviews', 'Identity verified', '\U000f0003'...
# 93                       85 Reviews', 'Identity verified
# 198                                           31 Reviews
# 271                      85 Reviews', 'Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Noyemberyan.index:
    if "Identity verified" in  hotel_full_Noyemberyan.host_identity_verified[i]:
        hotel_full_Noyemberyan.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Noyemberyan.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Noyemberyan
# Out:
#          city  country                                              name  \
# 1       Odzun  Armenia    Private Villa at Odzun Monastery | Առանձնատուն
# 5    Alaverdi  Armenia                               ARMBEE Honey Farm 2
# 10    Dilijan  Armenia                 Armenian village house in Dilijan
# 12    Dilijan  Armenia  Cosy and comfortable apartment with a great view
# 20   Berdavan  Armenia                               Berdavan guesthouse
# 35    Dilijan  Armenia                                    Guesthouse 121
# 44    Dilijan  Armenia                                    Guesthouse 121
# 93    Dilijan  Armenia                                  Dilijan Town Inn
# 198   Dilijan  Armenia                          "Petit Dilijan - Spring"
# 271   Dilijan  Armenia                              Dilijan Garden House
#
#      host_since                                 host_response_rate  \
# 1          2015  Languages: English, Deutsch, Русский\nResponse...
# ...

# %%
for i in hotel_full_Noyemberyan.index:
    if "Review" in  hotel_full_Noyemberyan.review[i]:
        hotel_full_Noyemberyan.loc[i, 'review'] = re.search("(\d+)", hotel_full_Noyemberyan.review[i]).group()
        
    else:
        hotel_full_Noyemberyan.loc[i, 'review'] = 0

# %%
hotel_full_Noyemberyan
# Out:
#          city  country                                              name  \
# 1       Odzun  Armenia    Private Villa at Odzun Monastery | Առանձնատուն
# 5    Alaverdi  Armenia                               ARMBEE Honey Farm 2
# 10    Dilijan  Armenia                 Armenian village house in Dilijan
# 12    Dilijan  Armenia  Cosy and comfortable apartment with a great view
# 20   Berdavan  Armenia                               Berdavan guesthouse
# 35    Dilijan  Armenia                                    Guesthouse 121
# 44    Dilijan  Armenia                                    Guesthouse 121
# 93    Dilijan  Armenia                                  Dilijan Town Inn
# 198   Dilijan  Armenia                          "Petit Dilijan - Spring"
# 271   Dilijan  Armenia                              Dilijan Garden House
#
#      host_since                                 host_response_rate  \
# 1          2015  Languages: English, Deutsch, Русский\nResponse...
# ...

# %%
for i in hotel_full_Noyemberyan.index:
    if "Superhost" in  hotel_full_Noyemberyan.superhost[i]:
        hotel_full_Noyemberyan.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Noyemberyan.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Noyemberyan.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire villa',
#  'Entire chalet',
#  'Entire residential home',
#  'Entire rental unit',
#  'Private room in farm stay',
#  'Hut',
#  'Hut',
#  'Entire residential home',
#  'Entire guesthouse',
#  'Entire villa']

# %%
hotel_full_Noyemberyan.property_type =prop_list

# %%
hotel_full_Noyemberyan
# Out:
#          city  country                                              name  \
# 1       Odzun  Armenia    Private Villa at Odzun Monastery | Առանձնատուն
# 5    Alaverdi  Armenia                               ARMBEE Honey Farm 2
# 10    Dilijan  Armenia                 Armenian village house in Dilijan
# 12    Dilijan  Armenia  Cosy and comfortable apartment with a great view
# 20   Berdavan  Armenia                               Berdavan guesthouse
# 35    Dilijan  Armenia                                    Guesthouse 121
# 44    Dilijan  Armenia                                    Guesthouse 121
# 93    Dilijan  Armenia                                  Dilijan Town Inn
# 198   Dilijan  Armenia                          "Petit Dilijan - Spring"
# 271   Dilijan  Armenia                              Dilijan Garden House
#
#      host_since                                 host_response_rate  \
# 1          2015  Languages: English, Deutsch, Русский\nResponse...
# ...

# %%
accomodates_list = []
for i in hotel_full_Noyemberyan.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Noyemberyan.accomodates = number

# %%
for i in hotel_full_Noyemberyan.index:
    if "Shared half-bath" in  hotel_full_Noyemberyan.number_bathroom[i]:
        hotel_full_Noyemberyan.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Noyemberyan.number_bathroom[i]:
        hotel_full_Noyemberyan.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Noyemberyan.number_bathroom[i]:
        hotel_full_Noyemberyan.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Noyemberyan.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Noyemberyan.number_bedroom[i])
        hotel_full_Noyemberyan.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Noyemberyan.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Noyemberyan.number_bedroom[i])
        hotel_full_Noyemberyan.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Noyemberyan.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Noyemberyan.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Noyemberyan.index:
    if "bed" in  hotel_full_Noyemberyan.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Noyemberyan.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Noyemberyan.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['4', '2', '3', '1', '8', '2', '2', '3', '2', '7']

# %%
len(hotel_full_Noyemberyan.number_beds)
# Out:
# 10

# %%
len(number_beds_list)
# Out:
# 10

# %%
hotel_full_Noyemberyan.number_beds = number_beds_list

# %%
hotel_full_Noyemberyan.number_beds
# Out:
# 1      4
# 5      2
# 10     3
# 12     1
# 20     8
# 35     2
# 44     2
# 93     3
# 198    2
# 271    7
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Noyemberyan.index:
    if "Studio" in  hotel_full_Noyemberyan.number_bedroom[i]:
        hotel_full_Noyemberyan.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Noyemberyan.number_bedroom[i])
        hotel_full_Noyemberyan.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Noyemberyan.index:
    if "Cleanliness" in  hotel_full_Noyemberyan.cleanliness[i]:
        hotel_full_Noyemberyan.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Noyemberyan.cleanliness[i])
    else:
        hotel_full_Noyemberyan.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Noyemberyan.index:
    if "Accuracy" in  hotel_full_Noyemberyan.accuracy[i]:
        hotel_full_Noyemberyan.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Noyemberyan.accuracy[i])
    else:
        hotel_full_Noyemberyan.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Noyemberyan.index:
    if "Communication" in  hotel_full_Noyemberyan.communication[i]:
        hotel_full_Noyemberyan.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Noyemberyan.communication[i])
    else:
        hotel_full_Noyemberyan.loc[i, 'communication'] = None

# %%
for i in hotel_full_Noyemberyan.index:
    if "Location" in  hotel_full_Noyemberyan.location[i]:
        try:
            hotel_full_Noyemberyan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Noyemberyan.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Noyemberyan.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Noyemberyan.location[i])
    
    else:
        hotel_full_Noyemberyan.loc[i, 'location'] = None

# %%
for i in hotel_full_Noyemberyan.index:
    if "Check-in" in  hotel_full_Noyemberyan.check_in[i]:
        hotel_full_Noyemberyan.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Noyemberyan.check_in[i])
    else:
        hotel_full_Noyemberyan.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Noyemberyan.index:
    if "Value" in  hotel_full_Noyemberyan.value[i]:
        hotel_full_Noyemberyan.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Noyemberyan.value[i])
    else:
        hotel_full_Noyemberyan.loc[i, 'value'] = None

# %%
for i in hotel_full_Noyemberyan.index:
    if "No reviews (yet)" in  hotel_full_Noyemberyan.rating[i]:
        hotel_full_Noyemberyan.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Noyemberyan.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Noyemberyan.price = price_list

# %%
for i in hotel_full_Noyemberyan.index:
    if "Response rate" in  hotel_full_Noyemberyan.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Noyemberyan.host_response_rate[i])
        hotel_full_Noyemberyan.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Noyemberyan.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Noyemberyan = hotel_full_Noyemberyan.astype(convert_dict)

# %%
hotel_full_Noyemberyan.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Noyemberyan.to_csv("cleaned_hotel_full_Noyemberyan.csv", index=False)
hotel_full_Noyemberyan.to_excel("cleaned_hotel_full_Noyemberyan2.xlsx", index=False)
