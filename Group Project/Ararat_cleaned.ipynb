# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import math
import numpy as np
import regex
pd.options.mode.chained_assignment = None 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Reading data**

# %%
hotel_full_Ararat = pd.read_csv('hotel_full_Ararat.csv')
hotel_full_Ararat
# Out:
#                                      city  \
# 0                                     NaN
# 1        Ararat, Ararat Province, Armenia
# 2       Aygavan, Ararat Province, Armenia
# 3     Shahumyan, Ararat Province, Armenia
# 4        Ararat, Ararat Province, Armenia
# 5     Nor Kyank, Ararat Province, Armenia
# 6     Urtsadzor, Ararat Province, Armenia
# 7                Ararat Province, Armenia
# 8              Urtsadzor, Ararat, Armenia
# 9              Surenavan, Ararat, Armenia
# 10                        Ararat, Armenia
# 11    Arevabuyr, Ararat Province, Armenia
# 12                                Armenia
# 13      Mrgavet, Ararat Province, Armenia
# 14             Urtsadzor, Ararat, Armenia
# 15                       Yerevan, Armenia
# 16  Marmarashen, Ararat Province, Armenia
# 17        Masis, Ararat Province, Armenia
# 18              Artashat, Ararat, Armenia
#
#                                   country  \
# 0                                     NaN
# ...

# %%
hotel_full_Ararat = hotel_full_Ararat.drop(labels = 0, axis = 0)
hotel_full_Ararat
# Out:
#                                      city  \
# 1        Ararat, Ararat Province, Armenia
# 2       Aygavan, Ararat Province, Armenia
# 3     Shahumyan, Ararat Province, Armenia
# 4        Ararat, Ararat Province, Armenia
# 5     Nor Kyank, Ararat Province, Armenia
# 6     Urtsadzor, Ararat Province, Armenia
# 7                Ararat Province, Armenia
# 8              Urtsadzor, Ararat, Armenia
# 9              Surenavan, Ararat, Armenia
# 10                        Ararat, Armenia
# 11    Arevabuyr, Ararat Province, Armenia
# 12                                Armenia
# 13      Mrgavet, Ararat Province, Armenia
# 14             Urtsadzor, Ararat, Armenia
# 15                       Yerevan, Armenia
# 16  Marmarashen, Ararat Province, Armenia
# 17        Masis, Ararat Province, Armenia
# 18              Artashat, Ararat, Armenia
#
#                                   country  \
# 1        Ararat, Ararat Province, Armenia
# 2       Aygavan, Ararat Province, Armenia
# ...

# %%
nan_value = float("Nan")
hotel_full_Ararat.replace("", nan_value, inplace = True)
hotel_full_Ararat.dropna(inplace= True)
hotel_full_Ararat
# Out:
#                                    city                              country  \
# 1      Ararat, Ararat Province, Armenia     Ararat, Ararat Province, Armenia
# 3   Shahumyan, Ararat Province, Armenia  Shahumyan, Ararat Province, Armenia
# 6   Urtsadzor, Ararat Province, Armenia  Urtsadzor, Ararat Province, Armenia
# 8            Urtsadzor, Ararat, Armenia           Urtsadzor, Ararat, Armenia
# 10                      Ararat, Armenia                      Ararat, Armenia
# 12                              Armenia                              Armenia
# 14           Urtsadzor, Ararat, Armenia           Urtsadzor, Ararat, Armenia
#
#                                                  name            host_since  \
# 1                        IVF cottage in the mountains  Joined in April 2019
# 3   HOUSE WITH POOL 6 km from Khor Virap! Three fl...  Joined in April 2021
# 6         Эко Центр, деревянный домик в середине леса  Joined in April 2016
# ...

# %%
city_list = []
for i in hotel_full_Ararat.index:
    text = re.sub(",", "", hotel_full_Ararat["city"][i][:hotel_full_Ararat["city"][i].index("Armenia")])
    city_list.append(text)

hotel_full_Ararat["city"]= city_list
hotel_full_Ararat
# Out:
#                           city                              country  \
# 1      Ararat Ararat Province      Ararat, Ararat Province, Armenia
# 3   Shahumyan Ararat Province   Shahumyan, Ararat Province, Armenia
# 6   Urtsadzor Ararat Province   Urtsadzor, Ararat Province, Armenia
# 8            Urtsadzor Ararat            Urtsadzor, Ararat, Armenia
# 10                     Ararat                       Ararat, Armenia
# 12                                                          Armenia
# 14           Urtsadzor Ararat            Urtsadzor, Ararat, Armenia
#
#                                                  name            host_since  \
# 1                        IVF cottage in the mountains  Joined in April 2019
# 3   HOUSE WITH POOL 6 km from Khor Virap! Three fl...  Joined in April 2021
# 6         Эко Центр, деревянный домик в середине леса  Joined in April 2016
# 8       Double/Twin room at the CWR - Shared Bathroom  Joined in April 2016
# ...

# %%
nan_value = float("Nan")
hotel_full_Ararat.replace("", nan_value, inplace = True)
hotel_full_Ararat.dropna(inplace= True)
hotel_full_Ararat
# Out:
#                           city                              country  \
# 1      Ararat Ararat Province      Ararat, Ararat Province, Armenia
# 3   Shahumyan Ararat Province   Shahumyan, Ararat Province, Armenia
# 6   Urtsadzor Ararat Province   Urtsadzor, Ararat Province, Armenia
# 8            Urtsadzor Ararat            Urtsadzor, Ararat, Armenia
# 10                     Ararat                       Ararat, Armenia
# 14           Urtsadzor Ararat            Urtsadzor, Ararat, Armenia
#
#                                                  name            host_since  \
# 1                        IVF cottage in the mountains  Joined in April 2019
# 3   HOUSE WITH POOL 6 km from Khor Virap! Three fl...  Joined in April 2021
# 6         Эко Центр, деревянный домик в середине леса  Joined in April 2016
# 8       Double/Twin room at the CWR - Shared Bathroom  Joined in April 2016
# 10          Eco Lodge in the Caucasus Wildlife Refuge  Joined in April 2016
# ...

# %%
c_l = []    
for k in hotel_full_Ararat["city"]:
    tex = re.search("\w+", k).group()
    c_l.append(tex)
hotel_full_Ararat["city"]= c_l
hotel_full_Ararat
# Out:
#          city                              country  \
# 1      Ararat     Ararat, Ararat Province, Armenia
# 3   Shahumyan  Shahumyan, Ararat Province, Armenia
# 6   Urtsadzor  Urtsadzor, Ararat Province, Armenia
# 8   Urtsadzor           Urtsadzor, Ararat, Armenia
# 10     Ararat                      Ararat, Armenia
# 14  Urtsadzor           Urtsadzor, Ararat, Armenia
#
#                                                  name            host_since  \
# 1                        IVF cottage in the mountains  Joined in April 2019
# 3   HOUSE WITH POOL 6 km from Khor Virap! Three fl...  Joined in April 2021
# 6         Эко Центр, деревянный домик в середине леса  Joined in April 2016
# 8       Double/Twin room at the CWR - Shared Bathroom  Joined in April 2016
# 10          Eco Lodge in the Caucasus Wildlife Refuge  Joined in April 2016
# 14        Double Room at the Caucasus Wildlife Refuge  Joined in April 2016
#
# ...

# %%
hotel_full_Ararat["city"]= hotel_full_Ararat["city"].replace({"Nor" : "Nor Kyank"})

# %%
hotel_full_Ararat
# Out:
#          city                              country  \
# 1      Ararat     Ararat, Ararat Province, Armenia
# 3   Shahumyan  Shahumyan, Ararat Province, Armenia
# 6   Urtsadzor  Urtsadzor, Ararat Province, Armenia
# 8   Urtsadzor           Urtsadzor, Ararat, Armenia
# 10     Ararat                      Ararat, Armenia
# 14  Urtsadzor           Urtsadzor, Ararat, Armenia
#
#                                                  name            host_since  \
# 1                        IVF cottage in the mountains  Joined in April 2019
# 3   HOUSE WITH POOL 6 km from Khor Virap! Three fl...  Joined in April 2021
# 6         Эко Центр, деревянный домик в середине леса  Joined in April 2016
# 8       Double/Twin room at the CWR - Shared Bathroom  Joined in April 2016
# 10          Eco Lodge in the Caucasus Wildlife Refuge  Joined in April 2016
# 14        Double Room at the Caucasus Wildlife Refuge  Joined in April 2016
#
# ...

# %%
country_list = []
for i in hotel_full_Ararat.index:
    text = re.search("Armenia", hotel_full_Ararat["country"][i]).group()
    country_list.append(text)

hotel_full_Ararat["country"] = country_list

# %%
hotel_full_Ararat
# Out:
#          city  country                                               name  \
# 1      Ararat  Armenia                       IVF cottage in the mountains
# 3   Shahumyan  Armenia  HOUSE WITH POOL 6 km from Khor Virap! Three fl...
# 6   Urtsadzor  Armenia        Эко Центр, деревянный домик в середине леса
# 8   Urtsadzor  Armenia      Double/Twin room at the CWR - Shared Bathroom
# 10     Ararat  Armenia          Eco Lodge in the Caucasus Wildlife Refuge
# 14  Urtsadzor  Armenia        Double Room at the Caucasus Wildlife Refuge
#
#               host_since                                 host_response_rate  \
# 1   Joined in April 2019  Language: Русский\nResponse rate: 100%\nRespon...
# 3   Joined in April 2021    Response rate: 50%\nResponse time: within a day
# 6   Joined in April 2016  Languages: Nederlands, English, Русский\nRespo...
# 8   Joined in April 2016  Languages: Nederlands, English, Русский\nRespo...
# ...

# %%
host_since_list = []
for i in hotel_full_Ararat.host_since:
    k = re.findall("(\d{4})", i)
    host_since_list.append(k)
hs = []   
host_since_list = [item for sublist in host_since_list for item in sublist]
for k in host_since_list:
    a = int(k)
    hs.append(a)
hotel_full_Ararat.host_since = hs 
hotel_full_Ararat.host_since
# Out:
# 1     2019
# 3     2021
# 6     2016
# 8     2016
# 10    2016
# 14    2016
# Name: host_since, dtype: int64

# %%
hotel_full_Ararat
# Out:
#          city  country                                               name  \
# 1      Ararat  Armenia                       IVF cottage in the mountains
# 3   Shahumyan  Armenia  HOUSE WITH POOL 6 km from Khor Virap! Three fl...
# 6   Urtsadzor  Armenia        Эко Центр, деревянный домик в середине леса
# 8   Urtsadzor  Armenia      Double/Twin room at the CWR - Shared Bathroom
# 10     Ararat  Armenia          Eco Lodge in the Caucasus Wildlife Refuge
# 14  Urtsadzor  Armenia        Double Room at the Caucasus Wildlife Refuge
#
#     host_since                                 host_response_rate  \
# 1         2019  Language: Русский\nResponse rate: 100%\nRespon...
# 3         2021    Response rate: 50%\nResponse time: within a day
# 6         2016  Languages: Nederlands, English, Русский\nRespo...
# 8         2016  Languages: Nederlands, English, Русский\nRespo...
# 10        2016  Languages: Nederlands, English, Русский\nRespo...
# ...

# %%
string = []
for i in hotel_full_Ararat.index:
    st = hotel_full_Ararat.host_identity_verified[i].strip('[]').strip("'")
    string.append(st)
string
# Out:
# ['3 Reviews',
#  'Identity verified',
#  'Identity verified',
#  'Identity verified',
#  'Identity verified',
#  'Identity verified']

# %%
hotel_full_Ararat.host_identity_verified = string
hotel_full_Ararat.host_identity_verified
# Out:
# 1             3 Reviews
# 3     Identity verified
# 6     Identity verified
# 8     Identity verified
# 10    Identity verified
# 14    Identity verified
# Name: host_identity_verified, dtype: object

# %%
for i in hotel_full_Ararat.index:
    if "Identity verified" in  hotel_full_Ararat.host_identity_verified[i]:
        hotel_full_Ararat.loc[i, 'host_identity_verified'] = "Identity verified"
    else:
        hotel_full_Ararat.loc[i, 'host_identity_verified'] = "Identity not verified"

# %%
hotel_full_Ararat
# Out:
#          city  country                                               name  \
# 1      Ararat  Armenia                       IVF cottage in the mountains
# 3   Shahumyan  Armenia  HOUSE WITH POOL 6 km from Khor Virap! Three fl...
# 6   Urtsadzor  Armenia        Эко Центр, деревянный домик в середине леса
# 8   Urtsadzor  Armenia      Double/Twin room at the CWR - Shared Bathroom
# 10     Ararat  Armenia          Eco Lodge in the Caucasus Wildlife Refuge
# 14  Urtsadzor  Armenia        Double Room at the Caucasus Wildlife Refuge
#
#     host_since                                 host_response_rate  \
# 1         2019  Language: Русский\nResponse rate: 100%\nRespon...
# 3         2021    Response rate: 50%\nResponse time: within a day
# 6         2016  Languages: Nederlands, English, Русский\nRespo...
# 8         2016  Languages: Nederlands, English, Русский\nRespo...
# 10        2016  Languages: Nederlands, English, Русский\nRespo...
# ...

# %%
for i in hotel_full_Ararat.index:
    if "Review" in  hotel_full_Ararat.review[i]:
        hotel_full_Ararat.loc[i, 'review'] = re.search("(\d+)", hotel_full_Ararat.review[i]).group()
        
    else:
        hotel_full_Ararat.loc[i, 'review'] = 0

# %%
hotel_full_Ararat
# Out:
#          city  country                                               name  \
# 1      Ararat  Armenia                       IVF cottage in the mountains
# 3   Shahumyan  Armenia  HOUSE WITH POOL 6 km from Khor Virap! Three fl...
# 6   Urtsadzor  Armenia        Эко Центр, деревянный домик в середине леса
# 8   Urtsadzor  Armenia      Double/Twin room at the CWR - Shared Bathroom
# 10     Ararat  Armenia          Eco Lodge in the Caucasus Wildlife Refuge
# 14  Urtsadzor  Armenia        Double Room at the Caucasus Wildlife Refuge
#
#     host_since                                 host_response_rate  \
# 1         2019  Language: Русский\nResponse rate: 100%\nRespon...
# 3         2021    Response rate: 50%\nResponse time: within a day
# 6         2016  Languages: Nederlands, English, Русский\nRespo...
# 8         2016  Languages: Nederlands, English, Русский\nRespo...
# 10        2016  Languages: Nederlands, English, Русский\nRespo...
# ...

# %%
for i in hotel_full_Ararat.index:
    if "Superhost" in  hotel_full_Ararat.superhost[i]:
        hotel_full_Ararat.loc[i, 'superhost'] = "Super host"
    else:
        hotel_full_Ararat.loc[i, 'superhost'] = "regular host"

# %%
prop_list = []
for i in hotel_full_Ararat.property_type:
    k = re.sub("hosted\sby\s\w*", "", i).strip(" ")
    prop_list.append(k)
prop_list
# Out:
# ['Entire residential home',
#  'Entire residential home',
#  'Private room in hut',
#  'Room in bed and breakfast',
#  'Room in nature lodge',
#  'Shared room in chalet']

# %%
hotel_full_Ararat.property_type =prop_list

# %%
hotel_full_Ararat
# Out:
#          city  country                                               name  \
# 1      Ararat  Armenia                       IVF cottage in the mountains
# 3   Shahumyan  Armenia  HOUSE WITH POOL 6 km from Khor Virap! Three fl...
# 6   Urtsadzor  Armenia        Эко Центр, деревянный домик в середине леса
# 8   Urtsadzor  Armenia      Double/Twin room at the CWR - Shared Bathroom
# 10     Ararat  Armenia          Eco Lodge in the Caucasus Wildlife Refuge
# 14  Urtsadzor  Armenia        Double Room at the Caucasus Wildlife Refuge
#
#     host_since                                 host_response_rate  \
# 1         2019  Language: Русский\nResponse rate: 100%\nRespon...
# 3         2021    Response rate: 50%\nResponse time: within a day
# 6         2016  Languages: Nederlands, English, Русский\nRespo...
# 8         2016  Languages: Nederlands, English, Русский\nRespo...
# 10        2016  Languages: Nederlands, English, Русский\nRespo...
# ...

# %%
accomodates_list = []
for i in hotel_full_Ararat.accomodates:
    k = re.findall("(\d+)\sguest", i)
    accomodates_list.append(k)
number = []   
accomodates_list = [item for sublist in accomodates_list for item in sublist]
for k in accomodates_list:
    a = int(k)
    number.append(a)
    
hotel_full_Ararat.accomodates = number

# %%
for i in hotel_full_Ararat.index:
    if "Shared half-bath" in  hotel_full_Ararat.number_bathroom[i]:
        hotel_full_Ararat.loc[i, 'number_bathroom'] = 0.5
    elif "Half-bath" in  hotel_full_Ararat.number_bathroom[i]:
        hotel_full_Ararat.loc[i, 'number_bathroom'] = 0.5
    elif "bath" not in  hotel_full_Ararat.number_bathroom[i]:
        hotel_full_Ararat.loc[i, 'number_bathroom'] = 0
    elif "private bath" in  hotel_full_Ararat.number_bathroom[i]:
        t = re.findall("(\d+(?:\.\d+)?)\sprivate", hotel_full_Ararat.number_bedroom[i])
        hotel_full_Ararat.loc[i, 'number_bathroom'] = t
    elif "shared bath" in  hotel_full_Ararat.number_bathroom[i]:
        sh = re.findall("(\d+(?:\.\d+)?)\sshared\sbath", hotel_full_Ararat.number_bedroom[i])
        hotel_full_Ararat.loc[i, 'number_bathroom'] = sh    
    else:
        
        k = re.findall("(\d+(?:\.\d+)?)\sbath", hotel_full_Ararat.number_bedroom[i])
        k = "".join(k)
        if k != "":
            hotel_full_Ararat.loc[i, 'number_bathroom'] = k

# %%
number_beds_list = []
for i in hotel_full_Ararat.index:
    if "bed" in  hotel_full_Ararat.number_beds[i]:
        try:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Ararat.number_beds[i]).group(1)
        except AttributeError:
            k = re.search("(\d+)\sbe\w{1,2}\s", hotel_full_Ararat.number_beds[i])
    
        number_beds_list.append(k) 

number_beds_list
# Out:
# ['3', '5', '7', '10', '8', '1']

# %%
len(hotel_full_Ararat.number_beds)
# Out:
# 6

# %%
len(number_beds_list)
# Out:
# 6

# %%
hotel_full_Ararat.number_beds = number_beds_list

# %%
hotel_full_Ararat.number_beds
# Out:
# 1      3
# 3      5
# 6      7
# 8     10
# 10     8
# 14     1
# Name: number_beds, dtype: object

# %%
for i in hotel_full_Ararat.index:
    if "Studio" in  hotel_full_Ararat.number_bedroom[i]:
        hotel_full_Ararat.loc[i, 'number_bedroom'] = 0
    else:
        k = re.findall("(\d+)\sbedroom", hotel_full_Ararat.number_bedroom[i])
        hotel_full_Ararat.loc[i, 'number_bedroom'] = k

# %%
for i in hotel_full_Ararat.index:
    if "Cleanliness" in  hotel_full_Ararat.cleanliness[i]:
        hotel_full_Ararat.loc[i, 'cleanliness'] = re.findall("Cleanliness\s(\d+(?:\.\d+)?)", hotel_full_Ararat.cleanliness[i])
    else:
        hotel_full_Ararat.loc[i, 'cleanliness'] = None

# %%
for i in hotel_full_Ararat.index:
    if "Accuracy" in  hotel_full_Ararat.accuracy[i]:
        hotel_full_Ararat.loc[i, 'accuracy'] = re.findall("Accuracy\s(\d+(?:\.\d+)?)", hotel_full_Ararat.accuracy[i])
    else:
        hotel_full_Ararat.loc[i, 'accuracy'] = None

# %%
for i in hotel_full_Ararat.index:
    if "Communication" in  hotel_full_Ararat.communication[i]:
        hotel_full_Ararat.loc[i, 'communication'] = re.findall("Communication\s(\d+(?:\.\d+)?)", hotel_full_Ararat.communication[i])
    else:
        hotel_full_Ararat.loc[i, 'communication'] = None

# %%
for i in hotel_full_Ararat.index:
    if "Location" in  hotel_full_Ararat.location[i]:
        try:
            hotel_full_Ararat.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Ararat.location[i]).group(1)
        
        except AttributeError:
            hotel_full_Ararat.loc[i, 'location'] = re.search("Location\s(\d+(?:\.\d+)?)", hotel_full_Ararat.location[i])
    
    else:
        hotel_full_Ararat.loc[i, 'location'] = None

# %%
for i in hotel_full_Ararat.index:
    if "Check-in" in  hotel_full_Ararat.check_in[i]:
        hotel_full_Ararat.loc[i, 'check_in'] = re.findall("Check-in\s(\d+(?:\.\d+)?)", hotel_full_Ararat.check_in[i])
    else:
        hotel_full_Ararat.loc[i, 'check_in'] = None

# %%
for i in hotel_full_Ararat.index:
    if "Value" in  hotel_full_Ararat.value[i]:
        hotel_full_Ararat.loc[i, 'value'] = re.findall("Value\s(\d+(?:\.\d+)?)", hotel_full_Ararat.value[i])
    else:
        hotel_full_Ararat.loc[i, 'value'] = None

# %%
for i in hotel_full_Ararat.index:
    if "No reviews (yet)" in  hotel_full_Ararat.rating[i]:
        hotel_full_Ararat.loc[i, 'rating'] = 0

# %%
price_list = []
for i in hotel_full_Ararat.price:
    k = re.findall("(\d+)\n", i)
    price_list.append(k)

price_list = [item for sublist in price_list for item in sublist]
  
hotel_full_Ararat.price = price_list

# %%
for i in hotel_full_Ararat.index:
    if "Response rate" in  hotel_full_Ararat.host_response_rate[i]:
        t = re.findall("\s(\d+)", hotel_full_Ararat.host_response_rate[i])
        hotel_full_Ararat.loc[i, 'host_response_rate'] = t 
    else:
        hotel_full_Ararat.loc[i, 'host_response_rate'] = None

# %%
convert_dict = {'host_since': float, 'host_response_rate': float,  'review': float,  'accomodates': float, 
                                        'number_bathroom': float, 'number_bedroom': float, 
                                        'number_beds': float,'rating': float,  'price': float,
                                        'cleanliness': float, 'accuracy': float, 'communication': float, 
                           'location': float, 'check_in': float, 'value': float}

# %%
hotel_full_Ararat = hotel_full_Ararat.astype(convert_dict)

# %%
hotel_full_Ararat.dtypes
# Out:
# city                       object
# country                    object
# name                       object
# host_since                float64
# host_response_rate        float64
# host_identity_verified     object
# review                    float64
# superhost                  object
# property_type              object
# accomodates               float64
# number_bathroom           float64
# number_bedroom            float64
# number_beds               float64
# rating                    float64
# price                     float64
# cleanliness               float64
# accuracy                  float64
# communication             float64
# location                  float64
# check_in                  float64
# value                     float64
# dtype: object

# %%
hotel_full_Ararat.to_csv("cleaned_hotel_full_Ararat.csv", index=False)
hotel_full_Ararat.to_excel("cleaned_hotel_full_Ararat2.xlsx", index=False)
